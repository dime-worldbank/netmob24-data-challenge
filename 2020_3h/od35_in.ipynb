# %%
# %reload_ext sql
# %config SqlMagic.autocommit=False
# %config SqlMagic.autolimit=0
# %config SqlMagic.autopandas=True
# %config SqlMagic.displaylimit=200

# %%
# %sql trino://localhost:9090/cuebiq/
# Out:
# 'Connected: @cuebiq/'

# %%
pip install python-geohash
# Out:
# Requirement already satisfied: python-geohash in /srv/conda/envs/notebook/lib/python3.9/site-packages (0.8.5)
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
import time
import geohash
import logging
import numpy as np
import pandas as pd
from datetime import datetime, timedelta
from sqlalchemy import create_engine

# %%
# SQL engine
from trino.dbapi import connect 
from sqlalchemy import create_engine
import pandas as pd
import time

class TrinoEngine():
    def __init__(self):
        conn = connect(
            host="localhost",
            port=9090,
            catalog="cuebiq"
        )
        self.cur = conn.cursor()
        self.engine = create_engine("trino://localhost:9090/cuebiq/")
    
    def execute_statement(self, query:str) -> list:
        """
        Create and drop statements.
        """
        self.cur.execute(query)
        return self.cur.fetchall()
    
    def read_sql(self, query:str) -> pd.DataFrame: 
        """
        Select and insert into operations.
        """
        return pd.read_sql(query, self.engine)

sql_engine = TrinoEngine()

# %%
schema_name = {'cda': 'cuebiq.paas_cda_pe_v3'}
pe_tj_table = f"{schema_name['cda']}.trajectory_uplevelled"

# %% [markdown]
# # Export to local

# %%
# Set up logging
logging.basicConfig(level=logging.INFO, format='%(asctime)s - %(levelname)s - %(message)s')

# %%
# Function to process data for a specific date
def process_data_for_date(event_date, country_code, export_path):
    errors = []  # List to keep track of errors
    
    # Define the export file paths
    csv3_file = f"od_{country_code.lower()}_agg3_3h.csv"
    csv5_file = f"od_{country_code.lower()}_agg5_3h.csv"
    csv3_file_path = f"{export_path}{csv3_file}"
    csv5_file_path = f"{export_path}{csv5_file}"

    # Loop through 24 hours in increments of 3 hours
    for start_hour in range(0, 24, 3):
        end_hour = start_hour + 3  # end hour for the 3-hour interval
        logging.info(f"Querying data for date: {event_date}, hours: {start_hour}-{end_hour}")

        try:
            # Fetch the data for the specified event date and country code
            pe_tj_df3 = sql_engine.read_sql(
                f"""
                SELECT 
                    cuebiq_id,
                    duration_minutes,
                    length_meters,
                    number_of_points,
                    TRY(date_parse(substr(start_zoned_datetime, 1, 19), '%Y-%m-%dT%H:%i:%s')) AS event_datetime_local,
                    EXTRACT(HOUR FROM TRY(date_parse(substr(start_zoned_datetime, 1, 19), '%Y-%m-%dT%H:%i:%s'))) AS event_hour,
                    geohash_encode(start_lat, start_lng, 5) AS start_geohash5,
                    geohash_encode(start_lat, start_lng, 3) AS start_geohash3,
                    geohash_encode(end_lat, end_lng, 5) AS end_geohash5,
                    geohash_encode(end_lat, end_lng, 3) AS end_geohash3,
                    DATE_FORMAT(date_parse(substr(start_zoned_datetime, 1, 10), '%Y-%m-%d'), '%Y%m%d') AS local_date
                FROM cuebiq.paas_cda_pe_v3.trajectory_uplevelled
                WHERE 
                    event_date = {event_date}
                    AND end_country = '{country_code}' 
                    AND start_country = '{country_code}' 
                """
            )

            # Filter the DataFrame for the current 3-hour interval
            logging.info(f"Processing data for date: {event_date}, hours: {start_hour}-{end_hour}")
            filtered_df = pe_tj_df3[(pe_tj_df3['event_hour'] >= start_hour) & (pe_tj_df3['event_hour'] < end_hour)]

            # Add user numbers to the aggregated data for geohash3
            aggregated_df3 = filtered_df.groupby(['start_geohash3', 'end_geohash3', 'local_date']).agg({
                'cuebiq_id': 'count',
                'duration_minutes': ['mean', 'median', 'std'],
                'length_meters': ['mean', 'median', 'std'],
                'number_of_points': ['mean', 'median', 'std']
            }).reset_index()

            # Flatten the MultiIndex columns
            aggregated_df3.columns = ['start_geohash3', 'end_geohash3', 'local_date', 'trip_count', 
                                      'm_duration_min', 'mdn_duration_min', 'sd_duration_min', 
                                      'm_length_m', 'mdn_length_m', 'sd_length_m',
                                      'm_points_no', 'mdn_points_no', 'sd_points_no']

            # Add the local_time column
            aggregated_df3['local_time'] = aggregated_df3['local_date'].astype(str) + \
                                           f" {start_hour:02d}:00:00 - {end_hour:02d}:00:00"

            # Filter out rows where trip_count is less than or equal to 9
            aggregated_df3 = aggregated_df3[aggregated_df3['trip_count'] > 9]

            # Append the results to the CSV file for geohash3
            logging.info(f"Exporting aggregated data (geohash3) for date: {event_date}, hours: {start_hour}-{end_hour}")
            if not os.path.isfile(csv3_file_path):
                aggregated_df3.to_csv(csv3_file_path, index=False)
            else:
                aggregated_df3.to_csv(csv3_file_path, mode='a', header=False, index=False)

            # Add user numbers to the aggregated data for geohash5
            aggregated_df5 = filtered_df.groupby(['start_geohash5', 'end_geohash5', 'local_date']).agg({
                'cuebiq_id': 'count',
                'duration_minutes': ['mean', 'median', 'std'],
                'length_meters': ['mean', 'median', 'std'],
                'number_of_points': ['mean', 'median', 'std']
            }).reset_index()

            # Flatten the MultiIndex columns
            aggregated_df5.columns = ['start_geohash5', 'end_geohash5', 'local_date', 'trip_count', 
                                      'm_duration_min', 'mdn_duration_min', 'sd_duration_min', 
                                      'm_length_m', 'mdn_length_m', 'sd_length_m',
                                      'm_points_no', 'mdn_points_no', 'sd_points_no']

            # Add the local_time column
            aggregated_df5['local_time'] = aggregated_df5['local_date'].astype(str) + \
                                           f" {start_hour:02d}:00:00 - {end_hour:02d}:00:00"

            # Filter out rows where trip_count is less than or equal to 9
            aggregated_df5 = aggregated_df5[aggregated_df5['trip_count'] > 9]

            # Append the results to the CSV file for geohash5
            logging.info(f"Exporting aggregated data (geohash5) for date: {event_date}, hours: {start_hour}-{end_hour}")
            if not os.path.isfile(csv5_file_path):
                aggregated_df5.to_csv(csv5_file_path, index=False)
            else:
                aggregated_df5.to_csv(csv5_file_path, mode='a', header=False, index=False)
        
        except Exception as e:
            error_message = f"Error processing date: {event_date}, hours: {start_hour}-{end_hour} - {str(e)}"
            logging.error(error_message)
            errors.append(error_message)
    
    return errors

# Function to process data for a range of dates
def process_data_for_date_range(start_date, end_date, country_code, export_path):
    current_date = start_date
    all_errors = []
    while current_date <= end_date:
        event_date = current_date.strftime("%Y%m%d")
        logging.info(f"Processing data for date: {event_date}")
        errors = process_data_for_date(event_date, country_code, export_path)
        all_errors.extend(errors)
        current_date += timedelta(days=1)
    
    # Log any errors that occurred
    if all_errors:
        logging.info("Errors occurred during processing:")
        for error in all_errors:
            logging.info(error)

# %%
# Specify the date range
start_date = datetime.strptime("20190228", "%Y%m%d")
end_date = datetime.strptime("20190630", "%Y%m%d")
country_code = 'IN'
export_path = '/home/jovyan/Data/TJ/3h/'

# Measure total execution time
start_time = time.time()

# Process data for the specified date range
process_data_for_date_range(start_date, end_date, country_code, export_path)
# Out:
# 2024-07-02 05:12:43,142 - INFO - Processing data for date: 20190228
# 2024-07-02 05:12:43,143 - INFO - Querying data for date: 20190228, hours: 0-3
# 2024-07-02 05:13:43,386 - INFO - Processing data for date: 20190228, hours: 0-3
# 2024-07-02 05:13:43,407 - INFO - Exporting aggregated data (geohash3) for date: 20190228, hours: 0-3
# 2024-07-02 05:13:43,445 - INFO - Exporting aggregated data (geohash5) for date: 20190228, hours: 0-3
# 2024-07-02 05:13:43,460 - INFO - Querying data for date: 20190228, hours: 3-6
# 2024-07-02 05:14:11,651 - INFO - Processing data for date: 20190228, hours: 3-6
# 2024-07-02 05:14:11,676 - INFO - Exporting aggregated data (geohash3) for date: 20190228, hours: 3-6
# 2024-07-02 05:14:11,711 - INFO - Exporting aggregated data (geohash5) for date: 20190228, hours: 3-6
# 2024-07-02 05:14:11,727 - INFO - Querying data for date: 20190228, hours: 6-9
# 2024-07-02 05:14:28,385 - INFO - Processing data for date: 20190228, hours: 6-9
# 2024-07-02 05:14:28,429 - INFO - Exporting aggregated data (geohash3) for date: 20190228, hours: 6-9
# 2024-07-02 05:14:28,494 - INFO - Exporting aggregated data (geohash5) for date: 20190228, hours: 6-9
# 2024-07-02 05:14:28,514 - INFO - Querying data for date: 20190228, hours: 9-12
# 2024-07-02 05:15:11,572 - INFO - Processing data for date: 20190228, hours: 9-12
# 2024-07-02 05:15:11,643 - INFO - Exporting aggregated data (geohash3) for date: 20190228, hours: 9-12
# 2024-07-02 05:15:11,740 - INFO - Exporting aggregated data (geohash5) for date: 20190228, hours: 9-12
# 2024-07-02 05:15:11,775 - INFO - Querying data for date: 20190228, hours: 12-15
# 2024-07-02 05:15:56,566 - INFO - Processing data for date: 20190228, hours: 12-15
# 2024-07-02 05:15:56,654 - INFO - Exporting aggregated data (geohash3) for date: 20190228, hours: 12-15
# 2024-07-02 05:15:56,761 - INFO - Exporting aggregated data (geohash5) for date: 20190228, hours: 12-15
# 2024-07-02 05:15:56,792 - INFO - Querying data for date: 20190228, hours: 15-18
# 2024-07-02 05:16:18,864 - INFO - Processing data for date: 20190228, hours: 15-18
# 2024-07-02 05:16:18,946 - INFO - Exporting aggregated data (geohash3) for date: 20190228, hours: 15-18
# 2024-07-02 05:16:19,043 - INFO - Exporting aggregated data (geohash5) for date: 20190228, hours: 15-18
# 2024-07-02 05:16:19,078 - INFO - Querying data for date: 20190228, hours: 18-21
# 2024-07-02 05:16:38,066 - INFO - Processing data for date: 20190228, hours: 18-21
# 2024-07-02 05:16:38,171 - INFO - Exporting aggregated data (geohash3) for date: 20190228, hours: 18-21
# 2024-07-02 05:16:38,255 - INFO - Exporting aggregated data (geohash5) for date: 20190228, hours: 18-21
# 2024-07-02 05:16:38,281 - INFO - Querying data for date: 20190228, hours: 21-24
# 2024-07-02 05:16:53,859 - INFO - Processing data for date: 20190228, hours: 21-24
# 2024-07-02 05:16:53,900 - INFO - Exporting aggregated data (geohash3) for date: 20190228, hours: 21-24
# 2024-07-02 05:16:53,940 - INFO - Exporting aggregated data (geohash5) for date: 20190228, hours: 21-24
# 2024-07-02 05:16:54,038 - INFO - Processing data for date: 20190301
# 2024-07-02 05:16:54,039 - INFO - Querying data for date: 20190301, hours: 0-3
# 2024-07-02 05:17:36,247 - INFO - Processing data for date: 20190301, hours: 0-3
# 2024-07-02 05:17:36,268 - INFO - Exporting aggregated data (geohash3) for date: 20190301, hours: 0-3
# 2024-07-02 05:17:36,306 - INFO - Exporting aggregated data (geohash5) for date: 20190301, hours: 0-3
# 2024-07-02 05:17:36,324 - INFO - Querying data for date: 20190301, hours: 3-6
# 2024-07-02 05:17:53,656 - INFO - Processing data for date: 20190301, hours: 3-6
# 2024-07-02 05:17:53,680 - INFO - Exporting aggregated data (geohash3) for date: 20190301, hours: 3-6
# 2024-07-02 05:17:53,714 - INFO - Exporting aggregated data (geohash5) for date: 20190301, hours: 3-6
# 2024-07-02 05:17:53,727 - INFO - Querying data for date: 20190301, hours: 6-9
# 2024-07-02 05:18:11,049 - INFO - Processing data for date: 20190301, hours: 6-9
# 2024-07-02 05:18:11,093 - INFO - Exporting aggregated data (geohash3) for date: 20190301, hours: 6-9
# 2024-07-02 05:18:11,161 - INFO - Exporting aggregated data (geohash5) for date: 20190301, hours: 6-9
# 2024-07-02 05:18:11,183 - INFO - Querying data for date: 20190301, hours: 9-12
# 2024-07-02 05:18:42,764 - INFO - Processing data for date: 20190301, hours: 9-12
# 2024-07-02 05:18:42,832 - INFO - Exporting aggregated data (geohash3) for date: 20190301, hours: 9-12
# 2024-07-02 05:18:42,927 - INFO - Exporting aggregated data (geohash5) for date: 20190301, hours: 9-12
# 2024-07-02 05:18:42,957 - INFO - Querying data for date: 20190301, hours: 12-15
# 2024-07-02 05:19:10,964 - INFO - Processing data for date: 20190301, hours: 12-15
# 2024-07-02 05:19:11,044 - INFO - Exporting aggregated data (geohash3) for date: 20190301, hours: 12-15
# 2024-07-02 05:19:11,145 - INFO - Exporting aggregated data (geohash5) for date: 20190301, hours: 12-15
# 2024-07-02 05:19:11,187 - INFO - Querying data for date: 20190301, hours: 15-18
# 2024-07-02 05:19:28,713 - INFO - Processing data for date: 20190301, hours: 15-18
# 2024-07-02 05:19:28,790 - INFO - Exporting aggregated data (geohash3) for date: 20190301, hours: 15-18
# 2024-07-02 05:19:28,883 - INFO - Exporting aggregated data (geohash5) for date: 20190301, hours: 15-18
# 2024-07-02 05:19:28,911 - INFO - Querying data for date: 20190301, hours: 18-21
# 2024-07-02 05:19:45,775 - INFO - Processing data for date: 20190301, hours: 18-21
# 2024-07-02 05:19:45,845 - INFO - Exporting aggregated data (geohash3) for date: 20190301, hours: 18-21
# 2024-07-02 05:19:45,930 - INFO - Exporting aggregated data (geohash5) for date: 20190301, hours: 18-21
# 2024-07-02 05:19:45,964 - INFO - Querying data for date: 20190301, hours: 21-24
# 2024-07-02 05:20:17,930 - INFO - Processing data for date: 20190301, hours: 21-24
# 2024-07-02 05:20:17,972 - INFO - Exporting aggregated data (geohash3) for date: 20190301, hours: 21-24
# 2024-07-02 05:20:18,015 - INFO - Exporting aggregated data (geohash5) for date: 20190301, hours: 21-24
# 2024-07-02 05:20:18,110 - INFO - Processing data for date: 20190302
# 2024-07-02 05:20:18,111 - INFO - Querying data for date: 20190302, hours: 0-3
# 2024-07-02 05:20:41,808 - INFO - Processing data for date: 20190302, hours: 0-3
# 2024-07-02 05:20:41,830 - INFO - Exporting aggregated data (geohash3) for date: 20190302, hours: 0-3
# 2024-07-02 05:20:41,866 - INFO - Exporting aggregated data (geohash5) for date: 20190302, hours: 0-3
# 2024-07-02 05:20:41,881 - INFO - Querying data for date: 20190302, hours: 3-6
# 2024-07-02 05:20:57,934 - INFO - Processing data for date: 20190302, hours: 3-6
# 2024-07-02 05:20:57,960 - INFO - Exporting aggregated data (geohash3) for date: 20190302, hours: 3-6
# 2024-07-02 05:20:57,996 - INFO - Exporting aggregated data (geohash5) for date: 20190302, hours: 3-6
# 2024-07-02 05:20:58,010 - INFO - Querying data for date: 20190302, hours: 6-9
# 2024-07-02 05:21:14,867 - INFO - Processing data for date: 20190302, hours: 6-9
# 2024-07-02 05:21:14,940 - INFO - Exporting aggregated data (geohash3) for date: 20190302, hours: 6-9
# 2024-07-02 05:21:15,034 - INFO - Exporting aggregated data (geohash5) for date: 20190302, hours: 6-9
# 2024-07-02 05:21:15,054 - INFO - Querying data for date: 20190302, hours: 9-12
# 2024-07-02 05:21:29,849 - INFO - Processing data for date: 20190302, hours: 9-12
# 2024-07-02 05:21:29,920 - INFO - Exporting aggregated data (geohash3) for date: 20190302, hours: 9-12
# 2024-07-02 05:21:30,015 - INFO - Exporting aggregated data (geohash5) for date: 20190302, hours: 9-12
# 2024-07-02 05:21:30,043 - INFO - Querying data for date: 20190302, hours: 12-15
# 2024-07-02 05:22:00,303 - INFO - Processing data for date: 20190302, hours: 12-15
# 2024-07-02 05:22:00,380 - INFO - Exporting aggregated data (geohash3) for date: 20190302, hours: 12-15
# 2024-07-02 05:22:00,475 - INFO - Exporting aggregated data (geohash5) for date: 20190302, hours: 12-15
# 2024-07-02 05:22:00,507 - INFO - Querying data for date: 20190302, hours: 15-18
# 2024-07-02 05:22:19,275 - INFO - Processing data for date: 20190302, hours: 15-18
# 2024-07-02 05:22:19,349 - INFO - Exporting aggregated data (geohash3) for date: 20190302, hours: 15-18
# 2024-07-02 05:22:19,448 - INFO - Exporting aggregated data (geohash5) for date: 20190302, hours: 15-18
# 2024-07-02 05:22:19,478 - INFO - Querying data for date: 20190302, hours: 18-21
# 2024-07-02 05:22:35,817 - INFO - Processing data for date: 20190302, hours: 18-21
# 2024-07-02 05:22:35,926 - INFO - Exporting aggregated data (geohash3) for date: 20190302, hours: 18-21
# 2024-07-02 05:22:36,020 - INFO - Exporting aggregated data (geohash5) for date: 20190302, hours: 18-21
# 2024-07-02 05:22:36,046 - INFO - Querying data for date: 20190302, hours: 21-24
# 2024-07-02 05:22:53,453 - INFO - Processing data for date: 20190302, hours: 21-24
# 2024-07-02 05:22:53,495 - INFO - Exporting aggregated data (geohash3) for date: 20190302, hours: 21-24
# 2024-07-02 05:22:53,539 - INFO - Exporting aggregated data (geohash5) for date: 20190302, hours: 21-24
# 2024-07-02 05:22:53,637 - INFO - Processing data for date: 20190303
# 2024-07-02 05:22:53,638 - INFO - Querying data for date: 20190303, hours: 0-3
# 2024-07-02 05:23:35,036 - INFO - Processing data for date: 20190303, hours: 0-3
# 2024-07-02 05:23:35,055 - INFO - Exporting aggregated data (geohash3) for date: 20190303, hours: 0-3
# 2024-07-02 05:23:35,089 - INFO - Exporting aggregated data (geohash5) for date: 20190303, hours: 0-3
# 2024-07-02 05:23:35,107 - INFO - Querying data for date: 20190303, hours: 3-6
# 2024-07-02 05:23:57,641 - INFO - Processing data for date: 20190303, hours: 3-6
# 2024-07-02 05:23:57,665 - INFO - Exporting aggregated data (geohash3) for date: 20190303, hours: 3-6
# 2024-07-02 05:23:57,745 - INFO - Exporting aggregated data (geohash5) for date: 20190303, hours: 3-6
# 2024-07-02 05:23:57,763 - INFO - Querying data for date: 20190303, hours: 6-9
# 2024-07-02 05:24:11,571 - INFO - Processing data for date: 20190303, hours: 6-9
# 2024-07-02 05:24:11,625 - INFO - Exporting aggregated data (geohash3) for date: 20190303, hours: 6-9
# 2024-07-02 05:24:11,685 - INFO - Exporting aggregated data (geohash5) for date: 20190303, hours: 6-9
# 2024-07-02 05:24:11,704 - INFO - Querying data for date: 20190303, hours: 9-12
# 2024-07-02 05:24:28,076 - INFO - Processing data for date: 20190303, hours: 9-12
# 2024-07-02 05:24:28,136 - INFO - Exporting aggregated data (geohash3) for date: 20190303, hours: 9-12
# 2024-07-02 05:24:28,221 - INFO - Exporting aggregated data (geohash5) for date: 20190303, hours: 9-12
# 2024-07-02 05:24:28,248 - INFO - Querying data for date: 20190303, hours: 12-15
# 2024-07-02 05:24:56,709 - INFO - Processing data for date: 20190303, hours: 12-15
# 2024-07-02 05:24:56,775 - INFO - Exporting aggregated data (geohash3) for date: 20190303, hours: 12-15
# 2024-07-02 05:24:56,860 - INFO - Exporting aggregated data (geohash5) for date: 20190303, hours: 12-15
# 2024-07-02 05:24:56,886 - INFO - Querying data for date: 20190303, hours: 15-18
# 2024-07-02 05:25:15,746 - INFO - Processing data for date: 20190303, hours: 15-18
# 2024-07-02 05:25:15,815 - INFO - Exporting aggregated data (geohash3) for date: 20190303, hours: 15-18
# 2024-07-02 05:25:15,900 - INFO - Exporting aggregated data (geohash5) for date: 20190303, hours: 15-18
# 2024-07-02 05:25:15,931 - INFO - Querying data for date: 20190303, hours: 18-21
# 2024-07-02 05:25:29,486 - INFO - Processing data for date: 20190303, hours: 18-21
# 2024-07-02 05:25:29,600 - INFO - Exporting aggregated data (geohash3) for date: 20190303, hours: 18-21
# 2024-07-02 05:25:29,734 - INFO - Exporting aggregated data (geohash5) for date: 20190303, hours: 18-21
# 2024-07-02 05:25:29,762 - INFO - Querying data for date: 20190303, hours: 21-24
# 2024-07-02 05:25:43,039 - INFO - Processing data for date: 20190303, hours: 21-24
# 2024-07-02 05:25:43,078 - INFO - Exporting aggregated data (geohash3) for date: 20190303, hours: 21-24
# 2024-07-02 05:25:43,119 - INFO - Exporting aggregated data (geohash5) for date: 20190303, hours: 21-24
# 2024-07-02 05:25:43,203 - INFO - Processing data for date: 20190304
# 2024-07-02 05:25:43,204 - INFO - Querying data for date: 20190304, hours: 0-3
# 2024-07-02 05:26:22,497 - INFO - Processing data for date: 20190304, hours: 0-3
# 2024-07-02 05:26:22,515 - INFO - Exporting aggregated data (geohash3) for date: 20190304, hours: 0-3
# 2024-07-02 05:26:22,549 - INFO - Exporting aggregated data (geohash5) for date: 20190304, hours: 0-3
# 2024-07-02 05:26:22,562 - INFO - Querying data for date: 20190304, hours: 3-6
# 2024-07-02 05:26:44,225 - INFO - Processing data for date: 20190304, hours: 3-6
# 2024-07-02 05:26:44,249 - INFO - Exporting aggregated data (geohash3) for date: 20190304, hours: 3-6
# 2024-07-02 05:26:44,295 - INFO - Exporting aggregated data (geohash5) for date: 20190304, hours: 3-6
# 2024-07-02 05:26:44,309 - INFO - Querying data for date: 20190304, hours: 6-9
# 2024-07-02 05:26:57,334 - INFO - Processing data for date: 20190304, hours: 6-9
# 2024-07-02 05:26:57,374 - INFO - Exporting aggregated data (geohash3) for date: 20190304, hours: 6-9
# 2024-07-02 05:26:57,437 - INFO - Exporting aggregated data (geohash5) for date: 20190304, hours: 6-9
# 2024-07-02 05:26:57,457 - INFO - Querying data for date: 20190304, hours: 9-12
# 2024-07-02 05:27:19,825 - INFO - Processing data for date: 20190304, hours: 9-12
# 2024-07-02 05:27:19,886 - INFO - Exporting aggregated data (geohash3) for date: 20190304, hours: 9-12
# 2024-07-02 05:27:19,976 - INFO - Exporting aggregated data (geohash5) for date: 20190304, hours: 9-12
# 2024-07-02 05:27:20,007 - INFO - Querying data for date: 20190304, hours: 12-15
# 2024-07-02 05:27:44,644 - INFO - Processing data for date: 20190304, hours: 12-15
# 2024-07-02 05:27:44,716 - INFO - Exporting aggregated data (geohash3) for date: 20190304, hours: 12-15
# 2024-07-02 05:27:44,811 - INFO - Exporting aggregated data (geohash5) for date: 20190304, hours: 12-15
# 2024-07-02 05:27:44,837 - INFO - Querying data for date: 20190304, hours: 15-18
# 2024-07-02 05:27:59,807 - INFO - Processing data for date: 20190304, hours: 15-18
# 2024-07-02 05:27:59,881 - INFO - Exporting aggregated data (geohash3) for date: 20190304, hours: 15-18
# 2024-07-02 05:28:00,041 - INFO - Exporting aggregated data (geohash5) for date: 20190304, hours: 15-18
# 2024-07-02 05:28:00,100 - INFO - Querying data for date: 20190304, hours: 18-21
# 2024-07-02 05:28:13,217 - INFO - Processing data for date: 20190304, hours: 18-21
# 2024-07-02 05:28:13,298 - INFO - Exporting aggregated data (geohash3) for date: 20190304, hours: 18-21
# 2024-07-02 05:28:13,395 - INFO - Exporting aggregated data (geohash5) for date: 20190304, hours: 18-21
# 2024-07-02 05:28:13,425 - INFO - Querying data for date: 20190304, hours: 21-24
# 2024-07-02 05:28:27,257 - INFO - Processing data for date: 20190304, hours: 21-24
# 2024-07-02 05:28:27,297 - INFO - Exporting aggregated data (geohash3) for date: 20190304, hours: 21-24
# 2024-07-02 05:28:27,339 - INFO - Exporting aggregated data (geohash5) for date: 20190304, hours: 21-24
# 2024-07-02 05:28:27,424 - INFO - Processing data for date: 20190305
# 2024-07-02 05:28:27,424 - INFO - Querying data for date: 20190305, hours: 0-3
# 2024-07-02 05:29:11,522 - INFO - Processing data for date: 20190305, hours: 0-3
# 2024-07-02 05:29:11,541 - INFO - Exporting aggregated data (geohash3) for date: 20190305, hours: 0-3
# 2024-07-02 05:29:11,575 - INFO - Exporting aggregated data (geohash5) for date: 20190305, hours: 0-3
# 2024-07-02 05:29:11,589 - INFO - Querying data for date: 20190305, hours: 3-6
# 2024-07-02 05:29:32,303 - INFO - Processing data for date: 20190305, hours: 3-6
# 2024-07-02 05:29:32,326 - INFO - Exporting aggregated data (geohash3) for date: 20190305, hours: 3-6
# 2024-07-02 05:29:32,361 - INFO - Exporting aggregated data (geohash5) for date: 20190305, hours: 3-6
# 2024-07-02 05:29:32,376 - INFO - Querying data for date: 20190305, hours: 6-9
# 2024-07-02 05:29:46,706 - INFO - Processing data for date: 20190305, hours: 6-9
# 2024-07-02 05:29:46,807 - INFO - Exporting aggregated data (geohash3) for date: 20190305, hours: 6-9
# 2024-07-02 05:29:46,930 - INFO - Exporting aggregated data (geohash5) for date: 20190305, hours: 6-9
# 2024-07-02 05:29:46,954 - INFO - Querying data for date: 20190305, hours: 9-12
# 2024-07-02 05:30:03,378 - INFO - Processing data for date: 20190305, hours: 9-12
# 2024-07-02 05:30:03,465 - INFO - Exporting aggregated data (geohash3) for date: 20190305, hours: 9-12
# 2024-07-02 05:30:03,618 - INFO - Exporting aggregated data (geohash5) for date: 20190305, hours: 9-12
# 2024-07-02 05:30:03,647 - INFO - Querying data for date: 20190305, hours: 12-15
# 2024-07-02 05:30:21,685 - INFO - Processing data for date: 20190305, hours: 12-15
# 2024-07-02 05:30:21,764 - INFO - Exporting aggregated data (geohash3) for date: 20190305, hours: 12-15
# 2024-07-02 05:30:21,860 - INFO - Exporting aggregated data (geohash5) for date: 20190305, hours: 12-15
# 2024-07-02 05:30:21,891 - INFO - Querying data for date: 20190305, hours: 15-18
# 2024-07-02 05:30:53,402 - INFO - Processing data for date: 20190305, hours: 15-18
# 2024-07-02 05:30:53,485 - INFO - Exporting aggregated data (geohash3) for date: 20190305, hours: 15-18
# 2024-07-02 05:30:53,575 - INFO - Exporting aggregated data (geohash5) for date: 20190305, hours: 15-18
# 2024-07-02 05:30:53,605 - INFO - Querying data for date: 20190305, hours: 18-21
# 2024-07-02 05:31:11,714 - INFO - Processing data for date: 20190305, hours: 18-21
# 2024-07-02 05:31:11,787 - INFO - Exporting aggregated data (geohash3) for date: 20190305, hours: 18-21
# 2024-07-02 05:31:11,866 - INFO - Exporting aggregated data (geohash5) for date: 20190305, hours: 18-21
# 2024-07-02 05:31:11,893 - INFO - Querying data for date: 20190305, hours: 21-24
# 2024-07-02 05:31:26,840 - INFO - Processing data for date: 20190305, hours: 21-24
# 2024-07-02 05:31:26,932 - INFO - Exporting aggregated data (geohash3) for date: 20190305, hours: 21-24
# 2024-07-02 05:31:27,016 - INFO - Exporting aggregated data (geohash5) for date: 20190305, hours: 21-24
# 2024-07-02 05:31:27,217 - INFO - Processing data for date: 20190306
# 2024-07-02 05:31:27,218 - INFO - Querying data for date: 20190306, hours: 0-3
# 2024-07-02 05:31:47,516 - INFO - Processing data for date: 20190306, hours: 0-3
# 2024-07-02 05:31:47,534 - INFO - Exporting aggregated data (geohash3) for date: 20190306, hours: 0-3
# 2024-07-02 05:31:47,572 - INFO - Exporting aggregated data (geohash5) for date: 20190306, hours: 0-3
# 2024-07-02 05:31:47,599 - INFO - Querying data for date: 20190306, hours: 3-6
# 2024-07-02 05:32:19,032 - INFO - Processing data for date: 20190306, hours: 3-6
# 2024-07-02 05:32:19,059 - INFO - Exporting aggregated data (geohash3) for date: 20190306, hours: 3-6
# 2024-07-02 05:32:19,106 - INFO - Exporting aggregated data (geohash5) for date: 20190306, hours: 3-6
# 2024-07-02 05:32:19,120 - INFO - Querying data for date: 20190306, hours: 6-9
# 2024-07-02 05:32:46,762 - INFO - Processing data for date: 20190306, hours: 6-9
# 2024-07-02 05:32:46,804 - INFO - Exporting aggregated data (geohash3) for date: 20190306, hours: 6-9
# 2024-07-02 05:32:46,870 - INFO - Exporting aggregated data (geohash5) for date: 20190306, hours: 6-9
# 2024-07-02 05:32:46,890 - INFO - Querying data for date: 20190306, hours: 9-12
# 2024-07-02 05:33:04,459 - INFO - Processing data for date: 20190306, hours: 9-12
# 2024-07-02 05:33:04,548 - INFO - Exporting aggregated data (geohash3) for date: 20190306, hours: 9-12
# 2024-07-02 05:33:04,644 - INFO - Exporting aggregated data (geohash5) for date: 20190306, hours: 9-12
# 2024-07-02 05:33:04,672 - INFO - Querying data for date: 20190306, hours: 12-15
# 2024-07-02 05:33:21,537 - INFO - Processing data for date: 20190306, hours: 12-15
# 2024-07-02 05:33:21,624 - INFO - Exporting aggregated data (geohash3) for date: 20190306, hours: 12-15
# 2024-07-02 05:33:21,729 - INFO - Exporting aggregated data (geohash5) for date: 20190306, hours: 12-15
# 2024-07-02 05:33:21,761 - INFO - Querying data for date: 20190306, hours: 15-18
# 2024-07-02 05:33:36,007 - INFO - Processing data for date: 20190306, hours: 15-18
# 2024-07-02 05:33:36,090 - INFO - Exporting aggregated data (geohash3) for date: 20190306, hours: 15-18
# 2024-07-02 05:33:36,188 - INFO - Exporting aggregated data (geohash5) for date: 20190306, hours: 15-18
# 2024-07-02 05:33:36,221 - INFO - Querying data for date: 20190306, hours: 18-21
# 2024-07-02 05:34:06,538 - INFO - Processing data for date: 20190306, hours: 18-21
# 2024-07-02 05:34:06,605 - INFO - Exporting aggregated data (geohash3) for date: 20190306, hours: 18-21
# 2024-07-02 05:34:06,683 - INFO - Exporting aggregated data (geohash5) for date: 20190306, hours: 18-21
# 2024-07-02 05:34:06,711 - INFO - Querying data for date: 20190306, hours: 21-24
# 2024-07-02 05:34:30,538 - INFO - Processing data for date: 20190306, hours: 21-24
# 2024-07-02 05:34:30,580 - INFO - Exporting aggregated data (geohash3) for date: 20190306, hours: 21-24
# 2024-07-02 05:34:30,623 - INFO - Exporting aggregated data (geohash5) for date: 20190306, hours: 21-24
# 2024-07-02 05:34:30,722 - INFO - Processing data for date: 20190307
# 2024-07-02 05:34:30,723 - INFO - Querying data for date: 20190307, hours: 0-3
# 2024-07-02 05:34:54,108 - INFO - Processing data for date: 20190307, hours: 0-3
# 2024-07-02 05:34:54,129 - INFO - Exporting aggregated data (geohash3) for date: 20190307, hours: 0-3
# 2024-07-02 05:34:54,167 - INFO - Exporting aggregated data (geohash5) for date: 20190307, hours: 0-3
# 2024-07-02 05:34:54,183 - INFO - Querying data for date: 20190307, hours: 3-6
# 2024-07-02 05:35:10,275 - INFO - Processing data for date: 20190307, hours: 3-6
# 2024-07-02 05:35:10,300 - INFO - Exporting aggregated data (geohash3) for date: 20190307, hours: 3-6
# 2024-07-02 05:35:10,334 - INFO - Exporting aggregated data (geohash5) for date: 20190307, hours: 3-6
# 2024-07-02 05:35:10,349 - INFO - Querying data for date: 20190307, hours: 6-9
# 2024-07-02 05:35:24,430 - INFO - Processing data for date: 20190307, hours: 6-9
# 2024-07-02 05:35:24,473 - INFO - Exporting aggregated data (geohash3) for date: 20190307, hours: 6-9
# 2024-07-02 05:35:24,541 - INFO - Exporting aggregated data (geohash5) for date: 20190307, hours: 6-9
# 2024-07-02 05:35:24,561 - INFO - Querying data for date: 20190307, hours: 9-12
# 2024-07-02 05:35:54,157 - INFO - Processing data for date: 20190307, hours: 9-12
# 2024-07-02 05:35:54,225 - INFO - Exporting aggregated data (geohash3) for date: 20190307, hours: 9-12
# 2024-07-02 05:35:54,323 - INFO - Exporting aggregated data (geohash5) for date: 20190307, hours: 9-12
# 2024-07-02 05:35:54,356 - INFO - Querying data for date: 20190307, hours: 12-15
# 2024-07-02 05:36:13,378 - INFO - Processing data for date: 20190307, hours: 12-15
# 2024-07-02 05:36:13,459 - INFO - Exporting aggregated data (geohash3) for date: 20190307, hours: 12-15
# 2024-07-02 05:36:13,555 - INFO - Exporting aggregated data (geohash5) for date: 20190307, hours: 12-15
# 2024-07-02 05:36:13,588 - INFO - Querying data for date: 20190307, hours: 15-18
# 2024-07-02 05:36:29,134 - INFO - Processing data for date: 20190307, hours: 15-18
# 2024-07-02 05:36:29,246 - INFO - Exporting aggregated data (geohash3) for date: 20190307, hours: 15-18
# 2024-07-02 05:36:29,360 - INFO - Exporting aggregated data (geohash5) for date: 20190307, hours: 15-18
# 2024-07-02 05:36:29,413 - INFO - Querying data for date: 20190307, hours: 18-21
# 2024-07-02 05:36:45,804 - INFO - Processing data for date: 20190307, hours: 18-21
# 2024-07-02 05:36:45,875 - INFO - Exporting aggregated data (geohash3) for date: 20190307, hours: 18-21
# 2024-07-02 05:36:45,987 - INFO - Exporting aggregated data (geohash5) for date: 20190307, hours: 18-21
# 2024-07-02 05:36:46,027 - INFO - Querying data for date: 20190307, hours: 21-24
# 2024-07-02 05:37:03,404 - INFO - Processing data for date: 20190307, hours: 21-24
# 2024-07-02 05:37:03,444 - INFO - Exporting aggregated data (geohash3) for date: 20190307, hours: 21-24
# 2024-07-02 05:37:03,488 - INFO - Exporting aggregated data (geohash5) for date: 20190307, hours: 21-24
# 2024-07-02 05:37:03,583 - INFO - Processing data for date: 20190308
# 2024-07-02 05:37:03,585 - INFO - Querying data for date: 20190308, hours: 0-3
# 2024-07-02 05:37:40,972 - INFO - Processing data for date: 20190308, hours: 0-3
# 2024-07-02 05:37:40,992 - INFO - Exporting aggregated data (geohash3) for date: 20190308, hours: 0-3
# 2024-07-02 05:37:41,024 - INFO - Exporting aggregated data (geohash5) for date: 20190308, hours: 0-3
# 2024-07-02 05:37:41,040 - INFO - Querying data for date: 20190308, hours: 3-6
# 2024-07-02 05:37:56,507 - INFO - Processing data for date: 20190308, hours: 3-6
# 2024-07-02 05:37:56,533 - INFO - Exporting aggregated data (geohash3) for date: 20190308, hours: 3-6
# 2024-07-02 05:37:56,569 - INFO - Exporting aggregated data (geohash5) for date: 20190308, hours: 3-6
# 2024-07-02 05:37:56,586 - INFO - Querying data for date: 20190308, hours: 6-9
# 2024-07-02 05:38:12,506 - INFO - Processing data for date: 20190308, hours: 6-9
# 2024-07-02 05:38:12,551 - INFO - Exporting aggregated data (geohash3) for date: 20190308, hours: 6-9
# 2024-07-02 05:38:12,617 - INFO - Exporting aggregated data (geohash5) for date: 20190308, hours: 6-9
# 2024-07-02 05:38:12,637 - INFO - Querying data for date: 20190308, hours: 9-12
# 2024-07-02 05:38:42,324 - INFO - Processing data for date: 20190308, hours: 9-12
# 2024-07-02 05:38:42,400 - INFO - Exporting aggregated data (geohash3) for date: 20190308, hours: 9-12
# 2024-07-02 05:38:42,492 - INFO - Exporting aggregated data (geohash5) for date: 20190308, hours: 9-12
# 2024-07-02 05:38:42,523 - INFO - Querying data for date: 20190308, hours: 12-15
# 2024-07-02 05:39:04,174 - INFO - Processing data for date: 20190308, hours: 12-15
# 2024-07-02 05:39:04,264 - INFO - Exporting aggregated data (geohash3) for date: 20190308, hours: 12-15
# 2024-07-02 05:39:04,371 - INFO - Exporting aggregated data (geohash5) for date: 20190308, hours: 12-15
# 2024-07-02 05:39:04,403 - INFO - Querying data for date: 20190308, hours: 15-18
# 2024-07-02 05:39:23,788 - INFO - Processing data for date: 20190308, hours: 15-18
# 2024-07-02 05:39:23,874 - INFO - Exporting aggregated data (geohash3) for date: 20190308, hours: 15-18
# 2024-07-02 05:39:23,966 - INFO - Exporting aggregated data (geohash5) for date: 20190308, hours: 15-18
# 2024-07-02 05:39:23,996 - INFO - Querying data for date: 20190308, hours: 18-21
# 2024-07-02 05:40:00,818 - INFO - Processing data for date: 20190308, hours: 18-21
# 2024-07-02 05:40:00,886 - INFO - Exporting aggregated data (geohash3) for date: 20190308, hours: 18-21
# 2024-07-02 05:40:00,974 - INFO - Exporting aggregated data (geohash5) for date: 20190308, hours: 18-21
# 2024-07-02 05:40:01,005 - INFO - Querying data for date: 20190308, hours: 21-24
# 2024-07-02 05:40:22,351 - INFO - Processing data for date: 20190308, hours: 21-24
# 2024-07-02 05:40:22,394 - INFO - Exporting aggregated data (geohash3) for date: 20190308, hours: 21-24
# 2024-07-02 05:40:22,437 - INFO - Exporting aggregated data (geohash5) for date: 20190308, hours: 21-24
# 2024-07-02 05:40:22,535 - INFO - Processing data for date: 20190309
# 2024-07-02 05:40:22,536 - INFO - Querying data for date: 20190309, hours: 0-3
# 2024-07-02 05:40:44,364 - INFO - Processing data for date: 20190309, hours: 0-3
# 2024-07-02 05:40:44,383 - INFO - Exporting aggregated data (geohash3) for date: 20190309, hours: 0-3
# 2024-07-02 05:40:44,417 - INFO - Exporting aggregated data (geohash5) for date: 20190309, hours: 0-3
# 2024-07-02 05:40:44,432 - INFO - Querying data for date: 20190309, hours: 3-6
# 2024-07-02 05:41:00,046 - INFO - Processing data for date: 20190309, hours: 3-6
# 2024-07-02 05:41:00,071 - INFO - Exporting aggregated data (geohash3) for date: 20190309, hours: 3-6
# 2024-07-02 05:41:00,108 - INFO - Exporting aggregated data (geohash5) for date: 20190309, hours: 3-6
# 2024-07-02 05:41:00,121 - INFO - Querying data for date: 20190309, hours: 6-9
# 2024-07-02 05:41:32,201 - INFO - Processing data for date: 20190309, hours: 6-9
# 2024-07-02 05:41:32,242 - INFO - Exporting aggregated data (geohash3) for date: 20190309, hours: 6-9
# 2024-07-02 05:41:32,307 - INFO - Exporting aggregated data (geohash5) for date: 20190309, hours: 6-9
# 2024-07-02 05:41:32,328 - INFO - Querying data for date: 20190309, hours: 9-12
# 2024-07-02 05:41:54,513 - INFO - Processing data for date: 20190309, hours: 9-12
# 2024-07-02 05:41:54,579 - INFO - Exporting aggregated data (geohash3) for date: 20190309, hours: 9-12
# 2024-07-02 05:41:54,668 - INFO - Exporting aggregated data (geohash5) for date: 20190309, hours: 9-12
# 2024-07-02 05:41:54,695 - INFO - Querying data for date: 20190309, hours: 12-15
# 2024-07-02 05:42:11,431 - INFO - Processing data for date: 20190309, hours: 12-15
# 2024-07-02 05:42:11,508 - INFO - Exporting aggregated data (geohash3) for date: 20190309, hours: 12-15
# 2024-07-02 05:42:11,604 - INFO - Exporting aggregated data (geohash5) for date: 20190309, hours: 12-15
# 2024-07-02 05:42:11,635 - INFO - Querying data for date: 20190309, hours: 15-18
# 2024-07-02 05:42:29,027 - INFO - Processing data for date: 20190309, hours: 15-18
# 2024-07-02 05:42:29,099 - INFO - Exporting aggregated data (geohash3) for date: 20190309, hours: 15-18
# 2024-07-02 05:42:29,196 - INFO - Exporting aggregated data (geohash5) for date: 20190309, hours: 15-18
# 2024-07-02 05:42:29,225 - INFO - Querying data for date: 20190309, hours: 18-21
# 2024-07-02 05:42:43,601 - INFO - Processing data for date: 20190309, hours: 18-21
# 2024-07-02 05:42:43,667 - INFO - Exporting aggregated data (geohash3) for date: 20190309, hours: 18-21
# 2024-07-02 05:42:43,743 - INFO - Exporting aggregated data (geohash5) for date: 20190309, hours: 18-21
# 2024-07-02 05:42:43,789 - INFO - Querying data for date: 20190309, hours: 21-24
# 2024-07-02 05:43:15,807 - INFO - Processing data for date: 20190309, hours: 21-24
# 2024-07-02 05:43:15,850 - INFO - Exporting aggregated data (geohash3) for date: 20190309, hours: 21-24
# 2024-07-02 05:43:15,930 - INFO - Exporting aggregated data (geohash5) for date: 20190309, hours: 21-24
# 2024-07-02 05:43:16,049 - INFO - Processing data for date: 20190310
# 2024-07-02 05:43:16,050 - INFO - Querying data for date: 20190310, hours: 0-3
# 2024-07-02 05:43:41,808 - INFO - Processing data for date: 20190310, hours: 0-3
# 2024-07-02 05:43:41,828 - INFO - Exporting aggregated data (geohash3) for date: 20190310, hours: 0-3
# 2024-07-02 05:43:41,910 - INFO - Exporting aggregated data (geohash5) for date: 20190310, hours: 0-3
# 2024-07-02 05:43:41,927 - INFO - Querying data for date: 20190310, hours: 3-6
# 2024-07-02 05:43:56,039 - INFO - Processing data for date: 20190310, hours: 3-6
# 2024-07-02 05:43:56,060 - INFO - Exporting aggregated data (geohash3) for date: 20190310, hours: 3-6
# 2024-07-02 05:43:56,129 - INFO - Exporting aggregated data (geohash5) for date: 20190310, hours: 3-6
# 2024-07-02 05:43:56,143 - INFO - Querying data for date: 20190310, hours: 6-9
# 2024-07-02 05:44:09,973 - INFO - Processing data for date: 20190310, hours: 6-9
# 2024-07-02 05:44:10,013 - INFO - Exporting aggregated data (geohash3) for date: 20190310, hours: 6-9
# 2024-07-02 05:44:10,079 - INFO - Exporting aggregated data (geohash5) for date: 20190310, hours: 6-9
# 2024-07-02 05:44:10,099 - INFO - Querying data for date: 20190310, hours: 9-12
# 2024-07-02 05:44:25,820 - INFO - Processing data for date: 20190310, hours: 9-12
# 2024-07-02 05:44:25,877 - INFO - Exporting aggregated data (geohash3) for date: 20190310, hours: 9-12
# 2024-07-02 05:44:25,960 - INFO - Exporting aggregated data (geohash5) for date: 20190310, hours: 9-12
# 2024-07-02 05:44:25,987 - INFO - Querying data for date: 20190310, hours: 12-15
# 2024-07-02 05:44:50,148 - INFO - Processing data for date: 20190310, hours: 12-15
# 2024-07-02 05:44:50,210 - INFO - Exporting aggregated data (geohash3) for date: 20190310, hours: 12-15
# 2024-07-02 05:44:50,287 - INFO - Exporting aggregated data (geohash5) for date: 20190310, hours: 12-15
# 2024-07-02 05:44:50,314 - INFO - Querying data for date: 20190310, hours: 15-18
# 2024-07-02 05:45:10,269 - INFO - Processing data for date: 20190310, hours: 15-18
# 2024-07-02 05:45:10,332 - INFO - Exporting aggregated data (geohash3) for date: 20190310, hours: 15-18
# 2024-07-02 05:45:10,411 - INFO - Exporting aggregated data (geohash5) for date: 20190310, hours: 15-18
# 2024-07-02 05:45:10,437 - INFO - Querying data for date: 20190310, hours: 18-21
# 2024-07-02 05:45:24,099 - INFO - Processing data for date: 20190310, hours: 18-21
# 2024-07-02 05:45:24,165 - INFO - Exporting aggregated data (geohash3) for date: 20190310, hours: 18-21
# 2024-07-02 05:45:24,248 - INFO - Exporting aggregated data (geohash5) for date: 20190310, hours: 18-21
# 2024-07-02 05:45:24,273 - INFO - Querying data for date: 20190310, hours: 21-24
# 2024-07-02 05:45:37,233 - INFO - Processing data for date: 20190310, hours: 21-24
# 2024-07-02 05:45:37,344 - INFO - Exporting aggregated data (geohash3) for date: 20190310, hours: 21-24
# 2024-07-02 05:45:37,399 - INFO - Exporting aggregated data (geohash5) for date: 20190310, hours: 21-24
# 2024-07-02 05:45:37,530 - INFO - Processing data for date: 20190311
# 2024-07-02 05:45:37,531 - INFO - Querying data for date: 20190311, hours: 0-3
# 2024-07-02 05:46:01,043 - INFO - Processing data for date: 20190311, hours: 0-3
# 2024-07-02 05:46:01,060 - INFO - Exporting aggregated data (geohash3) for date: 20190311, hours: 0-3
# 2024-07-02 05:46:01,092 - INFO - Exporting aggregated data (geohash5) for date: 20190311, hours: 0-3
# 2024-07-02 05:46:01,105 - INFO - Querying data for date: 20190311, hours: 3-6
# 2024-07-02 05:46:30,938 - INFO - Processing data for date: 20190311, hours: 3-6
# 2024-07-02 05:46:30,959 - INFO - Exporting aggregated data (geohash3) for date: 20190311, hours: 3-6
# 2024-07-02 05:46:30,996 - INFO - Exporting aggregated data (geohash5) for date: 20190311, hours: 3-6
# 2024-07-02 05:46:31,009 - INFO - Querying data for date: 20190311, hours: 6-9
# 2024-07-02 05:46:48,392 - INFO - Processing data for date: 20190311, hours: 6-9
# 2024-07-02 05:46:48,431 - INFO - Exporting aggregated data (geohash3) for date: 20190311, hours: 6-9
# 2024-07-02 05:46:48,494 - INFO - Exporting aggregated data (geohash5) for date: 20190311, hours: 6-9
# 2024-07-02 05:46:48,515 - INFO - Querying data for date: 20190311, hours: 9-12
# 2024-07-02 05:47:02,616 - INFO - Processing data for date: 20190311, hours: 9-12
# 2024-07-02 05:47:02,685 - INFO - Exporting aggregated data (geohash3) for date: 20190311, hours: 9-12
# 2024-07-02 05:47:02,784 - INFO - Exporting aggregated data (geohash5) for date: 20190311, hours: 9-12
# 2024-07-02 05:47:02,816 - INFO - Querying data for date: 20190311, hours: 12-15
# 2024-07-02 05:47:19,081 - INFO - Processing data for date: 20190311, hours: 12-15
# 2024-07-02 05:47:19,165 - INFO - Exporting aggregated data (geohash3) for date: 20190311, hours: 12-15
# 2024-07-02 05:47:19,275 - INFO - Exporting aggregated data (geohash5) for date: 20190311, hours: 12-15
# 2024-07-02 05:47:19,324 - INFO - Querying data for date: 20190311, hours: 15-18
# 2024-07-02 05:47:33,278 - INFO - Processing data for date: 20190311, hours: 15-18
# 2024-07-02 05:47:33,351 - INFO - Exporting aggregated data (geohash3) for date: 20190311, hours: 15-18
# 2024-07-02 05:47:33,432 - INFO - Exporting aggregated data (geohash5) for date: 20190311, hours: 15-18
# 2024-07-02 05:47:33,459 - INFO - Querying data for date: 20190311, hours: 18-21
# 2024-07-02 05:47:48,194 - INFO - Processing data for date: 20190311, hours: 18-21
# 2024-07-02 05:47:48,261 - INFO - Exporting aggregated data (geohash3) for date: 20190311, hours: 18-21
# 2024-07-02 05:47:48,341 - INFO - Exporting aggregated data (geohash5) for date: 20190311, hours: 18-21
# 2024-07-02 05:47:48,369 - INFO - Querying data for date: 20190311, hours: 21-24
# 2024-07-02 05:48:19,771 - INFO - Processing data for date: 20190311, hours: 21-24
# 2024-07-02 05:48:19,811 - INFO - Exporting aggregated data (geohash3) for date: 20190311, hours: 21-24
# 2024-07-02 05:48:19,851 - INFO - Exporting aggregated data (geohash5) for date: 20190311, hours: 21-24
# 2024-07-02 05:48:19,947 - INFO - Processing data for date: 20190312
# 2024-07-02 05:48:19,948 - INFO - Querying data for date: 20190312, hours: 0-3
# 2024-07-02 05:48:42,634 - INFO - Processing data for date: 20190312, hours: 0-3
# 2024-07-02 05:48:42,652 - INFO - Exporting aggregated data (geohash3) for date: 20190312, hours: 0-3
# 2024-07-02 05:48:42,690 - INFO - Exporting aggregated data (geohash5) for date: 20190312, hours: 0-3
# 2024-07-02 05:48:42,701 - INFO - Querying data for date: 20190312, hours: 3-6
# 2024-07-02 05:48:59,549 - INFO - Processing data for date: 20190312, hours: 3-6
# 2024-07-02 05:48:59,573 - INFO - Exporting aggregated data (geohash3) for date: 20190312, hours: 3-6
# 2024-07-02 05:48:59,615 - INFO - Exporting aggregated data (geohash5) for date: 20190312, hours: 3-6
# 2024-07-02 05:48:59,628 - INFO - Querying data for date: 20190312, hours: 6-9
# 2024-07-02 05:49:17,737 - INFO - Processing data for date: 20190312, hours: 6-9
# 2024-07-02 05:49:17,782 - INFO - Exporting aggregated data (geohash3) for date: 20190312, hours: 6-9
# 2024-07-02 05:49:17,850 - INFO - Exporting aggregated data (geohash5) for date: 20190312, hours: 6-9
# 2024-07-02 05:49:17,870 - INFO - Querying data for date: 20190312, hours: 9-12
# 2024-07-02 05:49:51,964 - INFO - Processing data for date: 20190312, hours: 9-12
# 2024-07-02 05:49:52,034 - INFO - Exporting aggregated data (geohash3) for date: 20190312, hours: 9-12
# 2024-07-02 05:49:52,123 - INFO - Exporting aggregated data (geohash5) for date: 20190312, hours: 9-12
# 2024-07-02 05:49:52,157 - INFO - Querying data for date: 20190312, hours: 12-15
# 2024-07-02 05:50:15,825 - INFO - Processing data for date: 20190312, hours: 12-15
# 2024-07-02 05:50:15,913 - INFO - Exporting aggregated data (geohash3) for date: 20190312, hours: 12-15
# 2024-07-02 05:50:16,015 - INFO - Exporting aggregated data (geohash5) for date: 20190312, hours: 12-15
# 2024-07-02 05:50:16,045 - INFO - Querying data for date: 20190312, hours: 15-18
# 2024-07-02 05:50:33,158 - INFO - Processing data for date: 20190312, hours: 15-18
# 2024-07-02 05:50:33,307 - INFO - Exporting aggregated data (geohash3) for date: 20190312, hours: 15-18
# 2024-07-02 05:50:33,437 - INFO - Exporting aggregated data (geohash5) for date: 20190312, hours: 15-18
# 2024-07-02 05:50:33,468 - INFO - Querying data for date: 20190312, hours: 18-21
# 2024-07-02 05:50:49,189 - INFO - Processing data for date: 20190312, hours: 18-21
# 2024-07-02 05:50:49,258 - INFO - Exporting aggregated data (geohash3) for date: 20190312, hours: 18-21
# 2024-07-02 05:50:49,337 - INFO - Exporting aggregated data (geohash5) for date: 20190312, hours: 18-21
# 2024-07-02 05:50:49,364 - INFO - Querying data for date: 20190312, hours: 21-24
# 2024-07-02 05:51:19,220 - INFO - Processing data for date: 20190312, hours: 21-24
# 2024-07-02 05:51:19,259 - INFO - Exporting aggregated data (geohash3) for date: 20190312, hours: 21-24
# 2024-07-02 05:51:19,299 - INFO - Exporting aggregated data (geohash5) for date: 20190312, hours: 21-24
# 2024-07-02 05:51:19,395 - INFO - Processing data for date: 20190313
# 2024-07-02 05:51:19,396 - INFO - Querying data for date: 20190313, hours: 0-3
# 2024-07-02 05:51:42,835 - INFO - Processing data for date: 20190313, hours: 0-3
# 2024-07-02 05:51:42,853 - INFO - Exporting aggregated data (geohash3) for date: 20190313, hours: 0-3
# 2024-07-02 05:51:42,918 - INFO - Exporting aggregated data (geohash5) for date: 20190313, hours: 0-3
# 2024-07-02 05:51:42,930 - INFO - Querying data for date: 20190313, hours: 3-6
# 2024-07-02 05:51:58,350 - INFO - Processing data for date: 20190313, hours: 3-6
# 2024-07-02 05:51:58,373 - INFO - Exporting aggregated data (geohash3) for date: 20190313, hours: 3-6
# 2024-07-02 05:51:58,408 - INFO - Exporting aggregated data (geohash5) for date: 20190313, hours: 3-6
# 2024-07-02 05:51:58,422 - INFO - Querying data for date: 20190313, hours: 6-9
# 2024-07-02 05:52:18,731 - INFO - Processing data for date: 20190313, hours: 6-9
# 2024-07-02 05:52:18,773 - INFO - Exporting aggregated data (geohash3) for date: 20190313, hours: 6-9
# 2024-07-02 05:52:18,838 - INFO - Exporting aggregated data (geohash5) for date: 20190313, hours: 6-9
# 2024-07-02 05:52:18,857 - INFO - Querying data for date: 20190313, hours: 9-12
# 2024-07-02 05:52:47,326 - INFO - Processing data for date: 20190313, hours: 9-12
# 2024-07-02 05:52:47,392 - INFO - Exporting aggregated data (geohash3) for date: 20190313, hours: 9-12
# 2024-07-02 05:52:47,493 - INFO - Exporting aggregated data (geohash5) for date: 20190313, hours: 9-12
# 2024-07-02 05:52:47,520 - INFO - Querying data for date: 20190313, hours: 12-15
# 2024-07-02 05:53:09,937 - INFO - Processing data for date: 20190313, hours: 12-15
# 2024-07-02 05:53:10,030 - INFO - Exporting aggregated data (geohash3) for date: 20190313, hours: 12-15
# 2024-07-02 05:53:10,141 - INFO - Exporting aggregated data (geohash5) for date: 20190313, hours: 12-15
# 2024-07-02 05:53:10,173 - INFO - Querying data for date: 20190313, hours: 15-18
# 2024-07-02 05:53:24,154 - INFO - Processing data for date: 20190313, hours: 15-18
# 2024-07-02 05:53:24,304 - INFO - Exporting aggregated data (geohash3) for date: 20190313, hours: 15-18
# 2024-07-02 05:53:24,416 - INFO - Exporting aggregated data (geohash5) for date: 20190313, hours: 15-18
# 2024-07-02 05:53:24,452 - INFO - Querying data for date: 20190313, hours: 18-21
# 2024-07-02 05:53:38,600 - INFO - Processing data for date: 20190313, hours: 18-21
# 2024-07-02 05:53:38,668 - INFO - Exporting aggregated data (geohash3) for date: 20190313, hours: 18-21
# 2024-07-02 05:53:38,765 - INFO - Exporting aggregated data (geohash5) for date: 20190313, hours: 18-21
# 2024-07-02 05:53:38,792 - INFO - Querying data for date: 20190313, hours: 21-24
# 2024-07-02 05:54:10,826 - INFO - Processing data for date: 20190313, hours: 21-24
# 2024-07-02 05:54:10,865 - INFO - Exporting aggregated data (geohash3) for date: 20190313, hours: 21-24
# 2024-07-02 05:54:10,906 - INFO - Exporting aggregated data (geohash5) for date: 20190313, hours: 21-24
# 2024-07-02 05:54:10,999 - INFO - Processing data for date: 20190314
# 2024-07-02 05:54:11,000 - INFO - Querying data for date: 20190314, hours: 0-3
# 2024-07-02 05:54:39,798 - INFO - Processing data for date: 20190314, hours: 0-3
# 2024-07-02 05:54:39,818 - INFO - Exporting aggregated data (geohash3) for date: 20190314, hours: 0-3
# 2024-07-02 05:54:39,851 - INFO - Exporting aggregated data (geohash5) for date: 20190314, hours: 0-3
# 2024-07-02 05:54:39,863 - INFO - Querying data for date: 20190314, hours: 3-6
# 2024-07-02 05:54:57,312 - INFO - Processing data for date: 20190314, hours: 3-6
# 2024-07-02 05:54:57,336 - INFO - Exporting aggregated data (geohash3) for date: 20190314, hours: 3-6
# 2024-07-02 05:54:57,374 - INFO - Exporting aggregated data (geohash5) for date: 20190314, hours: 3-6
# 2024-07-02 05:54:57,388 - INFO - Querying data for date: 20190314, hours: 6-9
# 2024-07-02 05:55:13,451 - INFO - Processing data for date: 20190314, hours: 6-9
# 2024-07-02 05:55:13,534 - INFO - Exporting aggregated data (geohash3) for date: 20190314, hours: 6-9
# 2024-07-02 05:55:13,644 - INFO - Exporting aggregated data (geohash5) for date: 20190314, hours: 6-9
# 2024-07-02 05:55:13,666 - INFO - Querying data for date: 20190314, hours: 9-12
# 2024-07-02 05:55:28,951 - INFO - Processing data for date: 20190314, hours: 9-12
# 2024-07-02 05:55:29,015 - INFO - Exporting aggregated data (geohash3) for date: 20190314, hours: 9-12
# 2024-07-02 05:55:29,100 - INFO - Exporting aggregated data (geohash5) for date: 20190314, hours: 9-12
# 2024-07-02 05:55:29,127 - INFO - Querying data for date: 20190314, hours: 12-15
# 2024-07-02 05:55:58,742 - INFO - Processing data for date: 20190314, hours: 12-15
# 2024-07-02 05:55:58,815 - INFO - Exporting aggregated data (geohash3) for date: 20190314, hours: 12-15
# 2024-07-02 05:55:58,908 - INFO - Exporting aggregated data (geohash5) for date: 20190314, hours: 12-15
# 2024-07-02 05:55:58,935 - INFO - Querying data for date: 20190314, hours: 15-18
# 2024-07-02 05:56:19,331 - INFO - Processing data for date: 20190314, hours: 15-18
# 2024-07-02 05:56:19,409 - INFO - Exporting aggregated data (geohash3) for date: 20190314, hours: 15-18
# 2024-07-02 05:56:19,513 - INFO - Exporting aggregated data (geohash5) for date: 20190314, hours: 15-18
# 2024-07-02 05:56:19,540 - INFO - Querying data for date: 20190314, hours: 18-21
# 2024-07-02 05:56:34,829 - INFO - Processing data for date: 20190314, hours: 18-21
# 2024-07-02 05:56:34,895 - INFO - Exporting aggregated data (geohash3) for date: 20190314, hours: 18-21
# 2024-07-02 05:56:34,974 - INFO - Exporting aggregated data (geohash5) for date: 20190314, hours: 18-21
# 2024-07-02 05:56:35,000 - INFO - Querying data for date: 20190314, hours: 21-24
# 2024-07-02 05:56:50,646 - INFO - Processing data for date: 20190314, hours: 21-24
# 2024-07-02 05:56:50,685 - INFO - Exporting aggregated data (geohash3) for date: 20190314, hours: 21-24
# 2024-07-02 05:56:50,729 - INFO - Exporting aggregated data (geohash5) for date: 20190314, hours: 21-24
# 2024-07-02 05:56:50,819 - INFO - Processing data for date: 20190315
# 2024-07-02 05:56:50,820 - INFO - Querying data for date: 20190315, hours: 0-3
# 2024-07-02 05:57:10,739 - INFO - Processing data for date: 20190315, hours: 0-3
# 2024-07-02 05:57:10,762 - INFO - Exporting aggregated data (geohash3) for date: 20190315, hours: 0-3
# 2024-07-02 05:57:10,798 - INFO - Exporting aggregated data (geohash5) for date: 20190315, hours: 0-3
# 2024-07-02 05:57:10,812 - INFO - Querying data for date: 20190315, hours: 3-6
# 2024-07-02 05:57:42,408 - INFO - Processing data for date: 20190315, hours: 3-6
# 2024-07-02 05:57:42,431 - INFO - Exporting aggregated data (geohash3) for date: 20190315, hours: 3-6
# 2024-07-02 05:57:42,466 - INFO - Exporting aggregated data (geohash5) for date: 20190315, hours: 3-6
# 2024-07-02 05:57:42,480 - INFO - Querying data for date: 20190315, hours: 6-9
# 2024-07-02 05:58:03,412 - INFO - Processing data for date: 20190315, hours: 6-9
# 2024-07-02 05:58:03,456 - INFO - Exporting aggregated data (geohash3) for date: 20190315, hours: 6-9
# 2024-07-02 05:58:03,525 - INFO - Exporting aggregated data (geohash5) for date: 20190315, hours: 6-9
# 2024-07-02 05:58:03,546 - INFO - Querying data for date: 20190315, hours: 9-12
# 2024-07-02 05:58:17,748 - INFO - Processing data for date: 20190315, hours: 9-12
# 2024-07-02 05:58:17,825 - INFO - Exporting aggregated data (geohash3) for date: 20190315, hours: 9-12
# 2024-07-02 05:58:17,928 - INFO - Exporting aggregated data (geohash5) for date: 20190315, hours: 9-12
# 2024-07-02 05:58:17,959 - INFO - Querying data for date: 20190315, hours: 12-15
# 2024-07-02 05:58:34,237 - INFO - Processing data for date: 20190315, hours: 12-15
# 2024-07-02 05:58:34,348 - INFO - Exporting aggregated data (geohash3) for date: 20190315, hours: 12-15
# 2024-07-02 05:58:34,503 - INFO - Exporting aggregated data (geohash5) for date: 20190315, hours: 12-15
# 2024-07-02 05:58:34,536 - INFO - Querying data for date: 20190315, hours: 15-18
# 2024-07-02 05:58:48,044 - INFO - Processing data for date: 20190315, hours: 15-18
# 2024-07-02 05:58:48,119 - INFO - Exporting aggregated data (geohash3) for date: 20190315, hours: 15-18
# 2024-07-02 05:58:48,203 - INFO - Exporting aggregated data (geohash5) for date: 20190315, hours: 15-18
# 2024-07-02 05:58:48,231 - INFO - Querying data for date: 20190315, hours: 18-21
# 2024-07-02 05:59:16,427 - INFO - Processing data for date: 20190315, hours: 18-21
# 2024-07-02 05:59:16,495 - INFO - Exporting aggregated data (geohash3) for date: 20190315, hours: 18-21
# 2024-07-02 05:59:16,573 - INFO - Exporting aggregated data (geohash5) for date: 20190315, hours: 18-21
# 2024-07-02 05:59:16,620 - INFO - Querying data for date: 20190315, hours: 21-24
# 2024-07-02 05:59:36,806 - INFO - Processing data for date: 20190315, hours: 21-24
# 2024-07-02 05:59:36,849 - INFO - Exporting aggregated data (geohash3) for date: 20190315, hours: 21-24
# 2024-07-02 05:59:36,890 - INFO - Exporting aggregated data (geohash5) for date: 20190315, hours: 21-24
# 2024-07-02 05:59:36,988 - INFO - Processing data for date: 20190316
# 2024-07-02 05:59:36,988 - INFO - Querying data for date: 20190316, hours: 0-3
# 2024-07-02 05:59:54,909 - INFO - Processing data for date: 20190316, hours: 0-3
# ...
# 2024-07-02 10:40:37,302 - INFO - Querying data for date: 20190625, hours: 0-3
# 2024-07-02 10:41:21,169 - INFO - Processing data for date: 20190625, hours: 0-3
# 2024-07-02 10:41:21,190 - INFO - Exporting aggregated data (geohash3) for date: 20190625, hours: 0-3
# 2024-07-02 10:41:21,225 - INFO - Exporting aggregated data (geohash5) for date: 20190625, hours: 0-3
# 2024-07-02 10:41:21,239 - INFO - Querying data for date: 20190625, hours: 3-6
# 2024-07-02 10:41:38,533 - INFO - Processing data for date: 20190625, hours: 3-6
# 2024-07-02 10:41:38,557 - INFO - Exporting aggregated data (geohash3) for date: 20190625, hours: 3-6
# 2024-07-02 10:41:38,599 - INFO - Exporting aggregated data (geohash5) for date: 20190625, hours: 3-6
# 2024-07-02 10:41:38,615 - INFO - Querying data for date: 20190625, hours: 6-9
# 2024-07-02 10:41:53,105 - INFO - Processing data for date: 20190625, hours: 6-9
# 2024-07-02 10:41:53,148 - INFO - Exporting aggregated data (geohash3) for date: 20190625, hours: 6-9
# 2024-07-02 10:41:53,214 - INFO - Exporting aggregated data (geohash5) for date: 20190625, hours: 6-9
# 2024-07-02 10:41:53,235 - INFO - Querying data for date: 20190625, hours: 9-12
# 2024-07-02 10:42:24,349 - INFO - Processing data for date: 20190625, hours: 9-12
# 2024-07-02 10:42:24,417 - INFO - Exporting aggregated data (geohash3) for date: 20190625, hours: 9-12
# 2024-07-02 10:42:24,509 - INFO - Exporting aggregated data (geohash5) for date: 20190625, hours: 9-12
# 2024-07-02 10:42:24,542 - INFO - Querying data for date: 20190625, hours: 12-15
# 2024-07-02 10:42:47,384 - INFO - Processing data for date: 20190625, hours: 12-15
# 2024-07-02 10:42:47,463 - INFO - Exporting aggregated data (geohash3) for date: 20190625, hours: 12-15
# 2024-07-02 10:42:47,553 - INFO - Exporting aggregated data (geohash5) for date: 20190625, hours: 12-15
# 2024-07-02 10:42:47,586 - INFO - Querying data for date: 20190625, hours: 15-18
# 2024-07-02 10:43:02,330 - INFO - Processing data for date: 20190625, hours: 15-18
# 2024-07-02 10:43:02,410 - INFO - Exporting aggregated data (geohash3) for date: 20190625, hours: 15-18
# 2024-07-02 10:43:02,519 - INFO - Exporting aggregated data (geohash5) for date: 20190625, hours: 15-18
# 2024-07-02 10:43:02,548 - INFO - Querying data for date: 20190625, hours: 18-21
# 2024-07-02 10:43:18,783 - INFO - Processing data for date: 20190625, hours: 18-21
# 2024-07-02 10:43:18,859 - INFO - Exporting aggregated data (geohash3) for date: 20190625, hours: 18-21
# 2024-07-02 10:43:18,956 - INFO - Exporting aggregated data (geohash5) for date: 20190625, hours: 18-21
# 2024-07-02 10:43:18,988 - INFO - Querying data for date: 20190625, hours: 21-24
# 2024-07-02 10:43:32,883 - INFO - Processing data for date: 20190625, hours: 21-24
# 2024-07-02 10:43:32,928 - INFO - Exporting aggregated data (geohash3) for date: 20190625, hours: 21-24
# 2024-07-02 10:43:32,970 - INFO - Exporting aggregated data (geohash5) for date: 20190625, hours: 21-24
# 2024-07-02 10:43:33,064 - INFO - Processing data for date: 20190626
# 2024-07-02 10:43:33,064 - INFO - Querying data for date: 20190626, hours: 0-3
# 2024-07-02 10:44:16,509 - INFO - Processing data for date: 20190626, hours: 0-3
# 2024-07-02 10:44:16,530 - INFO - Exporting aggregated data (geohash3) for date: 20190626, hours: 0-3
# 2024-07-02 10:44:16,568 - INFO - Exporting aggregated data (geohash5) for date: 20190626, hours: 0-3
# 2024-07-02 10:44:16,586 - INFO - Querying data for date: 20190626, hours: 3-6
# 2024-07-02 10:44:37,985 - INFO - Processing data for date: 20190626, hours: 3-6
# 2024-07-02 10:44:38,011 - INFO - Exporting aggregated data (geohash3) for date: 20190626, hours: 3-6
# 2024-07-02 10:44:38,053 - INFO - Exporting aggregated data (geohash5) for date: 20190626, hours: 3-6
# 2024-07-02 10:44:38,070 - INFO - Querying data for date: 20190626, hours: 6-9
# 2024-07-02 10:44:52,844 - INFO - Processing data for date: 20190626, hours: 6-9
# 2024-07-02 10:44:52,889 - INFO - Exporting aggregated data (geohash3) for date: 20190626, hours: 6-9
# 2024-07-02 10:44:52,966 - INFO - Exporting aggregated data (geohash5) for date: 20190626, hours: 6-9
# 2024-07-02 10:44:52,986 - INFO - Querying data for date: 20190626, hours: 9-12
# 2024-07-02 10:45:07,460 - INFO - Processing data for date: 20190626, hours: 9-12
# 2024-07-02 10:45:07,535 - INFO - Exporting aggregated data (geohash3) for date: 20190626, hours: 9-12
# 2024-07-02 10:45:07,636 - INFO - Exporting aggregated data (geohash5) for date: 20190626, hours: 9-12
# 2024-07-02 10:45:07,668 - INFO - Querying data for date: 20190626, hours: 12-15
# 2024-07-02 10:45:23,797 - INFO - Processing data for date: 20190626, hours: 12-15
# 2024-07-02 10:45:23,873 - INFO - Exporting aggregated data (geohash3) for date: 20190626, hours: 12-15
# 2024-07-02 10:45:23,964 - INFO - Exporting aggregated data (geohash5) for date: 20190626, hours: 12-15
# 2024-07-02 10:45:23,996 - INFO - Querying data for date: 20190626, hours: 15-18
# 2024-07-02 10:45:54,012 - INFO - Processing data for date: 20190626, hours: 15-18
# 2024-07-02 10:45:54,087 - INFO - Exporting aggregated data (geohash3) for date: 20190626, hours: 15-18
# 2024-07-02 10:45:54,173 - INFO - Exporting aggregated data (geohash5) for date: 20190626, hours: 15-18
# 2024-07-02 10:45:54,207 - INFO - Querying data for date: 20190626, hours: 18-21
# 2024-07-02 10:46:13,731 - INFO - Processing data for date: 20190626, hours: 18-21
# 2024-07-02 10:46:13,803 - INFO - Exporting aggregated data (geohash3) for date: 20190626, hours: 18-21
# 2024-07-02 10:46:13,885 - INFO - Exporting aggregated data (geohash5) for date: 20190626, hours: 18-21
# 2024-07-02 10:46:13,921 - INFO - Querying data for date: 20190626, hours: 21-24
# 2024-07-02 10:46:28,466 - INFO - Processing data for date: 20190626, hours: 21-24
# 2024-07-02 10:46:28,511 - INFO - Exporting aggregated data (geohash3) for date: 20190626, hours: 21-24
# 2024-07-02 10:46:28,562 - INFO - Exporting aggregated data (geohash5) for date: 20190626, hours: 21-24
# 2024-07-02 10:46:28,669 - INFO - Processing data for date: 20190627
# 2024-07-02 10:46:28,670 - INFO - Querying data for date: 20190627, hours: 0-3
# 2024-07-02 10:46:46,692 - INFO - Processing data for date: 20190627, hours: 0-3
# 2024-07-02 10:46:46,714 - INFO - Exporting aggregated data (geohash3) for date: 20190627, hours: 0-3
# 2024-07-02 10:46:46,746 - INFO - Exporting aggregated data (geohash5) for date: 20190627, hours: 0-3
# 2024-07-02 10:46:46,761 - INFO - Querying data for date: 20190627, hours: 3-6
# 2024-07-02 10:47:09,602 - INFO - Processing data for date: 20190627, hours: 3-6
# 2024-07-02 10:47:09,629 - INFO - Exporting aggregated data (geohash3) for date: 20190627, hours: 3-6
# 2024-07-02 10:47:09,664 - INFO - Exporting aggregated data (geohash5) for date: 20190627, hours: 3-6
# 2024-07-02 10:47:09,678 - INFO - Querying data for date: 20190627, hours: 6-9
# 2024-07-02 10:49:25,089 - INFO - Processing data for date: 20190628, hours: 0-3
# 2024-07-02 10:49:25,109 - INFO - Exporting aggregated data (geohash3) for date: 20190628, hours: 0-3
# 2024-07-02 10:49:25,144 - INFO - Exporting aggregated data (geohash5) for date: 20190628, hours: 0-3
# 2024-07-02 10:49:25,157 - INFO - Querying data for date: 20190628, hours: 3-6
# 2024-07-02 10:49:40,123 - INFO - Processing data for date: 20190628, hours: 3-6
# 2024-07-02 10:49:40,147 - INFO - Exporting aggregated data (geohash3) for date: 20190628, hours: 3-6
# 2024-07-02 10:49:40,180 - INFO - Exporting aggregated data (geohash5) for date: 20190628, hours: 3-6
# 2024-07-02 10:49:40,195 - INFO - Querying data for date: 20190628, hours: 6-9
# 2024-07-02 10:49:55,045 - INFO - Processing data for date: 20190628, hours: 6-9
# 2024-07-02 10:49:55,089 - INFO - Exporting aggregated data (geohash3) for date: 20190628, hours: 6-9
# 2024-07-02 10:49:55,165 - INFO - Exporting aggregated data (geohash5) for date: 20190628, hours: 6-9
# 2024-07-02 10:49:55,187 - INFO - Querying data for date: 20190628, hours: 9-12
# 2024-07-02 10:50:09,023 - INFO - Processing data for date: 20190628, hours: 9-12
# 2024-07-02 10:50:09,088 - INFO - Exporting aggregated data (geohash3) for date: 20190628, hours: 9-12
# 2024-07-02 10:50:09,174 - INFO - Exporting aggregated data (geohash5) for date: 20190628, hours: 9-12
# 2024-07-02 10:50:09,202 - INFO - Querying data for date: 20190628, hours: 12-15
# 2024-07-02 10:50:39,268 - INFO - Processing data for date: 20190628, hours: 12-15
# 2024-07-02 10:50:39,343 - INFO - Exporting aggregated data (geohash3) for date: 20190628, hours: 12-15
# 2024-07-02 10:50:39,435 - INFO - Exporting aggregated data (geohash5) for date: 20190628, hours: 12-15
# 2024-07-02 10:50:39,473 - INFO - Querying data for date: 20190628, hours: 15-18
# 2024-07-02 10:50:57,850 - INFO - Processing data for date: 20190628, hours: 15-18
# 2024-07-02 10:50:57,923 - INFO - Exporting aggregated data (geohash3) for date: 20190628, hours: 15-18
# 2024-07-02 10:50:58,009 - INFO - Exporting aggregated data (geohash5) for date: 20190628, hours: 15-18
# 2024-07-02 10:50:58,051 - INFO - Querying data for date: 20190628, hours: 18-21
# 2024-07-02 10:51:13,657 - INFO - Processing data for date: 20190628, hours: 18-21
# 2024-07-02 10:51:13,728 - INFO - Exporting aggregated data (geohash3) for date: 20190628, hours: 18-21
# 2024-07-02 10:51:13,811 - INFO - Exporting aggregated data (geohash5) for date: 20190628, hours: 18-21
# 2024-07-02 10:51:13,842 - INFO - Querying data for date: 20190628, hours: 21-24
# 2024-07-02 10:51:27,934 - INFO - Processing data for date: 20190628, hours: 21-24
# 2024-07-02 10:51:27,976 - INFO - Exporting aggregated data (geohash3) for date: 20190628, hours: 21-24
# 2024-07-02 10:51:28,017 - INFO - Exporting aggregated data (geohash5) for date: 20190628, hours: 21-24
# 2024-07-02 10:51:28,107 - INFO - Processing data for date: 20190629
# 2024-07-02 10:51:28,108 - INFO - Querying data for date: 20190629, hours: 0-3
# 2024-07-02 10:51:56,634 - INFO - Processing data for date: 20190629, hours: 0-3
# 2024-07-02 10:51:56,655 - INFO - Exporting aggregated data (geohash3) for date: 20190629, hours: 0-3
# 2024-07-02 10:51:56,688 - INFO - Exporting aggregated data (geohash5) for date: 20190629, hours: 0-3
# 2024-07-02 10:51:56,701 - INFO - Querying data for date: 20190629, hours: 3-6
# 2024-07-02 10:52:21,781 - INFO - Processing data for date: 20190629, hours: 3-6
# 2024-07-02 10:52:21,805 - INFO - Exporting aggregated data (geohash3) for date: 20190629, hours: 3-6
# 2024-07-02 10:52:21,842 - INFO - Exporting aggregated data (geohash5) for date: 20190629, hours: 3-6
# 2024-07-02 10:52:21,856 - INFO - Querying data for date: 20190629, hours: 6-9
# 2024-07-02 10:52:36,215 - INFO - Processing data for date: 20190629, hours: 6-9
# 2024-07-02 10:52:36,260 - INFO - Exporting aggregated data (geohash3) for date: 20190629, hours: 6-9
# 2024-07-02 10:52:36,353 - INFO - Exporting aggregated data (geohash5) for date: 20190629, hours: 6-9
# 2024-07-02 10:52:36,374 - INFO - Querying data for date: 20190629, hours: 9-12
# 2024-07-02 10:52:50,705 - INFO - Processing data for date: 20190629, hours: 9-12
# 2024-07-02 10:52:50,771 - INFO - Exporting aggregated data (geohash3) for date: 20190629, hours: 9-12
# 2024-07-02 10:52:50,862 - INFO - Exporting aggregated data (geohash5) for date: 20190629, hours: 9-12
# 2024-07-02 10:52:50,888 - INFO - Querying data for date: 20190629, hours: 12-15
# 2024-07-02 10:53:18,556 - INFO - Processing data for date: 20190629, hours: 12-15
# 2024-07-02 10:53:18,635 - INFO - Exporting aggregated data (geohash3) for date: 20190629, hours: 12-15
# 2024-07-02 10:53:18,725 - INFO - Exporting aggregated data (geohash5) for date: 20190629, hours: 12-15
# 2024-07-02 10:53:18,760 - INFO - Querying data for date: 20190629, hours: 15-18
# 2024-07-02 10:53:38,781 - INFO - Processing data for date: 20190629, hours: 15-18
# 2024-07-02 10:53:38,852 - INFO - Exporting aggregated data (geohash3) for date: 20190629, hours: 15-18
# 2024-07-02 10:53:38,939 - INFO - Exporting aggregated data (geohash5) for date: 20190629, hours: 15-18
# 2024-07-02 10:53:38,970 - INFO - Querying data for date: 20190629, hours: 18-21
# 2024-07-02 10:53:52,777 - INFO - Processing data for date: 20190629, hours: 18-21
# 2024-07-02 10:53:52,850 - INFO - Exporting aggregated data (geohash3) for date: 20190629, hours: 18-21
# 2024-07-02 10:53:52,936 - INFO - Exporting aggregated data (geohash5) for date: 20190629, hours: 18-21
# 2024-07-02 10:53:52,965 - INFO - Querying data for date: 20190629, hours: 21-24
# 2024-07-02 10:54:07,982 - INFO - Processing data for date: 20190629, hours: 21-24
# 2024-07-02 10:54:08,027 - INFO - Exporting aggregated data (geohash3) for date: 20190629, hours: 21-24
# 2024-07-02 10:54:08,074 - INFO - Exporting aggregated data (geohash5) for date: 20190629, hours: 21-24
# 2024-07-02 10:54:08,167 - INFO - Processing data for date: 20190630
# 2024-07-02 10:54:08,168 - INFO - Querying data for date: 20190630, hours: 0-3
# 2024-07-02 10:54:42,642 - INFO - Processing data for date: 20190630, hours: 0-3
# 2024-07-02 10:54:42,663 - INFO - Exporting aggregated data (geohash3) for date: 20190630, hours: 0-3
# 2024-07-02 10:54:42,698 - INFO - Exporting aggregated data (geohash5) for date: 20190630, hours: 0-3
# 2024-07-02 10:54:42,714 - INFO - Querying data for date: 20190630, hours: 3-6
# 2024-07-02 10:54:59,804 - INFO - Processing data for date: 20190630, hours: 3-6
# 2024-07-02 10:54:59,827 - INFO - Exporting aggregated data (geohash3) for date: 20190630, hours: 3-6
# 2024-07-02 10:54:59,861 - INFO - Exporting aggregated data (geohash5) for date: 20190630, hours: 3-6
# 2024-07-02 10:54:59,876 - INFO - Querying data for date: 20190630, hours: 6-9
# 2024-07-02 10:55:12,492 - INFO - Processing data for date: 20190630, hours: 6-9
# 2024-07-02 10:55:12,531 - INFO - Exporting aggregated data (geohash3) for date: 20190630, hours: 6-9
# 2024-07-02 10:55:12,592 - INFO - Exporting aggregated data (geohash5) for date: 20190630, hours: 6-9
# 2024-07-02 10:55:12,615 - INFO - Querying data for date: 20190630, hours: 9-12
# 2024-07-02 10:55:25,086 - INFO - Processing data for date: 20190630, hours: 9-12
# 2024-07-02 10:55:25,160 - INFO - Exporting aggregated data (geohash3) for date: 20190630, hours: 9-12
# 2024-07-02 10:55:25,245 - INFO - Exporting aggregated data (geohash5) for date: 20190630, hours: 9-12
# 2024-07-02 10:55:25,275 - INFO - Querying data for date: 20190630, hours: 12-15
# 2024-07-02 10:55:37,554 - INFO - Processing data for date: 20190630, hours: 12-15
# 2024-07-02 10:55:37,616 - INFO - Exporting aggregated data (geohash3) for date: 20190630, hours: 12-15
# 2024-07-02 10:55:37,692 - INFO - Exporting aggregated data (geohash5) for date: 20190630, hours: 12-15
# 2024-07-02 10:55:37,718 - INFO - Querying data for date: 20190630, hours: 15-18
# 2024-07-02 10:56:03,169 - INFO - Processing data for date: 20190630, hours: 15-18
# 2024-07-02 10:56:03,230 - INFO - Exporting aggregated data (geohash3) for date: 20190630, hours: 15-18
# 2024-07-02 10:56:03,305 - INFO - Exporting aggregated data (geohash5) for date: 20190630, hours: 15-18
# 2024-07-02 10:56:03,334 - INFO - Querying data for date: 20190630, hours: 18-21
# 2024-07-02 10:56:24,881 - INFO - Processing data for date: 20190630, hours: 18-21
# 2024-07-02 10:56:24,940 - INFO - Exporting aggregated data (geohash3) for date: 20190630, hours: 18-21
# 2024-07-02 10:56:25,009 - INFO - Exporting aggregated data (geohash5) for date: 20190630, hours: 18-21
# 2024-07-02 10:56:25,037 - INFO - Querying data for date: 20190630, hours: 21-24
# 2024-07-02 10:56:37,952 - INFO - Processing data for date: 20190630, hours: 21-24
# 2024-07-02 10:56:37,989 - INFO - Exporting aggregated data (geohash3) for date: 20190630, hours: 21-24
# 2024-07-02 10:56:38,033 - INFO - Exporting aggregated data (geohash5) for date: 20190630, hours: 21-24
# 2024-07-02 10:56:38,112 - INFO - Errors occurred during processing:
# 2024-07-02 10:56:38,113 - INFO - Error processing date: 20190429, hours: 18-21 - error 502: bad gateway
# 2024-07-02 10:56:38,114 - INFO - Error processing date: 20190509, hours: 21-24 - error 502: bad gateway
# 2024-07-02 10:56:38,115 - INFO - Error processing date: 20190510, hours: 0-3 - error 502: bad gateway

# %% [markdown]
# # Check missing dates/times

# %%
country_code = 'ID'
export_path = '/home/jovyan/Data/TJ/3h/'
# Define the export file paths
csv3_file = f"od_{country_code.lower()}_agg3_3h.csv"
csv5_file = f"od_{country_code.lower()}_agg5_3h.csv"
csv3_file_path = f"{export_path}{csv3_file}"
csv5_file_path = f"{export_path}{csv5_file}"

final_df = pd.read_csv(csv3_file_path)
final_df['local_date'] = final_df['local_date'].astype(int)
final_df
# Out:
#        start_geohash3 end_geohash3  local_date  trip_count  m_duration_min  \
# 0                 qpz          qpz    20190101          11      319.692424
# 1                 qqg          qqg    20190101         211      218.170853
# 2                 qqg          qqu    20190101          19      231.121930
# 3                 qqt          qqt    20190101          12      326.195833
# 4                 qqu          qqu    20190101         156      223.032158
# ...               ...          ...         ...         ...             ...
# 143486            w8j          w8j    20190819          10       22.165000
# 143487            w8p          w8p    20190819          77       28.174242
# 143488            wb0          wb0    20190819          26       31.460256
# 143489            wb2          wb2    20190819          97       30.447766
# 143490            wb4          wb4    20190819          26       27.331410
#
#         mdn_duration_min  sd_duration_min    m_length_m  mdn_length_m  \
# 0              18.150000       369.759705  10622.753732   4472.684420
# 1              53.916667       313.656801   8737.583672   1612.809195
# 2              68.200000       368.066313  36176.830101  15373.618545
# 3             217.708333       352.397390   4881.131911   3290.121849
# 4              64.300000       308.184984  12784.349973   1608.970669
# ...                  ...              ...           ...           ...
# 143486         26.116667        11.921284   3156.114443    634.385410
# 143487         21.483333        24.874522   4529.579396   2129.916561
# 143488         16.658333        29.282130   5706.383253    585.489566
# 143489         21.316667        27.862832   4446.269779   1572.560922
# 143490         16.666667        27.117736   2247.247241   1302.112921
#
#          sd_length_m  m_points_no  mdn_points_no  sd_points_no  \
# 0       13992.289067     6.272727            2.0     11.018992
# 1       24155.813606     5.000000            2.0      8.441959
# 2       43671.576650     4.263158            2.0      4.531888
# 3        6251.524776     4.000000            2.5      3.247377
# 4       56852.781262     4.570513            2.0      8.883557
# ...              ...          ...            ...           ...
# 143486   6463.030898     4.300000            4.0      1.828782
# 143487   6830.045733     5.038961            4.0      3.258356
# 143488  18198.006945     4.423077            3.0      4.419711
# 143489   7185.324481     5.463918            4.0      4.349478
# 143490   3062.971432     3.846154            3.0      2.166884
#
#                           local_time
# 0       20190101 00:00:00 - 03:00:00
# 1       20190101 00:00:00 - 03:00:00
# 2       20190101 00:00:00 - 03:00:00
# 3       20190101 00:00:00 - 03:00:00
# 4       20190101 00:00:00 - 03:00:00
# ...                              ...
# 143486  20190819 21:00:00 - 24:00:00
# 143487  20190819 21:00:00 - 24:00:00
# 143488  20190819 21:00:00 - 24:00:00
# 143489  20190819 21:00:00 - 24:00:00
# 143490  20190819 21:00:00 - 24:00:00
#
# [143491 rows x 14 columns]

# %% [markdown]
# ## Check missing dates

# %%
unique_values_count = final_df["local_date"].unique()
# unique_values_count = final_df["local_date"].nunique()
# unique_values_count.sort()
# unique_values_count
# len(unique_values_count)

all_dates = pd.date_range(start='2019-01-01', end='2019-08-19').strftime('%Y%m%d').astype(int)

# Convert to numpy array
all_dates = np.array(all_dates)

# Find missing dates
missing_dates = np.setdiff1d(all_dates, unique_values_count)

missing_dates
# Out:
# array([], dtype=int64)

# %% [markdown]
# ## Check missing times

# %%
# Convert local_date to datetime objects
final_df['local_date'] = pd.to_datetime(final_df['local_date'], format='%Y%m%d')

# Function to parse the local_time column and extract the start hour
def parse_start_hour(time_str):
    try:
        start_time_str, _ = time_str.split(' - ')
        start_time = datetime.strptime(start_time_str, '%Y%m%d %H:%M:%S')
        return start_time.hour
    except ValueError:
        return None

final_df['start_hour'] = final_df['local_time'].map(parse_start_hour)

# Required hours to check
required_hours = set([0, 3, 6, 9, 12, 15, 18, 21])

# Group by local_date and check missing hours
missing_hours = {}

for date, group in final_df.groupby('local_date'):
    present_hours = set(group['start_hour'])
    missing = required_hours - present_hours
    if missing:
        missing_hours[date] = sorted(list(missing))

# Convert missing hours dictionary to DataFrame for better readability
missing_hours_df = pd.DataFrame(list(missing_hours.items()), columns=['Date', 'Missing Hours'])

# Display the missing hours
print("Missing hours for each date:")
print(missing_hours_df)
# Out:
# Missing hours for each date:
#         Date Missing Hours
# 0 2019-01-02          [21]
# 1 2019-04-12           [3]
# 2 2019-05-26          [21]
# 3 2019-06-06          [12]
# 4 2019-08-01      [18, 21]

# %% [markdown]
# # Fillin Gaps

# %%
import time
import pandas as pd
import os
import logging
from datetime import datetime

# Configure logging
logging.basicConfig(level=logging.INFO, format='%(asctime)s - %(levelname)s - %(message)s')

# Function to process data for a specific date and time intervals
def process_data_for_date(event_date, country_code, export_path, start_hour, end_hour):
    # Define the export file paths
    csv3_file = f"od_{country_code.lower()}_agg3_3h.csv"
    csv5_file = f"od_{country_code.lower()}_agg5_3h.csv"
    csv3_file_path = f"{export_path}{csv3_file}"
    csv5_file_path = f"{export_path}{csv5_file}"

    # Loop through the specified hours in increments of 3 hours
    for hour in range(start_hour, end_hour, 3):
        next_hour = hour + 3  # end hour for the 3-hour interval
        logging.info(f"Querying data for date: {event_date}, hours: {hour}-{next_hour}")

        # Fetch the data for the specified event date and country code
        pe_tj_df3 = sql_engine.read_sql(
            f"""
            SELECT 
                cuebiq_id,
                duration_minutes,
                length_meters,
                number_of_points,
                TRY(date_parse(substr(start_zoned_datetime, 1, 19), '%Y-%m-%dT%H:%i:%s')) AS event_datetime_local,
                EXTRACT(HOUR FROM TRY(date_parse(substr(start_zoned_datetime, 1, 19), '%Y-%m-%dT%H:%i:%s'))) AS event_hour,
                geohash_encode(start_lat, start_lng, 5) AS start_geohash5,
                geohash_encode(start_lat, start_lng, 3) AS start_geohash3,
                geohash_encode(end_lat, end_lng, 5) AS end_geohash5,
                geohash_encode(end_lat, end_lng, 3) AS end_geohash3,
                DATE_FORMAT(date_parse(substr(start_zoned_datetime, 1, 10), '%Y-%m-%d'), '%Y%m%d') AS local_date
            FROM cuebiq.paas_cda_pe_v3.trajectory_uplevelled
            WHERE 
                event_date = {event_date}
                AND end_country = '{country_code}' 
                AND start_country = '{country_code}' 
            """
        )

        # Filter the DataFrame for the current 3-hour interval
        logging.info(f"Processing data for date: {event_date}, hours: {hour}-{next_hour}")
        filtered_df = pe_tj_df3[(pe_tj_df3['event_hour'] >= hour) & (pe_tj_df3['event_hour'] < next_hour)]

        # Add user numbers to the aggregated data for geohash3
        aggregated_df3 = filtered_df.groupby(['start_geohash3', 'end_geohash3', 'local_date']).agg({
            'cuebiq_id': 'count',
            'duration_minutes': ['mean', 'median', 'std'],
            'length_meters': ['mean', 'median', 'std'],
            'number_of_points': ['mean', 'median', 'std']
        }).reset_index()

        # Flatten the MultiIndex columns
        aggregated_df3.columns = ['start_geohash3', 'end_geohash3', 'local_date', 'trip_count', 
                                  'm_duration_min', 'mdn_duration_min', 'sd_duration_min', 
                                  'm_length_m', 'mdn_length_m', 'sd_length_m',
                                  'm_points_no', 'mdn_points_no', 'sd_points_no']

        # Add the local_time column
        aggregated_df3['local_time'] = aggregated_df3['local_date'].astype(str) + \
                                       f" {hour:02d}:00:00 - {next_hour:02d}:00:00"

        # Filter out rows where trip_count is less than or equal to 9
        aggregated_df3 = aggregated_df3[aggregated_df3['trip_count'] > 9]

        # Append the results to the CSV file for geohash3
        logging.info(f"Exporting aggregated data (geohash3) for date: {event_date}, hours: {hour}-{next_hour}")
        if not os.path.isfile(csv3_file_path):
            aggregated_df3.to_csv(csv3_file_path, index=False)
        else:
            aggregated_df3.to_csv(csv3_file_path, mode='a', header=False, index=False)

        # Add user numbers to the aggregated data for geohash5
        aggregated_df5 = filtered_df.groupby(['start_geohash5', 'end_geohash5', 'local_date']).agg({
            'cuebiq_id': 'count',
            'duration_minutes': ['mean', 'median', 'std'],
            'length_meters': ['mean', 'median', 'std'],
            'number_of_points': ['mean', 'median', 'std']
        }).reset_index()

        # Flatten the MultiIndex columns
        aggregated_df5.columns = ['start_geohash5', 'end_geohash5', 'local_date', 'trip_count', 
                                  'm_duration_min', 'mdn_duration_min', 'sd_duration_min', 
                                  'm_length_m', 'mdn_length_m', 'sd_length_m',
                                  'm_points_no', 'mdn_points_no', 'sd_points_no']

        # Add the local_time column
        aggregated_df5['local_time'] = aggregated_df5['local_date'].astype(str) + \
                                       f" {hour:02d}:00:00 - {next_hour:02d}:00:00"

        # Filter out rows where trip_count is less than or equal to 9
        aggregated_df5 = aggregated_df5[aggregated_df5['trip_count'] > 9]

        # Append the results to the CSV file for geohash5
        logging.info(f"Exporting aggregated data (geohash5) for date: {event_date}, hours: {hour}-{next_hour}")
        if not os.path.isfile(csv5_file_path):
            aggregated_df5.to_csv(csv5_file_path, index=False)
        else:
            aggregated_df5.to_csv(csv5_file_path, mode='a', header=False, index=False)

# %%
# Specify the date and initial time interval
event_date = "20190429"
start_hour = 18
end_hour = 21  # Process until the end of the day
country_code = 'IN'
export_path = '/home/jovyan/Data/TJ/3h/'

# Process data for the specified date and time intervals
process_data_for_date(event_date, country_code, export_path, start_hour, end_hour)
# Out:
# 2024-07-02 19:01:12,005 - INFO - Querying data for date: 20190429, hours: 18-21
# 2024-07-02 19:01:41,484 - INFO - Processing data for date: 20190429, hours: 18-21
# 2024-07-02 19:01:41,543 - INFO - Exporting aggregated data (geohash3) for date: 20190429, hours: 18-21
# 2024-07-02 19:01:41,632 - INFO - Exporting aggregated data (geohash5) for date: 20190429, hours: 18-21

# %% [markdown]
# # For Explanation

# %%
import time
import pandas as pd
import os

start_time = time.time()

event_date = 20190103

country_code = 'IN'

# Define the export file paths
csv3_file = f"od_{country_code.lower()}_2019_agg3_3h.csv"
csv5_file = f"od_{country_code.lower()}_2019_agg5_3h.csv"
export_path = '/home/jovyan/Data/TJ/3h/'
csv3_file_path = f"{export_path}{csv3_file}"
csv5_file_path = f"{export_path}{csv5_file}"

# Loop through 24 hours in increments of 3 hours
for start_hour in range(0, 24, 3):
    end_hour = start_hour + 3  # end hour for the 3-hour interval

    # Fetch the data for the specified event date and country code
    pe_tj_df3 = sql_engine.read_sql(
        f"""
        SELECT 
            cuebiq_id,
            duration_minutes,
            length_meters,
            number_of_points,
            TRY(date_parse(substr(start_zoned_datetime, 1, 19), '%Y-%m-%dT%H:%i:%s')) AS event_datetime_local,
            EXTRACT(HOUR FROM TRY(date_parse(substr(start_zoned_datetime, 1, 19), '%Y-%m-%dT%H:%i:%s'))) AS event_hour,
            geohash_encode(start_lat, start_lng, 5) AS start_geohash5,
            geohash_encode(start_lat, start_lng, 3) AS start_geohash3,
            geohash_encode(end_lat, end_lng, 5) AS end_geohash5,
            geohash_encode(end_lat, end_lng, 3) AS end_geohash3,
            DATE_FORMAT(date_parse(substr(start_zoned_datetime, 1, 10), '%Y-%m-%d'), '%Y%m%d') AS local_date
        FROM cuebiq.paas_cda_pe_v3.trajectory_uplevelled
        WHERE 
            event_date = {event_date}
            AND end_country = '{country_code}' 
            AND start_country = '{country_code}' 
        """
    )

    # Filter the DataFrame for the current 3-hour interval
    filtered_df = pe_tj_df3[(pe_tj_df3['event_hour'] >= start_hour) & (pe_tj_df3['event_hour'] < end_hour)]

    # Add user numbers to the aggregated data for geohash3
    aggregated_df3 = filtered_df.groupby(['start_geohash3', 'end_geohash3', 'local_date']).agg({
        'cuebiq_id': 'count',
        'duration_minutes': ['mean', 'median', 'std'],
        'length_meters': ['mean', 'median', 'std'],
        'number_of_points': ['mean', 'median', 'std']
    }).reset_index()

    # Flatten the MultiIndex columns
    aggregated_df3.columns = ['start_geohash3', 'end_geohash3', 'local_date', 'trip_count', 
                              'm_duration_min', 'mdn_duration_min', 'sd_duration_min', 
                              'm_length_m', 'mdn_length_m', 'sd_length_m',
                              'm_points_no', 'mdn_points_no', 'sd_points_no']

    # Add the local_time column
    aggregated_df3['local_time'] = aggregated_df3['local_date'].astype(str) + \
                                   f" {start_hour:02d}:00:00 - {end_hour:02d}:00:00"

    # Filter out rows where trip_count is less than or equal to 9
    aggregated_df3 = aggregated_df3[aggregated_df3['trip_count'] > 9]

    # # Append the results to the CSV file for geohash3
    # if not os.path.isfile(csv3_file_path):
    #     aggregated_df3.to_csv(csv3_file_path, index=False)
    # else:
    #     aggregated_df3.to_csv(csv3_file_path, mode='a', header=False, index=False)

    # Add user numbers to the aggregated data for geohash5
    aggregated_df5 = filtered_df.groupby(['start_geohash5', 'end_geohash5', 'local_date']).agg({
        'cuebiq_id': 'count',
        'duration_minutes': ['mean', 'median', 'std'],
        'length_meters': ['mean', 'median', 'std'],
        'number_of_points': ['mean', 'median', 'std']
    }).reset_index()

    # Flatten the MultiIndex columns
    aggregated_df5.columns = ['start_geohash5', 'end_geohash5', 'local_date', 'trip_count', 
                              'm_duration_min', 'mdn_duration_min', 'sd_duration_min', 
                              'm_length_m', 'mdn_length_m', 'sd_length_m',
                              'm_points_no', 'mdn_points_no', 'sd_points_no']

    # Add the local_time column
    aggregated_df5['local_time'] = aggregated_df5['local_date'].astype(str) + \
                                   f" {start_hour:02d}:00:00 - {end_hour:02d}:00:00"

    # Filter out rows where trip_count is less than or equal to 9
    aggregated_df5 = aggregated_df5[aggregated_df5['trip_count'] > 9]

    # # Append the results to the CSV file for geohash5
    # if not os.path.isfile(csv5_file_path):
    #     aggregated_df5.to_csv(csv5_file_path, index=False)
    # else:
    #     aggregated_df5.to_csv(csv5_file_path, mode='a', header=False, index=False)

pandas_time = time.time() - start_time
print(f"Pandas operations execution time: {pandas_time} seconds")
# Out:
# Pandas operations execution time: 149.8554482460022 seconds

# %%
aggregated_df3
# Out:
#     start_geohash3 end_geohash3 local_date  trip_count  m_duration_min  \
# 3              t9v          t9v   20190103          12       28.291667
# 6              t9w          t9w   20190103          79       36.799789
# 8              t9x          t9x   20190103          28       29.816667
# 9              t9y          t9y   20190103         245       36.955646
# 12             t9z          t9z   20190103          62       40.524194
# ..             ...          ...        ...         ...             ...
# 232            wh1          wh1   20190103          60       36.983333
# 237            wh6          wh6   20190103          20       31.115000
# 239            wh9          wh9   20190103          87       33.046360
# 241            whd          whd   20190103          19       35.208772
# 244            whg          whg   20190103          10       32.166667
#
#      mdn_duration_min  sd_duration_min    m_length_m  mdn_length_m  \
# 3           11.866667        36.693957   1556.880126   1002.937187
# 6           24.000000        33.789140   4250.759102    675.382234
# 8           18.075000        26.762632   3916.483534    640.739134
# 9           26.316667        32.344040   4263.265409   1019.369438
# 12          27.575000        35.611544   3380.254967   1038.797423
# ..                ...              ...           ...           ...
# 232         30.641667        28.802591  12088.731471   1022.960649
# 237         20.183333        28.292291   1606.360298    530.420567
# 239         24.000000        31.685464   9950.059312    818.173118
# 241         16.800000        30.987919   2620.389418    230.103694
# 244         19.141667        29.682906   4990.643719    227.694245
#
#       sd_length_m  m_points_no  mdn_points_no  sd_points_no  \
# 3     2043.622132     5.916667            4.5      5.195423
# 6     7595.562787     4.063291            3.0      2.538634
# 8    12866.515040     3.571429            3.0      2.588129
# 9     8182.492890     5.236735            4.0      8.018490
# 12    9386.756001     4.741935            4.0      3.552582
# ..            ...          ...            ...           ...
# 232  33209.130475     5.483333            5.0      2.971570
# 237   3159.900184     4.000000            3.5      2.635786
# 239  42120.831986     4.712644            4.0      2.765687
# 241   5793.475337     3.736842            2.0      2.490919
# 244  10903.487018     3.700000            3.0      2.057507
#
#                        local_time
# 3    20190103 21:00:00 - 24:00:00
# 6    20190103 21:00:00 - 24:00:00
# 8    20190103 21:00:00 - 24:00:00
# 9    20190103 21:00:00 - 24:00:00
# 12   20190103 21:00:00 - 24:00:00
# ..                            ...
# 232  20190103 21:00:00 - 24:00:00
# 237  20190103 21:00:00 - 24:00:00
# 239  20190103 21:00:00 - 24:00:00
# 241  20190103 21:00:00 - 24:00:00
# 244  20190103 21:00:00 - 24:00:00
#
# [107 rows x 14 columns]

# %%
aggregated_df5
# Out:
#      start_geohash5 end_geohash5 local_date  trip_count  m_duration_min  \
# 133           t9y30        t9y30   20190103          16       25.743750
# 195           t9ywx        t9ywx   20190103          18       27.483333
# 204           t9yy8        t9yy8   20190103          10       42.798333
# 235           t9z83        t9z83   20190103          10       32.678333
# 255           t9zvw        t9zvw   20190103          10       35.218333
# ...             ...          ...        ...         ...             ...
# 4032          wh1yv        wh1yv   20190103          17       36.124510
# 4037          wh1zj        wh1zj   20190103          21       22.729365
# 4055          wh6v1        wh6v1   20190103          13       29.178205
# 4069          wh9hz        wh9hz   20190103          12       35.159722
# 4084          wh9kb        wh9kb   20190103          15       39.338889
#
#       mdn_duration_min  sd_duration_min    m_length_m  mdn_length_m  \
# 133          18.100000        23.049263    914.540138    193.398505
# 195          14.108333        28.211835   2067.711361    655.826934
# 204          28.233333        38.503018   1398.170835    512.301681
# 235          25.216667        25.136182   1810.188211    623.218678
# 255          22.100000        34.476755   1080.602465    960.067620
# ...                ...              ...           ...           ...
# 4032         30.116667        30.635309   4969.236797    570.681507
# 4037         21.166667        13.335075  11931.911392    663.349774
# 4055         19.666667        27.840942    901.354044    457.448653
# 4069         22.600000        36.646429  28525.792259    516.490435
# 4084         14.933333        43.493141   3515.799882    980.702157
#
#        sd_length_m  m_points_no  mdn_points_no  sd_points_no  \
# 133    1682.530966     7.125000            4.0     13.652228
# 195    3242.225684     4.611111            4.0      2.831314
# 204    2152.095069     5.800000            5.0      3.392803
# 235    3426.718113     4.700000            3.0      3.917199
# 255     875.369104     4.100000            4.0      1.449138
# ...            ...          ...            ...           ...
# 4032  17027.435031     5.352941            4.0      3.823303
# 4037  34994.700861     4.285714            5.0      1.616875
# 4055   1237.177019     3.538462            4.0      1.560736
# 4069  96317.718967     5.833333            5.0      4.041452
# 4084   5302.015214     4.533333            5.0      2.642149
#
#                         local_time
# 133   20190103 21:00:00 - 24:00:00
# 195   20190103 21:00:00 - 24:00:00
# 204   20190103 21:00:00 - 24:00:00
# 235   20190103 21:00:00 - 24:00:00
# 255   20190103 21:00:00 - 24:00:00
# ...                            ...
# 4032  20190103 21:00:00 - 24:00:00
# 4037  20190103 21:00:00 - 24:00:00
# 4055  20190103 21:00:00 - 24:00:00
# 4069  20190103 21:00:00 - 24:00:00
# 4084  20190103 21:00:00 - 24:00:00
#
# [212 rows x 14 columns]

# %% [markdown]
# # Export to Schema

# %%
# # Set up logging
# logging.basicConfig(level=logging.INFO, format='%(asctime)s - %(levelname)s - %(message)s')

# # Database connection setup
# output_schema_name = 'od_matrix_10'
# con = create_engine(f"trino://localhost:9090/dedicated/{output_schema_name}")

# %%
# 这个还没改
# # Function to process data for a single day
# def process_day(event_date, country_code, sql_engine):
#     try:
#         # Read data from the SQL table
#         pe_tj_df = sql_engine.read_sql(
#             f"""
#             SELECT 
#                 cuebiq_id,
#                 start_lat,
#                 start_lng,
#                 end_lat,
#                 end_lng,
#                 duration_minutes,
#                 length_meters,
#                 number_of_points
#             FROM cuebiq.paas_cda_pe_v3.trajectory_uplevelled
#             WHERE 
#                 event_date = {event_date}
#                 AND end_country = '{country_code}' 
#                 AND start_country = '{country_code}' 
#             """
#         )
#         logging.info(f"Executing SQL query for date {event_date}")

#         # Encode geohashes
#         pe_tj_df['start_geohash3'] = pe_tj_df.apply(
#             lambda x: geohash.encode(x['start_lat'], x['start_lng'], precision=3), axis=1)
#         pe_tj_df['end_geohash3'] = pe_tj_df.apply(
#             lambda x: geohash.encode(x['end_lat'], x['end_lng'], precision=3), axis=1)

#         # Aggregate data
#         aggregated_df3 = pe_tj_df.groupby(['start_geohash3', 'end_geohash3']).agg({
#             'cuebiq_id': 'count',
#             'duration_minutes': ['mean', 'median', 'std'],
#             'length_meters': ['mean', 'median', 'std'],
#             'number_of_points': ['mean', 'median', 'std']
#         }).reset_index()
#         aggregated_df3.columns = ['start_geohash3', 'end_geohash3', 'trip_count', 
#                                   'm_duration_min', 'mdn_duration_min', 'sd_duration_min', 
#                                   'm_length_m', 'mdn_length_m', 'sd_length_m',
#                                   'm_points_no', 'mdn_points_no', 'sd_points_no']

#         # Filter aggregated data and reorder columns
#         filtered_df3= aggregated_df3.loc[aggregated_df3['trip_count'] > 9]
#         filtered_df3 = filtered_df3[['start_geohash3', 'end_geohash3', 'trip_count', 
#                                      'm_duration_min', 'mdn_duration_min', 'sd_duration_min', 
#                                      'm_length_m', 'mdn_length_m', 'sd_length_m',
#                                      'm_points_no', 'mdn_points_no', 'sd_points_no']]
#         return filtered_df3

#     except Exception as e:
#         logging.error(f"Error processing data for date {event_date}: {e}")
#         return pd.DataFrame()

# # Function to insert data with retry mechanism
# def insert_data_with_retry(df, table_name, con, retries=3, delay=5):
#     for attempt in range(retries):
#         try:
#             df.to_sql(
#                 table_name, 
#                 con, 
#                 index=False, 
#                 if_exists="append", 
#                 method="multi"
#             )
#             logging.info(f"Inserted data into table {table_name}")
#             break
#         except Exception as e:
#             logging.error(f"Attempt {attempt+1} failed with error: {e}")
#             if attempt < retries - 1:
#                 time.sleep(delay)
#             else:
#                 logging.error(f"Failed to insert data into table {table_name} after {retries} attempts")

# # Main processing loop
# def process_date_range(start_date, end_date, country_code, sql_engine):
#     start_time = time.time()  # Record start time before processing loop
        
#     current_date = start_date
#     while current_date <= end_date:
#         event_date = current_date.strftime('%Y%m%d')
        
#         filtered_df3 = process_day(event_date, country_code, sql_engine)

#         # Insert data into the database
#         if not filtered_df3.empty:
#             # table_name = f"{output_schema_name}.{country_code}_agg3"
#             table_name = f"od_{country_code.lower()}_{event_date}_agg3_10"
#             insert_data_with_retry(filtered_df3, table_name, con)
#         else:
#             logging.info(f"No data to insert for date {event_date}")

#         # Move to the next day
#         current_date += timedelta(days=1)
#     end_time = time.time()  # Record end time after processing loop
#     total_time = end_time - start_time
#     logging.info(f"Total processing time: {total_time:.2f} seconds")

# %%
# # Example usage:
# process_date_range(datetime(2019, 12, 31), datetime(2019, 12, 31), 'ID', sql_engine)
