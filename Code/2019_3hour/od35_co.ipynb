# %%
# %reload_ext sql
# %config SqlMagic.autocommit=False
# %config SqlMagic.autolimit=0
# %config SqlMagic.autopandas=True
# %config SqlMagic.displaylimit=200

# %%
# %sql trino://localhost:9090/cuebiq/
# Out:
# 'Connected: @cuebiq/'

# %%
pip install python-geohash
# Out:
# Requirement already satisfied: python-geohash in /srv/conda/envs/notebook/lib/python3.9/site-packages (0.8.5)
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
import time
import geohash
import logging
import pandas as pd
from datetime import datetime, timedelta
from sqlalchemy import create_engine

# %%
# SQL engine
from trino.dbapi import connect 
from sqlalchemy import create_engine
import pandas as pd
import time

class TrinoEngine():
    def __init__(self):
        conn = connect(
            host="localhost",
            port=9090,
            catalog="cuebiq"
        )
        self.cur = conn.cursor()
        self.engine = create_engine("trino://localhost:9090/cuebiq/")
    
    def execute_statement(self, query:str) -> list:
        """
        Create and drop statements.
        """
        self.cur.execute(query)
        return self.cur.fetchall()
    
    def read_sql(self, query:str) -> pd.DataFrame: 
        """
        Select and insert into operations.
        """
        return pd.read_sql(query, self.engine)

sql_engine = TrinoEngine()

# %%
schema_name = {'cda': 'cuebiq.paas_cda_pe_v3'}
pe_tj_table = f"{schema_name['cda']}.trajectory_uplevelled"

# %% [markdown]
# # Export to local

# %%
# Set up logging
logging.basicConfig(level=logging.INFO, format='%(asctime)s - %(levelname)s - %(message)s')

# %%
# Function to process data for a specific date
def process_data_for_date(event_date, country_code, export_path):
    
    # Define the export file paths
    csv3_file = f"od_{country_code.lower()}_agg3_3h.csv"
    csv5_file = f"od_{country_code.lower()}_agg5_3h.csv"
    csv3_file_path = f"{export_path}{csv3_file}"
    csv5_file_path = f"{export_path}{csv5_file}"

    # Loop through 24 hours in increments of 3 hours
    for start_hour in range(0, 24, 3):
        end_hour = start_hour + 3  # end hour for the 3-hour interval
        logging.info(f"Querying data for date: {event_date}, hours: {start_hour}-{end_hour}")

        # Fetch the data for the specified event date and country code
        pe_tj_df3 = sql_engine.read_sql(
            f"""
            SELECT 
                cuebiq_id,
                duration_minutes,
                length_meters,
                number_of_points,
                TRY(date_parse(substr(start_zoned_datetime, 1, 19), '%Y-%m-%dT%H:%i:%s')) AS event_datetime_local,
                EXTRACT(HOUR FROM TRY(date_parse(substr(start_zoned_datetime, 1, 19), '%Y-%m-%dT%H:%i:%s'))) AS event_hour,
                geohash_encode(start_lat, start_lng, 5) AS start_geohash5,
                geohash_encode(start_lat, start_lng, 3) AS start_geohash3,
                geohash_encode(end_lat, end_lng, 5) AS end_geohash5,
                geohash_encode(end_lat, end_lng, 3) AS end_geohash3,
                DATE_FORMAT(date_parse(substr(start_zoned_datetime, 1, 10), '%Y-%m-%d'), '%Y%m%d') AS local_date
            FROM cuebiq.paas_cda_pe_v3.trajectory_uplevelled
            WHERE 
                event_date = {event_date}
                AND end_country = '{country_code}' 
                AND start_country = '{country_code}' 
            """
        )

        # Filter the DataFrame for the current 3-hour interval
        logging.info(f"Processing data for date: {event_date}, hours: {start_hour}-{end_hour}")
        filtered_df = pe_tj_df3[(pe_tj_df3['event_hour'] >= start_hour) & (pe_tj_df3['event_hour'] < end_hour)]

        # Add user numbers to the aggregated data for geohash3
        aggregated_df3 = filtered_df.groupby(['start_geohash3', 'end_geohash3', 'local_date']).agg({
            'cuebiq_id': 'count',
            'duration_minutes': ['mean', 'median', 'std'],
            'length_meters': ['mean', 'median', 'std'],
            'number_of_points': ['mean', 'median', 'std']
        }).reset_index()

        # Flatten the MultiIndex columns
        aggregated_df3.columns = ['start_geohash3', 'end_geohash3', 'local_date', 'trip_count', 
                                  'm_duration_min', 'mdn_duration_min', 'sd_duration_min', 
                                  'm_length_m', 'mdn_length_m', 'sd_length_m',
                                  'm_points_no', 'mdn_points_no', 'sd_points_no']

        # Add the local_time column
        aggregated_df3['local_time'] = aggregated_df3['local_date'].astype(str) + \
                                       f" {start_hour:02d}:00:00 - {end_hour:02d}:00:00"

        # Filter out rows where trip_count is less than or equal to 9
        aggregated_df3 = aggregated_df3[aggregated_df3['trip_count'] > 9]

        # Append the results to the CSV file for geohash3
        logging.info(f"Exporting aggregated data (geohash3) for date: {event_date}, hours: {start_hour}-{end_hour}")
        if not os.path.isfile(csv3_file_path):
            aggregated_df3.to_csv(csv3_file_path, index=False)
        else:
            aggregated_df3.to_csv(csv3_file_path, mode='a', header=False, index=False)

        # Add user numbers to the aggregated data for geohash5
        aggregated_df5 = filtered_df.groupby(['start_geohash5', 'end_geohash5', 'local_date']).agg({
            'cuebiq_id': 'count',
            'duration_minutes': ['mean', 'median', 'std'],
            'length_meters': ['mean', 'median', 'std'],
            'number_of_points': ['mean', 'median', 'std']
        }).reset_index()

        # Flatten the MultiIndex columns
        aggregated_df5.columns = ['start_geohash5', 'end_geohash5', 'local_date', 'trip_count', 
                                  'm_duration_min', 'mdn_duration_min', 'sd_duration_min', 
                                  'm_length_m', 'mdn_length_m', 'sd_length_m',
                                  'm_points_no', 'mdn_points_no', 'sd_points_no']

        # Add the local_time column
        aggregated_df5['local_time'] = aggregated_df5['local_date'].astype(str) + \
                                       f" {start_hour:02d}:00:00 - {end_hour:02d}:00:00"

        # Filter out rows where trip_count is less than or equal to 9
        aggregated_df5 = aggregated_df5[aggregated_df5['trip_count'] > 9]

        # Append the results to the CSV file for geohash5
        logging.info(f"Exporting aggregated data (geohash5) for date: {event_date}, hours: {start_hour}-{end_hour}")
        if not os.path.isfile(csv5_file_path):
            aggregated_df5.to_csv(csv5_file_path, index=False)
        else:
            aggregated_df5.to_csv(csv5_file_path, mode='a', header=False, index=False)

# %%
# Dates to process (example: a range of dates)
start_date = datetime.strptime("20191214", "%Y%m%d")
end_date = datetime.strptime("20191231", "%Y%m%d")

# Process each date in the range
current_date = start_date
while current_date <= end_date:
    event_date = current_date.strftime("%Y%m%d")
    logging.info(f"Processing data for date: {event_date}")
    process_data_for_date(event_date, 'CO', '/home/jovyan/Data/TJ/3h/')
    current_date += timedelta(days=1)
# Out:
# 2024-07-02 01:34:55,934 - INFO - Processing data for date: 20191214
# 2024-07-02 01:34:55,935 - INFO - Querying data for date: 20191214, hours: 0-3
# 2024-07-02 01:35:26,118 - INFO - Processing data for date: 20191214, hours: 0-3
# 2024-07-02 01:35:26,130 - INFO - Exporting aggregated data (geohash3) for date: 20191214, hours: 0-3
# 2024-07-02 01:35:26,151 - INFO - Exporting aggregated data (geohash5) for date: 20191214, hours: 0-3
# 2024-07-02 01:35:26,162 - INFO - Querying data for date: 20191214, hours: 3-6
# 2024-07-02 01:35:43,522 - INFO - Processing data for date: 20191214, hours: 3-6
# 2024-07-02 01:35:43,535 - INFO - Exporting aggregated data (geohash3) for date: 20191214, hours: 3-6
# 2024-07-02 01:35:43,556 - INFO - Exporting aggregated data (geohash5) for date: 20191214, hours: 3-6
# 2024-07-02 01:35:43,569 - INFO - Querying data for date: 20191214, hours: 6-9
# 2024-07-02 01:35:53,681 - INFO - Processing data for date: 20191214, hours: 6-9
# 2024-07-02 01:35:53,696 - INFO - Exporting aggregated data (geohash3) for date: 20191214, hours: 6-9
# 2024-07-02 01:35:53,722 - INFO - Exporting aggregated data (geohash5) for date: 20191214, hours: 6-9
# 2024-07-02 01:35:53,736 - INFO - Querying data for date: 20191214, hours: 9-12
# 2024-07-02 01:36:00,649 - INFO - Processing data for date: 20191214, hours: 9-12
# 2024-07-02 01:36:00,667 - INFO - Exporting aggregated data (geohash3) for date: 20191214, hours: 9-12
# 2024-07-02 01:36:00,708 - INFO - Exporting aggregated data (geohash5) for date: 20191214, hours: 9-12
# 2024-07-02 01:36:00,725 - INFO - Querying data for date: 20191214, hours: 12-15
# 2024-07-02 01:36:07,400 - INFO - Processing data for date: 20191214, hours: 12-15
# 2024-07-02 01:36:07,421 - INFO - Exporting aggregated data (geohash3) for date: 20191214, hours: 12-15
# 2024-07-02 01:36:07,450 - INFO - Exporting aggregated data (geohash5) for date: 20191214, hours: 12-15
# 2024-07-02 01:36:07,469 - INFO - Querying data for date: 20191214, hours: 15-18
# 2024-07-02 01:36:14,013 - INFO - Processing data for date: 20191214, hours: 15-18
# 2024-07-02 01:36:14,035 - INFO - Exporting aggregated data (geohash3) for date: 20191214, hours: 15-18
# 2024-07-02 01:36:14,110 - INFO - Exporting aggregated data (geohash5) for date: 20191214, hours: 15-18
# 2024-07-02 01:36:14,129 - INFO - Querying data for date: 20191214, hours: 18-21
# 2024-07-02 01:36:20,442 - INFO - Processing data for date: 20191214, hours: 18-21
# 2024-07-02 01:36:20,469 - INFO - Exporting aggregated data (geohash3) for date: 20191214, hours: 18-21
# 2024-07-02 01:36:20,496 - INFO - Exporting aggregated data (geohash5) for date: 20191214, hours: 18-21
# 2024-07-02 01:36:20,511 - INFO - Querying data for date: 20191214, hours: 21-24
# 2024-07-02 01:36:38,698 - INFO - Processing data for date: 20191214, hours: 21-24
# 2024-07-02 01:36:38,714 - INFO - Exporting aggregated data (geohash3) for date: 20191214, hours: 21-24
# 2024-07-02 01:36:38,739 - INFO - Exporting aggregated data (geohash5) for date: 20191214, hours: 21-24
# 2024-07-02 01:36:38,761 - INFO - Processing data for date: 20191215
# 2024-07-02 01:36:38,762 - INFO - Querying data for date: 20191215, hours: 0-3
# 2024-07-02 01:37:01,542 - INFO - Processing data for date: 20191215, hours: 0-3
# 2024-07-02 01:37:01,554 - INFO - Exporting aggregated data (geohash3) for date: 20191215, hours:
# 2024-07-02 01:39:54,577 - INFO - Processing data for date: 20191216, hours: 6-9
# 2024-07-02 01:39:54,593 - INFO - Exporting aggregated data (geohash3) for date: 20191216, hours: 6-9
# 2024-07-02 01:39:54,620 - INFO - Exporting aggregated data (geohash5) for date: 20191216, hours: 6-9
# 2024-07-02 01:39:54,636 - INFO - Querying data for date: 20191216, hours: 9-12
# 2024-07-02 01:40:12,460 - INFO - Processing data for date: 20191216, hours: 9-12
# 2024-07-02 01:40:12,478 - INFO - Exporting aggregated data (geohash3) for date: 20191216, hours: 9-12
# 2024-07-02 01:40:12,504 - INFO - Exporting aggregated data (geohash5) for date: 20191216, hours: 9-12
# 2024-07-02 01:40:12,519 - INFO - Querying data for date: 20191216, hours: 12-15
# 2024-07-02 01:40:25,626 - INFO - Processing data for date: 20191216, hours: 12-15
# 2024-07-02 01:40:25,648 - INFO - Exporting aggregated data (geohash3) for date: 20191216, hours: 12-15
# 2024-07-02 01:40:25,676 - INFO - Exporting aggregated data (geohash5) for date: 20191216, hours: 12-15
# 2024-07-02 01:40:25,693 - INFO - Querying data for date: 20191216, hours: 15-18
# 2024-07-02 01:40:34,243 - INFO - Processing data for date: 20191216, hours: 15-18
# 2024-07-02 01:40:34,264 - INFO - Exporting aggregated data (geohash3) for date: 20191216, hours: 15-18
# 2024-07-02 01:40:34,293 - INFO - Exporting aggregated data (geohash5) for date: 20191216, hours: 15-18
# 2024-07-02 01:40:34,309 - INFO - Querying data for date: 20191216, hours: 18-21
# 2024-07-02 01:40:41,618 - INFO - Processing data for date: 20191216, hours: 18-21
# 2024-07-02 01:40:41,637 - INFO - Exporting aggregated data (geohash3) for date: 20191216, hours: 18-21
# 2024-07-02 01:40:41,663 - INFO - Exporting aggregated data (geohash5) for date: 20191216, hours: 18-21
# 2024-07-02 01:40:41,710 - INFO - Querying data for date: 20191216, hours: 21-24
# 2024-07-02 01:40:48,503 - INFO - Processing data for date: 20191216, hours: 21-24
# 2024-07-02 01:40:48,526 - INFO - Exporting aggregated data (geohash3) for date: 20191216, hours: 21-24
# 2024-07-02 01:40:48,555 - INFO - Exporting aggregated data (geohash5) for date: 20191216, hours: 21-24
# 2024-07-02 01:40:48,608 - INFO - Processing data for date: 20191217
# 2024-07-02 01:40:48,609 - INFO - Querying data for date: 20191217, hours: 0-3
# 2024-07-02 01:40:57,616 - INFO - Processing data for date: 20191217, hours: 0-3
# 2024-07-02 01:40:57,628 - INFO - Exporting aggregated data (geohash3) for date: 20191217, hours: 0-3
# 2024-07-02 01:40:57,650 - INFO - Exporting aggregated data (geohash5) for date: 20191217, hours: 0-3
# 2024-07-02 01:40:57,663 - INFO - Querying data for date: 20191217, hours: 3-6
# 2024-07-02 01:41:16,741 - INFO - Processing data for date: 20191217, hours: 3-6
# 2024-07-02 01:41:16,754 - INFO - Exporting aggregated data (geohash3) for date: 20191217, hours: 3-6
# 2024-07-02 01:41:16,775 - INFO - Exporting aggregated data (geohash5) for date: 20191217, hours: 3-6
# 2024-07-02 01:41:16,788 - INFO - Querying data for date: 20191217, hours: 6-9
# 2024-07-02 01:41:33,894 - INFO - Processing data for date: 20191217, hours: 6-9
# 2024-07-02 01:41:33,915 - INFO - Exporting aggregated data (geohash3) for date: 20191217, hours:
- INFO - Exporting aggregated data (geohash3) for date: 20191230, hours: 18-21
# 2024-07-02 02:10:43,854 - INFO - Exporting aggregated data (geohash5) for date: 20191230, hours: 18-21
# 2024-07-02 02:10:43,869 - INFO - Querying data for date: 20191230, hours: 21-24
# 2024-07-02 02:10:51,373 - INFO - Processing data for date: 20191230, hours: 21-24
# 2024-07-02 02:10:51,388 - INFO - Exporting aggregated data (geohash3) for date: 20191230, hours: 21-24
# 2024-07-02 02:10:51,410 - INFO - Exporting aggregated data (geohash5) for date: 20191230, hours: 21-24
# 2024-07-02 02:10:51,435 - INFO - Processing data for date: 20191231
# 2024-07-02 02:10:51,436 - INFO - Querying data for date: 20191231, hours: 0-3
# 2024-07-02 02:11:10,310 - INFO - Processing data for date: 20191231, hours: 0-3
# 2024-07-02 02:11:10,321 - INFO - Exporting aggregated data (geohash3) for date: 20191231, hours: 0-3
# 2024-07-02 02:11:10,331 - INFO - Exporting aggregated data (geohash5) for date: 20191231, hours: 0-3
# 2024-07-02 02:11:10,334 - INFO - Querying data for date: 20191231, hours: 3-6
# 2024-07-02 02:11:22,610 - INFO - Processing data for date: 20191231, hours: 3-6
# 2024-07-02 02:11:22,620 - INFO - Exporting aggregated data (geohash3) for date: 20191231, hours: 3-6
# 2024-07-02 02:11:22,630 - INFO - Exporting aggregated data (geohash5) for date: 20191231, hours: 3-6
# 2024-07-02 02:11:22,632 - INFO - Querying data for date: 20191231, hours: 6-9
# 2024-07-02 02:11:30,962 - INFO - Processing data for date: 20191231, hours: 6-9
# 2024-07-02 02:11:30,972 - INFO - Exporting aggregated data (geohash3) for date: 20191231, hours: 6-9
# 2024-07-02 02:11:30,985 - INFO - Exporting aggregated data (geohash5) for date: 20191231, hours: 6-9
# 2024-07-02 02:11:30,987 - INFO - Querying data for date: 20191231, hours: 9-12
# 2024-07-02 02:11:44,754 - INFO - Processing data for date: 20191231, hours: 9-12
# 2024-07-02 02:11:44,763 - INFO - Exporting aggregated data (geohash3) for date: 20191231, hours: 9-12
# 2024-07-02 02:11:44,775 - INFO - Exporting aggregated data (geohash5) for date: 20191231, hours: 9-12
# 2024-07-02 02:11:44,777 - INFO - Querying data for date: 20191231, hours: 12-15
# 2024-07-02 02:11:56,761 - INFO - Processing data for date: 20191231, hours: 12-15
# 2024-07-02 02:11:56,774 - INFO - Exporting aggregated data (geohash3) for date: 20191231, hours: 12-15
# 2024-07-02 02:11:56,797 - INFO - Exporting aggregated data (geohash5) for date: 20191231, hours: 12-15
# 2024-07-02 02:11:56,809 - INFO - Querying data for date: 20191231, hours: 15-18
# 2024-07-02 02:12:07,464 - INFO - Processing data for date: 20191231, hours: 15-18
# 2024-07-02 02:12:07,483 - INFO - Exporting aggregated data (geohash3) for date: 20191231, hours: 15-18
# 2024-07-02 02:12:07,513 - INFO - Exporting aggregated data (geohash5) for date: 20191231, hours: 15-18
# 2024-07-02 02:12:07,530 - INFO - Querying data for date: 20191231, hours: 18-21
# 2024-07-02 02:12:19,520 - INFO - Processing data for date: 20191231, hours: 18-21
# 2024-07-02 02:12:19,541 - INFO - Exporting aggregated data (geohash3) for date: 20191231, hours: 18-21
# 2024-07-02 02:12:19,572 - INFO - Exporting aggregated data (geohash5) for date: 20191231, hours: 18-21
# 2024-07-02 02:12:19,605 - INFO - Querying data for date: 20191231, hours: 21-24
# 2024-07-02 02:12:39,509 - INFO - Processing data for date: 20191231, hours: 21-24
# 2024-07-02 02:12:39,524 - INFO - Exporting aggregated data (geohash3) for date: 20191231, hours: 21-24
# 2024-07-02 02:12:39,550 - INFO - Exporting aggregated data (geohash5) for date: 20191231, hours: 21-24

# %% [markdown]
# # Fillin Gaps

# %%
import time
import pandas as pd
import os
import logging
from datetime import datetime

# Configure logging
logging.basicConfig(level=logging.INFO, format='%(asctime)s - %(levelname)s - %(message)s')

# Function to process data for a specific date and time intervals
def process_data_for_date(event_date, country_code, export_path, start_hour, end_hour):
    # Define the export file paths
    csv3_file = f"od_{country_code.lower()}_agg3_3h_1208.csv"
    csv5_file = f"od_{country_code.lower()}_agg5_3h_1208.csv"
    csv3_file_path = f"{export_path}{csv3_file}"
    csv5_file_path = f"{export_path}{csv5_file}"

    # Loop through the specified hours in increments of 3 hours
    for hour in range(start_hour, end_hour, 3):
        next_hour = hour + 3  # end hour for the 3-hour interval
        logging.info(f"Querying data for date: {event_date}, hours: {hour}-{next_hour}")

        # Fetch the data for the specified event date and country code
        pe_tj_df3 = sql_engine.read_sql(
            f"""
            SELECT 
                cuebiq_id,
                duration_minutes,
                length_meters,
                number_of_points,
                TRY(date_parse(substr(start_zoned_datetime, 1, 19), '%Y-%m-%dT%H:%i:%s')) AS event_datetime_local,
                EXTRACT(HOUR FROM TRY(date_parse(substr(start_zoned_datetime, 1, 19), '%Y-%m-%dT%H:%i:%s'))) AS event_hour,
                geohash_encode(start_lat, start_lng, 5) AS start_geohash5,
                geohash_encode(start_lat, start_lng, 3) AS start_geohash3,
                geohash_encode(end_lat, end_lng, 5) AS end_geohash5,
                geohash_encode(end_lat, end_lng, 3) AS end_geohash3,
                DATE_FORMAT(date_parse(substr(start_zoned_datetime, 1, 10), '%Y-%m-%d'), '%Y%m%d') AS local_date
            FROM cuebiq.paas_cda_pe_v3.trajectory_uplevelled
            WHERE 
                event_date = {event_date}
                AND end_country = '{country_code}' 
                AND start_country = '{country_code}' 
            """
        )

        # Filter the DataFrame for the current 3-hour interval
        logging.info(f"Processing data for date: {event_date}, hours: {hour}-{next_hour}")
        filtered_df = pe_tj_df3[(pe_tj_df3['event_hour'] >= hour) & (pe_tj_df3['event_hour'] < next_hour)]

        # Add user numbers to the aggregated data for geohash3
        aggregated_df3 = filtered_df.groupby(['start_geohash3', 'end_geohash3', 'local_date']).agg({
            'cuebiq_id': 'count',
            'duration_minutes': ['mean', 'median', 'std'],
            'length_meters': ['mean', 'median', 'std'],
            'number_of_points': ['mean', 'median', 'std']
        }).reset_index()

        # Flatten the MultiIndex columns
        aggregated_df3.columns = ['start_geohash3', 'end_geohash3', 'local_date', 'trip_count', 
                                  'm_duration_min', 'mdn_duration_min', 'sd_duration_min', 
                                  'm_length_m', 'mdn_length_m', 'sd_length_m',
                                  'm_points_no', 'mdn_points_no', 'sd_points_no']

        # Add the local_time column
        aggregated_df3['local_time'] = aggregated_df3['local_date'].astype(str) + \
                                       f" {hour:02d}:00:00 - {next_hour:02d}:00:00"

        # Filter out rows where trip_count is less than or equal to 9
        aggregated_df3 = aggregated_df3[aggregated_df3['trip_count'] > 9]

        # Append the results to the CSV file for geohash3
        logging.info(f"Exporting aggregated data (geohash3) for date: {event_date}, hours: {hour}-{next_hour}")
        if not os.path.isfile(csv3_file_path):
            aggregated_df3.to_csv(csv3_file_path, index=False)
        else:
            aggregated_df3.to_csv(csv3_file_path, mode='a', header=False, index=False)

        # Add user numbers to the aggregated data for geohash5
        aggregated_df5 = filtered_df.groupby(['start_geohash5', 'end_geohash5', 'local_date']).agg({
            'cuebiq_id': 'count',
            'duration_minutes': ['mean', 'median', 'std'],
            'length_meters': ['mean', 'median', 'std'],
            'number_of_points': ['mean', 'median', 'std']
        }).reset_index()

        # Flatten the MultiIndex columns
        aggregated_df5.columns = ['start_geohash5', 'end_geohash5', 'local_date', 'trip_count', 
                                  'm_duration_min', 'mdn_duration_min', 'sd_duration_min', 
                                  'm_length_m', 'mdn_length_m', 'sd_length_m',
                                  'm_points_no', 'mdn_points_no', 'sd_points_no']

        # Add the local_time column
        aggregated_df5['local_time'] = aggregated_df5['local_date'].astype(str) + \
                                       f" {hour:02d}:00:00 - {next_hour:02d}:00:00"

        # Filter out rows where trip_count is less than or equal to 9
        aggregated_df5 = aggregated_df5[aggregated_df5['trip_count'] > 9]

        # Append the results to the CSV file for geohash5
        logging.info(f"Exporting aggregated data (geohash5) for date: {event_date}, hours: {hour}-{next_hour}")
        if not os.path.isfile(csv5_file_path):
            aggregated_df5.to_csv(csv5_file_path, index=False)
        else:
            aggregated_df5.to_csv(csv5_file_path, mode='a', header=False, index=False)

# Specify the date and initial time interval
event_date = "20191231"
start_hour = 0
end_hour = 24  # Process until the end of the day
country_code = 'CO'
export_path = '/home/jovyan/Data/TJ/3h/'

# Process data for the specified date and time intervals
process_data_for_date(event_date, country_code, export_path, start_hour, end_hour)
# Out:
# 2024-07-02 18:25:51,331 - INFO - Querying data for date: 20191231, hours: 0-3
# 2024-07-02 18:26:13,271 - INFO - Processing data for date: 20191231, hours: 0-3
# 2024-07-02 18:26:13,281 - INFO - Exporting aggregated data (geohash3) for date: 20191231, hours: 0-3
# 2024-07-02 18:26:13,300 - INFO - Exporting aggregated data (geohash5) for date: 20191231, hours: 0-3
# 2024-07-02 18:26:13,312 - INFO - Querying data for date: 20191231, hours: 3-6
# 2024-07-02 18:26:25,872 - INFO - Processing data for date: 20191231, hours: 3-6
# 2024-07-02 18:26:25,883 - INFO - Exporting aggregated data (geohash3) for date: 20191231, hours: 3-6
# 2024-07-02 18:26:25,895 - INFO - Exporting aggregated data (geohash5) for date: 20191231, hours: 3-6
# 2024-07-02 18:26:25,899 - INFO - Querying data for date: 20191231, hours: 6-9
# 2024-07-02 18:26:40,953 - INFO - Processing data for date: 20191231, hours: 6-9
# 2024-07-02 18:26:40,964 - INFO - Exporting aggregated data (geohash3) for date: 20191231, hours: 6-9
# 2024-07-02 18:26:40,974 - INFO - Exporting aggregated data (geohash5) for date: 20191231, hours: 6-9
# 2024-07-02 18:26:40,976 - INFO - Querying data for date: 20191231, hours: 9-12
# 2024-07-02 18:26:46,679 - INFO - Processing data for date: 20191231, hours: 9-12
# 2024-07-02 18:26:46,689 - INFO - Exporting aggregated data (geohash3) for date: 20191231, hours: 9-12
# 2024-07-02 18:26:46,703 - INFO - Exporting aggregated data (geohash5) for date: 20191231, hours: 9-12
# 2024-07-02 18:26:46,706 - INFO - Querying data for date: 20191231, hours: 12-15
# 2024-07-02 18:26:52,933 - INFO - Processing data for date: 20191231, hours: 12-15
# 2024-07-02 18:26:52,948 - INFO - Exporting aggregated data (geohash3) for date: 20191231, hours: 12-15
# 2024-07-02 18:26:53,024 - INFO - Exporting aggregated data (geohash5) for date: 20191231, hours: 12-15
# 2024-07-02 18:26:53,032 - INFO - Querying data for date: 20191231, hours: 15-18
# 2024-07-02 18:26:58,737 - INFO - Processing data for date: 20191231, hours: 15-18
# 2024-07-02 18:26:58,756 - INFO - Exporting aggregated data (geohash3) for date: 20191231, hours: 15-18
# 2024-07-02 18:26:58,780 - INFO - Exporting aggregated data (geohash5) for date: 20191231, hours: 15-18
# 2024-07-02 18:26:58,791 - INFO - Querying data for date: 20191231, hours: 18-21
# 2024-07-02 18:27:09,223 - INFO - Processing data for date: 20191231, hours: 18-21
# 2024-07-02 18:27:09,241 - INFO - Exporting aggregated data (geohash3) for date: 20191231, hours: 18-21
# 2024-07-02 18:27:09,274 - INFO - Exporting aggregated data (geohash5) for date: 20191231, hours: 18-21
# 2024-07-02 18:27:09,301 - INFO - Querying data for date: 20191231, hours: 21-24
# 2024-07-02 18:27:15,522 - INFO - Processing data for date: 20191231, hours: 21-24
# 2024-07-02 18:27:15,537 - INFO - Exporting aggregated data (geohash3) for date: 20191231, hours: 21-24
# 2024-07-02 18:27:15,563 - INFO - Exporting aggregated data (geohash5) for date: 20191231, hours: 21-24
