# %%
# %reload_ext sql
# %config SqlMagic.autocommit=False
# %config SqlMagic.autolimit=0
# %config SqlMagic.autopandas=True
# %config SqlMagic.displaylimit=200

# %%
# %sql trino://localhost:9090/cuebiq/
# Out:
# 'Connected: @cuebiq/'

# %%
pip install python-geohash
# Out:
# Collecting python-geohash
#   Using cached python_geohash-0.8.5-cp39-cp39-linux_x86_64.whl
# Installing collected packages: python-geohash
# Successfully installed python-geohash-0.8.5
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
import time
import geohash
import logging
import pandas as pd
from datetime import datetime, timedelta
from sqlalchemy import create_engine

# %%
# SQL engine
from trino.dbapi import connect 
from sqlalchemy import create_engine
import pandas as pd
import time

class TrinoEngine():
    def __init__(self):
        conn = connect(
            host="localhost",
            port=9090,
            catalog="cuebiq"
        )
        self.cur = conn.cursor()
        self.engine = create_engine("trino://localhost:9090/cuebiq/")
    
    def execute_statement(self, query:str) -> list:
        """
        Create and drop statements.
        """
        self.cur.execute(query)
        return self.cur.fetchall()
    
    def read_sql(self, query:str) -> pd.DataFrame: 
        """
        Select and insert into operations.
        """
        return pd.read_sql(query, self.engine)

sql_engine = TrinoEngine()

# %%
schema_name = {'cda': 'cuebiq.paas_cda_pe_v3'}
pe_tj_table = f"{schema_name['cda']}.trajectory_uplevelled"

# %% [markdown]
# # Export to local

# %%
# Set up logging
logging.basicConfig(level=logging.INFO, format='%(asctime)s - %(levelname)s - %(message)s')

# %%
# Function to process data for a specific date
def process_data_for_date(event_date, country_code, export_path):
    errors = []  # List to keep track of errors
    
    # Define the export file paths
    csv3_file = f"od_{country_code.lower()}2_agg3_3h.csv"
    csv5_file = f"od_{country_code.lower()}2_agg5_3h.csv"
    csv3_file_path = f"{export_path}{csv3_file}"
    csv5_file_path = f"{export_path}{csv5_file}"

    # Loop through 24 hours in increments of 3 hours
    for start_hour in range(0, 24, 3):
        end_hour = start_hour + 3  # end hour for the 3-hour interval
        logging.info(f"Querying data for date: {event_date}, hours: {start_hour}-{end_hour}")

        try:
            # Fetch the data for the specified event date and country code
            pe_tj_df3 = sql_engine.read_sql(
                f"""
                SELECT 
                    cuebiq_id,
                    duration_minutes,
                    length_meters,
                    number_of_points,
                    TRY(date_parse(substr(start_zoned_datetime, 1, 19), '%Y-%m-%dT%H:%i:%s')) AS event_datetime_local,
                    EXTRACT(HOUR FROM TRY(date_parse(substr(start_zoned_datetime, 1, 19), '%Y-%m-%dT%H:%i:%s'))) AS event_hour,
                    geohash_encode(start_lat, start_lng, 5) AS start_geohash5,
                    geohash_encode(start_lat, start_lng, 3) AS start_geohash3,
                    geohash_encode(end_lat, end_lng, 5) AS end_geohash5,
                    geohash_encode(end_lat, end_lng, 3) AS end_geohash3,
                    DATE_FORMAT(date_parse(substr(start_zoned_datetime, 1, 10), '%Y-%m-%d'), '%Y%m%d') AS local_date
                FROM cuebiq.paas_cda_pe_v3.trajectory_uplevelled
                WHERE 
                    event_date = {event_date}
                    AND end_country = '{country_code}' 
                    AND start_country = '{country_code}' 
                """
            )

            # Filter the DataFrame for the current 3-hour interval
            logging.info(f"Processing data for date: {event_date}, hours: {start_hour}-{end_hour}")
            filtered_df = pe_tj_df3[(pe_tj_df3['event_hour'] >= start_hour) & (pe_tj_df3['event_hour'] < end_hour)]

            # Add user numbers to the aggregated data for geohash3
            aggregated_df3 = filtered_df.groupby(['start_geohash3', 'end_geohash3', 'local_date']).agg({
                'cuebiq_id': 'count',
                'duration_minutes': ['mean', 'median', 'std'],
                'length_meters': ['mean', 'median', 'std'],
                'number_of_points': ['mean', 'median', 'std']
            }).reset_index()

            # Flatten the MultiIndex columns
            aggregated_df3.columns = ['start_geohash3', 'end_geohash3', 'local_date', 'trip_count', 
                                      'm_duration_min', 'mdn_duration_min', 'sd_duration_min', 
                                      'm_length_m', 'mdn_length_m', 'sd_length_m',
                                      'm_points_no', 'mdn_points_no', 'sd_points_no']

            # Add the local_time column
            aggregated_df3['local_time'] = aggregated_df3['local_date'].astype(str) + \
                                           f" {start_hour:02d}:00:00 - {end_hour:02d}:00:00"

            # Filter out rows where trip_count is less than or equal to 9
            aggregated_df3 = aggregated_df3[aggregated_df3['trip_count'] > 9]

            # Append the results to the CSV file for geohash3
            logging.info(f"Exporting aggregated data (geohash3) for date: {event_date}, hours: {start_hour}-{end_hour}")
            if not os.path.isfile(csv3_file_path):
                aggregated_df3.to_csv(csv3_file_path, index=False)
            else:
                aggregated_df3.to_csv(csv3_file_path, mode='a', header=False, index=False)

            # Add user numbers to the aggregated data for geohash5
            aggregated_df5 = filtered_df.groupby(['start_geohash5', 'end_geohash5', 'local_date']).agg({
                'cuebiq_id': 'count',
                'duration_minutes': ['mean', 'median', 'std'],
                'length_meters': ['mean', 'median', 'std'],
                'number_of_points': ['mean', 'median', 'std']
            }).reset_index()

            # Flatten the MultiIndex columns
            aggregated_df5.columns = ['start_geohash5', 'end_geohash5', 'local_date', 'trip_count', 
                                      'm_duration_min', 'mdn_duration_min', 'sd_duration_min', 
                                      'm_length_m', 'mdn_length_m', 'sd_length_m',
                                      'm_points_no', 'mdn_points_no', 'sd_points_no']

            # Add the local_time column
            aggregated_df5['local_time'] = aggregated_df5['local_date'].astype(str) + \
                                           f" {start_hour:02d}:00:00 - {end_hour:02d}:00:00"

            # Filter out rows where trip_count is less than or equal to 9
            aggregated_df5 = aggregated_df5[aggregated_df5['trip_count'] > 9]

            # Append the results to the CSV file for geohash5
            logging.info(f"Exporting aggregated data (geohash5) for date: {event_date}, hours: {start_hour}-{end_hour}")
            if not os.path.isfile(csv5_file_path):
                aggregated_df5.to_csv(csv5_file_path, index=False)
            else:
                aggregated_df5.to_csv(csv5_file_path, mode='a', header=False, index=False)
        
        except Exception as e:
            error_message = f"Error processing date: {event_date}, hours: {start_hour}-{end_hour} - {str(e)}"
            logging.error(error_message)
            errors.append(error_message)
    
    return errors

# Function to process data for a range of dates
def process_data_for_date_range(start_date, end_date, country_code, export_path):
    current_date = start_date
    all_errors = []
    while current_date <= end_date:
        event_date = current_date.strftime("%Y%m%d")
        logging.info(f"Processing data for date: {event_date}")
        errors = process_data_for_date(event_date, country_code, export_path)
        all_errors.extend(errors)
        current_date += timedelta(days=1)
    
    # Log any errors that occurred
    if all_errors:
        logging.info("Errors occurred during processing:")
        for error in all_errors:
            logging.info(error)

# %%
# Dates to process (example: a range of dates)
start_date = datetime.strptime("20190610", "%Y%m%d")
end_date = datetime.strptime("20191231", "%Y%m%d")

# Process each date in the range
current_date = start_date
while current_date <= end_date:
    event_date = current_date.strftime("%Y%m%d")
    logging.info(f"Processing data for date: {event_date}")
    process_data_for_date(event_date, 'MX', '/home/jovyan/Data/TJ/3h/')
    current_date += timedelta(days=1)
# Out:
# 2024-07-02 22:36:46,213 - INFO - Processing data for date: 20190610
# 2024-07-02 22:36:46,214 - INFO - Querying data for date: 20190610, hours: 0-3
# 2024-07-02 22:37:38,241 - INFO - Processing data for date: 20190610, hours: 0-3
# 2024-07-02 22:37:38,266 - INFO - Exporting aggregated data (geohash3) for date: 20190610, hours: 0-3
# 2024-07-02 22:37:38,300 - INFO - Exporting aggregated data (geohash5) for date: 20190610, hours: 0-3
# 2024-07-02 22:37:38,318 - INFO - Querying data for date: 20190610, hours: 3-6
# 2024-07-02 22:38:14,871 - INFO - Processing data for date: 20190610, hours: 3-6
# 2024-07-02 22:38:14,905 - INFO - Exporting aggregated data (geohash3) for date: 20190610, hours: 3-6
# 2024-07-02 22:38:14,942 - INFO - Exporting aggregated data (geohash5) for date: 20190610, hours: 3-6
# 2024-07-02 22:38:14,957 - INFO - Querying data for date: 20190610, hours: 6-9
# 2024-07-02 22:38:49,783 - INFO - Processing data for date: 20190610, hours: 6-9
# 2024-07-02 22:38:49,860 - INFO - Exporting aggregated data (geohash3) for date: 20190610, hours: 6-9
# 2024-07-02 22:38:49,944 - INFO - Exporting aggregated data (geohash5) for date: 20190610, hours: 6-9
# 2024-07-02 22:38:49,983 - INFO - Querying data for date: 20190610, hours: 9-12
# 2024-07-02 22:39:33,277 - INFO - Processing data for date: 20190610, hours: 9-12
# 2024-07-02 22:39:33,390 - INFO - Exporting aggregated data (geohash3) for date: 20190610, hours: 9-12
# 2024-07-02 22:39:33,506 - INFO - Exporting aggregated data (geohash5) for date: 20190610, hours: 9-12
# 2024-07-02 22:39:33,547 - INFO - Querying data for date: 20190610, hours: 12-15
# 2024-07-02 22:40:17,767 - INFO - Processing data for date: 20190610, hours: 12-15
# 2024-07-02 22:40:17,919 - INFO - Exporting aggregated data (geohash3) for date: 20190610, hours: 12-15
# 2024-07-02 22:40:18,057 - INFO - Exporting aggregated data (geohash5) for date: 20190610, hours: 12-15
# 2024-07-02 22:40:18,111 - INFO - Querying data for date: 20190610, hours: 15-18
# 2024-07-02 22:40:54,426 - INFO - Processing data for date: 20190610, hours: 15-18
# 2024-07-02 22:40:54,555 - INFO - Exporting aggregated data (geohash3) for date: 20190610, hours: 15-18
# 2024-07-02 22:40:54,664 - INFO - Exporting aggregated data (geohash5) for date: 20190610, hours: 15-18
# 2024-07-02 22:40:54,718 - INFO - Querying data for date: 20190610, hours: 18-21
# 2024-07-02 22:41:28,703 - INFO - Processing data for date: 20190610, hours: 18-21
# 2024-07-02 22:41:28,821 - INFO - Exporting aggregated data (geohash3) for date: 20190610, hours: 18-21
# 2024-07-02 22:41:28,928 - INFO - Exporting aggregated data (geohash5) for date: 20190610, hours: 18-21
# 2024-07-02 22:41:28,971 - INFO - Querying data for date: 20190610, hours: 21-24
# 2024-07-02 22:42:03,819 - INFO - Processing data for date: 20190610, hours: 21-24
# 2024-07-02 22:42:03,887 - INFO - Exporting aggregated data (geohash3) for date: 20190610, hours: 21-24
# 2024-07-02 22:42:03,938 - INFO - Exporting aggregated data (geohash5) for date: 20190610, hours: 21-24
# 2024-07-02 22:42:04,097 - INFO - Processing data for date: 20190611
# 2024-07-02 22:42:04,098 - INFO - Querying data for date: 20190611, hours: 0-3
# 2024-07-02 22:43:08,094 - INFO - Processing data for date: 20190611, hours: 0-3
# 2024-07-02 22:43:08,118 - INFO - Exporting aggregated data (geohash3) for date: 20190611, hours: 0-3
# 2024-07-02 22:43:08,158 - INFO - Exporting aggregated data (geohash5) for date: 20190611, hours: 0-3
# 2024-07-02 22:43:08,175 - INFO - Querying data for date: 20190611, hours: 3-6
# 2024-07-02 22:43:49,907 - INFO - Processing data for date: 20190611, hours: 3-6
# 2024-07-02 22:43:49,944 - INFO - Exporting aggregated data (geohash3) for date: 20190611, hours: 3-6
# 2024-07-02 22:43:49,984 - INFO - Exporting aggregated data (geohash5) for date: 20190611, hours: 3-6
# 2024-07-02 22:43:50,003 - INFO - Querying data for date: 20190611, hours: 6-9
# 2024-07-02 22:44:24,655 - INFO - Processing data for date: 20190611, hours: 6-9
# 2024-07-02 22:44:24,735 - INFO - Exporting aggregated data (geohash3) for date: 20190611, hours: 6-9
# 2024-07-02 22:44:24,829 - INFO - Exporting aggregated data (geohash5) for date: 20190611, hours: 6-9
# 2024-07-02 22:44:24,864 - INFO - Querying data for date: 20190611, hours: 9-12
# 2024-07-02 22:45:03,199 - INFO - Processing data for date: 20190611, hours: 9-12
# 2024-07-02 22:45:03,320 - INFO - Exporting aggregated data (geohash3) for date: 20190611, hours: 9-12
# 2024-07-02 22:45:03,441 - INFO - Exporting aggregated data (geohash5) for date: 20190611, hours: 9-12
# 2024-07-02 22:45:03,492 - INFO - Querying data for date: 20190611, hours: 12-15
# 2024-07-02 22:45:58,956 - INFO - Processing data for date: 20190611, hours: 12-15
# 2024-07-02 22:45:59,095 - INFO - Exporting aggregated data (geohash3) for date: 20190611, hours: 12-15
# 2024-07-02 22:45:59,219 - INFO - Exporting aggregated data (geohash5) for date: 20190611, hours: 12-15
# 2024-07-02 22:45:59,267 - INFO - Querying data for date: 20190611, hours: 15-18
# 2024-07-02 22:46:41,437 - INFO - Processing data for date: 20190611, hours: 15-18
# 2024-07-02 22:46:41,578 - INFO - Exporting aggregated data (geohash3) for date: 20190611, hours: 15-18
# 2024-07-02 22:46:41,699 - INFO - Exporting aggregated data (geohash5) for date: 20190611, hours: 15-18
# 2024-07-02 22:46:41,750 - INFO - Querying data for date: 20190611, hours: 18-21
# 2024-07-02 22:47:19,811 - INFO - Processing data for date: 20190611, hours: 18-21
# 2024-07-02 22:47:19,941 - INFO - Exporting aggregated data (geohash3) for date: 20190611, hours: 18-21
# 2024-07-02 22:47:20,061 - INFO - Exporting aggregated data (geohash5) for date: 20190611, hours: 18-21
# 2024-07-02 22:47:20,105 - INFO - Querying data for date: 20190611, hours: 21-24
# 2024-07-02 22:47:57,370 - INFO - Processing data for date: 20190611, hours: 21-24
# 2024-07-02 22:47:57,437 - INFO - Exporting aggregated data (geohash3) for date: 20190611, hours: 21-24
# 2024-07-02 22:47:57,492 - INFO - Exporting aggregated data (geohash5) for date: 20190611, hours: 21-24
# 2024-07-02 22:47:57,654 - INFO - Processing data for date: 20190612
# 2024-07-02 22:47:57,655 - INFO - Querying data for date: 20190612, hours: 0-3
# 2024-07-02 22:48:51,563 - INFO - Processing data for date: 20190612, hours: 0-3
# 2024-07-02 22:48:51,587 - INFO - Exporting aggregated data (geohash3) for date: 20190612, hours: 0-3
# 2024-07-02 22:48:51,622 - INFO - Exporting aggregated data (geohash5) for date: 20190612, hours: 0-3
# 2024-07-02 22:48:51,639 - INFO - Querying data for date: 20190612, hours: 3-6
# 2024-07-02 22:49:20,231 - INFO - Processing data for date: 20190612, hours: 3-6
# 2024-07-02 22:49:20,266 - INFO - Exporting aggregated data (geohash3) for date: 20190612, hours: 3-6
# 2024-07-02 22:49:20,320 - INFO - Exporting aggregated data (geohash5) for date: 20190612, hours: 3-6
# 2024-07-02 22:49:20,336 - INFO - Querying data for date: 20190612, hours: 6-9
# 2024-07-02 22:49:53,100 - INFO - Processing data for date: 20190612, hours: 6-9
# 2024-07-02 22:49:53,227 - INFO - Exporting aggregated data (geohash3) for date: 20190612, hours: 6-9
# 2024-07-02 22:49:53,345 - INFO - Exporting aggregated data (geohash5) for date: 20190612, hours: 6-9
# 2024-07-02 22:49:53,422 - INFO - Querying data for date: 20190612, hours: 9-12
# 2024-07-02 22:50:32,656 - INFO - Processing data for date: 20190612, hours: 9-12
# 2024-07-02 22:50:32,785 - INFO - Exporting aggregated data (geohash3) for date: 20190612, hours: 9-12
# 2024-07-02 22:50:32,898 - INFO - Exporting aggregated data (geohash5) for date: 20190612, hours: 9-12
# 2024-07-02 22:50:32,944 - INFO - Querying data for date: 20190612, hours: 12-15
# 2024-07-02 22:51:10,882 - INFO - Processing data for date: 20190612, hours: 12-15
# 2024-07-02 22:51:11,021 - INFO - Exporting aggregated data (geohash3) for date: 20190612, hours: 12-15
# 2024-07-02 22:51:11,158 - INFO - Exporting aggregated data (geohash5) for date: 20190612, hours: 12-15
# 2024-07-02 22:51:11,206 - INFO - Querying data for date: 20190612, hours: 15-18
# 2024-07-02 22:51:47,129 - INFO - Processing data for date: 20190612, hours: 15-18
# 2024-07-02 22:51:47,412 - INFO - Exporting aggregated data (geohash3) for date: 20190612, hours: 15-18
# 2024-07-02 22:51:47,615 - INFO - Exporting aggregated data (geohash5) for date: 20190612, hours: 15-18
# 2024-07-02 22:51:47,657 - INFO - Querying data for date: 20190612, hours: 18-21
# 2024-07-02 22:52:08,925 - INFO - Processing data for date: 20190612, hours: 18-21
# 2024-07-02 22:52:09,042 - INFO - Exporting aggregated data (geohash3) for date: 20190612, hours: 18-21
# 2024-07-02 22:52:09,139 - INFO - Exporting aggregated data (geohash5) for date: 20190612, hours: 18-21
# 2024-07-02 22:52:09,182 - INFO - Querying data for date: 20190612, hours: 21-24
# 2024-07-02 22:52:47,589 - INFO - Processing data for date: 20190612, hours: 21-24
# 2024-07-02 22:52:47,671 - INFO - Exporting aggregated data (geohash3) for date: 20190612, hours: 21-24
# 2024-07-02 22:52:47,723 - INFO - Exporting aggregated data (geohash5) for date: 20190612, hours: 21-24
# 2024-07-02 22:52:47,885 - INFO - Processing data for date: 20190613
# 2024-07-02 22:52:47,886 - INFO - Querying data for date: 20190613, hours: 0-3
# 2024-07-02 22:53:33,258 - INFO - Processing data for date: 20190613, hours: 0-3
# 2024-07-02 22:53:33,284 - INFO - Exporting aggregated data (geohash3) for date: 20190613, hours: 0-3
# 2024-07-02 22:53:33,325 - INFO - Exporting aggregated data (geohash5) for date: 20190613, hours: 0-3
# 2024-07-02 22:53:33,346 - INFO - Querying data for date: 20190613, hours: 3-6
# 2024-07-02 22:54:14,383 - INFO - Processing data for date: 20190613, hours: 3-6
# 2024-07-02 22:54:14,415 - INFO - Exporting aggregated data (geohash3) for date: 20190613, hours: 3-6
# 2024-07-02 22:54:14,460 - INFO - Exporting aggregated data (geohash5) for date: 20190613, hours: 3-6
# 2024-07-02 22:54:14,479 - INFO - Querying data for date: 20190613, hours: 6-9
# 2024-07-02 22:55:05,792 - INFO - Processing data for date: 20190613, hours: 6-9
# 2024-07-02 22:55:05,872 - INFO - Exporting aggregated data (geohash3) for date: 20190613, hours: 6-9
# 2024-07-02 22:55:05,959 - INFO - Exporting aggregated data (geohash5) for date: 20190613, hours: 6-9
# 2024-07-02 22:55:05,994 - INFO - Querying data for date: 20190613, hours: 9-12
# 2024-07-02 22:55:48,758 - INFO - Processing data for date: 20190613, hours: 9-12
# 2024-07-02 22:55:48,882 - INFO - Exporting aggregated data (geohash3) for date: 20190613, hours: 9-12
# 2024-07-02 22:55:49,001 - INFO - Exporting aggregated data (geohash5) for date: 20190613, hours: 9-12
# 2024-07-02 22:55:49,048 - INFO - Querying data for date: 20190613, hours: 12-15
# 2024-07-02 22:56:28,070 - INFO - Processing data for date: 20190613, hours: 12-15
# 2024-07-02 22:56:28,240 - INFO - Exporting aggregated data (geohash3) for date: 20190613, hours: 12-15
# 2024-07-02 22:56:28,409 - INFO - Exporting aggregated data (geohash5) for date: 20190613, hours: 12-15
# 2024-07-02 22:56:28,460 - INFO - Querying data for date: 20190613, hours: 15-18
# 2024-07-02 22:57:07,190 - INFO - Processing data for date: 20190613, hours: 15-18
# 2024-07-02 22:57:07,338 - INFO - Exporting aggregated data (geohash3) for date: 20190613, hours: 15-18
# 2024-07-02 22:57:07,479 - INFO - Exporting aggregated data (geohash5) for date: 20190613, hours: 15-18
# 2024-07-02 22:57:07,523 - INFO - Querying data for date: 20190613, hours: 18-21
# 2024-07-02 22:57:50,846 - INFO - Processing data for date: 20190613, hours: 18-21
# 2024-07-02 22:57:50,963 - INFO - Exporting aggregated data (geohash3) for date: 20190613, hours: 18-21
# 2024-07-02 22:57:51,062 - INFO - Exporting aggregated data (geohash5) for date: 20190613, hours: 18-21
# 2024-07-02 22:57:51,105 - INFO - Querying data for date: 20190613, hours: 21-24
# 2024-07-02 22:58:26,589 - INFO - Processing data for date: 20190613, hours: 21-24
# 2024-07-02 22:58:26,656 - INFO - Exporting aggregated data (geohash3) for date: 20190613, hours: 21-24
# 2024-07-02 22:58:26,712 - INFO - Exporting aggregated data (geohash5) for date: 20190613, hours: 21-24
# 2024-07-02 22:58:26,877 - INFO - Processing data for date: 20190614
# 2024-07-02 22:58:26,878 - INFO - Querying data for date: 20190614, hours: 0-3
# 2024-07-02 22:59:18,707 - INFO - Processing data for date: 20190614, hours: 0-3
# 2024-07-02 22:59:18,734 - INFO - Exporting aggregated data (geohash3) for date: 20190614, hours: 0-3
# 2024-07-02 22:59:18,771 - INFO - Exporting aggregated data (geohash5) for date: 20190614, hours: 0-3
# 2024-07-02 22:59:18,787 - INFO - Querying data for date: 20190614, hours: 3-6
# 2024-07-02 23:00:02,191 - INFO - Processing data for date: 20190614, hours: 3-6
# 2024-07-02 23:00:02,236 - INFO - Exporting aggregated data (geohash3) for date: 20190614, hours: 3-6
# 2024-07-02 23:00:02,306 - INFO - Exporting aggregated data (geohash5) for date: 20190614, hours: 3-6
# 2024-07-02 23:00:02,323 - INFO - Querying data for date: 20190614, hours: 6-9
# 2024-07-02 23:00:44,999 - INFO - Processing data for date: 20190614, hours: 6-9
# 2024-07-02 23:00:45,079 - INFO - Exporting aggregated data (geohash3) for date: 20190614, hours: 6-9
# 2024-07-02 23:00:45,170 - INFO - Exporting aggregated data (geohash5) for date: 20190614, hours: 6-9
# 2024-07-02 23:00:45,209 - INFO - Querying data for date: 20190614, hours: 9-12
# 2024-07-02 23:01:25,071 - INFO - Processing data for date: 20190614, hours: 9-12
# 2024-07-02 23:01:25,204 - INFO - Exporting aggregated data (geohash3) for date: 20190614, hours: 9-12
# 2024-07-02 23:01:25,317 - INFO - Exporting aggregated data (geohash5) for date: 20190614, hours: 9-12
# 2024-07-02 23:01:25,365 - INFO - Querying data for date: 20190614, hours: 12-15
# 2024-07-02 23:02:07,914 - INFO - Processing data for date: 20190614, hours: 12-15
# 2024-07-02 23:02:08,062 - INFO - Exporting aggregated data (geohash3) for date: 20190614, hours: 12-15
# 2024-07-02 23:02:08,184 - INFO - Exporting aggregated data (geohash5) for date: 20190614, hours: 12-15
# 2024-07-02 23:02:08,246 - INFO - Querying data for date: 20190614, hours: 15-18
# 2024-07-02 23:02:51,940 - INFO - Processing data for date: 20190614, hours: 15-18
# 2024-07-02 23:02:52,085 - INFO - Exporting aggregated data (geohash3) for date: 20190614, hours: 15-18
# 2024-07-02 23:09:06,432 - INFO - Exporting aggregated data (geohash3) for date: 20190615, hours: 15-18
# 2024-07-02 23:09:06,551 - INFO - Exporting aggregated data (geohash5) for date: 20190615, hours: 15-18
# 2024-07-02 23:09:06,597 - INFO - Querying data for date: 20190615, hours: 18-21
# 2024-07-02 23:09:48,333 - INFO - Processing data for date: 20190615, hours: 18-21
# 2024-07-02 23:09:48,456 - INFO - Exporting aggregated data (geohash3) for date: 20190615, hours: 18-21
# 2024-07-02 23:09:48,580 - INFO - Exporting aggregated data (geohash5) for date: 20190615, hours: 18-21
# 2024-07-02 23:09:48,622 - INFO - Querying data for date: 20190615, hours: 21-24
# 2024-07-02 23:10:28,925 - INFO - Processing data for date: 20190615, hours: 21-24
# 2024-07-02 23:10:29,010 - INFO - Exporting aggregated data (geohash3) for date: 20190615, hours: 21-24
# 2024-07-02 23:10:29,079 - INFO - Exporting aggregated data (geohash5) for date: 20190615, hours: 21-24
# 2024-07-02 23:10:29,265 - INFO - Processing data for date: 20190616
# 2024-07-02 23:10:29,266 - INFO - Querying data for date: 20190616, hours: 0-3
# 2024-07-02 23:11:10,328 - INFO - Processing data for date: 20190616, hours: 0-3
# 2024-07-02 23:11:10,359 - INFO - Exporting aggregated data (geohash3) for date: 20190616, hours: 0-3
# 2024-07-02 23:11:10,404 - INFO - Exporting aggregated data (geohash5) for date: 20190616, hours: 0-3
# 2024-07-02 23:11:10,425 - INFO - Querying data for date: 20190616, hours: 3-6
# 2024-07-02 23:11:43,711 - INFO - Processing data for date: 20190616, hours: 3-6
# 2024-07-02 23:11:43,743 - INFO - Exporting aggregated data (geohash3) for date: 20190616, hours: 3-6
# 2024-07-02 23:11:43,780 - INFO - Exporting aggregated data (geohash5) for date: 20190616, hours: 3-6
# 2024-07-02 23:11:43,797 - INFO - Querying data for date: 20190616, hours: 6-9
# 2024-07-02 23:12:23,920 - INFO - Processing data for date: 20190616, hours: 6-9
# 2024-07-02 23:12:23,967 - INFO - Exporting aggregated data (geohash3) for date: 20190616, hours: 6-9
# 2024-07-02 23:12:24,024 - INFO - Exporting aggregated data (geohash5) for date: 20190616, hours: 6-9
# 2024-07-02 23:12:24,046 - INFO - Querying data for date: 20190616, hours: 9-12
# 2024-07-02 23:12:54,826 - INFO - Processing data for date: 20190616, hours: 9-12
# 2024-07-02 23:12:54,910 - INFO - Exporting aggregated data (geohash3) for date: 20190616, hours: 9-12
# 2024-07-02 23:12:54,999 - INFO - Exporting aggregated data (geohash5) for date: 20190616, hours: 9-12
# 2024-07-02 23:12:55,038 - INFO - Querying data for date: 20190616, hours: 12-15
# 2024-07-02 23:13:26,796 - INFO - Processing data for date: 20190616, hours: 12-15
# 2024-07-02 23:13:26,901 - INFO - Exporting aggregated data (geohash3) for date: 20190616, hours: 12-15
# 2024-07-02 23:13:27,003 - INFO - Exporting aggregated data (geohash5) for date: 20190616, hours: 12-15
# 2024-07-02 23:13:27,045 - INFO - Querying data for date: 20190616, hours: 15-18
# 2024-07-02 23:13:57,969 - INFO - Processing data for date: 20190616, hours: 15-18
# 2024-07-02 23:13:58,068 - INFO - Exporting aggregated data (geohash3) for date: 20190616, hours: 15-18
# 2024-07-02 23:13:58,161 - INFO - Exporting aggregated data (geohash5) for date: 20190616, hours: 15-18
# 2024-07-02 23:13:58,200 - INFO - Querying data for date: 20190616, hours: 18-21
# 2024-07-02 23:14:34,980 - INFO - Processing data for date: 20190616, hours: 18-21
# 2024-07-02 23:14:35,065 - INFO - Exporting aggregated data (geohash3) for date: 20190616, hours: 18-21
# 2024-07-02 23:14:35,143 - INFO - Exporting aggregated data (geohash5) for date: 20190616, hours: 18-21
# 2024-07-02 23:14:35,174 - INFO - Querying data for date: 20190616, hours: 21-24
# 2024-07-02 23:15:18,339 - INFO - Processing data for date: 20190616, hours: 21-24
# 2024-07-02 23:15:18,392 - INFO - Exporting aggregated data (geohash3) for date: 20190616, hours: 21-24
# 2024-07-02 23:15:18,443 - INFO - Exporting aggregated data (geohash5) for date: 20190616, hours: 21-24
# 2024-07-02 23:15:18,574 - INFO - Processing data for date: 20190617
# 2024-07-02 23:15:18,575 - INFO - Querying data for date: 20190617, hours: 0-3
# 2024-07-02 23:15:57,956 - INFO - Processing data for date: 20190617, hours: 0-3
# 2024-07-02 23:15:57,977 - INFO - Exporting aggregated data (geohash3) for date: 20190617, hours: 0-3
# 2024-07-02 23:15:58,012 - INFO - Exporting aggregated data (geohash5) for date: 20190617, hours: 0-3
# 2024-07-02 23:15:58,027 - INFO - Querying data for date: 20190617, hours: 3-6
# 2024-07-02 23:16:37,357 - INFO - Processing data for date: 20190617, hours: 3-6
# 2024-07-02 23:16:37,391 - INFO - Exporting aggregated data (geohash3) for date: 20190617, hours: 3-6
# 2024-07-02 23:16:37,428 - INFO - Exporting aggregated data (geohash5) for date: 20190617, hours: 3-6
# 2024-07-02 23:16:37,448 - INFO - Querying data for date: 20190617, hours: 6-9
# 2024-07-02 23:17:19,189 - INFO - Processing data for date: 20190617, hours: 6-9
# 2024-07-02 23:17:19,250 - INFO - Exporting aggregated data (geohash3) for date: 20190617, hours: 6-9
# 2024-07-02 23:17:19,322 - INFO - Exporting aggregated data (geohash5) for date: 20190617, hours: 6-9
# 2024-07-02 23:17:19,352 - INFO - Querying data for date: 20190617, hours: 9-12
# 2024-07-02 23:17:49,691 - INFO - Processing data for date: 20190617, hours: 9-12
# 2024-07-02 23:17:49,789 - INFO - Exporting aggregated data (geohash3) for date: 20190617, hours: 9-12
# 2024-07-02 23:17:49,884 - INFO - Exporting aggregated data (geohash5) for date: 20190617, hours: 9-12
# 2024-07-02 23:17:49,930 - INFO - Querying data for date: 20190617, hours: 12-15
# 2024-07-02 23:18:19,000 - INFO - Processing data for date: 20190617, hours: 12-15
# 2024-07-02 23:18:19,237 - INFO - Exporting aggregated data (geohash3) for date: 20190617, hours: 12-15
# 2024-07-02 23:18:19,377 - INFO - Exporting aggregated data (geohash5) for date: 20190617, hours: 12-15
# 2024-07-02 23:18:19,444 - INFO - Querying data for date: 20190617, hours: 15-18
# 2024-07-02 23:18:54,329 - INFO - Processing data for date: 20190617, hours: 15-18
# 2024-07-02 23:18:54,442 - INFO - Exporting aggregated data (geohash3) for date: 20190617, hours: 15-18
# 2024-07-02 23:18:54,540 - INFO - Exporting aggregated data (geohash5) for date: 20190617, hours: 15-18
# 2024-07-02 23:18:54,584 - INFO - Querying data for date: 20190617, hours: 18-21
# 2024-07-02 23:19:27,744 - INFO - Processing data for date: 20190617, hours: 18-21
# 2024-07-02 23:19:27,844 - INFO - Exporting aggregated data (geohash3) for date: 20190617, hours: 18-21
# 2024-07-02 23:19:27,932 - INFO - Exporting aggregated data (geohash5) for date: 20190617, hours: 18-21
# 2024-07-02 23:19:27,970 - INFO - Querying data for date: 20190617, hours: 21-24
# 2024-07-02 23:19:50,827 - INFO - Processing data for date: 20190617, hours: 21-24
# 2024-07-02 23:19:50,884 - INFO - Exporting aggregated data (geohash3) for date: 20190617, hours: 21-24
# 2024-07-02 23:19:50,930 - INFO - Exporting aggregated data (geohash5) for date: 20190617, hours: 21-24
# 2024-07-02 23:19:51,074 - INFO - Processing data for date: 20190618
# 2024-07-02 23:19:51,074 - INFO - Querying data for date: 20190618, hours: 0-3
# 2024-07-02 23:20:30,200 - INFO - Processing data for date: 20190618, hours: 0-3
# 2024-07-02 23:20:30,222 - INFO - Exporting aggregated data (geohash3) for date: 20190618, hours: 0-3
# 2024-07-02 23:20:30,258 - INFO - Exporting aggregated data (geohash5) for date: 20190618, hours: 0-3
# 2024-07-02 23:20:30,273 - INFO - Querying data for date: 20190618, hours: 3-6
# 2024-07-02 23:21:08,679 - INFO - Processing data for date: 20190618, hours: 3-6
# 2024-07-02 23:21:08,707 - INFO - Exporting aggregated data (geohash3) for date: 20190618, hours: 3-6
# 2024-07-02 23:21:08,740 - INFO - Exporting aggregated data (geohash5) for date: 20190618, hours: 3-6
# 2024-07-02 23:21:08,757 - INFO - Querying data for date: 20190618, hours: 6-9
# 2024-07-02 23:21:36,313 - INFO - Processing data for date: 20190618, hours: 6-9
# 2024-07-02 23:21:36,375 - INFO - Exporting aggregated data (geohash3) for date: 20190618, hours: 6-9
# 2024-07-02 23:21:36,446 - INFO - Exporting aggregated data (geohash5) for date: 20190618, hours: 6-9
# 2024-07-02 23:21:36,476 - INFO - Querying data for date: 20190618, hours: 9-12
# 2024-07-02 23:21:57,948 - INFO - Processing data for date: 20190618, hours: 9-12
# 2024-07-02 23:21:58,121 - INFO - Exporting aggregated data (geohash3) for date: 20190618, hours: 9-12
# 2024-07-02 23:21:58,226 - INFO - Exporting aggregated data (geohash5) for date: 20190618, hours: 9-12
# 2024-07-02 23:21:58,268 - INFO - Querying data for date: 20190618, hours: 12-15
# 2024-07-02 23:22:19,973 - INFO - Processing data for date: 20190618, hours: 12-15
# 2024-07-02 23:22:20,164 - INFO - Exporting aggregated data (geohash3) for date: 20190618, hours: 12-15
# 2024-07-02 23:22:20,318 - INFO - Exporting aggregated data (geohash5) for date: 20190618, hours: 12-15
# 2024-07-02 23:22:20,365 - INFO - Querying data for date: 20190618, hours: 15-18
# 2024-07-02 23:22:39,326 - INFO - Processing data for date: 20190618, hours: 15-18
# 2024-07-02 23:22:39,440 - INFO - Exporting aggregated data (geohash3) for date: 20190618, hours: 15-18
# 2024-07-02 23:22:39,542 - INFO - Exporting aggregated data (geohash5) for date: 20190618, hours: 15-18
# 2024-07-02 23:22:39,585 - INFO - Querying data for date: 20190618, hours: 18-21
# 2024-07-02 23:23:16,257 - INFO - Processing data for date: 20190618, hours: 18-21
# 2024-07-02 23:23:16,357 - INFO - Exporting aggregated data (geohash3) for date: 20190618, hours: 18-21
# 2024-07-02 23:23:16,445 - INFO - Exporting aggregated data (geohash5) for date: 20190618, hours: 18-21
# 2024-07-02 23:23:16,488 - INFO - Querying data for date: 20190618, hours: 21-24
# 2024-07-02 23:23:36,728 - INFO - Processing data for date: 20190618, hours: 21-24
# 2024-07-02 23:23:36,810 - INFO - Exporting aggregated data (geohash3) for date: 20190618, hours: 21-24
# 2024-07-02 23:23:36,875 - INFO - Exporting aggregated data (geohash5) for date: 20190618, hours: 21-24
# 2024-07-02 23:23:37,075 - INFO - Processing data for date: 20190619
# 2024-07-02 23:23:37,075 - INFO - Querying data for date: 20190619, hours: 0-3
# 2024-07-02 23:24:08,112 - INFO - Processing data for date: 20190619, hours: 0-3
# 2024-07-02 23:24:08,133 - INFO - Exporting aggregated data (geohash3) for date: 20190619, hours: 0-3
# 2024-07-02 23:24:08,166 - INFO - Exporting aggregated data (geohash5) for date: 20190619, hours: 0-3
# 2024-07-02 23:24:08,185 - INFO - Querying data for date: 20190619, hours: 3-6
# 2024-07-02 23:24:47,447 - INFO - Processing data for date: 20190619, hours: 3-6
# 2024-07-02 23:24:47,473 - INFO - Exporting aggregated data (geohash3) for date: 20190619, hours: 3-6
# 2024-07-02 23:24:47,516 - INFO - Exporting aggregated data (geohash5) for date: 20190619, hours: 3-6
# 2024-07-02 23:24:47,533 - INFO - Querying data for date: 20190619, hours: 6-9
# 2024-07-02 23:25:33,888 - INFO - Processing data for date: 20190619, hours: 6-9
# 2024-07-02 23:25:33,949 - INFO - Exporting aggregated data (geohash3) for date: 20190619, hours: 6-9
# 2024-07-02 23:25:34,018 - INFO - Exporting aggregated data (geohash5) for date: 20190619, hours: 6-9
# 2024-07-02 23:25:34,052 - INFO - Querying data for date: 20190619, hours: 9-12
# 2024-07-02 23:26:08,031 - INFO - Processing data for date: 20190619, hours: 9-12
# 2024-07-02 23:26:08,135 - INFO - Exporting aggregated data (geohash3) for date: 20190619, hours: 9-12
# 2024-07-02 23:26:08,233 - INFO - Exporting aggregated data (geohash5) for date: 20190619, hours: 9-12
# 2024-07-02 23:26:08,278 - INFO - Querying data for date: 20190619, hours: 12-15
# 2024-07-02 23:26:41,697 - INFO - Processing data for date: 20190619, hours: 12-15
# 2024-07-02 23:26:41,817 - INFO - Exporting aggregated data (geohash3) for date: 20190619, hours: 12-15
# 2024-07-02 23:26:41,928 - INFO - Exporting aggregated data (geohash5) for date: 20190619, hours: 12-15
# 2024-07-02 23:26:41,971 - INFO - Querying data for date: 20190619, hours: 15-18
# 2024-07-02 23:27:15,866 - INFO - Processing data for date: 20190619, hours: 15-18
# 2024-07-02 23:27:15,998 - INFO - Exporting aggregated data (geohash3) for date: 20190619, hours: 15-18
# 2024-07-02 23:27:16,117 - INFO - Exporting aggregated data (geohash5) for date: 20190619, hours: 15-18
# 2024-07-02 23:27:16,162 - INFO - Querying data for date: 20190619, hours: 18-21
# 2024-07-02 23:27:49,761 - INFO - Processing data for date: 20190619, hours: 18-21
# 2024-07-02 23:27:49,856 - INFO - Exporting aggregated data (geohash3) for date: 20190619, hours: 18-21
# 2024-07-02 23:27:49,949 - INFO - Exporting aggregated data (geohash5) for date: 20190619, hours: 18-21
# 2024-07-02 23:27:49,986 - INFO - Querying data for date: 20190619, hours: 21-24
# 2024-07-02 23:28:26,484 - INFO - Processing data for date: 20190619, hours: 21-24
# 2024-07-02 23:28:26,539 - INFO - Exporting aggregated data (geohash3) for date: 20190619, hours: 21-24
# 2024-07-02 23:28:26,587 - INFO - Exporting aggregated data (geohash5) for date: 20190619, hours: 21-24
# 2024-07-02 23:28:26,731 - INFO - Processing data for date: 20190620
# 2024-07-02 23:28:26,732 - INFO - Querying data for date: 20190620, hours: 0-3
# 2024-07-02 23:29:26,695 - INFO - Processing data for date: 20190620, hours: 0-3
# 2024-07-02 23:29:26,718 - INFO - Exporting aggregated data (geohash3) for date: 20190620, hours: 0-3
# 2024-07-02 23:29:26,752 - INFO - Exporting aggregated data (geohash5) for date: 20190620, hours: 0-3
# 2024-07-02 23:29:26,768 - INFO - Querying data for date: 20190620, hours: 3-6
# 2024-07-02 23:30:04,876 - INFO - Processing data for date: 20190620, hours: 3-6
# 2024-07-02 23:30:04,909 - INFO - Exporting aggregated data (geohash3) for date: 20190620, hours: 3-6
# 2024-07-02 23:30:04,951 - INFO - Exporting aggregated data (geohash5) for date: 20190620, hours: 3-6
# 2024-07-02 23:30:04,965 - INFO - Querying data for date: 20190620, hours: 6-9
# 2024-07-02 23:30:44,196 - INFO - Processing data for date: 20190620, hours: 6-9
# 2024-07-02 23:30:44,258 - INFO - Exporting aggregated data (geohash3) for date: 20190620, hours: 6-9
# 2024-07-02 23:30:44,331 - INFO - Exporting aggregated data (geohash5) for date: 20190620, hours: 6-9
# 2024-07-02 23:30:44,368 - INFO - Querying data for date: 20190620, hours: 9-12
# 2024-07-02 23:31:18,412 - INFO - Processing data for date: 20190620, hours: 9-12
# 2024-07-02 23:31:18,519 - INFO - Exporting aggregated data (geohash3) for date: 20190620, hours: 9-12
# 2024-07-02 23:31:18,630 - INFO - Exporting aggregated data (geohash5) for date: 20190620, hours: 9-12
# 2024-07-02 23:31:18,677 - INFO - Querying data for date: 20190620, hours: 12-15
# 2024-07-02 23:31:56,524 - INFO - Processing data for date: 20190620, hours: 12-15
# 2024-07-02 23:31:56,639 - INFO - Exporting aggregated data (geohash3) for date: 20190620, hours: 12-15
# 2024-07-02 23:31:56,747 - INFO - Exporting aggregated data (geohash5) for date: 20190620, hours: 12-15
# 2024-07-02 23:31:56,788 - INFO - Querying data for date: 20190620, hours: 15-18
# 2024-07-02 23:32:34,800 - INFO - Processing data for date: 20190620, hours: 15-18
# 2024-07-02 23:32:34,911 - INFO - Exporting aggregated data (geohash3) for date: 20190620, hours: 15-18
# 2024-07-02 23:32:35,007 - INFO - Exporting aggregated data (geohash5) for date: 20190620, hours: 15-18
# 2024-07-02 23:32:35,055 - INFO - Querying data for date: 20190620, hours: 18-21
# 2024-07-02 23:33:07,718 - INFO - Processing data for date: 20190620, hours: 18-21
# 2024-07-02 23:33:07,830 - INFO - Exporting aggregated data (geohash3) for date: 20190620, hours: 18-21
# 2024-07-02 23:33:07,932 - INFO - Exporting aggregated data (geohash5) for date: 20190620, hours: 18-21
# 2024-07-02 23:33:07,971 - INFO - Querying data for date: 20190620, hours: 21-24
# 2024-07-02 23:33:40,886 - INFO - Processing data for date: 20190620, hours: 21-24
# 2024-07-02 23:33:40,947 - INFO - Exporting aggregated data (geohash3) for date: 20190620, hours: 21-24
# 2024-07-02 23:33:41,002 - INFO - Exporting aggregated data (geohash5) for date: 20190620, hours: 21-24
# 2024-07-02 23:33:41,151 - INFO - Processing data for date: 20190621
# 2024-07-02 23:33:41,152 - INFO - Querying data for date: 20190621, hours: 0-3
# 2024-07-02 23:34:33,044 - INFO - Processing data for date: 20190621, hours: 0-3
# 2024-07-02 23:34:33,067 - INFO - Exporting aggregated data (geohash3) for date: 20190621, hours: 0-3
# 2024-07-02 23:34:33,099 - INFO - Exporting aggregated data (geohash5) for date: 20190621, hours: 0-3
# 2024-07-02 23:34:33,116 - INFO - Querying data for date: 20190621, hours: 3-6
# 2024-07-02 23:35:22,406 - INFO - Processing data for date: 20190621, hours: 3-6
# 2024-07-02 23:35:22,434 - INFO - Exporting aggregated data (geohash3) for date: 20190621, hours: 3-6
# 2024-07-02 23:35:22,469 - INFO - Exporting aggregated data (geohash5) for date: 20190621, hours: 3-6
# 2024-07-02 23:35:22,490 - INFO - Querying data for date: 20190621, hours: 6-9
# 2024-07-02 23:36:03,244 - INFO - Processing data for date: 20190621, hours: 6-9
# 2024-07-02 23:36:03,311 - INFO - Exporting aggregated data (geohash3) for date: 20190621, hours: 6-9
# 2024-07-02 23:36:03,389 - INFO - Exporting aggregated data (geohash5) for date: 20190621, hours: 6-9
# 2024-07-02 23:36:03,424 - INFO - Querying data for date: 20190621, hours: 9-12
# 2024-07-02 23:36:37,388 - INFO - Processing data for date: 20190621, hours: 9-12
# 2024-07-02 23:36:37,493 - INFO - Exporting aggregated data (geohash3) for date: 20190621, hours: 9-12
# 2024-07-02 23:36:37,591 - INFO - Exporting aggregated data (geohash5) for date: 20190621, hours: 9-12
# 2024-07-02 23:36:37,638 - INFO - Querying data for date: 20190621, hours: 12-15
# 2024-07-02 23:46:07,480 - INFO - Exporting aggregated data (geohash5) for date: 20190623, hours: 9-12
# 2024-07-02 23:46:07,538 - INFO - Querying data for date: 20190623, hours: 12-15
# 2024-07-02 23:46:32,597 - INFO - Processing data for date: 20190623, hours: 12-15
# 2024-07-02 23:46:32,697 - INFO - Exporting aggregated data (geohash3) for date: 20190623, hours: 12-15
# 2024-07-02 23:46:32,799 - INFO - Exporting aggregated data (geohash5) for date: 20190623, hours: 12-15
# 2024-07-02 23:46:32,836 - INFO - Querying data for date: 20190623, hours: 15-18
# 2024-07-02 23:47:04,196 - INFO - Processing data for date: 20190623, hours: 15-18
# 2024-07-02 23:47:04,287 - INFO - Exporting aggregated data (geohash3) for date: 20190623, hours: 15-18
# 2024-07-02 23:47:04,378 - INFO - Exporting aggregated data (geohash5) for date: 20190623, hours: 15-18
# 2024-07-02 23:47:04,416 - INFO - Querying data for date: 20190623, hours: 18-21
# 2024-07-02 23:47:33,156 - INFO - Processing data for date: 20190623, hours: 18-21
# 2024-07-02 23:47:33,234 - INFO - Exporting aggregated data (geohash3) for date: 20190623, hours: 18-21
# 2024-07-02 23:47:33,314 - INFO - Exporting aggregated data (geohash5) for date: 20190623, hours: 18-21
# 2024-07-02 23:47:33,347 - INFO - Querying data for date: 20190623, hours: 21-24
# 2024-07-02 23:47:56,324 - INFO - Processing data for date: 20190623, hours: 21-24
# 2024-07-02 23:47:56,384 - INFO - Exporting aggregated data (geohash3) for date: 20190623, hours: 21-24
# 2024-07-02 23:47:56,431 - INFO - Exporting aggregated data (geohash5) for date: 20190623, hours: 21-24
# 2024-07-02 23:47:56,571 - INFO - Processing data for date: 20190624
# 2024-07-02 23:47:56,572 - INFO - Querying data for date: 20190624, hours: 0-3
# 2024-07-02 23:48:18,440 - INFO - Processing data for date: 20190624, hours: 0-3
# 2024-07-02 23:48:18,462 - INFO - Exporting aggregated data (geohash3) for date: 20190624, hours: 0-3
# 2024-07-02 23:48:18,495 - INFO - Exporting aggregated data (geohash5) for date: 20190624, hours: 0-3
# 2024-07-02 23:48:18,513 - INFO - Querying data for date: 20190624, hours: 3-6
# 2024-07-02 23:48:38,111 - INFO - Processing data for date: 20190624, hours: 3-6
# 2024-07-02 23:48:38,136 - INFO - Exporting aggregated data (geohash3) for date: 20190624, hours: 3-6
# 2024-07-02 23:48:38,200 - INFO - Exporting aggregated data (geohash5) for date: 20190624, hours: 3-6
# 2024-07-02 23:48:38,213 - INFO - Querying data for date: 20190624, hours: 6-9
# 2024-07-02 23:48:56,191 - INFO - Processing data for date: 20190624, hours: 6-9
# 2024-07-02 23:48:56,247 - INFO - Exporting aggregated data (geohash3) for date: 20190624, hours: 6-9
# 2024-07-02 23:48:56,313 - INFO - Exporting aggregated data (geohash5) for date: 20190624, hours: 6-9
# 2024-07-02 23:48:56,341 - INFO - Querying data for date: 20190624, hours: 9-12
# 2024-07-02 23:49:27,840 - INFO - Processing data for date: 20190624, hours: 9-12
# 2024-07-03 01:00:30,382 - INFO - Exporting aggregated data (geohash5) for date: 20190709, hours: 12-15
# 2024-07-03 01:00:30,428 - INFO - Querying data for date: 20190709, hours: 15-18
# 2024-07-03 01:01:12,232 - INFO - Processing data for date: 20190709, hours: 15-18
# 2024-07-03 01:01:12,335 - INFO - Exporting aggregated data (geohash3) for date: 20190709, hours: 15-18
# 2024-07-03 01:01:12,435 - INFO - Exporting aggregated data (geohash5) for date: 20190709, hours: 15-18
# 2024-07-03 01:01:12,477 - INFO - Querying data for date: 20190709, hours: 18-21
# 2024-07-03 01:01:42,190 - INFO - Processing data for date: 20190709, hours: 18-21
# 2024-07-03 01:01:42,283 - INFO - Exporting aggregated data (geohash3) for date: 20190709, hours: 18-21
# 2024-07-03 01:01:42,364 - INFO - Exporting aggregated data (geohash5) for date: 20190709, hours: 18-21
# 2024-07-03 01:01:42,411 - INFO - Querying data for date: 20190709, hours: 21-24
# 2024-07-03 01:02:14,678 - INFO - Processing data for date: 20190709, hours: 21-24
# 2024-07-03 01:02:14,735 - INFO - Exporting aggregated data (geohash3) for date: 20190709, hours: 21-24
# 2024-07-03 01:02:14,780 - INFO - Exporting aggregated data (geohash5) for date: 20190709, hours: 21-24
# 2024-07-03 01:02:14,903 - INFO - Processing data for date: 20190710
# 2024-07-03 01:02:14,904 - INFO - Querying data for date: 20190710, hours: 0-3
# 2024-07-03 01:03:13,127 - INFO - Processing data for date: 20190710, hours: 0-3
# 2024-07-03 01:03:13,147 - INFO - Exporting aggregated data (geohash3) for date: 20190710, hours: 0-3
# 2024-07-03 01:03:13,179 - INFO - Exporting aggregated data (geohash5) for date: 20190710, hours: 0-3
# 2024-07-03 01:03:13,197 - INFO - Querying data for date: 20190710, hours: 3-6
# 2024-07-03 01:03:49,226 - INFO - Processing data for date: 20190710, hours: 3-6
# 2024-07-03 01:03:49,249 - INFO - Exporting aggregated data (geohash3) for date: 20190710, hours: 3-6
# 2024-07-03 01:03:49,288 - INFO - Exporting aggregated data (geohash5) for date: 20190710, hours: 3-6
# 2024-07-03 01:03:49,307 - INFO - Querying data for date: 20190710, hours: 6-9
# 2024-07-03 01:04:21,964 - INFO - Processing data for date: 20190710, hours: 6-9
# 2024-07-03 01:04:22,016 - INFO - Exporting aggregated data (geohash3) for date: 20190710, hours: 6-9
# 2024-07-03 01:04:22,076 - INFO - Exporting aggregated data (geohash5) for date: 20190710, hours: 6-9
# 2024-07-03 01:04:22,102 - INFO - Querying data for date: 20190710, hours: 9-12

# %% [markdown]
# # Fillin Gaps

# %%
import time
import pandas as pd
import os
import logging
from datetime import datetime

# Configure logging
logging.basicConfig(level=logging.INFO, format='%(asctime)s - %(levelname)s - %(message)s')

# Function to process data for a specific date and time intervals
def process_data_for_date(event_date, country_code, export_path, start_hour, end_hour):
    # Define the export file paths
    csv3_file = f"od_{country_code.lower()}2_agg3_3h.csv"
    csv5_file = f"od_{country_code.lower()}2_agg5_3h.csv"
    csv3_file_path = f"{export_path}{csv3_file}"
    csv5_file_path = f"{export_path}{csv5_file}"

    # Loop through the specified hours in increments of 3 hours
    for hour in range(start_hour, end_hour, 3):
        next_hour = hour + 3  # end hour for the 3-hour interval
        logging.info(f"Querying data for date: {event_date}, hours: {hour}-{next_hour}")

        # Fetch the data for the specified event date and country code
        pe_tj_df3 = sql_engine.read_sql(
            f"""
            SELECT 
                cuebiq_id,
                duration_minutes,
                length_meters,
                number_of_points,
                TRY(date_parse(substr(start_zoned_datetime, 1, 19), '%Y-%m-%dT%H:%i:%s')) AS event_datetime_local,
                EXTRACT(HOUR FROM TRY(date_parse(substr(start_zoned_datetime, 1, 19), '%Y-%m-%dT%H:%i:%s'))) AS event_hour,
                geohash_encode(start_lat, start_lng, 5) AS start_geohash5,
                geohash_encode(start_lat, start_lng, 3) AS start_geohash3,
                geohash_encode(end_lat, end_lng, 5) AS end_geohash5,
                geohash_encode(end_lat, end_lng, 3) AS end_geohash3,
                DATE_FORMAT(date_parse(substr(start_zoned_datetime, 1, 10), '%Y-%m-%d'), '%Y%m%d') AS local_date
            FROM cuebiq.paas_cda_pe_v3.trajectory_uplevelled
            WHERE 
                event_date = {event_date}
                AND end_country = '{country_code}' 
                AND start_country = '{country_code}' 
            """
        )

        # Filter the DataFrame for the current 3-hour interval
        logging.info(f"Processing data for date: {event_date}, hours: {hour}-{next_hour}")
        filtered_df = pe_tj_df3[(pe_tj_df3['event_hour'] >= hour) & (pe_tj_df3['event_hour'] < next_hour)]

        # Add user numbers to the aggregated data for geohash3
        aggregated_df3 = filtered_df.groupby(['start_geohash3', 'end_geohash3', 'local_date']).agg({
            'cuebiq_id': 'count',
            'duration_minutes': ['mean', 'median', 'std'],
            'length_meters': ['mean', 'median', 'std'],
            'number_of_points': ['mean', 'median', 'std']
        }).reset_index()

        # Flatten the MultiIndex columns
        aggregated_df3.columns = ['start_geohash3', 'end_geohash3', 'local_date', 'trip_count', 
                                  'm_duration_min', 'mdn_duration_min', 'sd_duration_min', 
                                  'm_length_m', 'mdn_length_m', 'sd_length_m',
                                  'm_points_no', 'mdn_points_no', 'sd_points_no']

        # Add the local_time column
        aggregated_df3['local_time'] = aggregated_df3['local_date'].astype(str) + \
                                       f" {hour:02d}:00:00 - {next_hour:02d}:00:00"

        # Filter out rows where trip_count is less than or equal to 9
        aggregated_df3 = aggregated_df3[aggregated_df3['trip_count'] > 9]

        # Append the results to the CSV file for geohash3
        logging.info(f"Exporting aggregated data (geohash3) for date: {event_date}, hours: {hour}-{next_hour}")
        if not os.path.isfile(csv3_file_path):
            aggregated_df3.to_csv(csv3_file_path, index=False)
        else:
            aggregated_df3.to_csv(csv3_file_path, mode='a', header=False, index=False)

        # Add user numbers to the aggregated data for geohash5
        aggregated_df5 = filtered_df.groupby(['start_geohash5', 'end_geohash5', 'local_date']).agg({
            'cuebiq_id': 'count',
            'duration_minutes': ['mean', 'median', 'std'],
            'length_meters': ['mean', 'median', 'std'],
            'number_of_points': ['mean', 'median', 'std']
        }).reset_index()

        # Flatten the MultiIndex columns
        aggregated_df5.columns = ['start_geohash5', 'end_geohash5', 'local_date', 'trip_count', 
                                  'm_duration_min', 'mdn_duration_min', 'sd_duration_min', 
                                  'm_length_m', 'mdn_length_m', 'sd_length_m',
                                  'm_points_no', 'mdn_points_no', 'sd_points_no']

        # Add the local_time column
        aggregated_df5['local_time'] = aggregated_df5['local_date'].astype(str) + \
                                       f" {hour:02d}:00:00 - {next_hour:02d}:00:00"

        # Filter out rows where trip_count is less than or equal to 9
        aggregated_df5 = aggregated_df5[aggregated_df5['trip_count'] > 9]

        # Append the results to the CSV file for geohash5
        logging.info(f"Exporting aggregated data (geohash5) for date: {event_date}, hours: {hour}-{next_hour}")
        if not os.path.isfile(csv5_file_path):
            aggregated_df5.to_csv(csv5_file_path, index=False)
        else:
            aggregated_df5.to_csv(csv5_file_path, mode='a', header=False, index=False)

# Specify the date and initial time interval
event_date = "20190205"
start_hour = 6
end_hour = 24  # Process until the end of the day
country_code = 'MX'
export_path = '/home/jovyan/Data/TJ/3h/'

# Process data for the specified date and time intervals
process_data_for_date(event_date, country_code, export_path, start_hour, end_hour)
# Out:
# 2024-07-02 22:32:52,248 - INFO - Querying data for date: 20190205, hours: 6-9
# 2024-07-02 22:33:46,783 - INFO - Processing data for date: 20190205, hours: 6-9
# 2024-07-02 22:33:46,842 - INFO - Exporting aggregated data (geohash3) for date: 20190205, hours: 6-9
# 2024-07-02 22:33:46,916 - INFO - Exporting aggregated data (geohash5) for date: 20190205, hours: 6-9
# 2024-07-02 22:33:46,949 - INFO - Querying data for date: 20190205, hours: 9-12
# 2024-07-02 22:34:22,322 - INFO - Processing data for date: 20190205, hours: 9-12
# 2024-07-02 22:34:22,419 - INFO - Exporting aggregated data (geohash3) for date: 20190205, hours: 9-12
# 2024-07-02 22:34:22,514 - INFO - Exporting aggregated data (geohash5) for date: 20190205, hours: 9-12
# 2024-07-02 22:34:22,553 - INFO - Querying data for date: 20190205, hours: 12-15
# 2024-07-02 22:34:56,744 - INFO - Processing data for date: 20190205, hours: 12-15
# 2024-07-02 22:34:56,870 - INFO - Exporting aggregated data (geohash3) for date: 20190205, hours: 12-15
# 2024-07-02 22:34:57,009 - INFO - Exporting aggregated data (geohash5) for date: 20190205, hours: 12-15
# 2024-07-02 22:34:57,055 - INFO - Querying data for date: 20190205, hours: 15-18
# 2024-07-02 22:35:28,989 - INFO - Processing data for date: 20190205, hours: 15-18
# 2024-07-02 22:35:29,135 - INFO - Exporting aggregated data (geohash3) for date: 20190205, hours: 15-18
# 2024-07-02 22:35:29,250 - INFO - Exporting aggregated data (geohash5) for date: 20190205, hours: 15-18
# 2024-07-02 22:35:29,295 - INFO - Querying data for date: 20190205, hours: 18-21
# 2024-07-02 22:36:06,914 - INFO - Processing data for date: 20190205, hours: 18-21
# 2024-07-02 22:36:07,016 - INFO - Exporting aggregated data (geohash3) for date: 20190205, hours: 18-21
# 2024-07-02 22:36:07,107 - INFO - Exporting aggregated data (geohash5) for date: 20190205, hours: 18-21
# 2024-07-02 22:36:07,148 - INFO - Querying data for date: 20190205, hours: 21-24
# 2024-07-02 22:36:45,800 - INFO - Processing data for date: 20190205, hours: 21-24
# 2024-07-02 22:36:45,853 - INFO - Exporting aggregated data (geohash3) for date: 20190205, hours: 21-24
# 2024-07-02 22:36:45,897 - INFO - Exporting aggregated data (geohash5) for date: 20190205, hours: 21-24
