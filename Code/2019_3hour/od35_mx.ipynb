# %%
# %reload_ext sql
# %config SqlMagic.autocommit=False
# %config SqlMagic.autolimit=0
# %config SqlMagic.autopandas=True
# %config SqlMagic.displaylimit=200

# %%
# %sql trino://localhost:9090/cuebiq/
# Out:
# 'Connected: @cuebiq/'

# %%
pip install python-geohash
# Out:
# Requirement already satisfied: python-geohash in /srv/conda/envs/notebook/lib/python3.9/site-packages (0.8.5)
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
import time
import geohash
import logging
import pandas as pd
from datetime import datetime, timedelta
from sqlalchemy import create_engine

# %%
# SQL engine
from trino.dbapi import connect 
from sqlalchemy import create_engine
import pandas as pd
import time

class TrinoEngine():
    def __init__(self):
        conn = connect(
            host="localhost",
            port=9090,
            catalog="cuebiq"
        )
        self.cur = conn.cursor()
        self.engine = create_engine("trino://localhost:9090/cuebiq/")
    
    def execute_statement(self, query:str) -> list:
        """
        Create and drop statements.
        """
        self.cur.execute(query)
        return self.cur.fetchall()
    
    def read_sql(self, query:str) -> pd.DataFrame: 
        """
        Select and insert into operations.
        """
        return pd.read_sql(query, self.engine)

sql_engine = TrinoEngine()

# %%
schema_name = {'cda': 'cuebiq.paas_cda_pe_v3'}
pe_tj_table = f"{schema_name['cda']}.trajectory_uplevelled"

# %% [markdown]
# # Export to local

# %%
# Set up logging
logging.basicConfig(level=logging.INFO, format='%(asctime)s - %(levelname)s - %(message)s')

# %%
# Function to process data for a specific date
def process_data_for_date(event_date, country_code, export_path):
    errors = []  # List to keep track of errors
    
    # Define the export file paths
    csv3_file = f"od_{country_code.lower()}_agg3_3h.csv"
    csv5_file = f"od_{country_code.lower()}_agg5_3h.csv"
    csv3_file_path = f"{export_path}{csv3_file}"
    csv5_file_path = f"{export_path}{csv5_file}"

    # Loop through 24 hours in increments of 3 hours
    for start_hour in range(0, 24, 3):
        end_hour = start_hour + 3  # end hour for the 3-hour interval
        logging.info(f"Querying data for date: {event_date}, hours: {start_hour}-{end_hour}")

        try:
            # Fetch the data for the specified event date and country code
            pe_tj_df3 = sql_engine.read_sql(
                f"""
                SELECT 
                    cuebiq_id,
                    duration_minutes,
                    length_meters,
                    number_of_points,
                    TRY(date_parse(substr(start_zoned_datetime, 1, 19), '%Y-%m-%dT%H:%i:%s')) AS event_datetime_local,
                    EXTRACT(HOUR FROM TRY(date_parse(substr(start_zoned_datetime, 1, 19), '%Y-%m-%dT%H:%i:%s'))) AS event_hour,
                    geohash_encode(start_lat, start_lng, 5) AS start_geohash5,
                    geohash_encode(start_lat, start_lng, 3) AS start_geohash3,
                    geohash_encode(end_lat, end_lng, 5) AS end_geohash5,
                    geohash_encode(end_lat, end_lng, 3) AS end_geohash3,
                    DATE_FORMAT(date_parse(substr(start_zoned_datetime, 1, 10), '%Y-%m-%d'), '%Y%m%d') AS local_date
                FROM cuebiq.paas_cda_pe_v3.trajectory_uplevelled
                WHERE 
                    event_date = {event_date}
                    AND end_country = '{country_code}' 
                    AND start_country = '{country_code}' 
                """
            )

            # Filter the DataFrame for the current 3-hour interval
            logging.info(f"Processing data for date: {event_date}, hours: {start_hour}-{end_hour}")
            filtered_df = pe_tj_df3[(pe_tj_df3['event_hour'] >= start_hour) & (pe_tj_df3['event_hour'] < end_hour)]

            # Add user numbers to the aggregated data for geohash3
            aggregated_df3 = filtered_df.groupby(['start_geohash3', 'end_geohash3', 'local_date']).agg({
                'cuebiq_id': 'count',
                'duration_minutes': ['mean', 'median', 'std'],
                'length_meters': ['mean', 'median', 'std'],
                'number_of_points': ['mean', 'median', 'std']
            }).reset_index()

            # Flatten the MultiIndex columns
            aggregated_df3.columns = ['start_geohash3', 'end_geohash3', 'local_date', 'trip_count', 
                                      'm_duration_min', 'mdn_duration_min', 'sd_duration_min', 
                                      'm_length_m', 'mdn_length_m', 'sd_length_m',
                                      'm_points_no', 'mdn_points_no', 'sd_points_no']

            # Add the local_time column
            aggregated_df3['local_time'] = aggregated_df3['local_date'].astype(str) + \
                                           f" {start_hour:02d}:00:00 - {end_hour:02d}:00:00"

            # Filter out rows where trip_count is less than or equal to 9
            aggregated_df3 = aggregated_df3[aggregated_df3['trip_count'] > 9]

            # Append the results to the CSV file for geohash3
            logging.info(f"Exporting aggregated data (geohash3) for date: {event_date}, hours: {start_hour}-{end_hour}")
            if not os.path.isfile(csv3_file_path):
                aggregated_df3.to_csv(csv3_file_path, index=False)
            else:
                aggregated_df3.to_csv(csv3_file_path, mode='a', header=False, index=False)

            # Add user numbers to the aggregated data for geohash5
            aggregated_df5 = filtered_df.groupby(['start_geohash5', 'end_geohash5', 'local_date']).agg({
                'cuebiq_id': 'count',
                'duration_minutes': ['mean', 'median', 'std'],
                'length_meters': ['mean', 'median', 'std'],
                'number_of_points': ['mean', 'median', 'std']
            }).reset_index()

            # Flatten the MultiIndex columns
            aggregated_df5.columns = ['start_geohash5', 'end_geohash5', 'local_date', 'trip_count', 
                                      'm_duration_min', 'mdn_duration_min', 'sd_duration_min', 
                                      'm_length_m', 'mdn_length_m', 'sd_length_m',
                                      'm_points_no', 'mdn_points_no', 'sd_points_no']

            # Add the local_time column
            aggregated_df5['local_time'] = aggregated_df5['local_date'].astype(str) + \
                                           f" {start_hour:02d}:00:00 - {end_hour:02d}:00:00"

            # Filter out rows where trip_count is less than or equal to 9
            aggregated_df5 = aggregated_df5[aggregated_df5['trip_count'] > 9]

            # Append the results to the CSV file for geohash5
            logging.info(f"Exporting aggregated data (geohash5) for date: {event_date}, hours: {start_hour}-{end_hour}")
            if not os.path.isfile(csv5_file_path):
                aggregated_df5.to_csv(csv5_file_path, index=False)
            else:
                aggregated_df5.to_csv(csv5_file_path, mode='a', header=False, index=False)
        
        except Exception as e:
            error_message = f"Error processing date: {event_date}, hours: {start_hour}-{end_hour} - {str(e)}"
            logging.error(error_message)
            errors.append(error_message)
    
    return errors

# Function to process data for a range of dates
def process_data_for_date_range(start_date, end_date, country_code, export_path):
    current_date = start_date
    all_errors = []
    while current_date <= end_date:
        event_date = current_date.strftime("%Y%m%d")
        logging.info(f"Processing data for date: {event_date}")
        errors = process_data_for_date(event_date, country_code, export_path)
        all_errors.extend(errors)
        current_date += timedelta(days=1)
    
    # Log any errors that occurred
    if all_errors:
        logging.info("Errors occurred during processing:")
        for error in all_errors:
            logging.info(error)

# %%
# Specify the date range
start_date = datetime.strptime("20190525", "%Y%m%d")
end_date = datetime.strptime("20190630", "%Y%m%d")
country_code = 'MX'
export_path = '/home/jovyan/Data/TJ/3h/'

# Process data for the specified date range
process_data_for_date_range(start_date, end_date, country_code, export_path)
# Out:
# 2024-07-03 06:28:08,894 - INFO - Processing data for date: 20190525
# 2024-07-03 06:28:08,895 - INFO - Querying data for date: 20190525, hours: 0-3
# 2024-07-03 06:28:44,187 - INFO - Processing data for date: 20190525, hours: 0-3
# 2024-07-03 06:28:44,219 - INFO - Exporting aggregated data (geohash3) for date: 20190525, hours: 0-3
# 2024-07-03 06:28:44,256 - INFO - Exporting aggregated data (geohash5) for date: 20190525, hours: 0-3
# 2024-07-03 06:28:44,272 - INFO - Querying data for date: 20190525, hours: 3-6
# 2024-07-03 06:29:23,288 - INFO - Processing data for date: 20190525, hours: 3-6
# 2024-07-03 06:29:23,325 - INFO - Exporting aggregated data (geohash3) for date: 20190525, hours: 3-6
# 2024-07-03 06:29:23,361 - INFO - Exporting aggregated data (geohash5) for date: 20190525, hours: 3-6
# 2024-07-03 06:29:23,374 - INFO - Querying data for date: 20190525, hours: 6-9
# 2024-07-03 06:29:49,689 - INFO - Processing data for date: 20190525, hours: 6-9
# 2024-07-03 06:29:49,751 - INFO - Exporting aggregated data (geohash3) for date: 20190525, hours: 6-9
# 2024-07-03 06:29:49,817 - INFO - Exporting aggregated data (geohash5) for date: 20190525, hours: 6-9
# 2024-07-03 06:29:49,844 - INFO - Querying data for date: 20190525, hours: 9-12
# 2024-07-03 06:30:43,439 - INFO - Processing data for date: 20190525, hours: 9-12
# 2024-07-03 06:30:43,554 - INFO - Exporting aggregated data (geohash3) for date: 20190525, hours: 9-12
# 2024-07-03 06:30:43,670 - INFO - Exporting aggregated data (geohash5) for date: 20190525, hours: 9-12
# 2024-07-03 06:30:43,708 - INFO - Querying data for date: 20190525, hours: 12-15
# 2024-07-03 06:31:07,122 - INFO - Processing data for date: 20190525, hours: 12-15
# 2024-07-03 06:31:07,371 - INFO - Exporting aggregated data (geohash3) for date: 20190525, hours: 12-15
# 2024-07-03 06:31:07,533 - INFO - Exporting aggregated data (geohash5) for date: 20190525, hours: 12-15
# 2024-07-03 06:31:07,593 - INFO - Querying data for date: 20190525, hours: 15-18
# 2024-07-03 06:31:35,602 - INFO - Processing data for date: 20190525, hours: 15-18
# 2024-07-03 06:31:35,726 - INFO - Exporting aggregated data (geohash3) for date: 20190525, hours: 15-18
# 2024-07-03 06:31:35,835 - INFO - Exporting aggregated data (geohash5) for date: 20190525, hours: 15-18
# 2024-07-03 06:31:35,880 - INFO - Querying data for date: 20190525, hours: 18-21
# 2024-07-03 06:32:19,762 - INFO - Processing data for date: 20190525, hours: 18-21
# 2024-07-03 06:32:19,876 - INFO - Exporting aggregated data (geohash3) for date: 20190525, hours: 18-21
# 2024-07-03 06:32:19,973 - INFO - Exporting aggregated data (geohash5) for date: 20190525, hours: 18-21
# 2024-07-03 06:32:20,014 - INFO - Querying data for date: 20190525, hours: 21-24
# 2024-07-03 06:33:11,709 - INFO - Processing data for date: 20190525, hours: 21-24
# 2024-07-03 06:33:11,785 - INFO - Exporting aggregated data (geohash3) for date: 20190525, hours: 21-24
# 2024-07-03 06:33:11,843 - INFO - Exporting aggregated data (geohash5) for date: 20190525, hours: 21-24
# 2024-07-03 06:33:12,022 - INFO - Processing data for date: 20190526
# 2024-07-03 06:33:12,022 - INFO - Querying data for date: 20190526, hours: 0-3
# 2024-07-03 06:34:37,460 - INFO - Processing data for date: 20190526, hours: 0-3
# 2024-07-03 06:34:37,495 - INFO - Exporting aggregated data (geohash3) for date: 20190526, hours: 0-3
# 2024-07-03 06:34:37,539 - INFO - Exporting aggregated data (geohash5) for date: 20190526, hours: 0-3
# 2024-07-03 06:34:37,560 - INFO - Querying data for date: 20190526, hours: 3-6
# 2024-07-03 06:35:37,189 - INFO - Processing data for date: 20190526, hours: 3-6
# 2024-07-03 06:35:37,225 - INFO - Exporting aggregated data (geohash3) for date: 20190526, hours: 3-6
# 2024-07-03 06:35:37,265 - INFO - Exporting aggregated data (geohash5) for date: 20190526, hours: 3-6
# 2024-07-03 06:35:37,281 - INFO - Querying data for date: 20190526, hours: 6-9
# 2024-07-03 06:36:33,018 - INFO - Processing data for date: 20190526, hours: 6-9
# 2024-07-03 06:36:33,068 - INFO - Exporting aggregated data (geohash3) for date: 20190526, hours: 6-9
# 2024-07-03 06:36:33,125 - INFO - Exporting aggregated data (geohash5) for date: 20190526, hours: 6-9
# 2024-07-03 06:36:33,146 - INFO - Querying data for date: 20190526, hours: 9-12
# 2024-07-03 06:37:01,537 - INFO - Processing data for date: 20190526, hours: 9-12
# 2024-07-03 06:37:01,620 - INFO - Exporting aggregated data (geohash3) for date: 20190526, hours: 9-12
# 2024-07-03 06:37:01,705 - INFO - Exporting aggregated data (geohash5) for date: 20190526, hours: 9-12
# 2024-07-03 06:37:01,744 - INFO - Querying data for date: 20190526, hours: 12-15
# 2024-07-03 06:37:51,388 - INFO - Processing data for date: 20190526, hours: 12-15
# 2024-07-03 06:37:51,493 - INFO - Exporting aggregated data (geohash3) for date: 20190526, hours: 12-15
# 2024-07-03 06:37:51,594 - INFO - Exporting aggregated data (geohash5) for date: 20190526, hours: 12-15
# 2024-07-03 06:37:51,633 - INFO - Querying data for date: 20190526, hours: 15-18
# 2024-07-03 06:38:47,071 - INFO - Processing data for date: 20190526, hours: 15-18
# 2024-07-03 06:38:47,211 - INFO - Exporting aggregated data (geohash3) for date: 20190526, hours: 15-18
# 2024-07-03 06:38:47,318 - INFO - Exporting aggregated data (geohash5) for date: 20190526, hours: 15-18
# 2024-07-03 06:38:47,355 - INFO - Querying data for date: 20190526, hours: 18-21
# 2024-07-03 06:39:51,850 - INFO - Processing data for date: 20190526, hours: 18-21
# 2024-07-03 06:39:51,944 - INFO - Exporting aggregated data (geohash3) for date: 20190526, hours: 18-21
# 2024-07-03 06:39:52,029 - INFO - Exporting aggregated data (geohash5) for date: 20190526, hours: 18-21
# 2024-07-03 06:39:52,061 - INFO - Querying data for date: 20190526, hours: 21-24
# 2024-07-03 06:40:39,647 - INFO - Processing data for date: 20190526, hours: 21-24
# 2024-07-03 06:40:39,708 - INFO - Exporting aggregated data (geohash3) for date: 20190526, hours: 21-24
# 2024-07-03 06:40:39,757 - INFO - Exporting aggregated data (geohash5) for date: 20190526, hours: 21-24
# 2024-07-03 06:40:39,902 - INFO - Processing data for date: 20190527
# 2024-07-03 06:40:39,903 - INFO - Querying data for date: 20190527, hours: 0-3
# 2024-07-03 06:42:03,393 - INFO - Processing data for date: 20190527, hours: 0-3
# 2024-07-03 06:42:03,421 - INFO - Exporting aggregated data (geohash3) for date: 20190527, hours: 0-3
# 2024-07-03 06:42:03,467 - INFO - Exporting aggregated data (geohash5) for date: 20190527, hours: 0-3
# 2024-07-03 06:42:03,482 - INFO - Querying data for date: 20190527, hours: 3-6
# 2024-07-03 06:42:38,291 - INFO - Processing data for date: 20190527, hours: 3-6
# 2024-07-03 06:42:38,326 - INFO - Exporting aggregated data (geohash3) for date: 20190527, hours: 3-6
# 2024-07-03 06:42:38,361 - INFO - Exporting aggregated data (geohash5) for date: 20190527, hours: 3-6
# 2024-07-03 06:42:38,375 - INFO - Querying data for date: 20190527, hours: 6-9
# 2024-07-03 06:43:46,222 - INFO - Processing data for date: 20190527, hours: 6-9
# 2024-07-03 06:43:46,299 - INFO - Exporting aggregated data (geohash3) for date: 20190527, hours: 6-9
# 2024-07-03 06:43:46,379 - INFO - Exporting aggregated data (geohash5) for date: 20190527, hours: 6-9
# 2024-07-03 06:43:46,410 - INFO - Querying data for date: 20190527, hours: 9-12
# 2024-07-03 06:44:53,343 - INFO - Processing data for date: 20190527, hours: 9-12
# 2024-07-03 06:44:53,470 - INFO - Exporting aggregated data (geohash3) for date: 20190527, hours: 9-12
# 2024-07-03 06:44:53,577 - INFO - Exporting aggregated data (geohash5) for date: 20190527, hours: 9-12
# 2024-07-03 06:44:53,618 - INFO - Querying data for date: 20190527, hours: 12-15
# 2024-07-03 06:45:48,288 - INFO - Processing data for date: 20190527, hours: 12-15
# 2024-07-03 06:45:48,425 - INFO - Exporting aggregated data (geohash3) for date: 20190527, hours: 12-15
# 2024-07-03 06:45:48,547 - INFO - Exporting aggregated data (geohash5) for date: 20190527, hours: 12-15
# 2024-07-03 06:45:48,592 - INFO - Querying data for date: 20190527, hours: 15-18
# 2024-07-03 06:46:53,204 - INFO - Processing data for date: 20190527, hours: 15-18
# 2024-07-03 06:46:53,350 - INFO - Exporting aggregated data (geohash3) for date: 20190527, hours: 15-18
# 2024-07-03 06:46:53,466 - INFO - Exporting aggregated data (geohash5) for date: 20190527, hours: 15-18
# 2024-07-03 06:46:53,509 - INFO - Querying data for date: 20190527, hours: 18-21
# 2024-07-03 06:47:40,150 - INFO - Processing data for date: 20190527, hours: 18-21
# 2024-07-03 06:47:40,272 - INFO - Exporting aggregated data (geohash3) for date: 20190527, hours: 18-21
# 2024-07-03 06:47:40,365 - INFO - Exporting aggregated data (geohash5) for date: 20190527, hours: 18-21
# 2024-07-03 06:47:40,412 - INFO - Querying data for date: 20190527, hours: 21-24
# 2024-07-03 06:48:29,373 - INFO - Processing data for date: 20190527, hours: 21-24
# 2024-07-03 06:48:29,443 - INFO - Exporting aggregated data (geohash3) for date: 20190527, hours: 21-24
# 2024-07-03 06:48:29,495 - INFO - Exporting aggregated data (geohash5) for date: 20190527, hours: 21-24
# 2024-07-03 06:48:29,663 - INFO - Processing data for date: 20190528
# 2024-07-03 06:48:29,663 - INFO - Querying data for date: 20190528, hours: 0-3
# 2024-07-03 06:49:46,474 - INFO - Processing data for date: 20190528, hours: 0-3
# 2024-07-03 06:49:46,502 - INFO - Exporting aggregated data (geohash3) for date: 20190528, hours: 0-3
# 2024-07-03 06:49:46,584 - INFO - Exporting aggregated data (geohash5) for date: 20190528, hours: 0-3
# 2024-07-03 06:49:46,602 - INFO - Querying data for date: 20190528, hours: 3-6
# 2024-07-03 06:51:08,413 - INFO - Processing data for date: 20190528, hours: 3-6
# 2024-07-03 06:51:08,447 - INFO - Exporting aggregated data (geohash3) for date: 20190528, hours: 3-6
# 2024-07-03 06:51:08,484 - INFO - Exporting aggregated data (geohash5) for date: 20190528, hours: 3-6
# 2024-07-03 06:51:08,499 - INFO - Querying data for date: 20190528, hours: 6-9
# 2024-07-03 06:52:12,234 - INFO - Processing data for date: 20190528, hours: 6-9
# 2024-07-03 06:52:12,317 - INFO - Exporting aggregated data (geohash3) for date: 20190528, hours: 6-9
# 2024-07-03 06:52:12,400 - INFO - Exporting aggregated data (geohash5) for date: 20190528, hours: 6-9
# 2024-07-03 06:52:12,434 - INFO - Querying data for date: 20190528, hours: 9-12
# 2024-07-03 06:52:48,484 - INFO - Processing data for date: 20190528, hours: 9-12
# 2024-07-03 06:52:48,606 - INFO - Exporting aggregated data (geohash3) for date: 20190528, hours: 9-12
# 2024-07-03 06:52:48,710 - INFO - Exporting aggregated data (geohash5) for date: 20190528, hours: 9-12
# 2024-07-03 06:52:48,753 - INFO - Querying data for date: 20190528, hours: 12-15
# 2024-07-03 06:53:25,876 - INFO - Processing data for date: 20190528, hours: 12-15
# 2024-07-03 06:53:26,056 - INFO - Exporting aggregated data (geohash3) for date: 20190528, hours: 12-15
# 2024-07-03 06:53:26,199 - INFO - Exporting aggregated data (geohash5) for date: 20190528, hours: 12-15
# 2024-07-03 06:53:26,248 - INFO - Querying data for date: 20190528, hours: 15-18
# 2024-07-03 06:53:50,983 - INFO - Processing data for date: 20190528, hours: 15-18
# 2024-07-03 06:53:51,119 - INFO - Exporting aggregated data (geohash3) for date: 20190528, hours: 15-18
# 2024-07-03 06:53:51,243 - INFO - Exporting aggregated data (geohash5) for date: 20190528, hours: 15-18
# 2024-07-03 06:53:51,288 - INFO - Querying data for date: 20190528, hours: 18-21
# 2024-07-03 06:54:54,612 - INFO - Processing data for date: 20190528, hours: 18-21
# 2024-07-03 06:54:54,729 - INFO - Exporting aggregated data (geohash3) for date: 20190528, hours: 18-21
# 2024-07-03 06:54:54,826 - INFO - Exporting aggregated data (geohash5) for date: 20190528, hours: 18-21
# 2024-07-03 06:54:54,866 - INFO - Querying data for date: 20190528, hours: 21-24
# 2024-07-03 06:55:53,393 - INFO - Processing data for date: 20190528, hours: 21-24
# 2024-07-03 06:55:53,461 - INFO - Exporting aggregated data (geohash3) for date: 20190528, hours: 21-24
# 2024-07-03 06:55:53,511 - INFO - Exporting aggregated data (geohash5) for date: 20190528, hours: 21-24
# 2024-07-03 06:55:53,678 - INFO - Processing data for date: 20190529
# 2024-07-03 06:55:53,679 - INFO - Querying data for date: 20190529, hours: 0-3
# 2024-07-03 06:57:26,842 - INFO - Processing data for date: 20190529, hours: 0-3
# 2024-07-03 06:57:26,865 - INFO - Exporting aggregated data (geohash3) for date: 20190529, hours: 0-3
# 2024-07-03 06:57:26,898 - INFO - Exporting aggregated data (geohash5) for date: 20190529, hours: 0-3
# 2024-07-03 06:57:26,913 - INFO - Querying data for date: 20190529, hours: 3-6
# 2024-07-03 06:58:20,070 - INFO - Processing data for date: 20190529, hours: 3-6
# 2024-07-03 06:58:20,172 - INFO - Exporting aggregated data (geohash3) for date: 20190529, hours: 3-6
# 2024-07-03 06:58:20,282 - INFO - Exporting aggregated data (geohash5) for date: 20190529, hours: 3-6
# 2024-07-03 06:58:20,302 - INFO - Querying data for date: 20190529, hours: 6-9
# 2024-07-03 06:58:56,714 - INFO - Processing data for date: 20190529, hours: 6-9
# 2024-07-03 06:58:56,800 - INFO - Exporting aggregated data (geohash3) for date: 20190529, hours: 6-9
# 2024-07-03 06:58:56,907 - INFO - Exporting aggregated data (geohash5) for date: 20190529, hours: 6-9
# 2024-07-03 06:58:56,945 - INFO - Querying data for date: 20190529, hours: 9-12
# 2024-07-03 06:59:39,626 - INFO - Processing data for date: 20190529, hours: 9-12
# 2024-07-03 06:59:39,763 - INFO - Exporting aggregated data (geohash3) for date: 20190529, hours: 9-12
# 2024-07-03 06:59:39,871 - INFO - Exporting aggregated data (geohash5) for date: 20190529, hours: 9-12
# 2024-07-03 06:59:39,914 - INFO - Querying data for date: 20190529, hours: 12-15
# 2024-07-03 07:00:35,251 - INFO - Processing data for date: 20190529, hours: 12-15
# 2024-07-03 07:00:35,394 - INFO - Exporting aggregated data (geohash3) for date: 20190529, hours: 12-15
# 2024-07-03 07:00:35,522 - INFO - Exporting aggregated data (geohash5) for date: 20190529, hours: 12-15
# 2024-07-03 07:00:35,568 - INFO - Querying data for date: 20190529, hours: 15-18
# 2024-07-03 07:01:44,820 - INFO - Processing data for date: 20190529, hours: 15-18
# 2024-07-03 07:01:44,957 - INFO - Exporting aggregated data (geohash3) for date: 20190529, hours: 15-18
# 2024-07-03 07:01:45,096 - INFO - Exporting aggregated data (geohash5) for date: 20190529, hours: 15-18
# 2024-07-03 07:01:45,146 - INFO - Querying data for date: 20190529, hours: 18-21
# 2024-07-03 07:02:43,270 - INFO - Processing data for date: 20190529, hours: 18-21
# 2024-07-03 07:02:43,388 - INFO - Exporting aggregated data (geohash3) for date: 20190529, hours: 18-21
# 2024-07-03 07:02:43,498 - INFO - Exporting aggregated data (geohash5) for date: 20190529, hours: 18-21
# 2024-07-03 07:02:43,542 - INFO - Querying data for date: 20190529, hours: 21-24
# 2024-07-03 07:03:52,272 - INFO - Processing data for date: 20190529, hours: 21-24
# 2024-07-03 07:03:52,345 - INFO - Exporting aggregated data (geohash3) for date: 20190529, hours: 21-24
# 2024-07-03 07:03:52,397 - INFO - Exporting aggregated data (geohash5) for date: 20190529, hours: 21-24
# 2024-07-03 07:03:52,578 - INFO - Processing data for date: 20190530
# 2024-07-03 07:03:52,578 - INFO - Querying data for date: 20190530, hours: 0-3
# 2024-07-03 07:04:33,131 - INFO - Processing data for date: 20190530, hours: 0-3
# 2024-07-03 07:04:33,167 - INFO - Exporting aggregated data (geohash3) for date: 20190530, hours: 0-3
# 2024-07-03 07:04:33,210 - INFO - Exporting aggregated data (geohash5) for date: 20190530, hours: 0-3
# 2024-07-03 07:04:33,228 - INFO - Querying data for date: 20190530, hours: 3-6
# 2024-07-03 07:05:12,281 - INFO - Processing data for date: 20190530, hours: 3-6
# 2024-07-03 07:05:12,382 - INFO - Exporting aggregated data (geohash3) for date: 20190530, hours: 3-6
# 2024-07-03 07:05:12,480 - INFO - Exporting aggregated data (geohash5) for date: 20190530, hours: 3-6
# 2024-07-03 07:05:12,496 - INFO - Querying data for date: 20190530, hours: 6-9
# 2024-07-03 07:05:47,368 - INFO - Processing data for date: 20190530, hours: 6-9
# 2024-07-03 07:05:47,490 - INFO - Exporting aggregated data (geohash3) for date: 20190530, hours: 6-9
# 2024-07-03 07:05:47,617 - INFO - Exporting aggregated data (geohash5) for date: 20190530, hours: 6-9
# 2024-07-03 07:05:47,664 - INFO - Querying data for date: 20190530, hours: 9-12
# 2024-07-03 07:06:38,125 - INFO - Processing data for date: 20190530, hours: 9-12
# 2024-07-03 07:06:38,307 - INFO - Exporting aggregated data (geohash3) for date: 20190530, hours: 9-12
# 2024-07-03 07:06:38,467 - INFO - Exporting aggregated data (geohash5) for date: 20190530, hours: 9-12
# 2024-07-03 07:06:38,507 - INFO - Querying data for date: 20190530, hours: 12-15
# 2024-07-03 07:07:43,563 - INFO - Processing data for date: 20190530, hours: 12-15
# 2024-07-03 07:07:43,712 - INFO - Exporting aggregated data (geohash3) for date: 20190530, hours: 12-15
# 2024-07-03 07:07:43,854 - INFO - Exporting aggregated data (geohash5) for date: 20190530, hours: 12-15
# 2024-07-03 07:07:43,898 - INFO - Querying data for date: 20190530, hours: 15-18
# 2024-07-03 07:08:57,530 - INFO - Processing data for date: 20190530, hours: 15-18
# 2024-07-03 07:08:57,710 - INFO - Exporting aggregated data (geohash3) for date: 20190530, hours: 15-18
# 2024-07-03 07:08:57,848 - INFO - Exporting aggregated data (geohash5) for date: 20190530, hours: 15-18
# 2024-07-03 07:08:57,894 - INFO - Querying data for date: 20190530, hours: 18-21
# 2024-07-03 07:10:03,965 - INFO - Processing data for date: 20190530, hours: 18-21
# 2024-07-03 07:10:04,096 - INFO - Exporting aggregated data (geohash3) for date: 20190530, hours: 18-21
# 2024-07-03 07:10:04,217 - INFO - Exporting aggregated data (geohash5) for date: 20190530, hours: 18-21
# 2024-07-03 07:10:04,260 - INFO - Querying data for date: 20190530, hours: 21-24
# 2024-07-03 07:11:12,493 - INFO - Processing data for date: 20190530, hours: 21-24
# 2024-07-03 07:18:24,894 - INFO - Exporting aggregated data (geohash3) for date: 20190531, hours: 21-24
# 2024-07-03 07:18:24,984 - INFO - Exporting aggregated data (geohash5) for date: 20190531, hours: 21-24
# 2024-07-03 07:18:25,241 - INFO - Processing data for date: 20190601
# 2024-07-03 07:18:25,264 - INFO - Querying data for date: 20190601, hours: 0-3
# 2024-07-03 07:19:41,461 - INFO - Processing data for date: 20190601, hours: 0-3
# 2024-07-03 07:19:41,495 - INFO - Exporting aggregated data (geohash3) for date: 20190601, hours: 0-3
# 2024-07-03 07:19:41,538 - INFO - Exporting aggregated data (geohash5) for date: 20190601, hours: 0-3
# 2024-07-03 07:19:41,558 - INFO - Querying data for date: 20190601, hours: 3-6
# 2024-07-03 07:20:23,604 - INFO - failed after 3 attempts
# 2024-07-03 07:20:24,361 - INFO - failed after 3 attempts
# 2024-07-03 07:20:24,361 - ERROR - Error closing cursor
# Traceback (most recent call last):
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/sqlalchemy/engine/base.py", line 1900, in _execute_context
#     self.dialect.do_execute(
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/sqlalchemy/dialect.py", line 365, in do_execute
#     cursor.execute(statement, parameters)
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/dbapi.py", line 501, in execute
#     self._iterator = iter(self._query.execute())
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/client.py", line 821, in execute
#     self._result.rows += self.fetch()
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/client.py", line 838, in fetch
#     status = self._request.process(response)
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/client.py", line 617, in process
#     self.raise_response_error(http_response)
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/client.py", line 600, in raise_response_error
#     raise exceptions.Http502Error("error 502: bad gateway")
# trino.exceptions.Http502Error: error 502: bad gateway
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/sqlalchemy/engine/base.py", line 1995, in _safe_close_cursor
#     cursor.close()
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/dbapi.py", line 618, in close
#     self.cancel()
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/dbapi.py", line 615, in cancel
#     self._query.cancel()
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/client.py", line 862, in cancel
#     self._request.raise_response_error(response)
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/client.py", line 600, in raise_response_error
#     raise exceptions.Http502Error("error 502: bad gateway")
# trino.exceptions.Http502Error: error 502: bad gateway
# 2024-07-03 07:20:24,363 - ERROR - Error processing date: 20190601, hours: 3-6 - error 502: bad gateway
# 2024-07-03 07:20:24,364 - INFO - Querying data for date: 20190601, hours: 6-9
# 2024-07-03 07:21:59,108 - INFO - Processing data for date: 20190601, hours: 6-9
# 2024-07-03 07:21:59,178 - INFO - Exporting aggregated data (geohash3) for date: 20190601, hours: 6-9
# 2024-07-03 07:21:59,247 - INFO - Exporting aggregated data (geohash5) for date: 20190601, hours: 6-9
# 2024-07-03 07:21:59,274 - INFO - Querying data for date: 20190601, hours: 9-12
# 2024-07-03 07:22:43,359 - INFO - Processing data for date: 20190601, hours: 9-12
# 2024-07-03 07:22:43,489 - INFO - Exporting aggregated data (geohash3) for date: 20190601, hours: 9-12
# 2024-07-03 07:22:43,601 - INFO - Exporting aggregated data (geohash5) for date: 20190601, hours: 9-12
# 2024-07-03 07:22:43,644 - INFO - Querying data for date: 20190601, hours: 12-15
# 2024-07-03 07:23:25,335 - INFO - Processing data for date: 20190601, hours: 12-15
# 2024-07-03 07:23:25,473 - INFO - Exporting aggregated data (geohash3) for date: 20190601, hours: 12-15
# 2024-07-03 07:23:25,600 - INFO - Exporting aggregated data (geohash5) for date: 20190601, hours: 12-15
# 2024-07-03 07:23:25,646 - INFO - Querying data for date: 20190601, hours: 15-18
# 2024-07-03 07:24:07,507 - INFO - Processing data for date: 20190601, hours: 15-18
# 2024-07-03 07:24:07,642 - INFO - Exporting aggregated data (geohash3) for date: 20190601, hours: 15-18
# 2024-07-03 07:24:07,764 - INFO - Exporting aggregated data (geohash5) for date: 20190601, hours: 15-18
# 2024-07-03 07:24:07,809 - INFO - Querying data for date: 20190601, hours: 18-21
# 2024-07-03 07:24:39,332 - INFO - Processing data for date: 20190601, hours: 18-21
# 2024-07-03 07:24:39,481 - INFO - Exporting aggregated data (geohash3) for date: 20190601, hours: 18-21
# 2024-07-03 07:24:39,598 - INFO - Exporting aggregated data (geohash5) for date: 20190601, hours: 18-21
# 2024-07-03 07:24:39,637 - INFO - Querying data for date: 20190601, hours: 21-24
# 2024-07-03 07:25:19,873 - INFO - Processing data for date: 20190601, hours: 21-24
# 2024-07-03 07:25:19,971 - INFO - Exporting aggregated data (geohash3) for date: 20190601, hours: 21-24
# 2024-07-03 07:25:20,070 - INFO - Exporting aggregated data (geohash5) for date: 20190601, hours: 21-24
# 2024-07-03 07:25:20,378 - INFO - Processing data for date: 20190602
# 2024-07-03 07:25:20,379 - INFO - Querying data for date: 20190602, hours: 0-3
# 2024-07-03 07:26:15,518 - INFO - Processing data for date: 20190602, hours: 0-3
# 2024-07-03 07:26:15,554 - INFO - Exporting aggregated data (geohash3) for date: 20190602, hours: 0-3
# 2024-07-03 07:26:15,600 - INFO - Exporting aggregated data (geohash5) for date: 20190602, hours: 0-3
# 2024-07-03 07:26:15,618 - INFO - Querying data for date: 20190602, hours: 3-6
# 2024-07-03 07:26:53,876 - INFO - Processing data for date: 20190602, hours: 3-6
# 2024-07-03 07:26:53,965 - INFO - Exporting aggregated data (geohash3) for date: 20190602, hours: 3-6
# 2024-07-03 07:26:54,002 - INFO - Exporting aggregated data (geohash5) for date: 20190602, hours: 3-6
# 2024-07-03 07:26:54,017 - INFO - Querying data for date: 20190602, hours: 6-9
# 2024-07-03 07:27:17,563 - INFO - Processing data for date: 20190602, hours: 6-9
# 2024-07-03 07:27:17,619 - INFO - Exporting aggregated data (geohash3) for date: 20190602, hours: 6-9
# 2024-07-03 07:27:17,776 - INFO - Exporting aggregated data (geohash5) for date: 20190602, hours: 6-9
# 2024-07-03 07:27:17,801 - INFO - Querying data for date: 20190602, hours: 9-12
# 2024-07-03 07:27:53,175 - INFO - Processing data for date: 20190602, hours: 9-12
# 2024-07-03 07:27:53,370 - INFO - Exporting aggregated data (geohash3) for date: 20190602, hours: 9-12
# 2024-07-03 07:27:53,577 - INFO - Exporting aggregated data (geohash5) for date: 20190602, hours: 9-12
# 2024-07-03 07:27:53,640 - INFO - Querying data for date: 20190602, hours: 12-15
# 2024-07-03 07:28:13,577 - INFO - Processing data for date: 20190602, hours: 12-15
# 2024-07-03 07:28:13,712 - INFO - Exporting aggregated data (geohash3) for date: 20190602, hours: 12-15
# 2024-07-03 07:28:13,847 - INFO - Exporting aggregated data (geohash5) for date: 20190602, hours: 12-15
# 2024-07-03 07:28:13,891 - INFO - Querying data for date: 20190602, hours: 15-18
# 2024-07-03 07:28:52,458 - INFO - Processing data for date: 20190602, hours: 15-18
# 2024-07-03 07:33:33,395 - INFO - Exporting aggregated data (geohash3) for date: 20190603, hours: 15-18
# 2024-07-03 07:33:33,503 - INFO - Exporting aggregated data (geohash5) for date: 20190603, hours: 15-18
# 2024-07-03 07:33:33,551 - INFO - Querying data for date: 20190603, hours: 18-21
# 2024-07-03 07:34:15,296 - INFO - Processing data for date: 20190603, hours: 18-21
# 2024-07-03 07:34:15,475 - INFO - Exporting aggregated data (geohash3) for date: 20190603, hours: 18-21
# 2024-07-03 07:34:15,622 - INFO - Exporting aggregated data (geohash5) for date: 20190603, hours: 18-21
# 2024-07-03 07:34:15,686 - INFO - Querying data for date: 20190603, hours: 21-24
# 2024-07-03 07:34:43,664 - INFO - Processing data for date: 20190603, hours: 21-24
# 2024-07-03 07:34:43,773 - INFO - Exporting aggregated data (geohash3) for date: 20190603, hours: 21-24
# 2024-07-03 07:34:43,827 - INFO - Exporting aggregated data (geohash5) for date: 20190603, hours: 21-24
# 2024-07-03 07:34:44,141 - INFO - Processing data for date: 20190604
# 2024-07-03 07:34:44,163 - INFO - Querying data for date: 20190604, hours: 0-3
# 2024-07-03 07:35:14,521 - INFO - Processing data for date: 20190604, hours: 0-3
# 2024-07-03 07:35:14,580 - INFO - Exporting aggregated data (geohash3) for date: 20190604, hours: 0-3
# 2024-07-03 07:35:14,614 - INFO - Exporting aggregated data (geohash5) for date: 20190604, hours: 0-3
# 2024-07-03 07:35:14,629 - INFO - Querying data for date: 20190604, hours: 3-6
# 2024-07-03 07:35:53,329 - INFO - Processing data for date: 20190604, hours: 3-6
# 2024-07-03 07:35:53,364 - INFO - Exporting aggregated data (geohash3) for date: 20190604, hours: 3-6
# 2024-07-03 07:35:53,401 - INFO - Exporting aggregated data (geohash5) for date: 20190604, hours: 3-6
# 2024-07-03 07:35:53,414 - INFO - Querying data for date: 20190604, hours: 6-9
# 2024-07-03 07:36:33,626 - INFO - Processing data for date: 20190604, hours: 6-9
# 2024-07-03 07:36:33,710 - INFO - Exporting aggregated data (geohash3) for date: 20190604, hours: 6-9
# 2024-07-03 07:36:33,798 - INFO - Exporting aggregated data (geohash5) for date: 20190604, hours: 6-9
# 2024-07-03 07:36:33,832 - INFO - Querying data for date: 20190604, hours: 9-12
# 2024-07-03 07:37:12,232 - INFO - Processing data for date: 20190604, hours: 9-12
# 2024-07-03 07:37:12,380 - INFO - Exporting aggregated data (geohash3) for date: 20190604, hours: 9-12
# 2024-07-03 07:37:12,609 - INFO - Exporting aggregated data (geohash5) for date: 20190604, hours: 9-12
# 2024-07-03 07:37:12,686 - INFO - Querying data for date: 20190604, hours: 12-15
# 2024-07-03 07:37:44,724 - INFO - Processing data for date: 20190604, hours: 12-15
# 2024-07-03 07:37:44,885 - INFO - Exporting aggregated data (geohash3) for date: 20190604, hours: 12-15
# 2024-07-03 07:37:45,028 - INFO - Exporting aggregated data (geohash5) for date: 20190604, hours: 12-15
# 2024-07-03 07:37:45,072 - INFO - Querying data for date: 20190604, hours: 15-18
# 2024-07-03 07:38:22,970 - INFO - Processing data for date: 20190604, hours: 15-18
- INFO - Exporting aggregated data (geohash3) for date: 20190606, hours: 21-24
# 2024-07-03 07:49:28,066 - INFO - Exporting aggregated data (geohash5) for date: 20190606, hours: 21-24
# 2024-07-03 07:49:28,305 - INFO - Processing data for date: 20190607
# 2024-07-03 07:49:28,306 - INFO - Querying data for date: 20190607, hours: 0-3
# 2024-07-03 07:50:05,817 - INFO - Processing data for date: 20190607, hours: 0-3
# 2024-07-03 07:50:05,878 - INFO - Exporting aggregated data (geohash3) for date: 20190607, hours: 0-3
# 2024-07-03 07:50:05,915 - INFO - Exporting aggregated data (geohash5) for date: 20190607, hours: 0-3
# 2024-07-03 07:50:05,977 - INFO - Querying data for date: 20190607, hours: 3-6
# 2024-07-03 07:50:29,968 - INFO - Processing data for date: 20190607, hours: 3-6
# 2024-07-03 07:50:30,005 - INFO - Exporting aggregated data (geohash3) for date: 20190607, hours: 3-6
# 2024-07-03 07:50:30,042 - INFO - Exporting aggregated data (geohash5) for date: 20190607, hours: 3-6
# 2024-07-03 07:50:30,056 - INFO - Querying data for date: 20190607, hours: 6-9
# 2024-07-03 07:51:10,552 - INFO - Processing data for date: 20190607, hours: 6-9
# 2024-07-03 07:51:10,640 - INFO - Exporting aggregated data (geohash3) for date: 20190607, hours: 6-9
# 2024-07-03 07:51:10,727 - INFO - Exporting aggregated data (geohash5) for date: 20190607, hours: 6-9
# 2024-07-03 07:51:10,760 - INFO - Querying data for date: 20190607, hours: 9-12
# 2024-07-03 07:51:50,450 - INFO - Processing data for date: 20190607, hours: 9-12
# 2024-07-03 07:51:50,577 - INFO - Exporting aggregated data (geohash3) for date: 20190607, hours: 9-12
# 2024-07-03 07:51:50,695 - INFO - Exporting aggregated data (geohash5) for date: 20190607, hours: 9-12
# 2024-07-03 07:51:50,737 - INFO - Querying data for date: 20190607, hours: 12-15
# 2024-07-03 07:52:29,518 - INFO - Processing data for date: 20190607, hours: 12-15
# 2024-07-03 07:52:29,674 - INFO - Exporting aggregated data (geohash3) for date: 20190607, hours: 12-15
# 2024-07-03 07:52:29,824 - INFO - Exporting aggregated data (geohash5) for date: 20190607, hours: 12-15
# 2024-07-03 07:52:29,873 - INFO - Querying data for date: 20190607, hours: 15-18
# 2024-07-03 07:53:05,599 - INFO - Processing data for date: 20190607, hours: 15-18
# 2024-07-03 07:53:05,752 - INFO - Exporting aggregated data (geohash3) for date: 20190607, hours: 15-18
# 2024-07-03 07:53:05,878 - INFO - Exporting aggregated data (geohash5) for date: 20190607, hours: 15-18
# 2024-07-03 07:53:05,922 - INFO - Querying data for date: 20190607, hours: 18-21
# 2024-07-03 07:53:49,148 - INFO - Processing data for date: 20190607, hours: 18-21
# 2024-07-03 07:53:49,282 - INFO - Exporting aggregated data (geohash3) for date: 20190607, hours: 18-21
# 2024-07-03 07:53:49,394 - INFO - Exporting aggregated data (geohash5) for date: 20190607, hours: 18-21
# 2024-07-03 07:53:49,433 - INFO - Querying data for date: 20190607, hours: 21-24
# 2024-07-03 07:54:32,912 - INFO - Processing data for date: 20190607, hours: 21-24
# 2024-07-03 07:54:33,006 - INFO - Exporting aggregated data (geohash3) for date: 20190607, hours: 21-24
# 2024-07-03 07:59:18,309 - INFO - Exporting aggregated data (geohash5) for date: 20190608, hours: 21-24
# 2024-07-03 07:59:18,598 - INFO - Processing data for date: 20190609
# 2024-07-03 07:59:18,599 - INFO - Querying data for date: 20190609, hours: 0-3
# 2024-07-03 07:59:51,011 - INFO - Processing data for date: 20190609, hours: 0-3
# 2024-07-03 07:59:51,087 - INFO - Exporting aggregated data (geohash3) for date: 20190609, hours: 0-3
# 2024-07-03 07:59:51,187 - INFO - Exporting aggregated data (geohash5) for date: 20190609, hours: 0-3
# 2024-07-03 07:59:51,210 - INFO - Querying data for date: 20190609, hours: 3-6
# 2024-07-03 08:00:20,096 - INFO - Processing data for date: 20190609, hours: 3-6
# 2024-07-03 08:00:20,168 - INFO - Exporting aggregated data (geohash3) for date: 20190609, hours: 3-6
# 2024-07-03 08:00:20,205 - INFO - Exporting aggregated data (geohash5) for date: 20190609, hours: 3-6
# 2024-07-03 08:00:20,220 - INFO - Querying data for date: 20190609, hours: 6-9
# 2024-07-03 08:00:40,910 - INFO - Processing data for date: 20190609, hours: 6-9
# 2024-07-03 08:00:40,958 - INFO - Exporting aggregated data (geohash3) for date: 20190609, hours: 6-9
# 2024-07-03 08:00:41,013 - INFO - Exporting aggregated data (geohash5) for date: 20190609, hours: 6-9
# 2024-07-03 08:00:41,035 - INFO - Querying data for date: 20190609, hours: 9-12
# ...
# 2024-07-03 09:08:27,506 - INFO - Exporting aggregated data (geohash5) for date: 20190625, hours: 15-18
# 2024-07-03 09:08:27,547 - INFO - Querying data for date: 20190625, hours: 18-21
# 2024-07-03 09:09:07,983 - INFO - Processing data for date: 20190625, hours: 18-21
# 2024-07-03 09:09:08,080 - INFO - Exporting aggregated data (geohash3) for date: 20190625, hours: 18-21
# 2024-07-03 09:09:08,161 - INFO - Exporting aggregated data (geohash5) for date: 20190625, hours: 18-21
# 2024-07-03 09:09:08,202 - INFO - Querying data for date: 20190625, hours: 21-24
# 2024-07-03 09:09:37,998 - INFO - Processing data for date: 20190625, hours: 21-24
# 2024-07-03 09:09:38,054 - INFO - Exporting aggregated data (geohash3) for date: 20190625, hours: 21-24
# 2024-07-03 09:09:38,097 - INFO - Exporting aggregated data (geohash5) for date: 20190625, hours: 21-24
# 2024-07-03 09:09:38,239 - INFO - Processing data for date: 20190626
# 2024-07-03 09:09:38,240 - INFO - Querying data for date: 20190626, hours: 0-3
# 2024-07-03 09:10:13,273 - INFO - Processing data for date: 20190626, hours: 0-3
# 2024-07-03 09:10:13,293 - INFO - Exporting aggregated data (geohash3) for date: 20190626, hours: 0-3
# 2024-07-03 09:10:13,325 - INFO - Exporting aggregated data (geohash5) for date: 20190626, hours: 0-3
# 2024-07-03 09:10:13,340 - INFO - Querying data for date: 20190626, hours: 3-6
# 2024-07-03 09:10:31,903 - INFO - Processing data for date: 20190626, hours: 3-6
# 2024-07-03 09:10:31,930 - INFO - Exporting aggregated data (geohash3) for date: 20190626, hours: 3-6
# 2024-07-03 09:10:31,960 - INFO - Exporting aggregated data (geohash5) for date: 20190626, hours: 3-6
# 2024-07-03 09:10:31,971 - INFO - Querying data for date: 20190626, hours: 6-9
# 2024-07-03 09:11:07,035 - INFO - Processing data for date: 20190626, hours: 6-9
# 2024-07-03 09:11:07,105 - INFO - Exporting aggregated data (geohash3) for date: 20190626, hours: 6-9
# 2024-07-03 09:11:07,192 - INFO - Exporting aggregated data (geohash5) for date: 20190626, hours: 6-9
# 2024-07-03 09:11:07,220 - INFO - Querying data for date: 20190626, hours: 9-12
# 2024-07-03 09:11:42,050 - INFO - Processing data for date: 20190626, hours: 9-12
# 2024-07-03 09:11:42,150 - INFO - Exporting aggregated data (geohash3) for date: 20190626, hours: 9-12
# 2024-07-03 09:11:42,244 - INFO - Exporting aggregated data (geohash5) for date: 20190626, hours: 9-12
# 2024-07-03 09:11:42,281 - INFO - Querying data for date: 20190626, hours: 12-15
# 2024-07-03 09:12:20,652 - INFO - Processing data for date: 20190626, hours: 12-15
# 2024-07-03 09:12:20,767 - INFO - Exporting aggregated data (geohash3) for date: 20190626, hours: 12-15
# 2024-07-03 09:12:20,873 - INFO - Exporting aggregated data (geohash5) for date: 20190626, hours: 12-15
# 2024-07-03 09:12:20,922 - INFO - Querying data for date: 20190626, hours: 15-18
# 2024-07-03 09:12:43,597 - INFO - Processing data for date: 20190626, hours: 15-18
# 2024-07-03 09:12:43,750 - INFO - Exporting aggregated data (geohash3) for date: 20190626, hours: 15-18
# 2024-07-03 09:12:43,887 - INFO - Exporting aggregated data (geohash5) for date: 20190626, hours: 15-18
# 2024-07-03 09:12:43,944 - INFO - Querying data for date: 20190626, hours: 18-21
# 2024-07-03 09:13:07,160 - INFO - Processing data for date: 20190626, hours: 18-21
# 2024-07-03 09:13:07,271 - INFO - Exporting aggregated data (geohash3) for date: 20190626, hours: 18-21
# 2024-07-03 09:13:07,374 - INFO - Exporting aggregated data (geohash5) for date: 20190626, hours: 18-21
# 2024-07-03 09:13:07,410 - INFO - Querying data for date: 20190626, hours: 21-24
# 2024-07-03 09:13:42,361 - INFO - Processing data for date: 20190626, hours: 21-24
# 2024-07-03 09:13:42,417 - INFO - Exporting aggregated data (geohash3) for date: 20190626, hours: 21-24
# 2024-07-03 09:13:42,463 - INFO - Exporting aggregated data (geohash5) for date: 20190626, hours: 21-24
# 2024-07-03 09:13:42,606 - INFO - Processing data for date: 20190627
# 2024-07-03 09:13:42,607 - INFO - Querying data for date: 20190627, hours: 0-3
# 2024-07-03 09:14:32,714 - INFO - Processing data for date: 20190627, hours: 0-3
# 2024-07-03 09:14:32,734 - INFO - Exporting aggregated data (geohash3) for date: 20190627, hours: 0-3
# 2024-07-03 09:14:32,768 - INFO - Exporting aggregated data (geohash5) for date: 20190627, hours: 0-3
# 2024-07-03 09:14:32,781 - INFO - Querying data for date: 20190627, hours: 3-6
# 2024-07-03 09:15:02,000 - INFO - Processing data for date: 20190627, hours: 3-6
# 2024-07-03 09:15:02,028 - INFO - Exporting aggregated data (geohash3) for date: 20190627, hours: 3-6
# 2024-07-03 09:15:02,066 - INFO - Exporting aggregated data (geohash5) for date: 20190627, hours: 3-6
# 2024-07-03 09:15:02,081 - INFO - Querying data for date: 20190627, hours: 6-9
# 2024-07-03 09:15:27,217 - INFO - Processing data for date: 20190627, hours: 6-9
# 2024-07-03 09:15:27,321 - INFO - Exporting aggregated data (geohash3) for date: 20190627, hours: 6-9
# 2024-07-03 09:15:27,420 - INFO - Exporting aggregated data (geohash5) for date: 20190627, hours: 6-9
# 2024-07-03 09:15:27,463 - INFO - Querying data for date: 20190627, hours: 9-12
# 2024-07-03 09:15:47,984 - INFO - Processing data for date: 20190627, hours: 9-12
# 2024-07-03 09:15:48,090 - INFO - Exporting aggregated data (geohash3) for date: 20190627, hours: 9-12
# 2024-07-03 09:15:48,201 - INFO - Exporting aggregated data (geohash5) for date: 20190627, hours: 9-12
# 2024-07-03 09:15:48,237 - INFO - Querying data for date: 20190627, hours: 12-15
# 2024-07-03 09:16:10,590 - INFO - Processing data for date: 20190627, hours: 12-15
# 2024-07-03 09:16:10,710 - INFO - Exporting aggregated data (geohash3) for date: 20190627, hours: 12-15
# 2024-07-03 09:16:10,828 - INFO - Exporting aggregated data (geohash5) for date: 20190627, hours: 12-15
# 2024-07-03 09:16:10,869 - INFO - Querying data for date: 20190627, hours: 15-18
# 2024-07-03 09:16:47,148 - INFO - Processing data for date: 20190627, hours: 15-18
# 2024-07-03 09:16:47,263 - INFO - Exporting aggregated data (geohash3) for date: 20190627, hours: 15-18
# 2024-07-03 09:16:47,365 - INFO - Exporting aggregated data (geohash5) for date: 20190627, hours: 15-18
# 2024-07-03 09:16:47,406 - INFO - Querying data for date: 20190627, hours: 18-21
# 2024-07-03 09:17:32,480 - INFO - Processing data for date: 20190627, hours: 18-21
# 2024-07-03 09:17:32,584 - INFO - Exporting aggregated data (geohash3) for date: 20190627, hours: 18-21
# 2024-07-03 09:17:32,682 - INFO - Exporting aggregated data (geohash5) for date: 20190627, hours: 18-21
# 2024-07-03 09:17:32,724 - INFO - Querying data for date: 20190627, hours: 21-24
# 2024-07-03 09:18:02,691 - INFO - Processing data for date: 20190627, hours: 21-24
# 2024-07-03 09:18:02,752 - INFO - Exporting aggregated data (geohash3) for date: 20190627, hours: 21-24
# 2024-07-03 09:18:02,801 - INFO - Exporting aggregated data (geohash5) for date: 20190627, hours: 21-24
# 2024-07-03 09:18:02,979 - INFO - Processing data for date: 20190628
# 2024-07-03 09:18:02,980 - INFO - Querying data for date: 20190628, hours: 0-3
# 2024-07-03 09:18:34,145 - INFO - Processing data for date: 20190628, hours: 0-3
# 2024-07-03 09:18:34,172 - INFO - Exporting aggregated data (geohash3) for date: 20190628, hours: 0-3
# 2024-07-03 09:18:34,206 - INFO - Exporting aggregated data (geohash5) for date: 20190628, hours: 0-3
# 2024-07-03 09:18:34,223 - INFO - Querying data for date: 20190628, hours: 3-6
# 2024-07-03 09:18:57,276 - INFO - Processing data for date: 20190628, hours: 3-6
# 2024-07-03 09:18:57,306 - INFO - Exporting aggregated data (geohash3) for date: 20190628, hours: 3-6
# 2024-07-03 09:18:57,338 - INFO - Exporting aggregated data (geohash5) for date: 20190628, hours: 3-6
# 2024-07-03 09:18:57,351 - INFO - Querying data for date: 20190628, hours: 6-9
# 2024-07-03 09:19:22,153 - INFO - Processing data for date: 20190628, hours: 6-9
# 2024-07-03 09:19:22,212 - INFO - Exporting aggregated data (geohash3) for date: 20190628, hours: 6-9
# 2024-07-03 09:19:22,281 - INFO - Exporting aggregated data (geohash5) for date: 20190628, hours: 6-9
# 2024-07-03 09:19:22,313 - INFO - Querying data for date: 20190628, hours: 9-12
# 2024-07-03 09:20:00,862 - INFO - Processing data for date: 20190628, hours: 9-12
# 2024-07-03 09:20:00,969 - INFO - Exporting aggregated data (geohash3) for date: 20190628, hours: 9-12
# 2024-07-03 09:20:01,079 - INFO - Exporting aggregated data (geohash5) for date: 20190628, hours: 9-12
# 2024-07-03 09:20:01,119 - INFO - Querying data for date: 20190628, hours: 12-15
# 2024-07-03 09:20:46,313 - INFO - Processing data for date: 20190628, hours: 12-15
# 2024-07-03 09:20:46,432 - INFO - Exporting aggregated data (geohash3) for date: 20190628, hours: 12-15
# 2024-07-03 09:20:46,535 - INFO - Exporting aggregated data (geohash5) for date: 20190628, hours: 12-15
# 2024-07-03 09:20:46,586 - INFO - Querying data for date: 20190628, hours: 15-18
# 2024-07-03 09:21:13,082 - INFO - Processing data for date: 20190628, hours: 15-18
# 2024-07-03 09:21:13,279 - INFO - Exporting aggregated data (geohash3) for date: 20190628, hours: 15-18
# 2024-07-03 09:21:13,472 - INFO - Exporting aggregated data (geohash5) for date: 20190628, hours: 15-18
# 2024-07-03 09:21:13,519 - INFO - Querying data for date: 20190628, hours: 18-21
# 2024-07-03 09:21:33,698 - INFO - Processing data for date: 20190628, hours: 18-21
# 2024-07-03 09:21:33,817 - INFO - Exporting aggregated data (geohash3) for date: 20190628, hours: 18-21
# 2024-07-03 09:21:33,923 - INFO - Exporting aggregated data (geohash5) for date: 20190628, hours: 18-21
# 2024-07-03 09:21:33,961 - INFO - Querying data for date: 20190628, hours: 21-24
# 2024-07-03 09:21:58,417 - INFO - Processing data for date: 20190628, hours: 21-24
# 2024-07-03 09:21:58,486 - INFO - Exporting aggregated data (geohash3) for date: 20190628, hours: 21-24
# 2024-07-03 09:21:58,553 - INFO - Exporting aggregated data (geohash5) for date: 20190628, hours: 21-24
# 2024-07-03 09:21:58,732 - INFO - Processing data for date: 20190629
# 2024-07-03 09:21:58,733 - INFO - Querying data for date: 20190629, hours: 0-3
# 2024-07-03 09:22:25,312 - INFO - Processing data for date: 20190629, hours: 0-3
# 2024-07-03 09:22:25,339 - INFO - Exporting aggregated data (geohash3) for date: 20190629, hours: 0-3
# 2024-07-03 09:22:25,412 - INFO - Exporting aggregated data (geohash5) for date: 20190629, hours: 0-3
# 2024-07-03 09:22:25,428 - INFO - Querying data for date: 20190629, hours: 3-6
# 2024-07-03 09:22:45,798 - INFO - Processing data for date: 20190629, hours: 3-6
# 2024-07-03 09:22:45,828 - INFO - Exporting aggregated data (geohash3) for date: 20190629, hours: 3-6
# 2024-07-03 09:22:45,858 - INFO - Exporting aggregated data (geohash5) for date: 20190629, hours: 3-6
# 2024-07-03 09:22:45,871 - INFO - Querying data for date: 20190629, hours: 6-9
# 2024-07-03 09:23:22,752 - INFO - Processing data for date: 20190629, hours: 6-9
# 2024-07-03 09:23:22,803 - INFO - Exporting aggregated data (geohash3) for date: 20190629, hours: 6-9
# 2024-07-03 09:23:22,864 - INFO - Exporting aggregated data (geohash5) for date: 20190629, hours: 6-9
# 2024-07-03 09:23:22,889 - INFO - Querying data for date: 20190629, hours: 9-12
# 2024-07-03 09:24:03,842 - INFO - Processing data for date: 20190629, hours: 9-12
# 2024-07-03 09:24:03,940 - INFO - Exporting aggregated data (geohash3) for date: 20190629, hours: 9-12
# 2024-07-03 09:24:04,033 - INFO - Exporting aggregated data (geohash5) for date: 20190629, hours: 9-12
# 2024-07-03 09:24:04,070 - INFO - Querying data for date: 20190629, hours: 12-15
# 2024-07-03 09:24:34,685 - INFO - Processing data for date: 20190629, hours: 12-15
# 2024-07-03 09:24:34,796 - INFO - Exporting aggregated data (geohash3) for date: 20190629, hours: 12-15
# 2024-07-03 09:24:34,899 - INFO - Exporting aggregated data (geohash5) for date: 20190629, hours: 12-15
# 2024-07-03 09:24:34,952 - INFO - Querying data for date: 20190629, hours: 15-18
# 2024-07-03 09:24:57,587 - INFO - Processing data for date: 20190629, hours: 15-18
# 2024-07-03 09:24:57,766 - INFO - Exporting aggregated data (geohash3) for date: 20190629, hours: 15-18
# 2024-07-03 09:24:57,913 - INFO - Exporting aggregated data (geohash5) for date: 20190629, hours: 15-18
# 2024-07-03 09:24:57,990 - INFO - Querying data for date: 20190629, hours: 18-21
# 2024-07-03 09:25:17,242 - INFO - Processing data for date: 20190629, hours: 18-21
# 2024-07-03 09:25:17,378 - INFO - Exporting aggregated data (geohash3) for date: 20190629, hours: 18-21
# 2024-07-03 09:25:17,501 - INFO - Exporting aggregated data (geohash5) for date: 20190629, hours: 18-21
# 2024-07-03 09:25:17,540 - INFO - Querying data for date: 20190629, hours: 21-24
# 2024-07-03 09:25:42,001 - INFO - Processing data for date: 20190629, hours: 21-24
# 2024-07-03 09:25:42,115 - INFO - Exporting aggregated data (geohash3) for date: 20190629, hours: 21-24
# 2024-07-03 09:25:42,210 - INFO - Exporting aggregated data (geohash5) for date: 20190629, hours: 21-24
# 2024-07-03 09:25:42,388 - INFO - Processing data for date: 20190630
# 2024-07-03 09:25:42,389 - INFO - Querying data for date: 20190630, hours: 0-3
# 2024-07-03 09:26:02,953 - INFO - Processing data for date: 20190630, hours: 0-3
# 2024-07-03 09:26:02,981 - INFO - Exporting aggregated data (geohash3) for date: 20190630, hours: 0-3
# 2024-07-03 09:26:03,019 - INFO - Exporting aggregated data (geohash5) for date: 20190630, hours: 0-3
# 2024-07-03 09:26:03,035 - INFO - Querying data for date: 20190630, hours: 3-6
# 2024-07-03 09:26:33,740 - INFO - Processing data for date: 20190630, hours: 3-6
# 2024-07-03 09:26:33,770 - INFO - Exporting aggregated data (geohash3) for date: 20190630, hours: 3-6
# 2024-07-03 09:26:33,804 - INFO - Exporting aggregated data (geohash5) for date: 20190630, hours: 3-6
# 2024-07-03 09:26:33,818 - INFO - Querying data for date: 20190630, hours: 6-9
# 2024-07-03 09:27:02,176 - INFO - Processing data for date: 20190630, hours: 6-9
# 2024-07-03 09:27:02,215 - INFO - Exporting aggregated data (geohash3) for date: 20190630, hours: 6-9
# 2024-07-03 09:27:02,271 - INFO - Exporting aggregated data (geohash5) for date: 20190630, hours: 6-9
# 2024-07-03 09:27:02,289 - INFO - Querying data for date: 20190630, hours: 9-12
# 2024-07-03 09:27:39,011 - INFO - Processing data for date: 20190630, hours: 9-12
# 2024-07-03 09:27:39,080 - INFO - Exporting aggregated data (geohash3) for date: 20190630, hours: 9-12
# 2024-07-03 09:27:39,161 - INFO - Exporting aggregated data (geohash5) for date: 20190630, hours: 9-12
# 2024-07-03 09:27:39,193 - INFO - Querying data for date: 20190630, hours: 12-15
# 2024-07-03 09:28:07,825 - INFO - Processing data for date: 20190630, hours: 12-15
# 2024-07-03 09:28:07,933 - INFO - Exporting aggregated data (geohash3) for date: 20190630, hours: 12-15
# 2024-07-03 09:28:08,033 - INFO - Exporting aggregated data (geohash5) for date: 20190630, hours: 12-15
# 2024-07-03 09:28:08,070 - INFO - Querying data for date: 20190630, hours: 15-18
# 2024-07-03 09:28:25,341 - INFO - Processing data for date: 20190630, hours: 15-18
# 2024-07-03 09:28:25,431 - INFO - Exporting aggregated data (geohash3) for date: 20190630, hours: 15-18
# 2024-07-03 09:28:25,521 - INFO - Exporting aggregated data (geohash5) for date: 20190630, hours: 15-18
# 2024-07-03 09:28:25,552 - INFO - Querying data for date: 20190630, hours: 18-21
# 2024-07-03 09:28:47,918 - INFO - Processing data for date: 20190630, hours: 18-21
# 2024-07-03 09:28:47,998 - INFO - Exporting aggregated data (geohash3) for date: 20190630, hours: 18-21
# 2024-07-03 09:28:48,074 - INFO - Exporting aggregated data (geohash5) for date: 20190630, hours: 18-21
# 2024-07-03 09:28:48,109 - INFO - Querying data for date: 20190630, hours: 21-24
# 2024-07-03 09:29:06,100 - INFO - Processing data for date: 20190630, hours: 21-24
# 2024-07-03 09:29:06,151 - INFO - Exporting aggregated data (geohash3) for date: 20190630, hours: 21-24
# 2024-07-03 09:29:06,194 - INFO - Exporting aggregated data (geohash5) for date: 20190630, hours: 21-24
# 2024-07-03 09:29:06,304 - INFO - Errors occurred during processing:
# 2024-07-03 09:29:06,305 - INFO - Error processing date: 20190601, hours: 3-6 - error 502: bad gateway

# %% [markdown]
# # Fillin Gaps

# %%
# Configure logging
logging.basicConfig(level=logging.INFO, format='%(asctime)s - %(levelname)s - %(message)s')

# Function to process data for a specific date and time intervals
def process_data_for_date(event_date, country_code, export_path, start_hour, end_hour):
    # Define the export file paths
    csv3_file = f"od_{country_code.lower()}_agg3_3h.csv"
    csv5_file = f"od_{country_code.lower()}_agg5_3h.csv"
    csv3_file_path = f"{export_path}{csv3_file}"
    csv5_file_path = f"{export_path}{csv5_file}"

    # Loop through the specified hours in increments of 3 hours
    for hour in range(start_hour, end_hour, 3):
        next_hour = hour + 3  # end hour for the 3-hour interval
        logging.info(f"Querying data for date: {event_date}, hours: {hour}-{next_hour}")

        # Fetch the data for the specified event date and country code
        pe_tj_df3 = sql_engine.read_sql(
            f"""
            SELECT 
                cuebiq_id,
                duration_minutes,
                length_meters,
                number_of_points,
                TRY(date_parse(substr(start_zoned_datetime, 1, 19), '%Y-%m-%dT%H:%i:%s')) AS event_datetime_local,
                EXTRACT(HOUR FROM TRY(date_parse(substr(start_zoned_datetime, 1, 19), '%Y-%m-%dT%H:%i:%s'))) AS event_hour,
                geohash_encode(start_lat, start_lng, 5) AS start_geohash5,
                geohash_encode(start_lat, start_lng, 3) AS start_geohash3,
                geohash_encode(end_lat, end_lng, 5) AS end_geohash5,
                geohash_encode(end_lat, end_lng, 3) AS end_geohash3,
                DATE_FORMAT(date_parse(substr(start_zoned_datetime, 1, 10), '%Y-%m-%d'), '%Y%m%d') AS local_date
            FROM cuebiq.paas_cda_pe_v3.trajectory_uplevelled
            WHERE 
                event_date = {event_date}
                AND end_country = '{country_code}' 
                AND start_country = '{country_code}' 
            """
        )

        # Filter the DataFrame for the current 3-hour interval
        logging.info(f"Processing data for date: {event_date}, hours: {hour}-{next_hour}")
        filtered_df = pe_tj_df3[(pe_tj_df3['event_hour'] >= hour) & (pe_tj_df3['event_hour'] < next_hour)]

        # Add user numbers to the aggregated data for geohash3
        aggregated_df3 = filtered_df.groupby(['start_geohash3', 'end_geohash3', 'local_date']).agg({
            'cuebiq_id': 'count',
            'duration_minutes': ['mean', 'median', 'std'],
            'length_meters': ['mean', 'median', 'std'],
            'number_of_points': ['mean', 'median', 'std']
        }).reset_index()

        # Flatten the MultiIndex columns
        aggregated_df3.columns = ['start_geohash3', 'end_geohash3', 'local_date', 'trip_count', 
                                  'm_duration_min', 'mdn_duration_min', 'sd_duration_min', 
                                  'm_length_m', 'mdn_length_m', 'sd_length_m',
                                  'm_points_no', 'mdn_points_no', 'sd_points_no']

        # Add the local_time column
        aggregated_df3['local_time'] = aggregated_df3['local_date'].astype(str) + \
                                       f" {hour:02d}:00:00 - {next_hour:02d}:00:00"

        # Filter out rows where trip_count is less than or equal to 9
        aggregated_df3 = aggregated_df3[aggregated_df3['trip_count'] > 9]

        # Append the results to the CSV file for geohash3
        logging.info(f"Exporting aggregated data (geohash3) for date: {event_date}, hours: {hour}-{next_hour}")
        if not os.path.isfile(csv3_file_path):
            aggregated_df3.to_csv(csv3_file_path, index=False)
        else:
            aggregated_df3.to_csv(csv3_file_path, mode='a', header=False, index=False)

        # Add user numbers to the aggregated data for geohash5
        aggregated_df5 = filtered_df.groupby(['start_geohash5', 'end_geohash5', 'local_date']).agg({
            'cuebiq_id': 'count',
            'duration_minutes': ['mean', 'median', 'std'],
            'length_meters': ['mean', 'median', 'std'],
            'number_of_points': ['mean', 'median', 'std']
        }).reset_index()

        # Flatten the MultiIndex columns
        aggregated_df5.columns = ['start_geohash5', 'end_geohash5', 'local_date', 'trip_count', 
                                  'm_duration_min', 'mdn_duration_min', 'sd_duration_min', 
                                  'm_length_m', 'mdn_length_m', 'sd_length_m',
                                  'm_points_no', 'mdn_points_no', 'sd_points_no']

        # Add the local_time column
        aggregated_df5['local_time'] = aggregated_df5['local_date'].astype(str) + \
                                       f" {hour:02d}:00:00 - {next_hour:02d}:00:00"

        # Filter out rows where trip_count is less than or equal to 9
        aggregated_df5 = aggregated_df5[aggregated_df5['trip_count'] > 9]

        # Append the results to the CSV file for geohash5
        logging.info(f"Exporting aggregated data (geohash5) for date: {event_date}, hours: {hour}-{next_hour}")
        if not os.path.isfile(csv5_file_path):
            aggregated_df5.to_csv(csv5_file_path, index=False)
        else:
            aggregated_df5.to_csv(csv5_file_path, mode='a', header=False, index=False)

# %%
# Specify the date and initial time interval
event_date = "20190524"
start_hour = 3
end_hour = 24  # Process until the end of the day
country_code = 'MX'
export_path = '/home/jovyan/Data/TJ/3h/'

# Process data for the specified date and time intervals
process_data_for_date(event_date, country_code, export_path, start_hour, end_hour)
# Out:
# 2024-07-03 06:24:51,898 - INFO - Querying data for date: 20190524, hours: 3-6
# 2024-07-03 06:25:26,529 - INFO - Processing data for date: 20190524, hours: 3-6
# 2024-07-03 06:25:26,559 - INFO - Exporting aggregated data (geohash3) for date: 20190524, hours: 3-6
# 2024-07-03 06:25:26,602 - INFO - Exporting aggregated data (geohash5) for date: 20190524, hours: 3-6
# 2024-07-03 06:25:26,618 - INFO - Querying data for date: 20190524, hours: 6-9
# 2024-07-03 06:25:52,302 - INFO - Processing data for date: 20190524, hours: 6-9
# 2024-07-03 06:25:52,381 - INFO - Exporting aggregated data (geohash3) for date: 20190524, hours: 6-9
# 2024-07-03 06:25:52,456 - INFO - Exporting aggregated data (geohash5) for date: 20190524, hours: 6-9
# 2024-07-03 06:25:52,485 - INFO - Querying data for date: 20190524, hours: 9-12
# 2024-07-03 06:26:16,348 - INFO - Processing data for date: 20190524, hours: 9-12
# 2024-07-03 06:26:16,462 - INFO - Exporting aggregated data (geohash3) for date: 20190524, hours: 9-12
# 2024-07-03 06:26:16,569 - INFO - Exporting aggregated data (geohash5) for date: 20190524, hours: 9-12
# 2024-07-03 06:26:16,606 - INFO - Querying data for date: 20190524, hours: 12-15
# 2024-07-03 06:26:48,764 - INFO - Processing data for date: 20190524, hours: 12-15
# 2024-07-03 06:26:48,898 - INFO - Exporting aggregated data (geohash3) for date: 20190524, hours: 12-15
# 2024-07-03 06:26:49,010 - INFO - Exporting aggregated data (geohash5) for date: 20190524, hours: 12-15
# 2024-07-03 06:26:49,059 - INFO - Querying data for date: 20190524, hours: 15-18
# 2024-07-03 06:27:19,203 - INFO - Processing data for date: 20190524, hours: 15-18
# 2024-07-03 06:27:19,337 - INFO - Exporting aggregated data (geohash3) for date: 20190524, hours: 15-18
# 2024-07-03 06:27:19,448 - INFO - Exporting aggregated data (geohash5) for date: 20190524, hours: 15-18
# 2024-07-03 06:27:19,494 - INFO - Querying data for date: 20190524, hours: 18-21
# 2024-07-03 06:27:43,738 - INFO - Processing data for date: 20190524, hours: 18-21
# 2024-07-03 06:27:43,874 - INFO - Exporting aggregated data (geohash3) for date: 20190524, hours: 18-21
# 2024-07-03 06:27:44,003 - INFO - Exporting aggregated data (geohash5) for date: 20190524, hours: 18-21
# 2024-07-03 06:27:44,045 - INFO - Querying data for date: 20190524, hours: 21-24
# 2024-07-03 06:28:08,357 - INFO - Processing data for date: 20190524, hours: 21-24
# 2024-07-03 06:28:08,438 - INFO - Exporting aggregated data (geohash3) for date: 20190524, hours: 21-24
# 2024-07-03 06:28:08,507 - INFO - Exporting aggregated data (geohash5) for date: 20190524, hours: 21-24
