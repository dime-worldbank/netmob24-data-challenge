# %%
# %reload_ext sql
# %config SqlMagic.autocommit=False
# %config SqlMagic.autolimit=0
# %config SqlMagic.autopandas=True
# %config SqlMagic.displaylimit=200

# %%
# %sql trino://localhost:9090/cuebiq/
# Out:
# 'Connected: @cuebiq/'

# %%
pip install python-geohash
# Out:
# Requirement already satisfied: python-geohash in /srv/conda/envs/notebook/lib/python3.9/site-packages (0.8.5)
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
import time
import geohash
import logging
import pandas as pd
from datetime import datetime, timedelta
from sqlalchemy import create_engine

# %%
# SQL engine
from trino.dbapi import connect 
from sqlalchemy import create_engine
import pandas as pd
import time

class TrinoEngine():
    def __init__(self):
        conn = connect(
            host="localhost",
            port=9090,
            catalog="cuebiq"
        )
        self.cur = conn.cursor()
        self.engine = create_engine("trino://localhost:9090/cuebiq/")
    
    def execute_statement(self, query:str) -> list:
        """
        Create and drop statements.
        """
        self.cur.execute(query)
        return self.cur.fetchall()
    
    def read_sql(self, query:str) -> pd.DataFrame: 
        """
        Select and insert into operations.
        """
        return pd.read_sql(query, self.engine)

sql_engine = TrinoEngine()

# %%
schema_name = {'cda': 'cuebiq.paas_cda_pe_v3'}
pe_tj_table = f"{schema_name['cda']}.trajectory_uplevelled"

# %% [markdown]
# # Export to local

# %%
# Set up logging
logging.basicConfig(level=logging.INFO, format='%(asctime)s - %(levelname)s - %(message)s')

# %%
# Function to process data for a specific date
def process_data_for_date(event_date, country_code, export_path):
    errors = []  # List to keep track of errors
    
    # Define the export file paths
    csv3_file = f"od_{country_code.lower()}_agg3_3h.csv"
    csv5_file = f"od_{country_code.lower()}_agg5_3h.csv"
    csv3_file_path = f"{export_path}{csv3_file}"
    csv5_file_path = f"{export_path}{csv5_file}"

    # Loop through 24 hours in increments of 3 hours
    for start_hour in range(0, 24, 3):
        end_hour = start_hour + 3  # end hour for the 3-hour interval
        logging.info(f"Querying data for date: {event_date}, hours: {start_hour}-{end_hour}")

        try:
            # Fetch the data for the specified event date and country code
            pe_tj_df3 = sql_engine.read_sql(
                f"""
                SELECT 
                    cuebiq_id,
                    duration_minutes,
                    length_meters,
                    number_of_points,
                    TRY(date_parse(substr(start_zoned_datetime, 1, 19), '%Y-%m-%dT%H:%i:%s')) AS event_datetime_local,
                    EXTRACT(HOUR FROM TRY(date_parse(substr(start_zoned_datetime, 1, 19), '%Y-%m-%dT%H:%i:%s'))) AS event_hour,
                    geohash_encode(start_lat, start_lng, 5) AS start_geohash5,
                    geohash_encode(start_lat, start_lng, 3) AS start_geohash3,
                    geohash_encode(end_lat, end_lng, 5) AS end_geohash5,
                    geohash_encode(end_lat, end_lng, 3) AS end_geohash3,
                    DATE_FORMAT(date_parse(substr(start_zoned_datetime, 1, 10), '%Y-%m-%d'), '%Y%m%d') AS local_date
                FROM cuebiq.paas_cda_pe_v3.trajectory_uplevelled
                WHERE 
                    event_date = {event_date}
                    AND end_country = '{country_code}' 
                    AND start_country = '{country_code}' 
                """
            )

            # Filter the DataFrame for the current 3-hour interval
            logging.info(f"Processing data for date: {event_date}, hours: {start_hour}-{end_hour}")
            filtered_df = pe_tj_df3[(pe_tj_df3['event_hour'] >= start_hour) & (pe_tj_df3['event_hour'] < end_hour)]

            # Add user numbers to the aggregated data for geohash3
            aggregated_df3 = filtered_df.groupby(['start_geohash3', 'end_geohash3', 'local_date']).agg({
                'cuebiq_id': 'count',
                'duration_minutes': ['mean', 'median', 'std'],
                'length_meters': ['mean', 'median', 'std'],
                'number_of_points': ['mean', 'median', 'std']
            }).reset_index()

            # Flatten the MultiIndex columns
            aggregated_df3.columns = ['start_geohash3', 'end_geohash3', 'local_date', 'trip_count', 
                                      'm_duration_min', 'mdn_duration_min', 'sd_duration_min', 
                                      'm_length_m', 'mdn_length_m', 'sd_length_m',
                                      'm_points_no', 'mdn_points_no', 'sd_points_no']

            # Add the local_time column
            aggregated_df3['local_time'] = aggregated_df3['local_date'].astype(str) + \
                                           f" {start_hour:02d}:00:00 - {end_hour:02d}:00:00"

            # Filter out rows where trip_count is less than or equal to 9
            aggregated_df3 = aggregated_df3[aggregated_df3['trip_count'] > 9]

            # Append the results to the CSV file for geohash3
            logging.info(f"Exporting aggregated data (geohash3) for date: {event_date}, hours: {start_hour}-{end_hour}")
            if not os.path.isfile(csv3_file_path):
                aggregated_df3.to_csv(csv3_file_path, index=False)
            else:
                aggregated_df3.to_csv(csv3_file_path, mode='a', header=False, index=False)

            # Add user numbers to the aggregated data for geohash5
            aggregated_df5 = filtered_df.groupby(['start_geohash5', 'end_geohash5', 'local_date']).agg({
                'cuebiq_id': 'count',
                'duration_minutes': ['mean', 'median', 'std'],
                'length_meters': ['mean', 'median', 'std'],
                'number_of_points': ['mean', 'median', 'std']
            }).reset_index()

            # Flatten the MultiIndex columns
            aggregated_df5.columns = ['start_geohash5', 'end_geohash5', 'local_date', 'trip_count', 
                                      'm_duration_min', 'mdn_duration_min', 'sd_duration_min', 
                                      'm_length_m', 'mdn_length_m', 'sd_length_m',
                                      'm_points_no', 'mdn_points_no', 'sd_points_no']

            # Add the local_time column
            aggregated_df5['local_time'] = aggregated_df5['local_date'].astype(str) + \
                                           f" {start_hour:02d}:00:00 - {end_hour:02d}:00:00"

            # Filter out rows where trip_count is less than or equal to 9
            aggregated_df5 = aggregated_df5[aggregated_df5['trip_count'] > 9]

            # Append the results to the CSV file for geohash5
            logging.info(f"Exporting aggregated data (geohash5) for date: {event_date}, hours: {start_hour}-{end_hour}")
            if not os.path.isfile(csv5_file_path):
                aggregated_df5.to_csv(csv5_file_path, index=False)
            else:
                aggregated_df5.to_csv(csv5_file_path, mode='a', header=False, index=False)
        
        except Exception as e:
            error_message = f"Error processing date: {event_date}, hours: {start_hour}-{end_hour} - {str(e)}"
            logging.error(error_message)
            errors.append(error_message)
    
    return errors

# Function to process data for a range of dates
def process_data_for_date_range(start_date, end_date, country_code, export_path):
    current_date = start_date
    all_errors = []
    while current_date <= end_date:
        event_date = current_date.strftime("%Y%m%d")
        logging.info(f"Processing data for date: {event_date}")
        errors = process_data_for_date(event_date, country_code, export_path)
        all_errors.extend(errors)
        current_date += timedelta(days=1)
    
    # Log any errors that occurred
    if all_errors:
        logging.info("Errors occurred during processing:")
        for error in all_errors:
            logging.info(error)

# %%
# Specify the date range
start_date = datetime.strptime("20190206", "%Y%m%d")
end_date = datetime.strptime("20190630", "%Y%m%d")
country_code = 'MX'
export_path = '/home/jovyan/Data/TJ/3h/'

# Process data for the specified date range
process_data_for_date_range(start_date, end_date, country_code, export_path)
# Out:
# 2024-07-02 22:34:19,566 - INFO - Processing data for date: 20190206
# 2024-07-02 22:34:19,567 - INFO - Querying data for date: 20190206, hours: 0-3
# 2024-07-02 22:35:03,359 - INFO - Processing data for date: 20190206, hours: 0-3
# 2024-07-02 22:35:03,387 - INFO - Exporting aggregated data (geohash3) for date: 20190206, hours: 0-3
# 2024-07-02 22:35:03,427 - INFO - Exporting aggregated data (geohash5) for date: 20190206, hours: 0-3
# 2024-07-02 22:35:03,443 - INFO - Querying data for date: 20190206, hours: 3-6
# 2024-07-02 22:35:37,824 - INFO - Processing data for date: 20190206, hours: 3-6
# 2024-07-02 22:35:37,857 - INFO - Exporting aggregated data (geohash3) for date: 20190206, hours: 3-6
# 2024-07-02 22:35:37,897 - INFO - Exporting aggregated data (geohash5) for date: 20190206, hours: 3-6
# 2024-07-02 22:35:37,914 - INFO - Querying data for date: 20190206, hours: 6-9
# 2024-07-02 22:36:18,446 - INFO - Processing data for date: 20190206, hours: 6-9
# 2024-07-02 22:36:18,520 - INFO - Exporting aggregated data (geohash3) for date: 20190206, hours: 6-9
# 2024-07-02 22:36:18,598 - INFO - Exporting aggregated data (geohash5) for date: 20190206, hours: 6-9
# 2024-07-02 22:36:18,636 - INFO - Querying data for date: 20190206, hours: 9-12
# 2024-07-02 22:36:59,572 - INFO - Processing data for date: 20190206, hours: 9-12
# 2024-07-02 22:36:59,675 - INFO - Exporting aggregated data (geohash3) for date: 20190206, hours: 9-12
# 2024-07-02 22:36:59,770 - INFO - Exporting aggregated data (geohash5) for date: 20190206, hours: 9-12
# 2024-07-02 22:36:59,808 - INFO - Querying data for date: 20190206, hours: 12-15
# 2024-07-02 22:37:31,030 - INFO - Processing data for date: 20190206, hours: 12-15
# 2024-07-02 22:37:31,159 - INFO - Exporting aggregated data (geohash3) for date: 20190206, hours: 12-15
# 2024-07-02 22:37:31,324 - INFO - Exporting aggregated data (geohash5) for date: 20190206, hours: 12-15
# 2024-07-02 22:37:31,394 - INFO - Querying data for date: 20190206, hours: 15-18
# 2024-07-02 22:38:03,276 - INFO - Processing data for date: 20190206, hours: 15-18
# 2024-07-02 22:38:03,403 - INFO - Exporting aggregated data (geohash3) for date: 20190206, hours: 15-18
# 2024-07-02 22:38:03,520 - INFO - Exporting aggregated data (geohash5) for date: 20190206, hours: 15-18
# 2024-07-02 22:38:03,569 - INFO - Querying data for date: 20190206, hours: 18-21
# 2024-07-02 22:38:34,726 - INFO - Processing data for date: 20190206, hours: 18-21
# 2024-07-02 22:38:34,826 - INFO - Exporting aggregated data (geohash3) for date: 20190206, hours: 18-21
# 2024-07-02 22:38:34,913 - INFO - Exporting aggregated data (geohash5) for date: 20190206, hours: 18-21
# 2024-07-02 22:38:34,950 - INFO - Querying data for date: 20190206, hours: 21-24
# 2024-07-02 22:39:12,438 - INFO - Processing data for date: 20190206, hours: 21-24
# 2024-07-02 22:39:12,496 - INFO - Exporting aggregated data (geohash3) for date: 20190206, hours: 21-24
# 2024-07-02 22:39:12,542 - INFO - Exporting aggregated data (geohash5) for date: 20190206, hours: 21-24
# 2024-07-02 22:39:12,689 - INFO - Processing data for date: 20190207
# 2024-07-02 22:39:12,689 - INFO - Querying data for date: 20190207, hours: 0-3
# 2024-07-02 22:40:18,609 - INFO - Processing data for date: 20190207, hours: 0-3
# 2024-07-02 22:40:18,640 - INFO - Exporting aggregated data (geohash3) for date: 20190207, hours: 0-3
# 2024-07-02 22:40:18,676 - INFO - Exporting aggregated data (geohash5) for date: 20190207, hours: 0-3
# 2024-07-02 22:40:18,691 - INFO - Querying data for date: 20190207, hours: 3-6
# 2024-07-02 22:40:52,102 - INFO - Processing data for date: 20190207, hours: 3-6
# 2024-07-02 22:40:52,134 - INFO - Exporting aggregated data (geohash3) for date: 20190207, hours: 3-6
# 2024-07-02 22:40:52,174 - INFO - Exporting aggregated data (geohash5) for date: 20190207, hours: 3-6
# 2024-07-02 22:40:52,190 - INFO - Querying data for date: 20190207, hours: 6-9
# 2024-07-02 22:41:23,479 - INFO - Processing data for date: 20190207, hours: 6-9
# 2024-07-02 22:41:23,570 - INFO - Exporting aggregated data (geohash3) for date: 20190207, hours: 6-9
# 2024-07-02 22:41:23,654 - INFO - Exporting aggregated data (geohash5) for date: 20190207, hours: 6-9
# 2024-07-02 22:41:23,690 - INFO - Querying data for date: 20190207, hours: 9-12
# 2024-07-02 22:41:56,123 - INFO - Processing data for date: 20190207, hours: 9-12
# 2024-07-02 22:41:56,226 - INFO - Exporting aggregated data (geohash3) for date: 20190207, hours: 9-12
# 2024-07-02 22:41:56,324 - INFO - Exporting aggregated data (geohash5) for date: 20190207, hours: 9-12
# 2024-07-02 22:41:56,374 - INFO - Querying data for date: 20190207, hours: 12-15
# 2024-07-02 22:42:34,168 - INFO - Processing data for date: 20190207, hours: 12-15
# 2024-07-02 22:42:34,288 - INFO - Exporting aggregated data (geohash3) for date: 20190207, hours: 12-15
# 2024-07-02 22:42:34,407 - INFO - Exporting aggregated data (geohash5) for date: 20190207, hours: 12-15
# 2024-07-02 22:42:34,460 - INFO - Querying data for date: 20190207, hours: 15-18
# 2024-07-02 22:43:09,006 - INFO - Processing data for date: 20190207, hours: 15-18
# 2024-07-02 22:43:09,122 - INFO - Exporting aggregated data (geohash3) for date: 20190207, hours: 15-18
# 2024-07-02 22:43:09,223 - INFO - Exporting aggregated data (geohash5) for date: 20190207, hours: 15-18
# 2024-07-02 22:43:09,263 - INFO - Querying data for date: 20190207, hours: 18-21
# 2024-07-02 22:43:40,464 - INFO - Processing data for date: 20190207, hours: 18-21
# 2024-07-02 22:43:40,564 - INFO - Exporting aggregated data (geohash3) for date: 20190207, hours: 18-21
# 2024-07-02 22:43:40,652 - INFO - Exporting aggregated data (geohash5) for date: 20190207, hours: 18-21
# 2024-07-02 22:43:40,689 - INFO - Querying data for date: 20190207, hours: 21-24
# 2024-07-02 22:44:12,031 - INFO - Processing data for date: 20190207, hours: 21-24
# 2024-07-02 22:44:12,090 - INFO - Exporting aggregated data (geohash3) for date: 20190207, hours: 21-24
# 2024-07-02 22:44:12,135 - INFO - Exporting aggregated data (geohash5) for date: 20190207, hours: 21-24
# 2024-07-02 22:44:12,319 - INFO - Processing data for date: 20190208
# 2024-07-02 22:44:12,320 - INFO - Querying data for date: 20190208, hours: 0-3
# 2024-07-02 22:45:15,524 - INFO - Processing data for date: 20190208, hours: 0-3
# 2024-07-02 22:45:15,549 - INFO - Exporting aggregated data (geohash3) for date: 20190208, hours: 0-3
# 2024-07-02 22:45:15,586 - INFO - Exporting aggregated data (geohash5) for date: 20190208, hours: 0-3
# 2024-07-02 22:45:15,602 - INFO - Querying data for date: 20190208, hours: 3-6
# 2024-07-02 22:46:02,332 - INFO - Processing data for date: 20190208, hours: 3-6
# 2024-07-02 22:46:02,364 - INFO - Exporting aggregated data (geohash3) for date: 20190208, hours: 3-6
# 2024-07-02 22:46:02,400 - INFO - Exporting aggregated data (geohash5) for date: 20190208, hours: 3-6
# 2024-07-02 22:46:02,417 - INFO - Querying data for date: 20190208, hours: 6-9
# 2024-07-02 22:46:40,870 - INFO - Processing data for date: 20190208, hours: 6-9
# 2024-07-02 22:46:40,955 - INFO - Exporting aggregated data (geohash3) for date: 20190208, hours: 6-9
# 2024-07-02 22:46:41,059 - INFO - Exporting aggregated data (geohash5) for date: 20190208, hours: 6-9
# 2024-07-02 22:46:41,090 - INFO - Querying data for date: 20190208, hours: 9-12
# 2024-07-02 22:47:16,413 - INFO - Processing data for date: 20190208, hours: 9-12
# 2024-07-02 22:47:16,561 - INFO - Exporting aggregated data (geohash3) for date: 20190208, hours: 9-12
# 2024-07-02 22:47:16,715 - INFO - Exporting aggregated data (geohash5) for date: 20190208, hours: 9-12
# 2024-07-02 22:47:16,754 - INFO - Querying data for date: 20190208, hours: 12-15
# 2024-07-02 22:47:52,921 - INFO - Processing data for date: 20190208, hours: 12-15
# 2024-07-02 22:47:53,052 - INFO - Exporting aggregated data (geohash3) for date: 20190208, hours: 12-15
# 2024-07-02 22:47:53,181 - INFO - Exporting aggregated data (geohash5) for date: 20190208, hours: 12-15
# 2024-07-02 22:47:53,238 - INFO - Querying data for date: 20190208, hours: 15-18
# 2024-07-02 22:48:28,325 - INFO - Processing data for date: 20190208, hours: 15-18
# 2024-07-02 22:48:28,439 - INFO - Exporting aggregated data (geohash3) for date: 20190208, hours: 15-18
# 2024-07-02 22:48:28,548 - INFO - Exporting aggregated data (geohash5) for date: 20190208, hours: 15-18
# 2024-07-02 22:48:28,593 - INFO - Querying data for date: 20190208, hours: 18-21
# 2024-07-02 22:49:04,194 - INFO - Processing data for date: 20190208, hours: 18-21
# 2024-07-02 22:49:04,298 - INFO - Exporting aggregated data (geohash3) for date: 20190208, hours: 18-21
# 2024-07-02 22:49:04,401 - INFO - Exporting aggregated data (geohash5) for date: 20190208, hours: 18-21
# 2024-07-02 22:49:04,441 - INFO - Querying data for date: 20190208, hours: 21-24
# 2024-07-02 22:49:28,336 - INFO - Processing data for date: 20190208, hours: 21-24
# 2024-07-02 22:49:28,400 - INFO - Exporting aggregated data (geohash3) for date: 20190208, hours: 21-24
# 2024-07-02 22:49:28,447 - INFO - Exporting aggregated data (geohash5) for date: 20190208, hours: 21-24
# 2024-07-02 22:49:28,600 - INFO - Processing data for date: 20190209
# 2024-07-02 22:49:28,601 - INFO - Querying data for date: 20190209, hours: 0-3
# 2024-07-02 22:50:02,036 - INFO - Processing data for date: 20190209, hours: 0-3
# 2024-07-02 22:50:02,066 - INFO - Exporting aggregated data (geohash3) for date: 20190209, hours: 0-3
# 2024-07-02 22:50:02,110 - INFO - Exporting aggregated data (geohash5) for date: 20190209, hours: 0-3
# 2024-07-02 22:50:02,128 - INFO - Querying data for date: 20190209, hours: 3-6
# 2024-07-02 22:50:39,472 - INFO - Processing data for date: 20190209, hours: 3-6
# 2024-07-02 22:50:39,501 - INFO - Exporting aggregated data (geohash3) for date: 20190209, hours: 3-6
# 2024-07-02 22:50:39,536 - INFO - Exporting aggregated data (geohash5) for date: 20190209, hours: 3-6
# 2024-07-02 22:50:39,552 - INFO - Querying data for date: 20190209, hours: 6-9
# 2024-07-02 22:51:12,140 - INFO - Processing data for date: 20190209, hours: 6-9
# 2024-07-02 22:51:12,191 - INFO - Exporting aggregated data (geohash3) for date: 20190209, hours: 6-9
# 2024-07-02 22:51:12,252 - INFO - Exporting aggregated data (geohash5) for date: 20190209, hours: 6-9
# 2024-07-02 22:51:12,278 - INFO - Querying data for date: 20190209, hours: 9-12
# 2024-07-02 22:51:38,710 - INFO - Processing data for date: 20190209, hours: 9-12
# 2024-07-02 22:51:38,899 - INFO - Exporting aggregated data (geohash3) for date: 20190209, hours: 9-12
# 2024-07-02 22:51:39,045 - INFO - Exporting aggregated data (geohash5) for date: 20190209, hours: 9-12
# 2024-07-02 22:51:39,120 - INFO - Querying data for date: 20190209, hours: 12-15
# 2024-07-02 22:51:58,655 - INFO - Processing data for date: 20190209, hours: 12-15
# 2024-07-02 22:51:58,816 - INFO - Exporting aggregated data (geohash3) for date: 20190209, hours: 12-15
# 2024-07-02 22:51:58,963 - INFO - Exporting aggregated data (geohash5) for date: 20190209, hours: 12-15
# 2024-07-02 22:51:59,020 - INFO - Querying data for date: 20190209, hours: 15-18
# 2024-07-02 22:52:33,834 - INFO - Processing data for date: 20190209, hours: 15-18
# 2024-07-02 22:52:33,937 - INFO - Exporting aggregated data (geohash3) for date: 20190209, hours: 15-18
# 2024-07-02 22:52:34,032 - INFO - Exporting aggregated data (geohash5) for date: 20190209, hours: 15-18
# 2024-07-02 22:52:34,075 - INFO - Querying data for date: 20190209, hours: 18-21
# 2024-07-02 22:53:04,817 - INFO - Processing data for date: 20190209, hours: 18-21
# 2024-07-02 22:53:04,907 - INFO - Exporting aggregated data (geohash3) for date: 20190209, hours: 18-21
# 2024-07-02 22:53:05,001 - INFO - Exporting aggregated data (geohash5) for date: 20190209, hours: 18-21
# 2024-07-02 22:53:05,042 - INFO - Querying data for date: 20190209, hours: 21-24
# 2024-07-02 22:53:28,815 - INFO - Processing data for date: 20190209, hours: 21-24
# 2024-07-02 22:53:28,907 - INFO - Exporting aggregated data (geohash3) for date: 20190209, hours: 21-24
# 2024-07-02 22:53:29,005 - INFO - Exporting aggregated data (geohash5) for date: 20190209, hours: 21-24
# 2024-07-02 22:53:29,209 - INFO - Processing data for date: 20190210
# 2024-07-02 22:53:29,210 - INFO - Querying data for date: 20190210, hours: 0-3
# 2024-07-02 22:54:17,606 - INFO - Processing data for date: 20190210, hours: 0-3
# 2024-07-02 22:54:17,631 - INFO - Exporting aggregated data (geohash3) for date: 20190210, hours: 0-3
# 2024-07-02 22:54:17,669 - INFO - Exporting aggregated data (geohash5) for date: 20190210, hours: 0-3
# 2024-07-02 22:54:17,688 - INFO - Querying data for date: 20190210, hours: 3-6
# 2024-07-02 22:55:00,030 - INFO - Processing data for date: 20190210, hours: 3-6
# 2024-07-02 22:55:00,058 - INFO - Exporting aggregated data (geohash3) for date: 20190210, hours: 3-6
# 2024-07-02 22:55:00,093 - INFO - Exporting aggregated data (geohash5) for date: 20190210, hours: 3-6
# 2024-07-02 22:55:00,109 - INFO - Querying data for date: 20190210, hours: 6-9
# 2024-07-02 22:55:33,604 - INFO - Processing data for date: 20190210, hours: 6-9
# 2024-07-02 22:55:33,645 - INFO - Exporting aggregated data (geohash3) for date: 20190210, hours: 6-9
# 2024-07-02 22:55:33,699 - INFO - Exporting aggregated data (geohash5) for date: 20190210, hours: 6-9
# 2024-07-02 22:55:33,720 - INFO - Querying data for date: 20190210, hours: 9-12
# 2024-07-02 22:56:05,502 - INFO - Processing data for date: 20190210, hours: 9-12
# 2024-07-02 22:56:05,575 - INFO - Exporting aggregated data (geohash3) for date: 20190210, hours: 9-12
# 2024-07-02 22:56:05,655 - INFO - Exporting aggregated data (geohash5) for date: 20190210, hours: 9-12
# 2024-07-02 22:56:05,690 - INFO - Querying data for date: 20190210, hours: 12-15
# 2024-07-02 22:56:33,556 - INFO - Processing data for date: 20190210, hours: 12-15
# 2024-07-02 22:56:33,648 - INFO - Exporting aggregated data (geohash3) for date: 20190210, hours: 12-15
# 2024-07-02 22:56:33,752 - INFO - Exporting aggregated data (geohash5) for date: 20190210, hours: 12-15
# 2024-07-02 22:56:33,808 - INFO - Querying data for date: 20190210, hours: 15-18
# 2024-07-02 22:57:04,520 - INFO - Processing data for date: 20190210, hours: 15-18
# 2024-07-02 22:57:04,629 - INFO - Exporting aggregated data (geohash3) for date: 20190210, hours: 15-18
# 2024-07-02 22:57:04,784 - INFO - Exporting aggregated data (geohash5) for date: 20190210, hours: 15-18
# 2024-07-02 22:57:04,833 - INFO - Querying data for date: 20190210, hours: 18-21
# 2024-07-02 22:57:37,604 - INFO - Processing data for date: 20190210, hours: 18-21
# 2024-07-02 22:57:37,718 - INFO - Exporting aggregated data (geohash3) for date: 20190210, hours: 18-21
# 2024-07-02 22:57:37,792 - INFO - Exporting aggregated data (geohash5) for date: 20190210, hours: 18-21
# 2024-07-02 22:57:37,824 - INFO - Querying data for date: 20190210, hours: 21-24
# 2024-07-02 22:58:08,741 - INFO - Processing data for date: 20190210, hours: 21-24
# 2024-07-02 22:58:08,785 - INFO - Exporting aggregated data (geohash3) for date: 20190210, hours: 21-24
# 2024-07-02 22:58:08,828 - INFO - Exporting aggregated data (geohash5) for date: 20190210, hours: 21-24
# 2024-07-02 22:58:08,930 - INFO - Processing data for date: 20190211
# 2024-07-02 22:58:08,931 - INFO - Querying data for date: 20190211, hours: 0-3
# 2024-07-02 22:58:54,996 - INFO - Processing data for date: 20190211, hours: 0-3
# 2024-07-02 22:58:55,017 - INFO - Exporting aggregated data (geohash3) for date: 20190211, hours: 0-3
# 2024-07-02 22:58:55,052 - INFO - Exporting aggregated data (geohash5) for date: 20190211, hours: 0-3
# 2024-07-02 22:58:55,067 - INFO - Querying data for date: 20190211, hours: 3-6
# 2024-07-02 22:59:29,123 - INFO - Processing data for date: 20190211, hours: 3-6
# 2024-07-02 22:59:29,152 - INFO - Exporting aggregated data (geohash3) for date: 20190211, hours: 3-6
# 2024-07-02 22:59:29,187 - INFO - Exporting aggregated data (geohash5) for date: 20190211, hours: 3-6
# 2024-07-02 22:59:29,203 - INFO - Querying data for date: 20190211, hours: 6-9
# 2024-07-02 23:00:02,168 - INFO - Processing data for date: 20190211, hours: 6-9
# 2024-07-02 23:00:02,249 - INFO - Exporting aggregated data (geohash3) for date: 20190211, hours: 6-9
# 2024-07-02 23:00:02,401 - INFO - Exporting aggregated data (geohash5) for date: 20190211, hours: 6-9
# 2024-07-02 23:00:02,439 - INFO - Querying data for date: 20190211, hours: 9-12
# 2024-07-02 23:00:34,069 - INFO - Processing data for date: 20190211, hours: 9-12
# 2024-07-02 23:00:34,203 - INFO - Exporting aggregated data (geohash3) for date: 20190211, hours: 9-12
# 2024-07-02 23:00:34,340 - INFO - Exporting aggregated data (geohash5) for date: 20190211, hours: 9-12
# 2024-07-02 23:00:34,379 - INFO - Querying data for date: 20190211, hours: 12-15
# 2024-07-02 23:01:13,621 - INFO - Processing data for date: 20190211, hours: 12-15
# 2024-07-02 23:01:13,762 - INFO - Exporting aggregated data (geohash3) for date: 20190211, hours: 12-15
# 2024-07-02 23:01:13,956 - INFO - Exporting aggregated data (geohash5) for date: 20190211, hours: 12-15
# 2024-07-02 23:01:14,027 - INFO - Querying data for date: 20190211, hours: 15-18
# 2024-07-02 23:01:47,740 - INFO - Processing data for date: 20190211, hours: 15-18
# 2024-07-02 23:01:47,849 - INFO - Exporting aggregated data (geohash3) for date: 20190211, hours: 15-18
# 2024-07-02 23:01:47,947 - INFO - Exporting aggregated data (geohash5) for date: 20190211, hours: 15-18
# 2024-07-02 23:01:47,991 - INFO - Querying data for date: 20190211, hours: 18-21
# 2024-07-02 23:02:21,236 - INFO - Processing data for date: 20190211, hours: 18-21
# 2024-07-02 23:02:21,328 - INFO - Exporting aggregated data (geohash3) for date: 20190211, hours: 18-21
# 2024-07-02 23:02:21,408 - INFO - Exporting aggregated data (geohash5) for date: 20190211, hours: 18-21
# 2024-07-02 23:02:21,447 - INFO - Querying data for date: 20190211, hours: 21-24
# 2024-07-02 23:02:53,872 - INFO - Processing data for date: 20190211, hours: 21-24
# 2024-07-02 23:02:53,919 - INFO - Exporting aggregated data (geohash3) for date: 20190211, hours: 21-24
# 2024-07-02 23:02:53,961 - INFO - Exporting aggregated data (geohash5) for date: 20190211, hours: 21-24
# 2024-07-02 23:02:54,088 - INFO - Processing data for date: 20190212
# 2024-07-02 23:02:54,089 - INFO - Querying data for date: 20190212, hours: 0-3
# 2024-07-02 23:03:40,406 - INFO - Processing data for date: 20190212, hours: 0-3
# 2024-07-02 23:03:40,427 - INFO - Exporting aggregated data (geohash3) for date: 20190212, hours: 0-3
# 2024-07-02 23:03:40,461 - INFO - Exporting aggregated data (geohash5) for date: 20190212, hours: 0-3
# 2024-07-02 23:03:40,509 - INFO - Querying data for date: 20190212, hours: 3-6
# 2024-07-02 23:04:08,803 - INFO - Processing data for date: 20190212, hours: 3-6
# 2024-07-02 23:04:08,829 - INFO - Exporting aggregated data (geohash3) for date: 20190212, hours: 3-6
# 2024-07-02 23:04:08,876 - INFO - Exporting aggregated data (geohash5) for date: 20190212, hours: 3-6
# 2024-07-02 23:04:08,889 - INFO - Querying data for date: 20190212, hours: 6-9
# 2024-07-02 23:04:44,668 - INFO - Processing data for date: 20190212, hours: 6-9
# 2024-07-02 23:04:44,726 - INFO - Exporting aggregated data (geohash3) for date: 20190212, hours: 6-9
# 2024-07-02 23:04:44,798 - INFO - Exporting aggregated data (geohash5) for date: 20190212, hours: 6-9
# 2024-07-02 23:04:44,824 - INFO - Querying data for date: 20190212, hours: 9-12
# 2024-07-02 23:05:23,205 - INFO - Processing data for date: 20190212, hours: 9-12
# 2024-07-02 23:05:23,290 - INFO - Exporting aggregated data (geohash3) for date: 20190212, hours: 9-12
# 2024-07-02 23:05:23,376 - INFO - Exporting aggregated data (geohash5) for date: 20190212, hours: 9-12
# 2024-07-02 23:05:23,410 - INFO - Querying data for date: 20190212, hours: 12-15
# 2024-07-02 23:06:00,885 - INFO - Processing data for date: 20190212, hours: 12-15
# 2024-07-02 23:06:00,990 - INFO - Exporting aggregated data (geohash3) for date: 20190212, hours: 12-15
# 2024-07-02 23:06:01,091 - INFO - Exporting aggregated data (geohash5) for date: 20190212, hours: 12-15
# 2024-07-02 23:06:01,129 - INFO - Querying data for date: 20190212, hours: 15-18
# 2024-07-02 23:06:30,357 - INFO - Processing data for date: 20190212, hours: 15-18
# 2024-07-02 23:06:30,452 - INFO - Exporting aggregated data (geohash3) for date: 20190212, hours: 15-18
# 2024-07-02 23:06:30,539 - INFO - Exporting aggregated data (geohash5) for date: 20190212, hours: 15-18
# 2024-07-02 23:06:30,575 - INFO - Querying data for date: 20190212, hours: 18-21
# 2024-07-02 23:07:00,849 - INFO - Processing data for date: 20190212, hours: 18-21
# 2024-07-02 23:07:00,932 - INFO - Exporting aggregated data (geohash3) for date: 20190212, hours: 18-21
# 2024-07-02 23:07:01,025 - INFO - Exporting aggregated data (geohash5) for date: 20190212, hours: 18-21
# 2024-07-02 23:07:01,066 - INFO - Querying data for date: 20190212, hours: 21-24
# 2024-07-02 23:07:32,868 - INFO - Processing data for date: 20190212, hours: 21-24
# 2024-07-02 23:07:32,912 - INFO - Exporting aggregated data (geohash3) for date: 20190212, hours: 21-24
# 2024-07-02 23:07:32,953 - INFO - Exporting aggregated data (geohash5) for date: 20190212, hours: 21-24
# 2024-07-02 23:07:33,065 - INFO - Processing data for date: 20190213
# 2024-07-02 23:07:33,066 - INFO - Querying data for date: 20190213, hours: 0-3
# 2024-07-02 23:08:29,161 - INFO - Processing data for date: 20190213, hours: 0-3
# 2024-07-02 23:08:29,183 - INFO - Exporting aggregated data (geohash3) for date: 20190213, hours: 0-3
# 2024-07-02 23:08:29,217 - INFO - Exporting aggregated data (geohash5) for date: 20190213, hours: 0-3
# 2024-07-02 23:08:29,234 - INFO - Querying data for date: 20190213, hours: 3-6
# 2024-07-02 23:09:16,015 - INFO - Processing data for date: 20190213, hours: 3-6
# 2024-07-02 23:09:16,047 - INFO - Exporting aggregated data (geohash3) for date: 20190213, hours: 3-6
# 2024-07-02 23:09:16,093 - INFO - Exporting aggregated data (geohash5) for date: 20190213, hours: 3-6
# 2024-07-02 23:09:16,109 - INFO - Querying data for date: 20190213, hours: 6-9
# 2024-07-02 23:09:54,055 - INFO - Processing data for date: 20190213, hours: 6-9
# 2024-07-02 23:09:54,125 - INFO - Exporting aggregated data (geohash3) for date: 20190213, hours: 6-9
# 2024-07-02 23:09:54,208 - INFO - Exporting aggregated data (geohash5) for date: 20190213, hours: 6-9
# 2024-07-02 23:09:54,240 - INFO - Querying data for date: 20190213, hours: 9-12
# 2024-07-02 23:10:31,222 - INFO - Processing data for date: 20190213, hours: 9-12
# 2024-07-02 23:10:31,342 - INFO - Exporting aggregated data (geohash3) for date: 20190213, hours: 9-12
# 2024-07-02 23:10:31,441 - INFO - Exporting aggregated data (geohash5) for date: 20190213, hours: 9-12
# 2024-07-02 23:10:31,489 - INFO - Querying data for date: 20190213, hours: 12-15
# 2024-07-02 23:11:06,573 - INFO - Processing data for date: 20190213, hours: 12-15
# 2024-07-02 23:11:06,704 - INFO - Exporting aggregated data (geohash3) for date: 20190213, hours: 12-15
# 2024-07-02 23:11:06,852 - INFO - Exporting aggregated data (geohash5) for date: 20190213, hours: 12-15
# 2024-07-02 23:11:06,915 - INFO - Querying data for date: 20190213, hours: 15-18
# 2024-07-02 23:11:52,061 - INFO - Processing data for date: 20190213, hours: 15-18
# 2024-07-02 23:11:52,181 - INFO - Exporting aggregated data (geohash3) for date: 20190213, hours: 15-18
# 2024-07-02 23:11:52,287 - INFO - Exporting aggregated data (geohash5) for date: 20190213, hours: 15-18
# 2024-07-02 23:11:52,339 - INFO - Querying data for date: 20190213, hours: 18-21
# 2024-07-02 23:12:33,450 - INFO - Processing data for date: 20190213, hours: 18-21
# 2024-07-02 23:12:33,551 - INFO - Exporting aggregated data (geohash3) for date: 20190213, hours: 18-21
# 2024-07-02 23:12:33,636 - INFO - Exporting aggregated data (geohash5) for date: 20190213, hours: 18-21
# 2024-07-02 23:12:33,675 - INFO - Querying data for date: 20190213, hours: 21-24
# 2024-07-02 23:13:09,348 - INFO - Processing data for date: 20190213, hours: 21-24
# 2024-07-02 23:13:09,403 - INFO - Exporting aggregated data (geohash3) for date: 20190213, hours: 21-24
# 2024-07-02 23:13:09,450 - INFO - Exporting aggregated data (geohash5) for date: 20190213, hours: 21-24
# 2024-07-02 23:13:09,605 - INFO - Processing data for date: 20190214
# 2024-07-02 23:13:09,606 - INFO - Querying data for date: 20190214, hours: 0-3
# 2024-07-02 23:14:01,179 - INFO - Processing data for date: 20190214, hours: 0-3
# 2024-07-02 23:14:01,204 - INFO - Exporting aggregated data (geohash3) for date: 20190214, hours: 0-3
# 2024-07-02 23:14:01,247 - INFO - Exporting aggregated data (geohash5) for date: 20190214, hours: 0-3
# 2024-07-02 23:14:01,265 - INFO - Querying data for date: 20190214, hours: 3-6
# 2024-07-02 23:15:03,337 - INFO - Processing data for date: 20190214, hours: 3-6
# 2024-07-02 23:15:03,373 - INFO - Exporting aggregated data (geohash3) for date: 20190214, hours: 3-6
# 2024-07-02 23:15:03,416 - INFO - Exporting aggregated data (geohash5) for date: 20190214, hours: 3-6
# 2024-07-02 23:15:03,433 - INFO - Querying data for date: 20190214, hours: 6-9
# 2024-07-02 23:15:47,049 - INFO - Processing data for date: 20190214, hours: 6-9
# 2024-07-02 23:15:47,139 - INFO - Exporting aggregated data (geohash3) for date: 20190214, hours: 6-9
# 2024-07-02 23:15:47,222 - INFO - Exporting aggregated data (geohash5) for date: 20190214, hours: 6-9
# 2024-07-02 23:15:47,254 - INFO - Querying data for date: 20190214, hours: 9-12
# 2024-07-02 23:16:24,813 - INFO - Processing data for date: 20190214, hours: 9-12
# 2024-07-02 23:16:24,924 - INFO - Exporting aggregated data (geohash3) for date: 20190214, hours: 9-12
# 2024-07-02 23:16:25,031 - INFO - Exporting aggregated data (geohash5) for date: 20190214, hours: 9-12
# 2024-07-02 23:16:25,071 - INFO - Querying data for date: 20190214, hours: 12-15
# 2024-07-02 23:17:10,414 - INFO - Processing data for date: 20190214, hours: 12-15
# 2024-07-02 23:17:10,552 - INFO - Exporting aggregated data (geohash3) for date: 20190214, hours: 12-15
# 2024-07-02 23:17:10,683 - INFO - Exporting aggregated data (geohash5) for date: 20190214, hours: 12-15
# 2024-07-02 23:17:10,741 - INFO - Querying data for date: 20190214, hours: 15-18
# 2024-07-02 23:17:45,917 - INFO - Processing data for date: 20190214, hours: 15-18
# 2024-07-02 23:17:46,058 - INFO - Exporting aggregated data (geohash3) for date: 20190214, hours: 15-18
# 2024-07-02 23:17:46,185 - INFO - Exporting aggregated data (geohash5) for date: 20190214, hours: 15-18
# 2024-07-02 23:17:46,229 - INFO - Querying data for date: 20190214, hours: 18-21
# 2024-07-02 23:18:20,169 - INFO - Processing data for date: 20190214, hours: 18-21
# 2024-07-02 23:18:20,277 - INFO - Exporting aggregated data (geohash3) for date: 20190214, hours: 18-21
# 2024-07-02 23:18:20,382 - INFO - Exporting aggregated data (geohash5) for date: 20190214, hours: 18-21
# 2024-07-02 23:18:20,427 - INFO - Querying data for date: 20190214, hours: 21-24
# 2024-07-02 23:18:47,993 - INFO - Processing data for date: 20190214, hours: 21-24
# 2024-07-02 23:18:48,055 - INFO - Exporting aggregated data (geohash3) for date: 20190214, hours: 21-24
# 2024-07-02 23:18:48,116 - INFO - Exporting aggregated data (geohash5) for date: 20190214, hours: 21-24
# 2024-07-02 23:18:48,270 - INFO - Processing data for date: 20190215
# 2024-07-02 23:18:48,271 - INFO - Querying data for date: 20190215, hours: 0-3
# 2024-07-02 23:19:35,992 - INFO - Processing data for date: 20190215, hours: 0-3
# 2024-07-02 23:19:36,017 - INFO - Exporting aggregated data (geohash3) for date: 20190215, hours: 0-3
# 2024-07-02 23:19:36,056 - INFO - Exporting aggregated data (geohash5) for date: 20190215, hours: 0-3
# 2024-07-02 23:19:36,074 - INFO - Querying data for date: 20190215, hours: 3-6
# 2024-07-02 23:20:04,672 - INFO - Processing data for date: 20190215, hours: 3-6
# 2024-07-02 23:20:04,708 - INFO - Exporting aggregated data (geohash3) for date: 20190215, hours: 3-6
# 2024-07-02 23:20:04,749 - INFO - Exporting aggregated data (geohash5) for date: 20190215, hours: 3-6
# 2024-07-02 23:20:04,765 - INFO - Querying data for date: 20190215, hours: 6-9
# 2024-07-02 23:20:38,999 - INFO - Processing data for date: 20190215, hours: 6-9
# 2024-07-02 23:20:39,072 - INFO - Exporting aggregated data (geohash3) for date: 20190215, hours: 6-9
# 2024-07-02 23:20:39,153 - INFO - Exporting aggregated data (geohash5) for date: 20190215, hours: 6-9
# 2024-07-02 23:20:39,186 - INFO - Querying data for date: 20190215, hours: 9-12
# 2024-07-02 23:21:29,857 - INFO - Processing data for date: 20190215, hours: 9-12
# 2024-07-02 23:21:29,972 - INFO - Exporting aggregated data (geohash3) for date: 20190215, hours: 9-12
# 2024-07-02 23:21:30,084 - INFO - Exporting aggregated data (geohash5) for date: 20190215, hours: 9-12
# 2024-07-02 23:21:30,128 - INFO - Querying data for date: 20190215, hours: 12-15
# 2024-07-02 23:21:57,724 - INFO - Processing data for date: 20190215, hours: 12-15
# 2024-07-02 23:21:57,948 - INFO - Exporting aggregated data (geohash3) for date: 20190215, hours: 12-15
# 2024-07-02 23:21:58,155 - INFO - Exporting aggregated data (geohash5) for date: 20190215, hours: 12-15
# 2024-07-02 23:21:58,206 - INFO - Querying data for date: 20190215, hours: 15-18
# 2024-07-02 23:22:21,876 - INFO - Processing data for date: 20190215, hours: 15-18
# 2024-07-02 23:22:22,009 - INFO - Exporting aggregated data (geohash3) for date: 20190215, hours: 15-18
# 2024-07-02 23:22:22,127 - INFO - Exporting aggregated data (geohash5) for date: 20190215, hours: 15-18
# 2024-07-02 23:22:22,172 - INFO - Querying data for date: 20190215, hours: 18-21
# 2024-07-02 23:22:42,185 - INFO - Processing data for date: 20190215, hours: 18-21
# 2024-07-02 23:22:42,298 - INFO - Exporting aggregated data (geohash3) for date: 20190215, hours: 18-21
# 2024-07-02 23:22:42,406 - INFO - Exporting aggregated data (geohash5) for date: 20190215, hours: 18-21
# 2024-07-02 23:22:42,448 - INFO - Querying data for date: 20190215, hours: 21-24
# 2024-07-02 23:23:20,456 - INFO - Processing data for date: 20190215, hours: 21-24
# 2024-07-02 23:23:20,522 - INFO - Exporting aggregated data (geohash3) for date: 20190215, hours: 21-24
# 2024-07-02 23:23:20,577 - INFO - Exporting aggregated data (geohash5) for date: 20190215, hours: 21-24
# 2024-07-02 23:23:20,737 - INFO - Processing data for date: 20190216
# 2024-07-02 23:23:20,737 - INFO - Querying data for date: 20190216, hours: 0-3
# 2024-07-02 23:23:42,239 - INFO - Processing data for date: 20190216, hours: 0-3
# 2024-07-02 23:23:42,267 - INFO - Exporting aggregated data (geohash3) for date: 20190216, hours: 0-3
# 2024-07-02 23:23:42,308 - INFO - Exporting aggregated data (geohash5) for date: 20190216, hours: 0-3
# 2024-07-02 23:23:42,325 - INFO - Querying data for date: 20190216, hours: 3-6
# 2024-07-02 23:24:15,067 - INFO - Processing data for date: 20190216, hours: 3-6
# 2024-07-02 23:24:15,097 - INFO - Exporting aggregated data (geohash3) for date: 20190216, hours: 3-6
# 2024-07-02 23:24:15,134 - INFO - Exporting aggregated data (geohash5) for date: 20190216, hours: 3-6
# 2024-07-02 23:24:15,154 - INFO - Querying data for date: 20190216, hours: 6-9
# 2024-07-02 23:24:52,143 - INFO - Processing data for date: 20190216, hours: 6-9
# 2024-07-02 23:24:52,200 - INFO - Exporting aggregated data (geohash3) for date: 20190216, hours: 6-9
# 2024-07-02 23:24:52,266 - INFO - Exporting aggregated data (geohash5) for date: 20190216, hours: 6-9
# 2024-07-02 23:24:52,291 - INFO - Querying data for date: 20190216, hours: 9-12
# 2024-07-02 23:25:25,787 - INFO - Processing data for date: 20190216, hours: 9-12
# 2024-07-02 23:25:25,890 - INFO - Exporting aggregated data (geohash3) for date: 20190216, hours: 9-12
# 2024-07-02 23:25:26,003 - INFO - Exporting aggregated data (geohash5) for date: 20190216, hours: 9-12
# 2024-07-02 23:25:26,047 - INFO - Querying data for date: 20190216, hours: 12-15
# 2024-07-02 23:26:01,949 - INFO - Processing data for date: 20190216, hours: 12-15
# 2024-07-02 23:26:02,077 - INFO - Exporting aggregated data (geohash3) for date: 20190216, hours: 12-15
# 2024-07-02 23:26:02,219 - INFO - Exporting aggregated data (geohash5) for date: 20190216, hours: 12-15
# 2024-07-02 23:26:02,268 - INFO - Querying data for date: 20190216, hours: 15-18
# 2024-07-02 23:26:34,829 - INFO - Processing data for date: 20190216, hours: 15-18
# 2024-07-02 23:26:34,948 - INFO - Exporting aggregated data (geohash3) for date: 20190216, hours: 15-18
# 2024-07-02 23:26:35,074 - INFO - Exporting aggregated data (geohash5) for date: 20190216, hours: 15-18
# 2024-07-02 23:26:35,120 - INFO - Querying data for date: 20190216, hours: 18-21
# 2024-07-02 23:27:08,583 - INFO - Processing data for date: 20190216, hours: 18-21
# 2024-07-02 23:27:08,700 - INFO - Exporting aggregated data (geohash3) for date: 20190216, hours: 18-21
# 2024-07-02 23:27:08,823 - INFO - Exporting aggregated data (geohash5) for date: 20190216, hours: 18-21
# 2024-07-02 23:27:08,859 - INFO - Querying data for date: 20190216, hours: 21-24
# 2024-07-02 23:27:41,149 - INFO - Processing data for date: 20190216, hours: 21-24
# 2024-07-02 23:27:41,216 - INFO - Exporting aggregated data (geohash3) for date: 20190216, hours: 21-24
# 2024-07-02 23:27:41,273 - INFO - Exporting aggregated data (geohash5) for date: 20190216, hours: 21-24
# 2024-07-02 23:27:41,423 - INFO - Processing data for date: 20190217
# 2024-07-02 23:27:41,424 - INFO - Querying data for date: 20190217, hours: 0-3
# 2024-07-02 23:28:29,429 - INFO - Processing data for date: 20190217, hours: 0-3
# 2024-07-02 23:28:29,457 - INFO - Exporting aggregated data (geohash3) for date: 20190217, hours: 0-3
# 2024-07-02 23:28:29,505 - INFO - Exporting aggregated data (geohash5) for date: 20190217, hours: 0-3
# 2024-07-02 23:28:29,530 - INFO - Querying data for date: 20190217, hours: 3-6
# 2024-07-02 23:29:05,016 - INFO - Processing data for date: 20190217, hours: 3-6
# 2024-07-02 23:29:05,045 - INFO - Exporting aggregated data (geohash3) for date: 20190217, hours: 3-6
# 2024-07-02 23:29:05,081 - INFO - Exporting aggregated data (geohash5) for date: 20190217, hours: 3-6
# 2024-07-02 23:29:05,096 - INFO - Querying data for date: 20190217, hours: 6-9
# 2024-07-02 23:29:36,870 - INFO - Processing data for date: 20190217, hours: 6-9
# 2024-07-02 23:29:36,914 - INFO - Exporting aggregated data (geohash3) for date: 20190217, hours: 6-9
# 2024-07-02 23:29:36,973 - INFO - Exporting aggregated data (geohash5) for date: 20190217, hours: 6-9
# 2024-07-02 23:29:36,993 - INFO - Querying data for date: 20190217, hours: 9-12
# 2024-07-02 23:30:06,149 - INFO - Processing data for date: 20190217, hours: 9-12
# 2024-07-02 23:30:06,235 - INFO - Exporting aggregated data (geohash3) for date: 20190217, hours: 9-12
# 2024-07-02 23:30:06,327 - INFO - Exporting aggregated data (geohash5) for date: 20190217, hours: 9-12
# 2024-07-02 23:30:06,365 - INFO - Querying data for date: 20190217, hours: 12-15
# 2024-07-02 23:30:34,215 - INFO - Processing data for date: 20190217, hours: 12-15
# 2024-07-02 23:30:34,343 - INFO - Exporting aggregated data (geohash3) for date: 20190217, hours: 12-15
# 2024-07-02 23:30:34,451 - INFO - Exporting aggregated data (geohash5) for date: 20190217, hours: 12-15
# 2024-07-02 23:30:34,489 - INFO - Querying data for date: 20190217, hours: 15-18
# 2024-07-02 23:31:10,792 - INFO - Processing data for date: 20190217, hours: 15-18
# 2024-07-02 23:31:10,888 - INFO - Exporting aggregated data (geohash3) for date: 20190217, hours: 15-18
# 2024-07-02 23:31:10,982 - INFO - Exporting aggregated data (geohash5) for date: 20190217, hours: 15-18
# 2024-07-02 23:31:11,018 - INFO - Querying data for date: 20190217, hours: 18-21
# 2024-07-02 23:31:48,310 - INFO - Processing data for date: 20190217, hours: 18-21
# 2024-07-02 23:31:48,404 - INFO - Exporting aggregated data (geohash3) for date: 20190217, hours: 18-21
# 2024-07-02 23:31:48,488 - INFO - Exporting aggregated data (geohash5) for date: 20190217, hours: 18-21
# 2024-07-02 23:31:48,526 - INFO - Querying data for date: 20190217, hours: 21-24
# 2024-07-02 23:32:23,319 - INFO - Processing data for date: 20190217, hours: 21-24
# 2024-07-02 23:32:23,368 - INFO - Exporting aggregated data (geohash3) for date: 20190217, hours: 21-24
# 2024-07-02 23:32:23,416 - INFO - Exporting aggregated data (geohash5) for date: 20190217, hours: 21-24
# 2024-07-02 23:32:23,533 - INFO - Processing data for date: 20190218
# 2024-07-02 23:32:23,534 - INFO - Querying data for date: 20190218, hours: 0-3
# 2024-07-02 23:33:08,940 - INFO - Processing data for date: 20190218, hours: 0-3
# 2024-07-02 23:33:08,965 - INFO - Exporting aggregated data (geohash3) for date: 20190218, hours: 0-3
# 2024-07-02 23:33:09,004 - INFO - Exporting aggregated data (geohash5) for date: 20190218, hours: 0-3
# 2024-07-02 23:33:09,022 - INFO - Querying data for date: 20190218, hours: 3-6
# 2024-07-02 23:33:42,215 - INFO - Processing data for date: 20190218, hours: 3-6
# 2024-07-02 23:33:42,249 - INFO - Exporting aggregated data (geohash3) for date: 20190218, hours: 3-6
# 2024-07-02 23:33:42,292 - INFO - Exporting aggregated data (geohash5) for date: 20190218, hours: 3-6
# 2024-07-02 23:33:42,307 - INFO - Querying data for date: 20190218, hours: 6-9
# 2024-07-02 23:34:13,860 - INFO - Processing data for date: 20190218, hours: 6-9
# 2024-07-02 23:34:13,949 - INFO - Exporting aggregated data (geohash3) for date: 20190218, hours: 6-9
# 2024-07-02 23:34:14,044 - INFO - Exporting aggregated data (geohash5) for date: 20190218, hours: 6-9
# 2024-07-02 23:34:14,083 - INFO - Querying data for date: 20190218, hours: 9-12
# 2024-07-02 23:34:46,646 - INFO - Processing data for date: 20190218, hours: 9-12
# 2024-07-02 23:34:46,754 - INFO - Exporting aggregated data (geohash3) for date: 20190218, hours: 9-12
# 2024-07-02 23:34:46,855 - INFO - Exporting aggregated data (geohash5) for date: 20190218, hours: 9-12
# 2024-07-02 23:34:46,902 - INFO - Querying data for date: 20190218, hours: 12-15
# 2024-07-02 23:35:21,168 - INFO - Processing data for date: 20190218, hours: 12-15
# 2024-07-02 23:35:21,307 - INFO - Exporting aggregated data (geohash3) for date: 20190218, hours: 12-15
# 2024-07-02 23:35:21,445 - INFO - Exporting aggregated data (geohash5) for date: 20190218, hours: 12-15
# 2024-07-02 23:35:21,499 - INFO - Querying data for date: 20190218, hours: 15-18
# 2024-07-02 23:35:55,844 - INFO - Processing data for date: 20190218, hours: 15-18
# 2024-07-02 23:35:55,965 - INFO - Exporting aggregated data (geohash3) for date: 20190218, hours: 15-18
# 2024-07-02 23:35:56,078 - INFO - Exporting aggregated data (geohash5) for date: 20190218, hours: 15-18
# 2024-07-02 23:35:56,128 - INFO - Querying data for date: 20190218, hours: 18-21
# 2024-07-02 23:36:27,636 - INFO - Processing data for date: 20190218, hours: 18-21
# 2024-07-02 23:36:27,738 - INFO - Exporting aggregated data (geohash3) for date: 20190218, hours: 18-21
# 2024-07-02 23:36:27,828 - INFO - Exporting aggregated data (geohash5) for date: 20190218, hours: 18-21
# 2024-07-02 23:36:27,878 - INFO - Querying data for date: 20190218, hours: 21-24
# 2024-07-02 23:37:01,312 - INFO - Processing data for date: 20190218, hours: 21-24
# 2024-07-02 23:37:01,374 - INFO - Exporting aggregated data (geohash3) for date: 20190218, hours: 21-24
# 2024-07-02 23:37:01,424 - INFO - Exporting aggregated data (geohash5) for date: 20190218, hours: 21-24
# 2024-07-02 23:37:01,636 - INFO - Processing data for date: 20190219
# 2024-07-02 23:37:01,637 - INFO - Querying data for date: 20190219, hours: 0-3
# 2024-07-02 23:37:48,443 - INFO - Processing data for date: 20190219, hours: 0-3
# 2024-07-02 23:37:48,467 - INFO - Exporting aggregated data (geohash3) for date: 20190219, hours: 0-3
# 2024-07-02 23:37:48,510 - INFO - Exporting aggregated data (geohash5) for date: 20190219, hours: 0-3
# 2024-07-02 23:37:48,529 - INFO - Querying data for date: 20190219, hours: 3-6
# 2024-07-02 23:38:24,823 - INFO - Processing data for date: 20190219, hours: 3-6
# 2024-07-02 23:38:24,855 - INFO - Exporting aggregated data (geohash3) for date: 20190219, hours: 3-6
# 2024-07-02 23:38:24,898 - INFO - Exporting aggregated data (geohash5) for date: 20190219, hours: 3-6
# 2024-07-02 23:38:24,921 - INFO - Querying data for date: 20190219, hours: 6-9
# 2024-07-02 23:39:01,547 - INFO - Processing data for date: 20190219, hours: 6-9
# 2024-07-02 23:39:01,625 - INFO - Exporting aggregated data (geohash3) for date: 20190219, hours: 6-9
# 2024-07-02 23:39:01,716 - INFO - Exporting aggregated data (geohash5) for date: 20190219, hours: 6-9
# 2024-07-02 23:39:01,758 - INFO - Querying data for date: 20190219, hours: 9-12
# 2024-07-02 23:39:36,721 - INFO - Processing data for date: 20190219, hours: 9-12
# 2024-07-02 23:39:36,826 - INFO - Exporting aggregated data (geohash3) for date: 20190219, hours: 9-12
# 2024-07-02 23:39:36,937 - INFO - Exporting aggregated data (geohash5) for date: 20190219, hours: 9-12
# 2024-07-02 23:39:36,978 - INFO - Querying data for date: 20190219, hours: 12-15
# 2024-07-02 23:40:22,801 - INFO - Processing data for date: 20190219, hours: 12-15
# 2024-07-02 23:40:22,939 - INFO - Exporting aggregated data (geohash3) for date: 20190219, hours: 12-15
# 2024-07-02 23:40:23,075 - INFO - Exporting aggregated data (geohash5) for date: 20190219, hours: 12-15
# 2024-07-02 23:40:23,133 - INFO - Querying data for date: 20190219, hours: 15-18
# 2024-07-02 23:40:54,548 - INFO - Processing data for date: 20190219, hours: 15-18
# 2024-07-02 23:40:54,669 - INFO - Exporting aggregated data (geohash3) for date: 20190219, hours: 15-18
# 2024-07-02 23:40:54,784 - INFO - Exporting aggregated data (geohash5) for date: 20190219, hours: 15-18
# 2024-07-02 23:40:54,830 - INFO - Querying data for date: 20190219, hours: 18-21
# 2024-07-02 23:41:25,570 - INFO - Processing data for date: 20190219, hours: 18-21
# 2024-07-02 23:41:25,702 - INFO - Exporting aggregated data (geohash3) for date: 20190219, hours: 18-21
# 2024-07-02 23:41:25,814 - INFO - Exporting aggregated data (geohash5) for date: 20190219, hours: 18-21
# 2024-07-02 23:41:25,858 - INFO - Querying data for date: 20190219, hours: 21-24
# 2024-07-02 23:41:57,477 - INFO - Processing data for date: 20190219, hours: 21-24
# 2024-07-02 23:41:57,532 - INFO - Exporting aggregated data (geohash3) for date: 20190219, hours: 21-24
# 2024-07-02 23:41:57,580 - INFO - Exporting aggregated data (geohash5) for date: 20190219, hours: 21-24
# 2024-07-02 23:41:57,728 - INFO - Processing data for date: 20190220
# 2024-07-02 23:41:57,728 - INFO - Querying data for date: 20190220, hours: 0-3
# 2024-07-02 23:42:56,371 - INFO - Processing data for date: 20190220, hours: 0-3
# 2024-07-02 23:42:56,394 - INFO - Exporting aggregated data (geohash3) for date: 20190220, hours: 0-3
# 2024-07-02 23:42:56,428 - INFO - Exporting aggregated data (geohash5) for date: 20190220, hours: 0-3
# 2024-07-02 23:42:56,444 - INFO - Querying data for date: 20190220, hours: 3-6
# 2024-07-02 23:43:30,021 - INFO - Processing data for date: 20190220, hours: 3-6
# 2024-07-02 23:43:30,055 - INFO - Exporting aggregated data (geohash3) for date: 20190220, hours: 3-6
# 2024-07-02 23:43:30,095 - INFO - Exporting aggregated data (geohash5) for date: 20190220, hours: 3-6
# 2024-07-02 23:43:30,111 - INFO - Querying data for date: 20190220, hours: 6-9
# 2024-07-02 23:44:01,127 - INFO - Processing data for date: 20190220, hours: 6-9
# 2024-07-02 23:44:01,219 - INFO - Exporting aggregated data (geohash3) for date: 20190220, hours: 6-9
# 2024-07-02 23:44:01,323 - INFO - Exporting aggregated data (geohash5) for date: 20190220, hours: 6-9
# 2024-07-02 23:44:01,357 - INFO - Querying data for date: 20190220, hours: 9-12
# 2024-07-02 23:44:38,323 - INFO - Processing data for date: 20190220, hours: 9-12
# 2024-07-02 23:44:38,434 - INFO - Exporting aggregated data (geohash3) for date: 20190220, hours: 9-12
# 2024-07-02 23:44:38,544 - INFO - Exporting aggregated data (geohash5) for date: 20190220, hours: 9-12
# 2024-07-02 23:44:38,585 - INFO - Querying data for date: 20190220, hours: 12-15
# 2024-07-02 23:45:21,433 - INFO - Processing data for date: 20190220, hours: 12-15
# 2024-07-02 23:45:21,564 - INFO - Exporting aggregated data (geohash3) for date: 20190220, hours: 12-15
# 2024-07-02 23:45:21,686 - INFO - Exporting aggregated data (geohash5) for date: 20190220, hours: 12-15
# 2024-07-02 23:45:21,744 - INFO - Querying data for date: 20190220, hours: 15-18
# 2024-07-02 23:45:50,219 - INFO - Processing data for date: 20190220, hours: 15-18
# 2024-07-02 23:45:50,349 - INFO - Exporting aggregated data (geohash3) for date: 20190220, hours: 15-18
# 2024-07-02 23:45:50,467 - INFO - Exporting aggregated data (geohash5) for date: 20190220, hours: 15-18
# 2024-07-02 23:45:50,513 - INFO - Querying data for date: 20190220, hours: 18-21
# 2024-07-02 23:46:13,850 - INFO - Processing data for date: 20190220, hours: 18-21
# 2024-07-02 23:46:13,961 - INFO - Exporting aggregated data (geohash3) for date: 20190220, hours: 18-21
# 2024-07-02 23:46:14,059 - INFO - Exporting aggregated data (geohash5) for date: 20190220, hours: 18-21
# 2024-07-02 23:46:14,100 - INFO - Querying data for date: 20190220, hours: 21-24
# 2024-07-02 23:46:41,841 - INFO - Processing data for date: 20190220, hours: 21-24
# 2024-07-02 23:46:41,898 - INFO - Exporting aggregated data (geohash3) for date: 20190220, hours: 21-24
# 2024-07-02 23:46:41,945 - INFO - Exporting aggregated data (geohash5) for date: 20190220, hours: 21-24
# 2024-07-02 23:46:42,096 - INFO - Processing data for date: 20190221
# 2024-07-02 23:46:42,097 - INFO - Querying data for date: 20190221, hours: 0-3
# 2024-07-02 23:47:36,662 - INFO - Processing data for date: 20190221, hours: 0-3
# 2024-07-02 23:47:36,686 - INFO - Exporting aggregated data (geohash3) for date: 20190221, hours: 0-3
# 2024-07-02 23:47:36,723 - INFO - Exporting aggregated data (geohash5) for date: 20190221, hours: 0-3
# 2024-07-02 23:47:36,743 - INFO - Querying data for date: 20190221, hours: 3-6
# 2024-07-02 23:48:01,942 - INFO - Processing data for date: 20190221, hours: 3-6
# 2024-07-02 23:48:01,977 - INFO - Exporting aggregated data (geohash3) for date: 20190221, hours: 3-6
# 2024-07-02 23:48:02,016 - INFO - Exporting aggregated data (geohash5) for date: 20190221, hours: 3-6
# 2024-07-02 23:48:02,033 - INFO - Querying data for date: 20190221, hours: 6-9
# 2024-07-02 23:48:22,198 - INFO - Processing data for date: 20190221, hours: 6-9
# 2024-07-02 23:48:22,275 - INFO - Exporting aggregated data (geohash3) for date: 20190221, hours: 6-9
# 2024-07-02 23:48:22,362 - INFO - Exporting aggregated data (geohash5) for date: 20190221, hours: 6-9
# 2024-07-02 23:48:22,397 - INFO - Querying data for date: 20190221, hours: 9-12
# 2024-07-02 23:48:43,159 - INFO - Processing data for date: 20190221, hours: 9-12
# 2024-07-02 23:48:43,271 - INFO - Exporting aggregated data (geohash3) for date: 20190221, hours: 9-12
# 2024-07-02 23:48:43,376 - INFO - Exporting aggregated data (geohash5) for date: 20190221, hours: 9-12
# 2024-07-02 23:48:43,418 - INFO - Querying data for date: 20190221, hours: 12-15
# 2024-07-02 23:49:16,842 - INFO - Processing data for date: 20190221, hours: 12-15
# 2024-07-02 23:49:16,979 - INFO - Exporting aggregated data (geohash3) for date: 20190221, hours: 12-15
# 2024-07-02 23:49:17,121 - INFO - Exporting aggregated data (geohash5) for date: 20190221, hours: 12-15
# 2024-07-02 23:49:17,177 - INFO - Querying data for date: 20190221, hours: 15-18
# 2024-07-02 23:49:43,953 - INFO - Processing data for date: 20190221, hours: 15-18
# 2024-07-02 23:49:44,094 - INFO - Exporting aggregated data (geohash3) for date: 20190221, hours: 15-18
# 2024-07-02 23:49:44,224 - INFO - Exporting aggregated data (geohash5) for date: 20190221, hours: 15-18
# 2024-07-02 23:49:44,268 - INFO - Querying data for date: 20190221, hours: 18-21
# 2024-07-02 23:50:03,917 - INFO - Processing data for date: 20190221, hours: 18-21
# 2024-07-02 23:50:04,032 - INFO - Exporting aggregated data (geohash3) for date: 20190221, hours: 18-21
# 2024-07-02 23:50:04,169 - INFO - Exporting aggregated data (geohash5) for date: 20190221, hours: 18-21
# 2024-07-02 23:50:04,229 - INFO - Querying data for date: 20190221, hours: 21-24
# 2024-07-02 23:50:24,824 - INFO - Processing data for date: 20190221, hours: 21-24
# 2024-07-02 23:50:24,915 - INFO - Exporting aggregated data (geohash3) for date: 20190221, hours: 21-24
# 2024-07-02 23:50:24,971 - INFO - Exporting aggregated data (geohash5) for date: 20190221, hours: 21-24
# 2024-07-02 23:50:25,221 - INFO - Processing data for date: 20190222
# 2024-07-02 23:50:25,222 - INFO - Querying data for date: 20190222, hours: 0-3
# 2024-07-02 23:50:51,163 - INFO - Processing data for date: 20190222, hours: 0-3
# ...
# 2024-07-03 00:38:47,233 - INFO - Exporting aggregated data (geohash5) for date: 20190303, hours: 15-18
# 2024-07-03 00:38:47,272 - INFO - Querying data for date: 20190303, hours: 18-21
# 2024-07-03 00:39:14,298 - INFO - Processing data for date: 20190303, hours: 18-21
# 2024-07-03 00:39:14,387 - INFO - Exporting aggregated data (geohash3) for date: 20190303, hours: 18-21
# 2024-07-03 00:39:14,479 - INFO - Exporting aggregated data (geohash5) for date: 20190303, hours: 18-21
# 2024-07-03 00:39:14,512 - INFO - Querying data for date: 20190303, hours: 21-24
# 2024-07-03 00:39:46,594 - INFO - Processing data for date: 20190303, hours: 21-24
# 2024-07-03 00:39:46,646 - INFO - Exporting aggregated data (geohash3) for date: 20190303, hours: 21-24
# 2024-07-03 00:39:46,695 - INFO - Exporting aggregated data (geohash5) for date: 20190303, hours: 21-24
# 2024-07-03 00:39:46,838 - INFO - Processing data for date: 20190304
# 2024-07-03 00:39:46,838 - INFO - Querying data for date: 20190304, hours: 0-3
# 2024-07-03 00:40:25,412 - INFO - Processing data for date: 20190304, hours: 0-3
# 2024-07-03 00:40:25,435 - INFO - Exporting aggregated data (geohash3) for date: 20190304, hours: 0-3
# 2024-07-03 00:40:25,471 - INFO - Exporting aggregated data (geohash5) for date: 20190304, hours: 0-3
# 2024-07-03 00:40:25,491 - INFO - Querying data for date: 20190304, hours: 3-6
# 2024-07-03 00:40:57,088 - INFO - Processing data for date: 20190304, hours: 3-6
# 2024-07-03 00:40:57,131 - INFO - Exporting aggregated data (geohash3) for date: 20190304, hours: 3-6
# 2024-07-03 00:40:57,218 - INFO - Exporting aggregated data (geohash5) for date: 20190304, hours: 3-6
# 2024-07-03 00:40:57,235 - INFO - Querying data for date: 20190304, hours: 6-9
# 2024-07-03 00:41:20,305 - INFO - Processing data for date: 20190304, hours: 6-9
# 2024-07-03 00:41:20,375 - INFO - Exporting aggregated data (geohash3) for date: 20190304, hours: 6-9
# 2024-07-03 00:41:20,453 - INFO - Exporting aggregated data (geohash5) for date: 20190304, hours: 6-9
# 2024-07-03 00:41:20,485 - INFO - Querying data for date: 20190304, hours: 9-12
# 2024-07-03 00:41:51,513 - INFO - Processing data for date: 20190304, hours: 9-12
# 2024-07-03 00:41:51,629 - INFO - Exporting aggregated data (geohash3) for date: 20190304, hours: 9-12
# 2024-07-03 00:41:51,746 - INFO - Exporting aggregated data (geohash5) for date: 20190304, hours: 9-12
# 2024-07-03 00:41:51,788 - INFO - Querying data for date: 20190304, hours: 12-15
# 2024-07-03 00:42:11,390 - INFO - Processing data for date: 20190304, hours: 12-15
# 2024-07-03 00:42:11,566 - INFO - Exporting aggregated data (geohash3) for date: 20190304, hours: 12-15
# 2024-07-03 00:42:11,701 - INFO - Exporting aggregated data (geohash5) for date: 20190304, hours: 12-15
# 2024-07-03 00:42:11,750 - INFO - Querying data for date: 20190304, hours: 15-18
# 2024-07-03 00:42:32,210 - INFO - Processing data for date: 20190304, hours: 15-18
# 2024-07-03 00:42:32,357 - INFO - Exporting aggregated data (geohash3) for date: 20190304, hours: 15-18
# 2024-07-03 00:42:32,602 - INFO - Exporting aggregated data (geohash5) for date: 20190304, hours: 15-18
# 2024-07-03 00:42:32,654 - INFO - Querying data for date: 20190304, hours: 18-21
# 2024-07-03 00:42:51,681 - INFO - Processing data for date: 20190304, hours: 18-21
# 2024-07-03 00:42:51,780 - INFO - Exporting aggregated data (geohash3) for date: 20190304, hours: 18-21
# 2024-07-03 00:42:51,866 - INFO - Exporting aggregated data (geohash5) for date: 20190304, hours: 18-21
# 2024-07-03 00:42:51,908 - INFO - Querying data for date: 20190304, hours: 21-24
# 2024-07-03 00:43:23,876 - INFO - Processing data for date: 20190304, hours: 21-24
# 2024-07-03 00:43:23,930 - INFO - Exporting aggregated data (geohash3) for date: 20190304, hours: 21-24
# 2024-07-03 00:43:23,977 - INFO - Exporting aggregated data (geohash5) for date: 20190304, hours: 21-24
# 2024-07-03 00:43:24,125 - INFO - Processing data for date: 20190305
# 2024-07-03 00:43:24,125 - INFO - Querying data for date: 20190305, hours: 0-3
# 2024-07-03 00:43:46,877 - INFO - Processing data for date: 20190305, hours: 0-3
# 2024-07-03 00:43:46,901 - INFO - Exporting aggregated data (geohash3) for date: 20190305, hours: 0-3
# 2024-07-03 00:43:46,937 - INFO - Exporting aggregated data (geohash5) for date: 20190305, hours: 0-3
# 2024-07-03 00:43:46,952 - INFO - Querying data for date: 20190305, hours: 3-6
# 2024-07-03 00:44:06,942 - INFO - Processing data for date: 20190305, hours: 3-6
# 2024-07-03 00:44:06,988 - INFO - Exporting aggregated data (geohash3) for date: 20190305, hours: 3-6
# 2024-07-03 00:44:07,028 - INFO - Exporting aggregated data (geohash5) for date: 20190305, hours: 3-6
# 2024-07-03 00:44:07,043 - INFO - Querying data for date: 20190305, hours: 6-9
# 2024-07-03 00:44:45,107 - INFO - Processing data for date: 20190305, hours: 6-9
# 2024-07-03 00:44:45,182 - INFO - Exporting aggregated data (geohash3) for date: 20190305, hours: 6-9
# 2024-07-03 00:44:45,268 - INFO - Exporting aggregated data (geohash5) for date: 20190305, hours: 6-9
# 2024-07-03 00:44:45,304 - INFO - Querying data for date: 20190305, hours: 9-12
# 2024-07-03 00:45:32,207 - INFO - Processing data for date: 20190305, hours: 9-12
# 2024-07-03 00:45:32,324 - INFO - Exporting aggregated data (geohash3) for date: 20190305, hours: 9-12
# 2024-07-03 00:45:32,439 - INFO - Exporting aggregated data (geohash5) for date: 20190305, hours: 9-12
# 2024-07-03 00:45:32,482 - INFO - Querying data for date: 20190305, hours: 12-15
# 2024-07-03 00:46:08,586 - INFO - Processing data for date: 20190305, hours: 12-15
# 2024-07-03 00:46:08,719 - INFO - Exporting aggregated data (geohash3) for date: 20190305, hours: 12-15
# 2024-07-03 00:46:08,855 - INFO - Exporting aggregated data (geohash5) for date: 20190305, hours: 12-15
# 2024-07-03 00:46:08,911 - INFO - Querying data for date: 20190305, hours: 15-18
# 2024-07-03 00:46:41,570 - INFO - Processing data for date: 20190305, hours: 15-18
# 2024-07-03 00:46:41,695 - INFO - Exporting aggregated data (geohash3) for date: 20190305, hours: 15-18
# 2024-07-03 00:46:41,805 - INFO - Exporting aggregated data (geohash5) for date: 20190305, hours: 15-18
# 2024-07-03 00:46:41,857 - INFO - Querying data for date: 20190305, hours: 18-21
# 2024-07-03 00:47:18,883 - INFO - Processing data for date: 20190305, hours: 18-21
# 2024-07-03 00:47:18,984 - INFO - Exporting aggregated data (geohash3) for date: 20190305, hours: 18-21
# 2024-07-03 00:47:19,090 - INFO - Exporting aggregated data (geohash5) for date: 20190305, hours: 18-21
# 2024-07-03 00:47:19,134 - INFO - Querying data for date: 20190305, hours: 21-24
# 2024-07-03 00:47:59,437 - INFO - Processing data for date: 20190305, hours: 21-24
# 2024-07-03 00:47:59,493 - INFO - Exporting aggregated data (geohash3) for date: 20190305, hours: 21-24
# 2024-07-03 00:47:59,539 - INFO - Exporting aggregated data (geohash5) for date: 20190305, hours: 21-24
# 2024-07-03 00:47:59,697 - INFO - Processing data for date: 20190306
# 2024-07-03 00:47:59,698 - INFO - Querying data for date: 20190306, hours: 0-3
# 2024-07-03 00:48:48,448 - INFO - Processing data for date: 20190306, hours: 0-3
# 2024-07-03 00:48:48,471 - INFO - Exporting aggregated data (geohash3) for date: 20190306, hours: 0-3
# 2024-07-03 00:48:48,505 - INFO - Exporting aggregated data (geohash5) for date: 20190306, hours: 0-3
# 2024-07-03 00:48:48,527 - INFO - Querying data for date: 20190306, hours: 3-6
# 2024-07-03 00:49:26,003 - INFO - Processing data for date: 20190306, hours: 3-6
# 2024-07-03 00:49:26,041 - INFO - Exporting aggregated data (geohash3) for date: 20190306, hours: 3-6
# 2024-07-03 00:49:26,081 - INFO - Exporting aggregated data (geohash5) for date: 20190306, hours: 3-6
# 2024-07-03 00:49:26,099 - INFO - Querying data for date: 20190306, hours: 6-9
# 2024-07-03 00:50:05,353 - INFO - Processing data for date: 20190306, hours: 6-9
# 2024-07-03 00:50:05,433 - INFO - Exporting aggregated data (geohash3) for date: 20190306, hours: 6-9
# 2024-07-03 00:50:05,521 - INFO - Exporting aggregated data (geohash5) for date: 20190306, hours: 6-9
# 2024-07-03 00:50:05,568 - INFO - Querying data for date: 20190306, hours: 9-12
# 2024-07-03 00:50:42,583 - INFO - Processing data for date: 20190306, hours: 9-12
# 2024-07-03 00:50:42,703 - INFO - Exporting aggregated data (geohash3) for date: 20190306, hours: 9-12
# 2024-07-03 00:50:42,809 - INFO - Exporting aggregated data (geohash5) for date: 20190306, hours: 9-12
# 2024-07-03 00:50:42,856 - INFO - Querying data for date: 20190306, hours: 12-15
# 2024-07-03 00:51:23,166 - INFO - Processing data for date: 20190306, hours: 12-15
# 2024-07-03 00:51:23,305 - INFO - Exporting aggregated data (geohash3) for date: 20190306, hours: 12-15
# 2024-07-03 00:51:23,436 - INFO - Exporting aggregated data (geohash5) for date: 20190306, hours: 12-15
# 2024-07-03 00:51:23,498 - INFO - Querying data for date: 20190306, hours: 15-18
# 2024-07-03 00:52:00,005 - INFO - Processing data for date: 20190306, hours: 15-18
# 2024-07-03 00:52:00,147 - INFO - Exporting aggregated data (geohash3) for date: 20190306, hours: 15-18
# 2024-07-03 00:52:00,292 - INFO - Exporting aggregated data (geohash5) for date: 20190306, hours: 15-18
# 2024-07-03 00:52:00,341 - INFO - Querying data for date: 20190306, hours: 18-21
# 2024-07-03 00:52:33,582 - INFO - Processing data for date: 20190306, hours: 18-21
# 2024-07-03 00:52:33,699 - INFO - Exporting aggregated data (geohash3) for date: 20190306, hours: 18-21
# 2024-07-03 00:52:33,804 - INFO - Exporting aggregated data (geohash5) for date: 20190306, hours: 18-21
# 2024-07-03 00:52:33,850 - INFO - Querying data for date: 20190306, hours: 21-24
# 2024-07-03 00:53:08,554 - INFO - Processing data for date: 20190306, hours: 21-24
# 2024-07-03 00:53:08,612 - INFO - Exporting aggregated data (geohash3) for date: 20190306, hours: 21-24
# 2024-07-03 00:53:08,659 - INFO - Exporting aggregated data (geohash5) for date: 20190306, hours: 21-24
# 2024-07-03 00:53:08,818 - INFO - Processing data for date: 20190307
# 2024-07-03 00:53:08,818 - INFO - Querying data for date: 20190307, hours: 0-3
# 2024-07-03 00:54:12,254 - INFO - Processing data for date: 20190307, hours: 0-3
# 2024-07-03 00:54:12,277 - INFO - Exporting aggregated data (geohash3) for date: 20190307, hours: 0-3
# 2024-07-03 00:54:12,313 - INFO - Exporting aggregated data (geohash5) for date: 20190307, hours: 0-3
# 2024-07-03 00:54:12,329 - INFO - Querying data for date: 20190307, hours: 3-6
# 2024-07-03 00:54:53,093 - INFO - Processing data for date: 20190307, hours: 3-6
# 2024-07-03 00:54:53,128 - INFO - Exporting aggregated data (geohash3) for date: 20190307, hours: 3-6
# 2024-07-03 00:54:53,168 - INFO - Exporting aggregated data (geohash5) for date: 20190307, hours: 3-6
# 2024-07-03 00:54:53,184 - INFO - Querying data for date: 20190307, hours: 6-9
# 2024-07-03 00:55:33,554 - INFO - Processing data for date: 20190307, hours: 6-9
# 2024-07-03 00:55:33,635 - INFO - Exporting aggregated data (geohash3) for date: 20190307, hours: 6-9
# 2024-07-03 00:55:33,725 - INFO - Exporting aggregated data (geohash5) for date: 20190307, hours: 6-9
# 2024-07-03 00:55:33,765 - INFO - Querying data for date: 20190307, hours: 9-12
# 2024-07-03 00:56:14,235 - INFO - Processing data for date: 20190307, hours: 9-12
# 2024-07-03 00:56:14,349 - INFO - Exporting aggregated data (geohash3) for date: 20190307, hours: 9-12
# 2024-07-03 00:56:14,453 - INFO - Exporting aggregated data (geohash5) for date: 20190307, hours: 9-12
# 2024-07-03 00:56:14,493 - INFO - Querying data for date: 20190307, hours: 12-15
# 2024-07-03 00:56:49,672 - INFO - Processing data for date: 20190307, hours: 12-15
# 2024-07-03 00:56:49,807 - INFO - Exporting aggregated data (geohash3) for date: 20190307, hours: 12-15
# 2024-07-03 00:56:49,931 - INFO - Exporting aggregated data (geohash5) for date: 20190307, hours: 12-15
# 2024-07-03 00:56:49,979 - INFO - Querying data for date: 20190307, hours: 15-18
# 2024-07-03 00:57:23,144 - INFO - Processing data for date: 20190307, hours: 15-18
# 2024-07-03 00:57:23,276 - INFO - Exporting aggregated data (geohash3) for date: 20190307, hours: 15-18
# 2024-07-03 00:57:23,393 - INFO - Exporting aggregated data (geohash5) for date: 20190307, hours: 15-18
# 2024-07-03 00:57:23,448 - INFO - Querying data for date: 20190307, hours: 18-21
# 2024-07-03 00:57:57,237 - INFO - Processing data for date: 20190307, hours: 18-21
# 2024-07-03 00:57:57,353 - INFO - Exporting aggregated data (geohash3) for date: 20190307, hours: 18-21
# 2024-07-03 00:57:57,463 - INFO - Exporting aggregated data (geohash5) for date: 20190307, hours: 18-21
# 2024-07-03 00:57:57,506 - INFO - Querying data for date: 20190307, hours: 21-24
# 2024-07-03 00:58:37,517 - INFO - Processing data for date: 20190307, hours: 21-24
# 2024-07-03 00:58:37,578 - INFO - Exporting aggregated data (geohash3) for date: 20190307, hours: 21-24
# 2024-07-03 00:58:37,627 - INFO - Exporting aggregated data (geohash5) for date: 20190307, hours: 21-24
# 2024-07-03 00:58:37,789 - INFO - Processing data for date: 20190308
# 2024-07-03 00:58:37,790 - INFO - Querying data for date: 20190308, hours: 0-3
# 2024-07-03 00:59:25,042 - INFO - Processing data for date: 20190308, hours: 0-3
# 2024-07-03 00:59:25,068 - INFO - Exporting aggregated data (geohash3) for date: 20190308, hours: 0-3
# 2024-07-03 00:59:25,107 - INFO - Exporting aggregated data (geohash5) for date: 20190308, hours: 0-3
# 2024-07-03 00:59:25,126 - INFO - Querying data for date: 20190308, hours: 3-6
# 2024-07-03 01:00:01,987 - INFO - Processing data for date: 20190308, hours: 3-6
# 2024-07-03 01:00:02,025 - INFO - Exporting aggregated data (geohash3) for date: 20190308, hours: 3-6
# 2024-07-03 01:00:02,066 - INFO - Exporting aggregated data (geohash5) for date: 20190308, hours: 3-6
# 2024-07-03 01:00:02,083 - INFO - Querying data for date: 20190308, hours: 6-9
# 2024-07-03 01:00:58,399 - INFO - Processing data for date: 20190308, hours: 6-9
# 2024-07-03 01:00:58,477 - INFO - Exporting aggregated data (geohash3) for date: 20190308, hours: 6-9
# 2024-07-03 01:00:58,566 - INFO - Exporting aggregated data (geohash5) for date: 20190308, hours: 6-9
# 2024-07-03 01:00:58,605 - INFO - Querying data for date: 20190308, hours: 9-12
# 2024-07-03 01:01:33,955 - INFO - Processing data for date: 20190308, hours: 9-12
# 2024-07-03 01:01:34,069 - INFO - Exporting aggregated data (geohash3) for date: 20190308, hours: 9-12
# 2024-07-03 01:01:34,176 - INFO - Exporting aggregated data (geohash5) for date: 20190308, hours: 9-12
# 2024-07-03 01:01:34,224 - INFO - Querying data for date: 20190308, hours: 12-15
# 2024-07-03 01:02:13,420 - INFO - Processing data for date: 20190308, hours: 12-15
# 2024-07-03 01:02:13,565 - INFO - Exporting aggregated data (geohash3) for date: 20190308, hours: 12-15
# 2024-07-03 01:02:13,708 - INFO - Exporting aggregated data (geohash5) for date: 20190308, hours: 12-15
# 2024-07-03 01:02:13,758 - INFO - Querying data for date: 20190308, hours: 15-18
# 2024-07-03 01:02:52,503 - INFO - Processing data for date: 20190308, hours: 15-18
# 2024-07-03 01:02:52,630 - INFO - Exporting aggregated data (geohash3) for date: 20190308, hours: 15-18
# 2024-07-03 01:02:52,744 - INFO - Exporting aggregated data (geohash5) for date: 20190308, hours: 15-18
# 2024-07-03 01:02:52,791 - INFO - Querying data for date: 20190308, hours: 18-21
# 2024-07-03 01:03:34,822 - INFO - Processing data for date: 20190308, hours: 18-21
# 2024-07-03 01:03:34,936 - INFO - Exporting aggregated data (geohash3) for date: 20190308, hours: 18-21
# 2024-07-03 01:03:35,040 - INFO - Exporting aggregated data (geohash5) for date: 20190308, hours: 18-21
# 2024-07-03 01:03:35,085 - INFO - Querying data for date: 20190308, hours: 21-24
# 2024-07-03 01:04:08,155 - INFO - Processing data for date: 20190308, hours: 21-24
# 2024-07-03 01:04:08,226 - INFO - Exporting aggregated data (geohash3) for date: 20190308, hours: 21-24
# 2024-07-03 01:04:08,284 - INFO - Exporting aggregated data (geohash5) for date: 20190308, hours: 21-24
# 2024-07-03 01:04:08,460 - INFO - Processing data for date: 20190309
# 2024-07-03 01:04:08,461 - INFO - Querying data for date: 20190309, hours: 0-3

# %% [markdown]
# # Fillin Gaps

# %%
# Configure logging
logging.basicConfig(level=logging.INFO, format='%(asctime)s - %(levelname)s - %(message)s')

# Function to process data for a specific date and time intervals
def process_data_for_date(event_date, country_code, export_path, start_hour, end_hour):
    # Define the export file paths
    csv3_file = f"od_{country_code.lower()}_agg3_3h.csv"
    csv5_file = f"od_{country_code.lower()}_agg5_3h.csv"
    csv3_file_path = f"{export_path}{csv3_file}"
    csv5_file_path = f"{export_path}{csv5_file}"

    # Loop through the specified hours in increments of 3 hours
    for hour in range(start_hour, end_hour, 3):
        next_hour = hour + 3  # end hour for the 3-hour interval
        logging.info(f"Querying data for date: {event_date}, hours: {hour}-{next_hour}")

        # Fetch the data for the specified event date and country code
        pe_tj_df3 = sql_engine.read_sql(
            f"""
            SELECT 
                cuebiq_id,
                duration_minutes,
                length_meters,
                number_of_points,
                TRY(date_parse(substr(start_zoned_datetime, 1, 19), '%Y-%m-%dT%H:%i:%s')) AS event_datetime_local,
                EXTRACT(HOUR FROM TRY(date_parse(substr(start_zoned_datetime, 1, 19), '%Y-%m-%dT%H:%i:%s'))) AS event_hour,
                geohash_encode(start_lat, start_lng, 5) AS start_geohash5,
                geohash_encode(start_lat, start_lng, 3) AS start_geohash3,
                geohash_encode(end_lat, end_lng, 5) AS end_geohash5,
                geohash_encode(end_lat, end_lng, 3) AS end_geohash3,
                DATE_FORMAT(date_parse(substr(start_zoned_datetime, 1, 10), '%Y-%m-%d'), '%Y%m%d') AS local_date
            FROM cuebiq.paas_cda_pe_v3.trajectory_uplevelled
            WHERE 
                event_date = {event_date}
                AND end_country = '{country_code}' 
                AND start_country = '{country_code}' 
            """
        )

        # Filter the DataFrame for the current 3-hour interval
        logging.info(f"Processing data for date: {event_date}, hours: {hour}-{next_hour}")
        filtered_df = pe_tj_df3[(pe_tj_df3['event_hour'] >= hour) & (pe_tj_df3['event_hour'] < next_hour)]

        # Add user numbers to the aggregated data for geohash3
        aggregated_df3 = filtered_df.groupby(['start_geohash3', 'end_geohash3', 'local_date']).agg({
            'cuebiq_id': 'count',
            'duration_minutes': ['mean', 'median', 'std'],
            'length_meters': ['mean', 'median', 'std'],
            'number_of_points': ['mean', 'median', 'std']
        }).reset_index()

        # Flatten the MultiIndex columns
        aggregated_df3.columns = ['start_geohash3', 'end_geohash3', 'local_date', 'trip_count', 
                                  'm_duration_min', 'mdn_duration_min', 'sd_duration_min', 
                                  'm_length_m', 'mdn_length_m', 'sd_length_m',
                                  'm_points_no', 'mdn_points_no', 'sd_points_no']

        # Add the local_time column
        aggregated_df3['local_time'] = aggregated_df3['local_date'].astype(str) + \
                                       f" {hour:02d}:00:00 - {next_hour:02d}:00:00"

        # Filter out rows where trip_count is less than or equal to 9
        aggregated_df3 = aggregated_df3[aggregated_df3['trip_count'] > 9]

        # Append the results to the CSV file for geohash3
        logging.info(f"Exporting aggregated data (geohash3) for date: {event_date}, hours: {hour}-{next_hour}")
        if not os.path.isfile(csv3_file_path):
            aggregated_df3.to_csv(csv3_file_path, index=False)
        else:
            aggregated_df3.to_csv(csv3_file_path, mode='a', header=False, index=False)

        # Add user numbers to the aggregated data for geohash5
        aggregated_df5 = filtered_df.groupby(['start_geohash5', 'end_geohash5', 'local_date']).agg({
            'cuebiq_id': 'count',
            'duration_minutes': ['mean', 'median', 'std'],
            'length_meters': ['mean', 'median', 'std'],
            'number_of_points': ['mean', 'median', 'std']
        }).reset_index()

        # Flatten the MultiIndex columns
        aggregated_df5.columns = ['start_geohash5', 'end_geohash5', 'local_date', 'trip_count', 
                                  'm_duration_min', 'mdn_duration_min', 'sd_duration_min', 
                                  'm_length_m', 'mdn_length_m', 'sd_length_m',
                                  'm_points_no', 'mdn_points_no', 'sd_points_no']

        # Add the local_time column
        aggregated_df5['local_time'] = aggregated_df5['local_date'].astype(str) + \
                                       f" {hour:02d}:00:00 - {next_hour:02d}:00:00"

        # Filter out rows where trip_count is less than or equal to 9
        aggregated_df5 = aggregated_df5[aggregated_df5['trip_count'] > 9]

        # Append the results to the CSV file for geohash5
        logging.info(f"Exporting aggregated data (geohash5) for date: {event_date}, hours: {hour}-{next_hour}")
        if not os.path.isfile(csv5_file_path):
            aggregated_df5.to_csv(csv5_file_path, index=False)
        else:
            aggregated_df5.to_csv(csv5_file_path, mode='a', header=False, index=False)

# %%
# Specify the date and initial time interval
event_date = "20190125"
start_hour = 18
end_hour = 24  # Process until the end of the day
country_code = 'MX'
export_path = '/home/jovyan/Data/TJ/3h/'

# Process data for the specified date and time intervals
process_data_for_date(event_date, country_code, export_path, start_hour, end_hour)
# Out:
# 2024-07-02 13:57:47,419 - INFO - Querying data for date: 20190125, hours: 18-21
# 2024-07-02 13:58:40,951 - INFO - Processing data for date: 20190125, hours: 18-21
# 2024-07-02 13:58:41,016 - INFO - Exporting aggregated data (geohash3) for date: 20190125, hours: 18-21
# 2024-07-02 13:58:41,095 - INFO - Exporting aggregated data (geohash5) for date: 20190125, hours: 18-21
# 2024-07-02 13:58:41,139 - INFO - Querying data for date: 20190125, hours: 21-24
# 2024-07-02 13:59:15,069 - INFO - Processing data for date: 20190125, hours: 21-24
# 2024-07-02 13:59:15,124 - INFO - Exporting aggregated data (geohash3) for date: 20190125, hours: 21-24
# 2024-07-02 13:59:15,171 - INFO - Exporting aggregated data (geohash5) for date: 20190125, hours: 21-24
