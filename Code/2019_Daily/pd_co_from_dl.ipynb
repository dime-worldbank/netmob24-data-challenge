# %%
# %reload_ext sql
# %config SqlMagic.autocommit=False
# %config SqlMagic.autolimit=0
# %config SqlMagic.autopandas=True
# %config SqlMagic.displaylimit=200

# %%
# %sql trino://localhost:9090/cuebiq/
# Out:
# 'Connected: @cuebiq/'

# %%
pip install geohash2
# Out:
# Collecting geohash2
#   Using cached geohash2-1.1-py3-none-any.whl
# Collecting docutils>=0.3
#   Using cached docutils-0.21.2-py3-none-any.whl (587 kB)
# Installing collected packages: docutils, geohash2
# Successfully installed docutils-0.21.2 geohash2-1.1
# Note: you may need to restart the kernel to use updated packages.

# %%
import gc
import os
import time
import logging
import geohash2
import pandas as pd
from sqlalchemy import create_engine
from datetime import datetime, timedelta
from trino.dbapi import connect

# %%
# SQL engine
class TrinoEngine():
    def __init__(self):
        conn = connect(
            host="localhost",
            port=9090,
            catalog="cuebiq"
        )
        self.cur = conn.cursor()
        self.engine = create_engine("trino://localhost:9090/cuebiq/")
    
    def execute_statement(self, query:str) -> list:
        """
        Create and drop statements.
        """
        self.cur.execute(query)
        return self.cur.fetchall()
    
    def read_sql(self, query:str) -> pd.DataFrame: 
        """
        Select and insert into operations.
        """
        return pd.read_sql(query, self.engine)

    def read_sql_chunked(self, query: str, chunksize: int = 10000):
        return pd.read_sql(query, self.engine, chunksize=chunksize)

sql_engine = TrinoEngine()

# %%
schema_name = {'cda': 'cuebiq.paas_cda_pe_v3'}
pe_dl_table = f"{schema_name['cda']}.device_location_uplevelled"

# %%
# Function to insert data with retry mechanism
def insert_data_with_retry(df, table_name, con, retries=3, delay=5):
    for attempt in range(retries):
        try:
            df.to_sql(
                table_name, 
                con, 
                index=False, 
                if_exists="append", 
                method="multi"
            )
            logging.info(f"Inserted data into table {table_name}")
            return True
        except Exception as e:
            logging.error(f"Attempt {attempt+1} failed with error: {e}")
            if attempt < retries - 1:
                time.sleep(delay)
            else:
                logging.error(f"Failed to insert data into table {table_name} after {retries} attempts")
    return False

# %%
# test seperate by lon, and record error:

# %%
# Set up logging
logging.basicConfig(level=logging.INFO, format='%(asctime)s - %(levelname)s - %(message)s')

# Database connection setup
output_schema_name = 'pop_density'
con = create_engine(f"trino://localhost:9090/dedicated/{output_schema_name}")

start_time = time.time()  # Start timing

# Define the input parameters
country_code = 'CO'
start_date = 20191020
end_date = 20191031
longitude_ranges = [(-82, -74.53125), (-74.53125, -65)]  # CO specific longitude ranges

# Define the input schema and table name
schema_name = {'cda': 'cuebiq.paas_cda_pe_v3'}
pe_dl_table = f"{schema_name['cda']}.device_location_uplevelled"

# Convert integer dates to datetime objects
start_date_dt = datetime.strptime(str(start_date), '%Y%m%d')
end_date_dt = datetime.strptime(str(end_date), '%Y%m%d')

failed_inserts = []

# %%
# Loop through each day from start_date to end_date
current_date = start_date_dt
while current_date <= end_date_dt:
    try:
        # Calculate the lookback and lookahead dates
        lookback_date = current_date - timedelta(days=1)
        lookahead_date = current_date + timedelta(days=35)
        
        # Format dates for the SQL query
        formatted_lookback_date = lookback_date.strftime('%Y%m%d')
        formatted_current_date = current_date.strftime('%Y%m%d')
        formatted_lookahead_date = lookahead_date.strftime('%Y%m%d')
        
        # Loop through each longitude range
        for min_lon, max_lon in longitude_ranges:
            
            # Construct the SQL query
            query = f"""
            SELECT 
                cuebiq_id, 
                event_zoned_datetime, 
                processing_date,
                lat,
                lng
            FROM {pe_dl_table}
            WHERE 
                processing_date BETWEEN {formatted_lookback_date} AND {formatted_lookahead_date}
                AND country_code = '{country_code}' 
                AND event_zoned_datetime IS NOT NULL
                AND TRY(date_parse(substr(event_zoned_datetime, 1, 19), '%Y-%m-%dT%H:%i:%s')) IS NOT NULL
                AND DATE(TRY(date_parse(substr(event_zoned_datetime, 1, 19), '%Y-%m-%dT%H:%i:%s'))) = date_parse('{formatted_current_date}', '%Y%m%d')
                AND lng BETWEEN {min_lon} AND {max_lon}
            """
            
            logging.info(f"Executing SQL query for date {formatted_current_date} and longitude range {min_lon} to {max_lon}")
            
            try:
                pe_dl_table_gen = sql_engine.read_sql_chunked(query)
                
                # Convert the generator to a DataFrame
                chunks = [chunk for chunk in pe_dl_table_gen]
                if chunks:
                    pe_dl_table_df = pd.concat(chunks, ignore_index=True)
                    
                    # Calculate geohashes
                    pe_dl_table_df['geohash5'] = pe_dl_table_df.apply(lambda row: geohash2.encode(row['lat'], row['lng'], precision=5), axis=1)
                    pe_dl_table_df['geohash3'] = pe_dl_table_df.apply(lambda row: geohash2.encode(row['lat'], row['lng'], precision=3), axis=1)
                    
                    # Aggregate data for geohash5
                    aggregated_data_5 = pe_dl_table_df.groupby('geohash5').agg(
                        no_of_points=('geohash5', 'size'),
                        no_of_unique_users=('cuebiq_id', 'nunique')
                    ).reset_index()

                    # Filter rows with no_of_unique_users > 10
                    filtered_data_5 = aggregated_data_5[aggregated_data_5['no_of_unique_users'] > 10].copy()
                    
                    # Add the local_date column
                    filtered_data_5.loc[:, 'local_date'] = formatted_current_date
                    
                    # Insert filtered aggregated data for geohash5 into SQL table
                    if not filtered_data_5.empty:
                        table_name_agg5 = f"pd_{country_code.lower()}_{formatted_current_date}_agg5"
                        if not insert_data_with_retry(filtered_data_5, table_name_agg5, con):
                            failed_inserts.append((formatted_current_date, min_lon, max_lon, 'agg5'))
                    
                    # Aggregate data for geohash3
                    aggregated_data_3 = pe_dl_table_df.groupby('geohash3').agg(
                        no_of_points=('geohash3', 'size'),
                        no_of_unique_users=('cuebiq_id', 'nunique')
                    ).reset_index()
                    
                    # Filter rows with no_of_unique_users > 10
                    filtered_data_3 = aggregated_data_3[aggregated_data_3['no_of_unique_users'] > 10].copy()
                    
                    # Add the local_date column
                    filtered_data_3.loc[:, 'local_date'] = formatted_current_date
                    
                    # Insert filtered aggregated data for geohash3 into SQL table
                    if not filtered_data_3.empty:
                        table_name_agg3 = f"pd_{country_code.lower()}_{formatted_current_date}_agg3"
                        if not insert_data_with_retry(filtered_data_3, table_name_agg3, con):
                            failed_inserts.append((formatted_current_date, min_lon, max_lon, 'agg3'))
            
            except Exception as e:
                logging.error(f"Error while processing data for date {formatted_current_date} and longitude range {min_lon} to {max_lon}: {e}")
                failed_inserts.append((formatted_current_date, min_lon, max_lon, 'both'))
    
    except Exception as e:
        logging.error(f"Error while processing data for date {formatted_current_date}: {e}")
        failed_inserts.append((formatted_current_date, None, None, 'both'))
    
    # Move to the next day
    current_date += timedelta(days=1)

# Print the failed inserts
if failed_inserts:
    print("Failed inserts:")
    for failed_insert in failed_inserts:
        print(failed_insert)

logging.info("Data extraction, aggregation, and saving completed.")

end_time = time.time()  # End timing

# Calculate and print the total time taken
total_time = end_time - start_time
logging.info(f"Total time taken: {total_time} seconds")
# Out:
# 2024-06-12 23:02:26,324 - INFO - Executing SQL query for date 20191020 and longitude range -82 to -74.53125
# 2024-06-12 23:03:18,645 - INFO - failed after 3 attempts
# 2024-06-12 23:03:19,326 - INFO - failed after 3 attempts
# 2024-06-12 23:03:19,326 - ERROR - Attempt 1 failed with error: error 502: bad gateway
# 2024-06-12 23:03:24,808 - INFO - failed after 3 attempts
# 2024-06-12 23:03:24,809 - ERROR - Error closing cursor
# Traceback (most recent call last):
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/sqlalchemy/engine/base.py", line 1900, in _execute_context
#     self.dialect.do_execute(
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/sqlalchemy/dialect.py", line 365, in do_execute
#     cursor.execute(statement, parameters)
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/dbapi.py", line 482, in execute
#     self._prepare_statement(operation, statement_name)
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/dbapi.py", line 379, in _prepare_statement
#     query.execute()
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/client.py", line 807, in execute
#     status = self._request.process(response)
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/client.py", line 617, in process
#     self.raise_response_error(http_response)
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/client.py", line 600, in raise_response_error
#     raise exceptions.Http502Error("error 502: bad gateway")
# trino.exceptions.Http502Error: error 502: bad gateway
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/sqlalchemy/engine/base.py", line 1995, in _safe_close_cursor
#     cursor.close()
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/dbapi.py", line 618, in close
#     self.cancel()
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/dbapi.py", line 612, in cancel
#     raise trino.exceptions.OperationalError(
# trino.exceptions.OperationalError: Cancel query failed; no running query
# 2024-06-12 23:03:24,811 - ERROR - Attempt 2 failed with error: error 502: bad gateway
# 2024-06-12 23:03:30,243 - INFO - failed after 3 attempts
# 2024-06-12 23:03:30,244 - ERROR - Error closing cursor
# Traceback (most recent call last):
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/sqlalchemy/engine/base.py", line 1900, in _execute_context
#     self.dialect.do_execute(
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/sqlalchemy/dialect.py", line 365, in do_execute
#     cursor.execute(statement, parameters)
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/dbapi.py", line 482, in execute
#     self._prepare_statement(operation, statement_name)
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/dbapi.py", line 379, in _prepare_statement
#     query.execute()
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/client.py", line 807, in execute
#     status = self._request.process(response)
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/client.py", line 617, in process
#     self.raise_response_error(http_response)
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/client.py", line 600, in raise_response_error
#     raise exceptions.Http502Error("error 502: bad gateway")
# trino.exceptions.Http502Error: error 502: bad gateway
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/sqlalchemy/engine/base.py", line 1995, in _safe_close_cursor
#     cursor.close()
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/dbapi.py", line 618, in close
#     self.cancel()
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/dbapi.py", line 612, in cancel
#     raise trino.exceptions.OperationalError(
# trino.exceptions.OperationalError: Cancel query failed; no running query
# 2024-06-12 23:03:30,245 - ERROR - Attempt 3 failed with error: error 502: bad gateway
# 2024-06-12 23:03:30,245 - ERROR - Failed to insert data into table pd_co_20191020_agg5 after 3 attempts
# 2024-06-12 23:03:30,718 - INFO - failed after 3 attempts
# 2024-06-12 23:03:30,718 - ERROR - Error closing cursor
# Traceback (most recent call last):
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/sqlalchemy/engine/base.py", line 1900, in _execute_context
#     self.dialect.do_execute(
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/sqlalchemy/dialect.py", line 365, in do_execute
#     cursor.execute(statement, parameters)
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/dbapi.py", line 482, in execute
#     self._prepare_statement(operation, statement_name)
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/dbapi.py", line 379, in _prepare_statement
#     query.execute()
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/client.py", line 807, in execute
#     status = self._request.process(response)
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/client.py", line 617, in process
#     self.raise_response_error(http_response)
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/client.py", line 600, in raise_response_error
#     raise exceptions.Http502Error("error 502: bad gateway")
# trino.exceptions.Http502Error: error 502: bad gateway
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/sqlalchemy/engine/base.py", line 1995, in _safe_close_cursor
#     cursor.close()
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/dbapi.py", line 618, in close
#     self.cancel()
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/dbapi.py", line 612, in cancel
#     raise trino.exceptions.OperationalError(
# trino.exceptions.OperationalError: Cancel query failed; no running query
# 2024-06-12 23:03:30,719 - ERROR - Attempt 1 failed with error: error 502: bad gateway
# 2024-06-12 23:03:36,715 - INFO - failed after 3 attempts
# 2024-06-12 23:03:36,716 - ERROR - Error closing cursor
# Traceback (most recent call last):
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/sqlalchemy/engine/base.py", line 1900, in _execute_context
#     self.dialect.do_execute(
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/sqlalchemy/dialect.py", line 365, in do_execute
#     cursor.execute(statement, parameters)
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/dbapi.py", line 482, in execute
#     self._prepare_statement(operation, statement_name)
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/dbapi.py", line 379, in _prepare_statement
#     query.execute()
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/client.py", line 807, in execute
#     status = self._request.process(response)
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/client.py", line 617, in process
#     self.raise_response_error(http_response)
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/client.py", line 600, in raise_response_error
#     raise exceptions.Http502Error("error 502: bad gateway")
# trino.exceptions.Http502Error: error 502: bad gateway
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/sqlalchemy/engine/base.py", line 1995, in _safe_close_cursor
#     cursor.close()
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/dbapi.py", line 618, in close
#     self.cancel()
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/dbapi.py", line 612, in cancel
#     raise trino.exceptions.OperationalError(
# trino.exceptions.OperationalError: Cancel query failed; no running query
# 2024-06-12 23:03:36,717 - ERROR - Attempt 2 failed with error: error 502: bad gateway
# 2024-06-12 23:03:42,440 - INFO - failed after 3 attempts
# 2024-06-12 23:03:42,441 - ERROR - Error closing cursor
# Traceback (most recent call last):
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/sqlalchemy/engine/base.py", line 1900, in _execute_context
#     self.dialect.do_execute(
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/sqlalchemy/dialect.py", line 365, in do_execute
#     cursor.execute(statement, parameters)
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/dbapi.py", line 482, in execute
#     self._prepare_statement(operation, statement_name)
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/dbapi.py", line 379, in _prepare_statement
#     query.execute()
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/client.py", line 807, in execute
#     status = self._request.process(response)
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/client.py", line 617, in process
#     self.raise_response_error(http_response)
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/client.py", line 600, in raise_response_error
#     raise exceptions.Http502Error("error 502: bad gateway")
# trino.exceptions.Http502Error: error 502: bad gateway
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/sqlalchemy/engine/base.py", line 1995, in _safe_close_cursor
#     cursor.close()
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/dbapi.py", line 618, in close
#     self.cancel()
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/dbapi.py", line 612, in cancel
#     raise trino.exceptions.OperationalError(
# trino.exceptions.OperationalError: Cancel query failed; no running query
# 2024-06-12 23:03:42,442 - ERROR - Attempt 3 failed with error: error 502: bad gateway
# 2024-06-12 23:03:42,442 - ERROR - Failed to insert data into table pd_co_20191020_agg3 after 3 attempts
# 2024-06-12 23:03:42,442 - INFO - Executing SQL query for date 20191020 and longitude range -74.53125 to -65
# 2024-06-12 23:04:26,821 - INFO - failed after 3 attempts
# 2024-06-12 23:04:26,822 - ERROR - Error closing cursor
# Traceback (most recent call last):
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/sqlalchemy/engine/base.py", line 1900, in _execute_context
#     self.dialect.do_execute(
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/sqlalchemy/dialect.py", line 365, in do_execute
#     cursor.execute(statement, parameters)
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/dbapi.py", line 482, in execute
#     self._prepare_statement(operation, statement_name)
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/dbapi.py", line 379, in _prepare_statement
#     query.execute()
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/client.py", line 807, in execute
#     status = self._request.process(response)
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/client.py", line 617, in process
#     self.raise_response_error(http_response)
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/client.py", line 600, in raise_response_error
#     raise exceptions.Http502Error("error 502: bad gateway")
# trino.exceptions.Http502Error: error 502: bad gateway
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/sqlalchemy/engine/base.py", line 1995, in _safe_close_cursor
#     cursor.close()
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/dbapi.py", line 618, in close
#     self.cancel()
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/dbapi.py", line 612, in cancel
#     raise trino.exceptions.OperationalError(
# trino.exceptions.OperationalError: Cancel query failed; no running query
# 2024-06-12 23:04:26,823 - ERROR - Attempt 1 failed with error: error 502: bad gateway
# 2024-06-12 23:04:32,368 - INFO - failed after 3 attempts
# 2024-06-12 23:04:32,369 - ERROR - Error closing cursor
# Traceback (most recent call last):
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/sqlalchemy/engine/base.py", line 1900, in _execute_context
#     self.dialect.do_execute(
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/sqlalchemy/dialect.py", line 365, in do_execute
#     cursor.execute(statement, parameters)
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/dbapi.py", line 482, in execute
#     self._prepare_statement(operation, statement_name)
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/dbapi.py", line 379, in _prepare_statement
#     query.execute()
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/client.py", line 807, in execute
#     status = self._request.process(response)
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/client.py", line 617, in process
#     self.raise_response_error(http_response)
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/client.py", line 600, in raise_response_error
#     raise exceptions.Http502Error("error 502: bad gateway")
# trino.exceptions.Http502Error: error 502: bad gateway
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/sqlalchemy/engine/base.py", line 1995, in _safe_close_cursor
#     cursor.close()
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/dbapi.py", line 618, in close
#     self.cancel()
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/dbapi.py", line 612, in cancel
#     raise trino.exceptions.OperationalError(
# trino.exceptions.OperationalError: Cancel query failed; no running query
# 2024-06-12 23:04:32,370 - ERROR - Attempt 2 failed with error: error 502: bad gateway
# 2024-06-12 23:04:38,528 - INFO - failed after 3 attempts
# 2024-06-12 23:04:38,529 - ERROR - Error closing cursor
# Traceback (most recent call last):
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/sqlalchemy/engine/base.py", line 1900, in _execute_context
#     self.dialect.do_execute(
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/sqlalchemy/dialect.py", line 365, in do_execute
#     cursor.execute(statement, parameters)
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/dbapi.py", line 482, in execute
#     self._prepare_statement(operation, statement_name)
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/dbapi.py", line 379, in _prepare_statement
#     query.execute()
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/client.py", line 807, in execute
#     status = self._request.process(response)
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/client.py", line 617, in process
#     self.raise_response_error(http_response)
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/client.py", line 600, in raise_response_error
#     raise exceptions.Http502Error("error 502: bad gateway")
# trino.exceptions.Http502Error: error 502: bad gateway
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/sqlalchemy/engine/base.py", line 1995, in _safe_close_cursor
#     cursor.close()
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/dbapi.py", line 618, in close
#     self.cancel()
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/dbapi.py", line 612, in cancel
#     raise trino.exceptions.OperationalError(
# trino.exceptions.OperationalError: Cancel query failed; no running query
# 2024-06-12 23:04:38,530 - ERROR - Attempt 3 failed with error: error 502: bad gateway
# 2024-06-12 23:04:38,531 - ERROR - Failed to insert data into table pd_co_20191020_agg5 after 3 attempts
# 2024-06-12 23:04:39,564 - INFO - failed after 3 attempts
# 2024-06-12 23:04:39,565 - ERROR - Error closing cursor
# Traceback (most recent call last):
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/sqlalchemy/engine/base.py", line 1900, in _execute_context
#     self.dialect.do_execute(
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/sqlalchemy/dialect.py", line 365, in do_execute
#     cursor.execute(statement, parameters)
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/dbapi.py", line 482, in execute
#     self._prepare_statement(operation, statement_name)
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/dbapi.py", line 379, in _prepare_statement
#     query.execute()
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/client.py", line 807, in execute
#     status = self._request.process(response)
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/client.py", line 617, in process
#     self.raise_response_error(http_response)
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/client.py", line 600, in raise_response_error
#     raise exceptions.Http502Error("error 502: bad gateway")
# trino.exceptions.Http502Error: error 502: bad gateway
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/sqlalchemy/engine/base.py", line 1995, in _safe_close_cursor
#     cursor.close()
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/dbapi.py", line 618, in close
#     self.cancel()
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/dbapi.py", line 612, in cancel
#     raise trino.exceptions.OperationalError(
# trino.exceptions.OperationalError: Cancel query failed; no running query
# 2024-06-12 23:04:39,566 - ERROR - Attempt 1 failed with error: error 502: bad gateway
# 2024-06-12 23:04:45,535 - INFO - failed after 3 attempts
# 2024-06-12 23:04:45,536 - ERROR - Error closing cursor
# Traceback (most recent call last):
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/sqlalchemy/engine/base.py", line 1900, in _execute_context
#     self.dialect.do_execute(
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/sqlalchemy/dialect.py", line 365, in do_execute
#     cursor.execute(statement, parameters)
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/dbapi.py", line 482, in execute
#     self._prepare_statement(operation, statement_name)
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/dbapi.py", line 379, in _prepare_statement
#     query.execute()
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/client.py", line 807, in execute
#     status = self._request.process(response)
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/client.py", line 617, in process
#     self.raise_response_error(http_response)
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/client.py", line 600, in raise_response_error
#     raise exceptions.Http502Error("error 502: bad gateway")
# trino.exceptions.Http502Error: error 502: bad gateway
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/sqlalchemy/engine/base.py", line 1995, in _safe_close_cursor
#     cursor.close()
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/dbapi.py", line 618, in close
#     self.cancel()
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/dbapi.py", line 612, in cancel
#     raise trino.exceptions.OperationalError(
# trino.exceptions.OperationalError: Cancel query failed; no running query
# 2024-06-12 23:04:45,537 - ERROR - Attempt 2 failed with error: error 502: bad gateway
# 2024-06-12 23:04:51,051 - INFO - failed after 3 attempts
# 2024-06-12 23:04:51,052 - ERROR - Error closing cursor
# Traceback (most recent call last):
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/sqlalchemy/engine/base.py", line 1900, in _execute_context
#     self.dialect.do_execute(
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/sqlalchemy/dialect.py", line 365, in do_execute
#     cursor.execute(statement, parameters)
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/dbapi.py", line 482, in execute
#     self._prepare_statement(operation, statement_name)
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/dbapi.py", line 379, in _prepare_statement
#     query.execute()
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/client.py", line 807, in execute
#     status = self._request.process(response)
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/client.py", line 617, in process
#     self.raise_response_error(http_response)
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/client.py", line 600, in raise_response_error
#     raise exceptions.Http502Error("error 502: bad gateway")
# trino.exceptions.Http502Error: error 502: bad gateway
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/sqlalchemy/engine/base.py", line 1995, in _safe_close_cursor
#     cursor.close()
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/dbapi.py", line 618, in close
#     self.cancel()
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/dbapi.py", line 612, in cancel
#     raise trino.exceptions.OperationalError(
# trino.exceptions.OperationalError: Cancel query failed; no running query
# 2024-06-12 23:04:51,053 - ERROR - Attempt 3 failed with error: error 502: bad gateway
# 2024-06-12 23:04:51,054 - ERROR - Failed to insert data into table pd_co_20191020_agg3 after 3 attempts
# 2024-06-12 23:04:51,054 - INFO - Executing SQL query for date 20191021 and longitude range -82 to -74.53125
# 2024-06-12 23:05:26,858 - INFO - failed after 3 attempts
# 2024-06-12 23:05:26,859 - ERROR - Error closing cursor
# Traceback (most recent call last):
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/sqlalchemy/engine/base.py", line 1900, in _execute_context
#     self.dialect.do_execute(
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/sqlalchemy/dialect.py", line 365, in do_execute
#     cursor.execute(statement, parameters)
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/dbapi.py", line 482, in execute
#     self._prepare_statement(operation, statement_name)
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/dbapi.py", line 379, in _prepare_statement
#     query.execute()
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/client.py", line 807, in execute
#     status = self._request.process(response)
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/client.py", line 617, in process
#     self.raise_response_error(http_response)
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/client.py", line 600, in raise_response_error
#     raise exceptions.Http502Error("error 502: bad gateway")
# trino.exceptions.Http502Error: error 502: bad gateway
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/sqlalchemy/engine/base.py", line 1995, in _safe_close_cursor
#     cursor.close()
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/dbapi.py", line 618, in close
#     self.cancel()
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/dbapi.py", line 612, in cancel
#     raise trino.exceptions.OperationalError(
# trino.exceptions.OperationalError: Cancel query failed; no running query
# 2024-06-12 23:05:26,860 - ERROR - Attempt 1 failed with error: error 502: bad gateway
# 2024-06-12 23:05:32,758 - INFO - failed after 3 attempts
# 2024-06-12 23:05:32,759 - ERROR - Error closing cursor
# Traceback (most recent call last):
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/sqlalchemy/engine/base.py", line 1900, in _execute_context
#     self.dialect.do_execute(
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/sqlalchemy/dialect.py", line 365, in do_execute
#     cursor.execute(statement, parameters)
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/dbapi.py", line 482, in execute
#     self._prepare_statement(operation, statement_name)
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/dbapi.py", line 379, in _prepare_statement
#     query.execute()
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/client.py", line 807, in execute
#     status = self._request.process(response)
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/client.py", line 617, in process
#     self.raise_response_error(http_response)
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/client.py", line 600, in raise_response_error
#     raise exceptions.Http502Error("error 502: bad gateway")
# trino.exceptions.Http502Error: error 502: bad gateway
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/sqlalchemy/engine/base.py", line 1995, in _safe_close_cursor
#     cursor.close()
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/dbapi.py", line 618, in close
#     self.cancel()
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/dbapi.py", line 612, in cancel
#     raise trino.exceptions.OperationalError(
# trino.exceptions.OperationalError: Cancel query failed; no running query
# 2024-06-12 23:05:32,761 - ERROR - Attempt 2 failed with error: error 502: bad gateway
# 2024-06-12 23:05:38,887 - INFO - failed after 3 attempts
# 2024-06-12 23:05:38,888 - ERROR - Error closing cursor
# Traceback (most recent call last):
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/sqlalchemy/engine/base.py", line 1900, in _execute_context
#     self.dialect.do_execute(
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/sqlalchemy/dialect.py", line 365, in do_execute
#     cursor.execute(statement, parameters)
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/dbapi.py", line 482, in execute
#     self._prepare_statement(operation, statement_name)
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/dbapi.py", line 379, in _prepare_statement
#     query.execute()
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/client.py", line 807, in execute
#     status = self._request.process(response)
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/client.py", line 617, in process
#     self.raise_response_error(http_response)
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/client.py", line 600, in raise_response_error
#     raise exceptions.Http502Error("error 502: bad gateway")
# trino.exceptions.Http502Error: error 502: bad gateway
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/sqlalchemy/engine/base.py", line 1995, in _safe_close_cursor
#     cursor.close()
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/dbapi.py", line 618, in close
#     self.cancel()
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/dbapi.py", line 612, in cancel
#     raise trino.exceptions.OperationalError(
# trino.exceptions.OperationalError: Cancel query failed; no running query
# 2024-06-12 23:05:38,889 - ERROR - Attempt 3 failed with error: error 502: bad gateway
# 2024-06-12 23:05:38,889 - ERROR - Failed to insert data into table pd_co_20191021_agg5 after 3 attempts
# 2024-06-12 23:05:39,223 - INFO - failed after 3 attempts
# 2024-06-12 23:05:39,224 - ERROR - Error closing cursor
# Traceback (most recent call last):
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/sqlalchemy/engine/base.py", line 1900, in _execute_context
#     self.dialect.do_execute(
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/sqlalchemy/dialect.py", line 365, in do_execute
#     cursor.execute(statement, parameters)
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/dbapi.py", line 482, in execute
#     self._prepare_statement(operation, statement_name)
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/dbapi.py", line 379, in _prepare_statement
#     query.execute()
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/client.py", line 807, in execute
#     status = self._request.process(response)
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/client.py", line 617, in process
#     self.raise_response_error(http_response)
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/client.py", line 600, in raise_response_error
#     raise exceptions.Http502Error("error 502: bad gateway")
# trino.exceptions.Http502Error: error 502: bad gateway
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/sqlalchemy/engine/base.py", line 1995, in _safe_close_cursor
#     cursor.close()
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/dbapi.py", line 618, in close
#     self.cancel()
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/dbapi.py", line 612, in cancel
#     raise trino.exceptions.OperationalError(
# trino.exceptions.OperationalError: Cancel query failed; no running query
# 2024-06-12 23:05:39,226 - ERROR - Attempt 1 failed with error: error 502: bad gateway
# 2024-06-12 23:05:44,488 - INFO - failed after 3 attempts
# 2024-06-12 23:05:44,488 - ERROR - Error closing cursor
# Traceback (most recent call last):
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/sqlalchemy/engine/base.py", line 1900, in _execute_context
#     self.dialect.do_execute(
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/sqlalchemy/dialect.py", line 365, in do_execute
#     cursor.execute(statement, parameters)
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/dbapi.py", line 482, in execute
#     self._prepare_statement(operation, statement_name)
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/dbapi.py", line 379, in _prepare_statement
#     query.execute()
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/client.py", line 807, in execute
#     status = self._request.process(response)
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/client.py", line 617, in process
#     self.raise_response_error(http_response)
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/client.py", line 600, in raise_response_error
#     raise exceptions.Http502Error("error 502: bad gateway")
# trino.exceptions.Http502Error: error 502: bad gateway
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/sqlalchemy/engine/base.py", line 1995, in _safe_close_cursor
#     cursor.close()
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/dbapi.py", line 618, in close
#     self.cancel()
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/dbapi.py", line 612, in cancel
#     raise trino.exceptions.OperationalError(
# trino.exceptions.OperationalError: Cancel query failed; no running query
# 2024-06-12 23:05:44,489 - ERROR - Attempt 2 failed with error: error 502: bad gateway
# 2024-06-12 23:05:50,151 - INFO - failed after 3 attempts
# 2024-06-12 23:05:50,152 - ERROR - Error closing cursor
# Traceback (most recent call last):
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/sqlalchemy/engine/base.py", line 1900, in _execute_context
#     self.dialect.do_execute(
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/sqlalchemy/dialect.py", line 365, in do_execute
#     cursor.execute(statement, parameters)
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/dbapi.py", line 482, in execute
#     self._prepare_statement(operation, statement_name)
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/dbapi.py", line 379, in _prepare_statement
#     query.execute()
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/client.py", line 807, in execute
#     status = self._request.process(response)
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/client.py", line 617, in process
#     self.raise_response_error(http_response)
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/client.py", line 600, in raise_response_error
#     raise exceptions.Http502Error("error 502: bad gateway")
# trino.exceptions.Http502Error: error 502: bad gateway
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/sqlalchemy/engine/base.py", line 1995, in _safe_close_cursor
#     cursor.close()
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/dbapi.py", line 618, in close
#     self.cancel()
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/dbapi.py", line 612, in cancel
#     raise trino.exceptions.OperationalError(
# trino.exceptions.OperationalError: Cancel query failed; no running query
# 2024-06-12 23:05:50,153 - ERROR - Attempt 3 failed with error: error 502: bad gateway
# 2024-06-12 23:05:50,154 - ERROR - Failed to insert data into table pd_co_20191021_agg3 after 3 attempts
# 2024-06-12 23:05:50,154 - INFO - Executing SQL query for date 20191021 and longitude range -74.53125 to -65
# 2024-06-12 23:06:17,563 - INFO - failed after 3 attempts
# 2024-06-12 23:06:17,564 - ERROR - Error closing cursor
# Traceback (most recent call last):
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/sqlalchemy/engine/base.py", line 1900, in _execute_context
#     self.dialect.do_execute(
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/sqlalchemy/dialect.py", line 365, in do_execute
#     cursor.execute(statement, parameters)
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/dbapi.py", line 482, in execute
#     self._prepare_statement(operation, statement_name)
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/dbapi.py", line 379, in _prepare_statement
#     query.execute()
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/client.py", line 807, in execute
#     status = self._request.process(response)
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/client.py", line 617, in process
#     self.raise_response_error(http_response)
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/client.py", line 600, in raise_response_error
#     raise exceptions.Http502Error("error 502: bad gateway")
# trino.exceptions.Http502Error: error 502: bad gateway
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/sqlalchemy/engine/base.py", line 1995, in _safe_close_cursor
#     cursor.close()
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/dbapi.py", line 618, in close
#     self.cancel()
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/dbapi.py", line 612, in cancel
#     raise trino.exceptions.OperationalError(
# trino.exceptions.OperationalError: Cancel query failed; no running query
# 2024-06-12 23:06:17,565 - ERROR - Attempt 1 failed with error: error 502: bad gateway
# 2024-06-12 23:06:23,358 - INFO - failed after 3 attempts
# 2024-06-12 23:06:23,359 - ERROR - Error closing cursor
# Traceback (most recent call last):
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/sqlalchemy/engine/base.py", line 1900, in _execute_context
#     self.dialect.do_execute(
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/sqlalchemy/dialect.py", line 365, in do_execute
#     cursor.execute(statement, parameters)
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/dbapi.py", line 482, in execute
#     self._prepare_statement(operation, statement_name)
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/dbapi.py", line 379, in _prepare_statement
#     query.execute()
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/client.py", line 807, in execute
#     status = self._request.process(response)
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/client.py", line 617, in process
#     self.raise_response_error(http_response)
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/client.py", line 600, in raise_response_error
#     raise exceptions.Http502Error("error 502: bad gateway")
# trino.exceptions.Http502Error: error 502: bad gateway
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/sqlalchemy/engine/base.py", line 1995, in _safe_close_cursor
#     cursor.close()
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/dbapi.py", line 618, in close
#     self.cancel()
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/dbapi.py", line 612, in cancel
#     raise trino.exceptions.OperationalError(
# trino.exceptions.OperationalError: Cancel query failed; no running query
# 2024-06-12 23:06:23,360 - ERROR - Attempt 2 failed with error: error 502: bad gateway
# 2024-06-12 23:06:28,862 - INFO - failed after 3 attempts
# 2024-06-12 23:06:28,863 - ERROR - Error closing cursor
# Traceback (most recent call last):
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/sqlalchemy/engine/base.py", line 1900, in _execute_context
#     self.dialect.do_execute(
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/sqlalchemy/dialect.py", line 365, in do_execute
#     cursor.execute(statement, parameters)
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/dbapi.py", line 482, in execute
#     self._prepare_statement(operation, statement_name)
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/dbapi.py", line 379, in _prepare_statement
#     query.execute()
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/client.py", line 807, in execute
#     status = self._request.process(response)
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/client.py", line 617, in process
#     self.raise_response_error(http_response)
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/client.py", line 600, in raise_response_error
#     raise exceptions.Http502Error("error 502: bad gateway")
# trino.exceptions.Http502Error: error 502: bad gateway
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/sqlalchemy/engine/base.py", line 1995, in _safe_close_cursor
#     cursor.close()
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/dbapi.py", line 618, in close
#     self.cancel()
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/dbapi.py", line 612, in cancel
#     raise trino.exceptions.OperationalError(
# trino.exceptions.OperationalError: Cancel query failed; no running query
# 2024-06-12 23:06:28,864 - ERROR - Attempt 3 failed with error: error 502: bad gateway
# 2024-06-12 23:06:28,865 - ERROR - Failed to insert data into table pd_co_20191021_agg5 after 3 attempts
# 2024-06-12 23:06:29,519 - INFO - failed after 3 attempts
# 2024-06-12 23:06:29,520 - ERROR - Error closing cursor
# Traceback (most recent call last):
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/sqlalchemy/engine/base.py", line 1900, in _execute_context
#     self.dialect.do_execute(
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/sqlalchemy/dialect.py", line 365, in do_execute
#     cursor.execute(statement, parameters)
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/dbapi.py", line 482, in execute
#     self._prepare_statement(operation, statement_name)
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/dbapi.py", line 379, in _prepare_statement
#     query.execute()
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/client.py", line 807, in execute
#     status = self._request.process(response)
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/client.py", line 617, in process
#     self.raise_response_error(http_response)
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/client.py", line 600, in raise_response_error
#     raise exceptions.Http502Error("error 502: bad gateway")
# trino.exceptions.Http502Error: error 502: bad gateway
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/sqlalchemy/engine/base.py", line 1995, in _safe_close_cursor
#     cursor.close()
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/dbapi.py", line 618, in close
#     self.cancel()
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/dbapi.py", line 612, in cancel
#     raise trino.exceptions.OperationalError(
# trino.exceptions.OperationalError: Cancel query failed; no running query
# 2024-06-12 23:06:29,521 - ERROR - Attempt 1 failed with error: error 502: bad gateway
# 2024-06-12 23:06:35,421 - INFO - failed after 3 attempts
# 2024-06-12 23:06:35,422 - ERROR - Error closing cursor
# Traceback (most recent call last):
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/sqlalchemy/engine/base.py", line 1900, in _execute_context
#     self.dialect.do_execute(
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/sqlalchemy/dialect.py", line 365, in do_execute
#     cursor.execute(statement, parameters)
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/dbapi.py", line 482, in execute
#     self._prepare_statement(operation, statement_name)
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/dbapi.py", line 379, in _prepare_statement
#     query.execute()
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/client.py", line 807, in execute
#     status = self._request.process(response)
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/client.py", line 617, in process
#     self.raise_response_error(http_response)
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/client.py", line 600, in raise_response_error
#     raise exceptions.Http502Error("error 502: bad gateway")
# trino.exceptions.Http502Error: error 502: bad gateway
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/sqlalchemy/engine/base.py", line 1995, in _safe_close_cursor
#     cursor.close()
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/dbapi.py", line 618, in close
#     self.cancel()
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/dbapi.py", line 612, in cancel
#     raise trino.exceptions.OperationalError(
# trino.exceptions.OperationalError: Cancel query failed; no running query
# 2024-06-12 23:06:35,423 - ERROR - Attempt 2 failed with error: error 502: bad gateway
# 2024-06-12 23:06:40,849 - INFO - failed after 3 attempts
# 2024-06-12 23:06:40,850 - ERROR - Error closing cursor
# Traceback (most recent call last):
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/sqlalchemy/engine/base.py", line 1900, in _execute_context
#     self.dialect.do_execute(
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/sqlalchemy/dialect.py", line 365, in do_execute
#     cursor.execute(statement, parameters)
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/dbapi.py", line 482, in execute
#     self._prepare_statement(operation, statement_name)
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/dbapi.py", line 379, in _prepare_statement
#     query.execute()
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/client.py", line 807, in execute
#     status = self._request.process(response)
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/client.py", line 617, in process
#     self.raise_response_error(http_response)
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/client.py", line 600, in raise_response_error
#     raise exceptions.Http502Error("error 502: bad gateway")
# trino.exceptions.Http502Error: error 502: bad gateway
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/sqlalchemy/engine/base.py", line 1995, in _safe_close_cursor
#     cursor.close()
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/dbapi.py", line 618, in close
#     self.cancel()
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/dbapi.py", line 612, in cancel
#     raise trino.exceptions.OperationalError(
# trino.exceptions.OperationalError: Cancel query failed; no running query
# 2024-06-12 23:06:40,850 - ERROR - Attempt 3 failed with error: error 502: bad gateway
# 2024-06-12 23:06:40,851 - ERROR - Failed to insert data into table pd_co_20191021_agg3 after 3 attempts
# 2024-06-12 23:06:40,851 - INFO - Executing SQL query for date 20191022 and longitude range -82 to -74.53125
# 2024-06-12 23:07:51,725 - INFO - failed after 3 attempts
# 2024-06-12 23:07:51,725 - ERROR - Error closing cursor
# Traceback (most recent call last):
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/sqlalchemy/engine/base.py", line 1900, in _execute_context
#     self.dialect.do_execute(
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/sqlalchemy/dialect.py", line 365, in do_execute
#     cursor.execute(statement, parameters)
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/dbapi.py", line 482, in execute
#     self._prepare_statement(operation, statement_name)
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/dbapi.py", line 379, in _prepare_statement
#     query.execute()
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/client.py", line 807, in execute
#     status = self._request.process(response)
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/client.py", line 617, in process
#     self.raise_response_error(http_response)
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/client.py", line 600, in raise_response_error
#     raise exceptions.Http502Error("error 502: bad gateway")
# trino.exceptions.Http502Error: error 502: bad gateway
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/sqlalchemy/engine/base.py", line 1995, in _safe_close_cursor
#     cursor.close()
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/dbapi.py", line 618, in close
#     self.cancel()
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/dbapi.py", line 612, in cancel
#     raise trino.exceptions.OperationalError(
# trino.exceptions.OperationalError: Cancel query failed; no running query
# 2024-06-12 23:07:51,726 - ERROR - Attempt 1 failed with error: error 502: bad gateway
# 2024-06-12 23:07:57,751 - INFO - failed after 3 attempts
# 2024-06-12 23:07:57,752 - ERROR - Error closing cursor
# Traceback (most recent call last):
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/sqlalchemy/engine/base.py", line 1900, in _execute_context
#     self.dialect.do_execute(
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/sqlalchemy/dialect.py", line 365, in do_execute
# ...
#     raise trino.exceptions.OperationalError(
# trino.exceptions.OperationalError: Cancel query failed; no running query
# 2024-06-12 23:41:18,301 - ERROR - Attempt 2 failed with error: error 502: bad gateway
# 2024-06-12 23:41:23,858 - INFO - failed after 3 attempts
# 2024-06-12 23:41:23,859 - ERROR - Error closing cursor
# Traceback (most recent call last):
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/sqlalchemy/engine/base.py", line 1900, in _execute_context
#     self.dialect.do_execute(
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/sqlalchemy/dialect.py", line 365, in do_execute
#     cursor.execute(statement, parameters)
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/dbapi.py", line 482, in execute
#     self._prepare_statement(operation, statement_name)
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/dbapi.py", line 379, in _prepare_statement
#     query.execute()
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/client.py", line 807, in execute
#     status = self._request.process(response)
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/client.py", line 617, in process
#     self.raise_response_error(http_response)
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/client.py", line 600, in raise_response_error
#     raise exceptions.Http502Error("error 502: bad gateway")
# trino.exceptions.Http502Error: error 502: bad gateway
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/sqlalchemy/engine/base.py", line 1995, in _safe_close_cursor
#     cursor.close()
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/dbapi.py", line 618, in close
#     self.cancel()
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/dbapi.py", line 612, in cancel
#     raise trino.exceptions.OperationalError(
# trino.exceptions.OperationalError: Cancel query failed; no running query
# 2024-06-12 23:41:23,860 - ERROR - Attempt 3 failed with error: error 502: bad gateway
# 2024-06-12 23:41:23,860 - ERROR - Failed to insert data into table pd_co_20191031_agg3 after 3 attempts
# 2024-06-12 23:41:23,861 - INFO - Executing SQL query for date 20191031 and longitude range -74.53125 to -65
# 2024-06-12 23:43:01,933 - INFO - failed after 3 attempts
# 2024-06-12 23:43:01,934 - ERROR - Error closing cursor
# Traceback (most recent call last):
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/sqlalchemy/engine/base.py", line 1900, in _execute_context
#     self.dialect.do_execute(
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/sqlalchemy/dialect.py", line 365, in do_execute
#     cursor.execute(statement, parameters)
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/dbapi.py", line 482, in execute
#     self._prepare_statement(operation, statement_name)
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/dbapi.py", line 379, in _prepare_statement
#     query.execute()
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/client.py", line 807, in execute
#     status = self._request.process(response)
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/client.py", line 617, in process
#     self.raise_response_error(http_response)
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/client.py", line 600, in raise_response_error
#     raise exceptions.Http502Error("error 502: bad gateway")
# trino.exceptions.Http502Error: error 502: bad gateway
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/sqlalchemy/engine/base.py", line 1995, in _safe_close_cursor
#     cursor.close()
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/dbapi.py", line 618, in close
#     self.cancel()
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/dbapi.py", line 612, in cancel
#     raise trino.exceptions.OperationalError(
# trino.exceptions.OperationalError: Cancel query failed; no running query
# 2024-06-12 23:43:01,935 - ERROR - Attempt 1 failed with error: error 502: bad gateway
# 2024-06-12 23:43:07,512 - INFO - failed after 3 attempts
# 2024-06-12 23:43:07,513 - ERROR - Error closing cursor
# Traceback (most recent call last):
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/sqlalchemy/engine/base.py", line 1900, in _execute_context
#     self.dialect.do_execute(
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/sqlalchemy/dialect.py", line 365, in do_execute
#     cursor.execute(statement, parameters)
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/dbapi.py", line 482, in execute
#     self._prepare_statement(operation, statement_name)
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/dbapi.py", line 379, in _prepare_statement
#     query.execute()
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/client.py", line 807, in execute
#     status = self._request.process(response)
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/client.py", line 617, in process
#     self.raise_response_error(http_response)
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/client.py", line 600, in raise_response_error
#     raise exceptions.Http502Error("error 502: bad gateway")
# trino.exceptions.Http502Error: error 502: bad gateway
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/sqlalchemy/engine/base.py", line 1995, in _safe_close_cursor
#     cursor.close()
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/dbapi.py", line 618, in close
#     self.cancel()
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/dbapi.py", line 612, in cancel
#     raise trino.exceptions.OperationalError(
# trino.exceptions.OperationalError: Cancel query failed; no running query
# 2024-06-12 23:43:07,514 - ERROR - Attempt 2 failed with error: error 502: bad gateway
# 2024-06-12 23:43:13,449 - INFO - failed after 3 attempts
# 2024-06-12 23:43:13,450 - ERROR - Error closing cursor
# Traceback (most recent call last):
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/sqlalchemy/engine/base.py", line 1900, in _execute_context
#     self.dialect.do_execute(
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/sqlalchemy/dialect.py", line 365, in do_execute
#     cursor.execute(statement, parameters)
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/dbapi.py", line 482, in execute
#     self._prepare_statement(operation, statement_name)
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/dbapi.py", line 379, in _prepare_statement
#     query.execute()
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/client.py", line 807, in execute
#     status = self._request.process(response)
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/client.py", line 617, in process
#     self.raise_response_error(http_response)
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/client.py", line 600, in raise_response_error
#     raise exceptions.Http502Error("error 502: bad gateway")
# trino.exceptions.Http502Error: error 502: bad gateway
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/sqlalchemy/engine/base.py", line 1995, in _safe_close_cursor
#     cursor.close()
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/dbapi.py", line 618, in close
#     self.cancel()
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/dbapi.py", line 612, in cancel
#     raise trino.exceptions.OperationalError(
# trino.exceptions.OperationalError: Cancel query failed; no running query
# 2024-06-12 23:43:13,451 - ERROR - Attempt 3 failed with error: error 502: bad gateway
# 2024-06-12 23:43:13,451 - ERROR - Failed to insert data into table pd_co_20191031_agg5 after 3 attempts
# 2024-06-12 23:43:14,102 - INFO - failed after 3 attempts
# 2024-06-12 23:43:14,103 - ERROR - Error closing cursor
# Traceback (most recent call last):
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/sqlalchemy/engine/base.py", line 1900, in _execute_context
#     self.dialect.do_execute(
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/sqlalchemy/dialect.py", line 365, in do_execute
#     cursor.execute(statement, parameters)
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/dbapi.py", line 482, in execute
#     self._prepare_statement(operation, statement_name)
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/dbapi.py", line 379, in _prepare_statement
#     query.execute()
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/client.py", line 807, in execute
#     status = self._request.process(response)
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/client.py", line 617, in process
#     self.raise_response_error(http_response)
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/client.py", line 600, in raise_response_error
#     raise exceptions.Http502Error("error 502: bad gateway")
# trino.exceptions.Http502Error: error 502: bad gateway
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/sqlalchemy/engine/base.py", line 1995, in _safe_close_cursor
#     cursor.close()
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/dbapi.py", line 618, in close
#     self.cancel()
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/dbapi.py", line 612, in cancel
#     raise trino.exceptions.OperationalError(
# trino.exceptions.OperationalError: Cancel query failed; no running query
# 2024-06-12 23:43:14,104 - ERROR - Attempt 1 failed with error: error 502: bad gateway
# 2024-06-12 23:43:19,629 - INFO - failed after 3 attempts
# 2024-06-12 23:43:19,630 - ERROR - Error closing cursor
# Traceback (most recent call last):
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/sqlalchemy/engine/base.py", line 1900, in _execute_context
#     self.dialect.do_execute(
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/sqlalchemy/dialect.py", line 365, in do_execute
#     cursor.execute(statement, parameters)
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/dbapi.py", line 482, in execute
#     self._prepare_statement(operation, statement_name)
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/dbapi.py", line 379, in _prepare_statement
#     query.execute()
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/client.py", line 807, in execute
#     status = self._request.process(response)
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/client.py", line 617, in process
#     self.raise_response_error(http_response)
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/client.py", line 600, in raise_response_error
#     raise exceptions.Http502Error("error 502: bad gateway")
# trino.exceptions.Http502Error: error 502: bad gateway
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/sqlalchemy/engine/base.py", line 1995, in _safe_close_cursor
#     cursor.close()
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/dbapi.py", line 618, in close
#     self.cancel()
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/dbapi.py", line 612, in cancel
#     raise trino.exceptions.OperationalError(
# trino.exceptions.OperationalError: Cancel query failed; no running query
# 2024-06-12 23:43:19,631 - ERROR - Attempt 2 failed with error: error 502: bad gateway
# 2024-06-12 23:43:25,452 - INFO - failed after 3 attempts
# 2024-06-12 23:43:25,453 - ERROR - Error closing cursor
# Traceback (most recent call last):
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/sqlalchemy/engine/base.py", line 1900, in _execute_context
#     self.dialect.do_execute(
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/sqlalchemy/dialect.py", line 365, in do_execute
#     cursor.execute(statement, parameters)
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/dbapi.py", line 482, in execute
#     self._prepare_statement(operation, statement_name)
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/dbapi.py", line 379, in _prepare_statement
#     query.execute()
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/client.py", line 807, in execute
#     status = self._request.process(response)
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/client.py", line 617, in process
#     self.raise_response_error(http_response)
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/client.py", line 600, in raise_response_error
#     raise exceptions.Http502Error("error 502: bad gateway")
# trino.exceptions.Http502Error: error 502: bad gateway
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/sqlalchemy/engine/base.py", line 1995, in _safe_close_cursor
#     cursor.close()
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/dbapi.py", line 618, in close
#     self.cancel()
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/dbapi.py", line 612, in cancel
#     raise trino.exceptions.OperationalError(
# trino.exceptions.OperationalError: Cancel query failed; no running query
# 2024-06-12 23:43:25,454 - ERROR - Attempt 3 failed with error: error 502: bad gateway
# 2024-06-12 23:43:25,455 - ERROR - Failed to insert data into table pd_co_20191031_agg3 after 3 attempts
# 2024-06-12 23:43:25,456 - INFO - Data extraction, aggregation, and saving completed.
# 2024-06-12 23:43:25,456 - INFO - Total time taken: 2464.7775242328644 seconds
# Failed inserts:
# ('20191020', -82, -74.53125, 'agg5')
# ('20191020', -82, -74.53125, 'agg3')
# ('20191020', -74.53125, -65, 'agg5')
# ('20191020', -74.53125, -65, 'agg3')
# ('20191021', -82, -74.53125, 'agg5')
# ('20191021', -82, -74.53125, 'agg3')
# ('20191021', -74.53125, -65, 'agg5')
# ('20191021', -74.53125, -65, 'agg3')
# ('20191022', -82, -74.53125, 'agg5')
# ('20191022', -82, -74.53125, 'agg3')
# ('20191022', -74.53125, -65, 'agg5')
# ('20191022', -74.53125, -65, 'agg3')
# ('20191023', -82, -74.53125, 'agg5')
# ('20191023', -82, -74.53125, 'agg3')
# ('20191023', -74.53125, -65, 'agg5')
# ('20191023', -74.53125, -65, 'agg3')
# ('20191024', -82, -74.53125, 'agg5')
# ('20191024', -82, -74.53125, 'agg3')
# ('20191024', -74.53125, -65, 'agg5')
# ('20191024', -74.53125, -65, 'agg3')
# ('20191025', -82, -74.53125, 'agg5')
# ('20191025', -82, -74.53125, 'agg3')
# ('20191025', -74.53125, -65, 'agg5')
# ('20191025', -74.53125, -65, 'agg3')
# ('20191026', -82, -74.53125, 'agg5')
# ('20191026', -82, -74.53125, 'agg3')
# ('20191026', -74.53125, -65, 'agg5')
# ('20191026', -74.53125, -65, 'agg3')
# ('20191027', -82, -74.53125, 'agg5')
# ('20191027', -82, -74.53125, 'agg3')
# ('20191027', -74.53125, -65, 'agg5')
# ('20191027', -74.53125, -65, 'agg3')
# ('20191028', -82, -74.53125, 'agg5')
# ('20191028', -82, -74.53125, 'agg3')
# ('20191028', -74.53125, -65, 'agg5')
# ('20191028', -74.53125, -65, 'agg3')
# ('20191029', -82, -74.53125, 'agg5')
# ('20191029', -82, -74.53125, 'agg3')
# ('20191029', -74.53125, -65, 'agg5')
# ('20191029', -74.53125, -65, 'agg3')
# ('20191030', -82, -74.53125, 'agg5')
# ('20191030', -82, -74.53125, 'agg3')
# ('20191030', -74.53125, -65, 'agg5')
# ('20191030', -74.53125, -65, 'agg3')
# ('20191031', -82, -74.53125, 'agg5')
# ('20191031', -82, -74.53125, 'agg3')
# ('20191031', -74.53125, -65, 'agg5')
# ('20191031', -74.53125, -65, 'agg3')

# %%
# Set up logging
logging.basicConfig(level=logging.INFO, format='%(asctime)s - %(levelname)s - %(message)s')

# Database connection setup
output_schema_name = 'pop_density'
con = create_engine(f"trino://localhost:9090/dedicated/{output_schema_name}")

start_time = time.time()  # Start timing

# Define the input parameters
country_code = 'CO'
start_date = 20191015
end_date = 20191015

# Define the input schema and table name
schema_name = {'cda': 'cuebiq.paas_cda_pe_v3'}
pe_dl_table = f"{schema_name['cda']}.device_location_uplevelled"

# Convert integer dates to datetime objects
start_date_dt = datetime.strptime(str(start_date), '%Y%m%d')
end_date_dt = datetime.strptime(str(end_date), '%Y%m%d')

# Function to insert data with retry mechanism
def insert_data_with_retry(df, table_name, con, retries=3, delay=5):
    for attempt in range(retries):
        try:
            df.to_sql(
                table_name, 
                con, 
                index=False, 
                if_exists="append", 
                method="multi"
            )
            logging.info(f"Inserted data into table {table_name}")
            break
        except Exception as e:
            logging.error(f"Attempt {attempt+1} failed with error: {e}")
            if attempt < retries - 1:
                time.sleep(delay)
            else:
                logging.error(f"Failed to insert data into table {table_name} after {retries} attempts")

# Loop through each day from start_date to end_date
current_date = start_date_dt
while current_date <= end_date_dt:
    try:
        # Calculate the lookback and lookahead dates
        lookback_date = current_date - timedelta(days=1)
        lookahead_date = current_date + timedelta(days=35)
        
        # Format dates for the SQL query
        formatted_lookback_date = lookback_date.strftime('%Y%m%d')
        formatted_current_date = current_date.strftime('%Y%m%d')
        formatted_lookahead_date = lookahead_date.strftime('%Y%m%d')
        
        # Construct the SQL query
        query = f"""
        SELECT 
            cuebiq_id, 
            event_zoned_datetime, 
            processing_date,
            lat,
            lng
        FROM {pe_dl_table}
        WHERE 
            processing_date BETWEEN {formatted_lookback_date} AND {formatted_lookahead_date}
            AND country_code = '{country_code}' 
            AND event_zoned_datetime IS NOT NULL
            AND TRY(date_parse(substr(event_zoned_datetime, 1, 19), '%Y-%m-%dT%H:%i:%s')) IS NOT NULL
            AND DATE(TRY(date_parse(substr(event_zoned_datetime, 1, 19), '%Y-%m-%dT%H:%i:%s'))) = date_parse('{formatted_current_date}', '%Y%m%d')
        """
        
        logging.info(f"Executing SQL query for date {formatted_current_date}")
        
        pe_dl_table_gen = sql_engine.read_sql_chunked(query)
        
        # Convert the generator to a DataFrame
        chunks = [chunk for chunk in pe_dl_table_gen]
        if chunks:
            pe_dl_table_df = pd.concat(chunks, ignore_index=True)
            
            # Calculate geohashes
            pe_dl_table_df['geohash5'] = pe_dl_table_df.apply(lambda row: geohash2.encode(row['lat'], row['lng'], precision=5), axis=1)
            pe_dl_table_df['geohash3'] = pe_dl_table_df.apply(lambda row: geohash2.encode(row['lat'], row['lng'], precision=3), axis=1)
            
            # Aggregate data for geohash5
            aggregated_data_5 = pe_dl_table_df.groupby('geohash5').agg(
                no_of_points=('geohash5', 'size'),
                no_of_unique_users=('cuebiq_id', 'nunique')
            ).reset_index()

            # Filter rows with no_of_unique_users > 10
            filtered_data_5 = aggregated_data_5[aggregated_data_5['no_of_unique_users'] > 10].copy()
            
            # Add the local_date column
            filtered_data_5.loc[:, 'local_date'] = formatted_current_date
            
            # Insert filtered aggregated data for geohash5 into SQL table
            if not filtered_data_5.empty:
                table_name_agg5 = f"pd_{country_code.lower()}_{formatted_current_date}_agg5"
                insert_data_with_retry(filtered_data_5, table_name_agg5, con)
            
            # Aggregate data for geohash3
            aggregated_data_3 = pe_dl_table_df.groupby('geohash3').agg(
                no_of_points=('geohash3', 'size'),
                no_of_unique_users=('cuebiq_id', 'nunique')
            ).reset_index()
            
            # Filter rows with no_of_unique_users > 10
            filtered_data_3 = aggregated_data_3[aggregated_data_3['no_of_unique_users'] > 10].copy()
            
            # Add the local_date column
            filtered_data_3.loc[:, 'local_date'] = formatted_current_date
            
            # Insert filtered aggregated data for geohash3 into SQL table
            if not filtered_data_3.empty:
                table_name_agg3 = f"pd_{country_code.lower()}_{formatted_current_date}_agg3"
                insert_data_with_retry(filtered_data_3, table_name_agg3, con)
        
    except Exception as e:
        logging.error(f"Error while processing data for date {formatted_current_date}: {e}")
    
    # Move to the next day
    current_date += timedelta(days=1)

logging.info("Data extraction, aggregation, and saving completed.")

end_time = time.time()  # End timing

# Calculate and print the total time taken
total_time = end_time - start_time
logging.info(f"Total time taken: {total_time} seconds")
# Out:
# 2024-06-07 17:58:41,889 - INFO - Executing SQL query for date 20191015
# 2024-06-07 17:59:16,778 - INFO - failed after 3 attempts
# 2024-06-07 17:59:17,191 - INFO - failed after 3 attempts
# 2024-06-07 17:59:17,193 - ERROR - Attempt 1 failed with error: error 502: bad gateway
# 2024-06-07 17:59:22,693 - INFO - failed after 3 attempts
# 2024-06-07 17:59:22,694 - ERROR - Error closing cursor
# Traceback (most recent call last):
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/sqlalchemy/engine/base.py", line 1900, in _execute_context
#     self.dialect.do_execute(
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/sqlalchemy/dialect.py", line 365, in do_execute
#     cursor.execute(statement, parameters)
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/dbapi.py", line 482, in execute
#     self._prepare_statement(operation, statement_name)
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/dbapi.py", line 379, in _prepare_statement
#     query.execute()
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/client.py", line 807, in execute
#     status = self._request.process(response)
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/client.py", line 617, in process
#     self.raise_response_error(http_response)
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/client.py", line 600, in raise_response_error
#     raise exceptions.Http502Error("error 502: bad gateway")
# trino.exceptions.Http502Error: error 502: bad gateway
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/sqlalchemy/engine/base.py", line 1995, in _safe_close_cursor
#     cursor.close()
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/dbapi.py", line 618, in close
#     self.cancel()
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/dbapi.py", line 612, in cancel
#     raise trino.exceptions.OperationalError(
# trino.exceptions.OperationalError: Cancel query failed; no running query
# 2024-06-07 17:59:22,695 - ERROR - Attempt 2 failed with error: error 502: bad gateway
# 2024-06-07 17:59:28,205 - INFO - failed after 3 attempts
# 2024-06-07 17:59:28,206 - ERROR - Error closing cursor
# Traceback (most recent call last):
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/sqlalchemy/engine/base.py", line 1900, in _execute_context
#     self.dialect.do_execute(
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/sqlalchemy/dialect.py", line 365, in do_execute
#     cursor.execute(statement, parameters)
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/dbapi.py", line 482, in execute
#     self._prepare_statement(operation, statement_name)
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/dbapi.py", line 379, in _prepare_statement
#     query.execute()
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/client.py", line 807, in execute
#     status = self._request.process(response)
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/client.py", line 617, in process
#     self.raise_response_error(http_response)
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/client.py", line 600, in raise_response_error
#     raise exceptions.Http502Error("error 502: bad gateway")
# trino.exceptions.Http502Error: error 502: bad gateway
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/sqlalchemy/engine/base.py", line 1995, in _safe_close_cursor
#     cursor.close()
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/dbapi.py", line 618, in close
#     self.cancel()
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/dbapi.py", line 612, in cancel
#     raise trino.exceptions.OperationalError(
# trino.exceptions.OperationalError: Cancel query failed; no running query
# 2024-06-07 17:59:28,207 - ERROR - Attempt 3 failed with error: error 502: bad gateway
# 2024-06-07 17:59:28,207 - ERROR - Failed to insert data into table pd_co_20191015_agg5 after 3 attempts
# 2024-06-07 17:59:29,227 - INFO - failed after 3 attempts
# 2024-06-07 17:59:29,228 - ERROR - Error closing cursor
# Traceback (most recent call last):
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/sqlalchemy/engine/base.py", line 1900, in _execute_context
#     self.dialect.do_execute(
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/sqlalchemy/dialect.py", line 365, in do_execute
#     cursor.execute(statement, parameters)
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/dbapi.py", line 482, in execute
#     self._prepare_statement(operation, statement_name)
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/dbapi.py", line 379, in _prepare_statement
#     query.execute()
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/client.py", line 807, in execute
#     status = self._request.process(response)
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/client.py", line 617, in process
#     self.raise_response_error(http_response)
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/client.py", line 600, in raise_response_error
#     raise exceptions.Http502Error("error 502: bad gateway")
# trino.exceptions.Http502Error: error 502: bad gateway
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/sqlalchemy/engine/base.py", line 1995, in _safe_close_cursor
#     cursor.close()
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/dbapi.py", line 618, in close
#     self.cancel()
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/dbapi.py", line 612, in cancel
#     raise trino.exceptions.OperationalError(
# trino.exceptions.OperationalError: Cancel query failed; no running query
# 2024-06-07 17:59:29,229 - ERROR - Attempt 1 failed with error: error 502: bad gateway
# 2024-06-07 17:59:35,037 - INFO - failed after 3 attempts
# 2024-06-07 17:59:35,037 - ERROR - Error closing cursor
# Traceback (most recent call last):
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/sqlalchemy/engine/base.py", line 1900, in _execute_context
#     self.dialect.do_execute(
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/sqlalchemy/dialect.py", line 365, in do_execute
#     cursor.execute(statement, parameters)
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/dbapi.py", line 482, in execute
#     self._prepare_statement(operation, statement_name)
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/dbapi.py", line 379, in _prepare_statement
#     query.execute()
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/client.py", line 807, in execute
#     status = self._request.process(response)
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/client.py", line 617, in process
#     self.raise_response_error(http_response)
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/client.py", line 600, in raise_response_error
#     raise exceptions.Http502Error("error 502: bad gateway")
# trino.exceptions.Http502Error: error 502: bad gateway
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/sqlalchemy/engine/base.py", line 1995, in _safe_close_cursor
#     cursor.close()
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/dbapi.py", line 618, in close
#     self.cancel()
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/dbapi.py", line 612, in cancel
#     raise trino.exceptions.OperationalError(
# trino.exceptions.OperationalError: Cancel query failed; no running query
# 2024-06-07 17:59:35,039 - ERROR - Attempt 2 failed with error: error 502: bad gateway
# 2024-06-07 17:59:40,662 - INFO - failed after 3 attempts
# 2024-06-07 17:59:40,663 - ERROR - Error closing cursor
# Traceback (most recent call last):
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/sqlalchemy/engine/base.py", line 1900, in _execute_context
#     self.dialect.do_execute(
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/sqlalchemy/dialect.py", line 365, in do_execute
#     cursor.execute(statement, parameters)
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/dbapi.py", line 482, in execute
#     self._prepare_statement(operation, statement_name)
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/dbapi.py", line 379, in _prepare_statement
#     query.execute()
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/client.py", line 807, in execute
#     status = self._request.process(response)
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/client.py", line 617, in process
#     self.raise_response_error(http_response)
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/client.py", line 600, in raise_response_error
#     raise exceptions.Http502Error("error 502: bad gateway")
# trino.exceptions.Http502Error: error 502: bad gateway
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/sqlalchemy/engine/base.py", line 1995, in _safe_close_cursor
#     cursor.close()
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/dbapi.py", line 618, in close
#     self.cancel()
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/dbapi.py", line 612, in cancel
#     raise trino.exceptions.OperationalError(
# trino.exceptions.OperationalError: Cancel query failed; no running query
# 2024-06-07 17:59:40,664 - ERROR - Attempt 3 failed with error: error 502: bad gateway
# 2024-06-07 17:59:40,665 - ERROR - Failed to insert data into table pd_co_20191015_agg3 after 3 attempts
# 2024-06-07 17:59:40,666 - INFO - Data extraction, aggregation, and saving completed.
# 2024-06-07 17:59:40,667 - INFO - Total time taken: 58.777867555618286 seconds

# %%
# This one seemms to be working 

# Set up logging
logging.basicConfig(level=logging.INFO, format='%(asctime)s - %(levelname)s - %(message)s')

# Database connection setup
output_schema_name = 'pop_density'
con = create_engine(f"trino://localhost:9090/dedicated/{output_schema_name}")

start_time = time.time()  # Start timing

# Define the input parameters
country_code = 'CO'
start_date = 20191015
end_date = 20191015

# Define the input schema and table name
schema_name = {'cda': 'cuebiq.paas_cda_pe_v3'}
pe_dl_table = f"{schema_name['cda']}.device_location_uplevelled"

# Convert integer dates to datetime objects
start_date_dt = datetime.strptime(str(start_date), '%Y%m%d')
end_date_dt = datetime.strptime(str(end_date), '%Y%m%d')

# Function to insert data with retry mechanism
def insert_data_with_retry(df, table_name, con, retries=3, delay=5):
    for attempt in range(retries):
        try:
            df.to_sql(
                table_name, 
                con, 
                index=False, 
                if_exists="append", 
                method="multi"
            )
            logging.info(f"Inserted data into table {table_name}")
            break
        except Exception as e:
            logging.error(f"Attempt {attempt+1} failed with error: {e}")
            if attempt < retries - 1:
                time.sleep(delay)
            else:
                logging.error(f"Failed to insert data into table {table_name} after {retries} attempts")

# Loop through each day from start_date to end_date
current_date = start_date_dt
while current_date <= end_date_dt:
    try:
        # Calculate the lookback and lookahead dates
        lookback_date = current_date - timedelta(days=1)
        lookahead_date = current_date + timedelta(days=35)
        
        # Format dates for the SQL query
        formatted_lookback_date = lookback_date.strftime('%Y%m%d')
        formatted_current_date = current_date.strftime('%Y%m%d')
        formatted_lookahead_date = lookahead_date.strftime('%Y%m%d')
        
        # Construct the SQL query
        query = f"""
        SELECT 
            cuebiq_id, 
            event_zoned_datetime, 
            processing_date,
            lat,
            lng
        FROM {pe_dl_table}
        WHERE 
            processing_date BETWEEN {formatted_lookback_date} AND {formatted_lookahead_date}
            AND country_code = '{country_code}' 
            AND event_zoned_datetime IS NOT NULL
            AND TRY(date_parse(substr(event_zoned_datetime, 1, 19), '%Y-%m-%dT%H:%i:%s')) IS NOT NULL
            AND DATE(TRY(date_parse(substr(event_zoned_datetime, 1, 19), '%Y-%m-%dT%H:%i:%s'))) = date_parse('{formatted_current_date}', '%Y%m%d')
        """
        
        logging.info(f"Executing SQL query for date {formatted_current_date}")
        
        pe_dl_table_gen = sql_engine.read_sql_chunked(query)
        
        # Convert the generator to a DataFrame
        chunks = [chunk for chunk in pe_dl_table_gen]
        if chunks:
            pe_dl_table_df = pd.concat(chunks, ignore_index=True)
            
            # Calculate geohashes
            pe_dl_table_df['geohash5'] = pe_dl_table_df.apply(lambda row: geohash2.encode(row['lat'], row['lng'], precision=5), axis=1)
            pe_dl_table_df['geohash3'] = pe_dl_table_df.apply(lambda row: geohash2.encode(row['lat'], row['lng'], precision=3), axis=1)
            
            # Aggregate data for geohash5
            aggregated_data_5 = pe_dl_table_df.groupby('geohash5').agg(
                no_of_points=('geohash5', 'size'),
                no_of_unique_users=('cuebiq_id', 'nunique')
            ).reset_index()

            # Filter rows with no_of_unique_users > 10
            filtered_data_5 = aggregated_data_5[aggregated_data_5['no_of_unique_users'] > 10].copy()
            
            # Add the local_date column
            filtered_data_5.loc[:, 'local_date'] = formatted_current_date
            
            # Insert filtered aggregated data for geohash5 into SQL table
            if not filtered_data_5.empty:
                table_name_agg5 = f"pd_{country_code.lower()}_{formatted_current_date}_agg5"
                insert_data_with_retry(filtered_data_5, table_name_agg5, con)
            
            # Aggregate data for geohash3
            aggregated_data_3 = pe_dl_table_df.groupby('geohash3').agg(
                no_of_points=('geohash3', 'size'),
                no_of_unique_users=('cuebiq_id', 'nunique')
            ).reset_index()
            
            # Filter rows with no_of_unique_users > 10
            filtered_data_3 = aggregated_data_3[aggregated_data_3['no_of_unique_users'] > 10].copy()
            
            # Add the local_date column
            filtered_data_3.loc[:, 'local_date'] = formatted_current_date
            
            # Insert filtered aggregated data for geohash3 into SQL table
            if not filtered_data_3.empty:
                table_name_agg3 = f"pd_{country_code.lower()}_{formatted_current_date}_agg3"
                insert_data_with_retry(filtered_data_3, table_name_agg3, con)
        
    except Exception as e:
        logging.error(f"Error while processing data for date {formatted_current_date}: {e}")
    
    # Move to the next day
    current_date += timedelta(days=1)

logging.info("Data extraction, aggregation, and saving completed.")

end_time = time.time()  # End timing

# Calculate and print the total time taken
total_time = end_time - start_time
logging.info(f"Total time taken: {total_time} seconds")
# Out:
# 2024-06-06 22:27:10,473 - INFO - Executing SQL query for date 20191015
# 2024-06-06 22:27:29,402 - INFO - failed after 3 attempts
# 2024-06-06 22:27:30,069 - INFO - failed after 3 attempts
# 2024-06-06 22:27:30,070 - ERROR - Attempt 1 failed with error: error 502: bad gateway
# 2024-06-06 22:27:35,994 - INFO - failed after 3 attempts
# 2024-06-06 22:27:35,995 - ERROR - Error closing cursor
# Traceback (most recent call last):
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/sqlalchemy/engine/base.py", line 1900, in _execute_context
#     self.dialect.do_execute(
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/sqlalchemy/dialect.py", line 365, in do_execute
#     cursor.execute(statement, parameters)
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/dbapi.py", line 482, in execute
#     self._prepare_statement(operation, statement_name)
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/dbapi.py", line 379, in _prepare_statement
#     query.execute()
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/client.py", line 807, in execute
#     status = self._request.process(response)
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/client.py", line 617, in process
#     self.raise_response_error(http_response)
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/client.py", line 600, in raise_response_error
#     raise exceptions.Http502Error("error 502: bad gateway")
# trino.exceptions.Http502Error: error 502: bad gateway
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/sqlalchemy/engine/base.py", line 1995, in _safe_close_cursor
#     cursor.close()
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/dbapi.py", line 618, in close
#     self.cancel()
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/dbapi.py", line 612, in cancel
#     raise trino.exceptions.OperationalError(
# trino.exceptions.OperationalError: Cancel query failed; no running query
# 2024-06-06 22:27:35,997 - ERROR - Attempt 2 failed with error: error 502: bad gateway
# 2024-06-06 22:27:41,760 - INFO - failed after 3 attempts
# 2024-06-06 22:27:41,761 - ERROR - Error closing cursor
# Traceback (most recent call last):
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/sqlalchemy/engine/base.py", line 1900, in _execute_context
#     self.dialect.do_execute(
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/sqlalchemy/dialect.py", line 365, in do_execute
#     cursor.execute(statement, parameters)
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/dbapi.py", line 482, in execute
#     self._prepare_statement(operation, statement_name)
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/dbapi.py", line 379, in _prepare_statement
#     query.execute()
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/client.py", line 807, in execute
#     status = self._request.process(response)
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/client.py", line 617, in process
#     self.raise_response_error(http_response)
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/client.py", line 600, in raise_response_error
#     raise exceptions.Http502Error("error 502: bad gateway")
# trino.exceptions.Http502Error: error 502: bad gateway
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/sqlalchemy/engine/base.py", line 1995, in _safe_close_cursor
#     cursor.close()
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/dbapi.py", line 618, in close
#     self.cancel()
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/dbapi.py", line 612, in cancel
#     raise trino.exceptions.OperationalError(
# trino.exceptions.OperationalError: Cancel query failed; no running query
# 2024-06-06 22:27:41,762 - ERROR - Attempt 3 failed with error: error 502: bad gateway
# 2024-06-06 22:27:41,763 - ERROR - Failed to insert data into table pd_co_20191015_agg5 after 3 attempts
# 2024-06-06 22:27:42,432 - INFO - failed after 3 attempts
# 2024-06-06 22:27:42,433 - ERROR - Error closing cursor
# Traceback (most recent call last):
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/sqlalchemy/engine/base.py", line 1900, in _execute_context
#     self.dialect.do_execute(
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/sqlalchemy/dialect.py", line 365, in do_execute
#     cursor.execute(statement, parameters)
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/dbapi.py", line 482, in execute
#     self._prepare_statement(operation, statement_name)
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/dbapi.py", line 379, in _prepare_statement
#     query.execute()
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/client.py", line 807, in execute
#     status = self._request.process(response)
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/client.py", line 617, in process
#     self.raise_response_error(http_response)
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/client.py", line 600, in raise_response_error
#     raise exceptions.Http502Error("error 502: bad gateway")
# trino.exceptions.Http502Error: error 502: bad gateway
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/sqlalchemy/engine/base.py", line 1995, in _safe_close_cursor
#     cursor.close()
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/dbapi.py", line 618, in close
#     self.cancel()
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/dbapi.py", line 612, in cancel
#     raise trino.exceptions.OperationalError(
# trino.exceptions.OperationalError: Cancel query failed; no running query
# 2024-06-06 22:27:42,433 - ERROR - Attempt 1 failed with error: error 502: bad gateway
# 2024-06-06 22:27:47,956 - INFO - failed after 3 attempts
# 2024-06-06 22:27:47,957 - ERROR - Error closing cursor
# Traceback (most recent call last):
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/sqlalchemy/engine/base.py", line 1900, in _execute_context
#     self.dialect.do_execute(
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/sqlalchemy/dialect.py", line 365, in do_execute
#     cursor.execute(statement, parameters)
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/dbapi.py", line 482, in execute
#     self._prepare_statement(operation, statement_name)
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/dbapi.py", line 379, in _prepare_statement
#     query.execute()
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/client.py", line 807, in execute
#     status = self._request.process(response)
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/client.py", line 617, in process
#     self.raise_response_error(http_response)
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/client.py", line 600, in raise_response_error
#     raise exceptions.Http502Error("error 502: bad gateway")
# trino.exceptions.Http502Error: error 502: bad gateway
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/sqlalchemy/engine/base.py", line 1995, in _safe_close_cursor
#     cursor.close()
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/dbapi.py", line 618, in close
#     self.cancel()
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/dbapi.py", line 612, in cancel
#     raise trino.exceptions.OperationalError(
# trino.exceptions.OperationalError: Cancel query failed; no running query
# 2024-06-06 22:27:47,958 - ERROR - Attempt 2 failed with error: error 502: bad gateway
# 2024-06-06 22:27:53,363 - INFO - failed after 3 attempts
# 2024-06-06 22:27:53,364 - ERROR - Error closing cursor
# Traceback (most recent call last):
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/sqlalchemy/engine/base.py", line 1900, in _execute_context
#     self.dialect.do_execute(
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/sqlalchemy/dialect.py", line 365, in do_execute
#     cursor.execute(statement, parameters)
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/dbapi.py", line 482, in execute
#     self._prepare_statement(operation, statement_name)
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/dbapi.py", line 379, in _prepare_statement
#     query.execute()
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/client.py", line 807, in execute
#     status = self._request.process(response)
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/client.py", line 617, in process
#     self.raise_response_error(http_response)
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/client.py", line 600, in raise_response_error
#     raise exceptions.Http502Error("error 502: bad gateway")
# trino.exceptions.Http502Error: error 502: bad gateway
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/sqlalchemy/engine/base.py", line 1995, in _safe_close_cursor
#     cursor.close()
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/dbapi.py", line 618, in close
#     self.cancel()
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/dbapi.py", line 612, in cancel
#     raise trino.exceptions.OperationalError(
# trino.exceptions.OperationalError: Cancel query failed; no running query
# 2024-06-06 22:27:53,365 - ERROR - Attempt 3 failed with error: error 502: bad gateway
# 2024-06-06 22:27:53,366 - ERROR - Failed to insert data into table pd_co_20191015_agg3 after 3 attempts
# 2024-06-06 22:27:53,367 - INFO - Data extraction, aggregation, and saving completed.
# 2024-06-06 22:27:53,367 - INFO - Total time taken: 42.89572620391846 seconds

# %%
# Database connection setup
output_schema_name = 'pop_density'
con = create_engine(f"trino://localhost:9090/dedicated/{output_schema_name}")

start_time = time.time()  # Start timing

# Define the input parameters
country_code = 'CO'
start_date = 20191015
end_date = 20191015

# Define the input schema and table name
schema_name = {'cda': 'cuebiq.paas_cda_pe_v3'}
pe_dl_table = f"{schema_name['cda']}.device_location_uplevelled"

# Convert integer dates to datetime objects
start_date_dt = datetime.strptime(str(start_date), '%Y%m%d')
end_date_dt = datetime.strptime(str(end_date), '%Y%m%d')

# Calculate the lookback and lookahead dates
lookback_date = current_date - timedelta(days=1)
lookahead_date = current_date + timedelta(days=35)

# Format dates for the SQL query
formatted_lookback_date = lookback_date.strftime('%Y%m%d')
formatted_current_date = current_date.strftime('%Y%m%d')
formatted_lookahead_date = lookahead_date.strftime('%Y%m%d')

query = f"""
SELECT 
    cuebiq_id, 
    event_zoned_datetime, 
    processing_date,
    lat,
    lng
FROM {pe_dl_table}
WHERE 
    processing_date BETWEEN {formatted_lookback_date} AND {formatted_lookahead_date}
    AND country_code = '{country_code}' 
    AND event_zoned_datetime IS NOT NULL
    AND TRY(date_parse(substr(event_zoned_datetime, 1, 19), '%Y-%m-%dT%H:%i:%s')) IS NOT NULL
    AND DATE(TRY(date_parse(substr(event_zoned_datetime, 1, 19), '%Y-%m-%dT%H:%i:%s'))) = date_parse('{formatted_current_date}', '%Y%m%d')
"""

logging.info(f"Executing SQL query for date {formatted_current_date}")

pe_dl_table_gen = sql_engine.read_sql_chunked(query)

# Convert the generator to a DataFrame
chunks = [chunk for chunk in pe_dl_table_gen]
if chunks:
    pe_dl_table_df = pd.concat(chunks, ignore_index=True)
pe_dl_table_df
# Out:
# 2024-06-06 17:15:06,916 - INFO - Executing SQL query for date 20191017
#         cuebiq_id       event_zoned_datetime  processing_date       lat  \
# 0      2380378528  2019-10-17T16:57:25-05:00         20191105  3.330445
# 1      2380378528  2019-10-17T16:50:32-05:00         20191105  3.330306
# 2      2380378528  2019-10-17T16:50:32-05:00         20191105  3.330306
# 3      2380378528  2019-10-17T16:48:25-05:00         20191105  3.332553
# 4      2380378528  2019-10-17T17:10:33-05:00         20191105  3.337887
# ...           ...                        ...              ...       ...
# 35792  2488939223  2019-10-17T23:13:02-05:00         20191114  1.215279
# 35793  2488939223  2019-10-17T23:13:02-05:00         20191114  1.215279
# 35794  2488939223  2019-10-17T23:13:02-05:00         20191114  1.215279
# 35795  2488939223  2019-10-17T23:13:02-05:00         20191114  1.215279
# 35796  2488939223  2019-10-17T23:13:02-05:00         20191114  1.215279
#
#              lng
# 0     -76.543109
# 1     -76.542735
# 2     -76.542735
# 3     -76.541478
# 4     -76.534914
# ...          ...
# 35792 -77.288334
# 35793 -77.288334
# 35794 -77.288334
# 35795 -77.288334
# 35796 -77.288334
#
# [35797 rows x 5 columns]

# %%
# Calculate geohashes
pe_dl_table_df['geohash5'] = pe_dl_table_df.apply(lambda row: geohash2.encode(row['lat'], row['lng'], precision=5), axis=1)
pe_dl_table_df['geohash3'] = pe_dl_table_df.apply(lambda row: geohash2.encode(row['lat'], row['lng'], precision=3), axis=1)
pe_dl_table_df
# Out:
#         cuebiq_id       event_zoned_datetime  processing_date       lat  \
# 0      2380378528  2019-10-17T16:57:25-05:00         20191105  3.330445
# 1      2380378528  2019-10-17T16:50:32-05:00         20191105  3.330306
# 2      2380378528  2019-10-17T16:50:32-05:00         20191105  3.330306
# 3      2380378528  2019-10-17T16:48:25-05:00         20191105  3.332553
# 4      2380378528  2019-10-17T17:10:33-05:00         20191105  3.337887
# ...           ...                        ...              ...       ...
# 35792  2488939223  2019-10-17T23:13:02-05:00         20191114  1.215279
# 35793  2488939223  2019-10-17T23:13:02-05:00         20191114  1.215279
# 35794  2488939223  2019-10-17T23:13:02-05:00         20191114  1.215279
# 35795  2488939223  2019-10-17T23:13:02-05:00         20191114  1.215279
# 35796  2488939223  2019-10-17T23:13:02-05:00         20191114  1.215279
#
#              lng geohash5 geohash3
# 0     -76.543109    d29df      d29
# 1     -76.542735    d29df      d29
# 2     -76.542735    d29df      d29
# 3     -76.541478    d29df      d29
# 4     -76.534914    d29df      d29
# ...          ...      ...      ...
# 35792 -77.288334    d21nc      d21
# 35793 -77.288334    d21nc      d21
# 35794 -77.288334    d21nc      d21
# 35795 -77.288334    d21nc      d21
# 35796 -77.288334    d21nc      d21
#
# [35797 rows x 7 columns]

# %%
# Aggregate data for geohash5
aggregated_data_5 = pe_dl_table_df.groupby('geohash5').agg(
    no_of_points=('geohash5', 'size'),
    no_of_unique_users=('cuebiq_id', 'nunique')
).reset_index()

# Filter rows with no_of_unique_users > 10
filtered_data_5 = aggregated_data_5[aggregated_data_5['no_of_unique_users'] > 10].copy()

# Add the local_date column
filtered_data_5.loc[:, 'local_date'] = formatted_current_date

# Aggregate data for geohash3
aggregated_data_3 = pe_dl_table_df.groupby('geohash3').agg(
    no_of_points=('geohash3', 'size'),
    no_of_unique_users=('cuebiq_id', 'nunique')
).reset_index()

# Filter rows with no_of_unique_users > 10
filtered_data_3 = aggregated_data_3[aggregated_data_3['no_of_unique_users'] > 10].copy()

# Add the local_date column
filtered_data_3.loc[:, 'local_date'] = formatted_current_date

# %%
filtered_data_3
# Out:
#    geohash3  no_of_points  no_of_unique_users local_date
# 0       6rf            55                  35   20191017
# 1       6rg           112                  71   20191017
# 3       6ru            64                  25   20191017
# 4       6rv            23                  18   20191017
# 6       d20           214                  20   20191017
# 7       d21           270                  35   20191017
# 8       d22            89                  13   20191017
# 9       d23           747                  63   20191017
# 10      d26           273                  21   20191017
# 12      d29          3285                 292   20191017
# 14      d2c            63                  14   20191017
# 15      d2d           449                  46   20191017
# 16      d2e           656                  52   20191017
# 17      d2f          2040                 217   20191017
# 18      d2g         13170                1028   20191017
# 22      d2u           381                  27   20191017
# 26      d31           103                  11   20191017
# 28      d33           359                  20   20191017
# 29      d34          5440                 417   20191017
# 30      d35           405                  40   20191017
# 31      d36           224                  19   20191017
# 32      d37           738                  78   20191017
# 34      d3d           654                  67   20191017
# 35      d3e           130                  18   20191017
# 36      d3f          2566                 244   20191017
# 37      d3g           656                  66   20191017
# 38      d3h           554                  51   20191017
# 40      d3k          1335                 121   20191017

# %%
filtered_data_5
# Out:
#      geohash5  no_of_points  no_of_unique_users local_date
# 115     d21nc           156                  22   20191017
# 182     d23tb           274                  22   20191017
# 185     d23w1            55                  12   20191017
# 257     d29e3            79                  12   20191017
# 258     d29e4           302                  34   20191017
# ...       ...           ...                 ...        ...
# 1178    d3k00           129                  22   20191017
# 1180    d3k02           504                  48   20191017
# 1181    d3k08           182                  24   20191017
# 1197    d3kky           138                  17   20191017
# 1199    d3kmn           136                  12   20191017
#
# [85 rows x 4 columns]

# %%
# Insert filtered aggregated data for geohash5 into SQL table
if not filtered_data_5.empty:
    table_name_agg5 = f"pd_{country_code.lower()}_{formatted_current_date}_agg5"
    insert_data_with_retry(filtered_data_5, table_name_agg5, con)

# Insert filtered aggregated data for geohash3 into SQL table
if not filtered_data_3.empty:
    table_name_agg3 = f"pd_{country_code.lower()}_{formatted_current_date}_agg3"
    insert_data_with_retry(filtered_data_3, table_name_agg3, con)
# Out:
# 2024-06-06 17:16:57,110 - INFO - failed after 3 attempts
# 2024-06-06 17:16:58,128 - INFO - failed after 3 attempts
# 2024-06-06 17:16:58,129 - ERROR - Attempt 1 failed with error: error 502: bad gateway
# 2024-06-06 17:17:03,340 - INFO - failed after 3 attempts
# 2024-06-06 17:17:03,341 - ERROR - Error closing cursor
# Traceback (most recent call last):
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/sqlalchemy/engine/base.py", line 1900, in _execute_context
#     self.dialect.do_execute(
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/sqlalchemy/dialect.py", line 365, in do_execute
#     cursor.execute(statement, parameters)
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/dbapi.py", line 482, in execute
#     self._prepare_statement(operation, statement_name)
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/dbapi.py", line 379, in _prepare_statement
#     query.execute()
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/client.py", line 807, in execute
#     status = self._request.process(response)
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/client.py", line 617, in process
#     self.raise_response_error(http_response)
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/client.py", line 600, in raise_response_error
#     raise exceptions.Http502Error("error 502: bad gateway")
# trino.exceptions.Http502Error: error 502: bad gateway
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/sqlalchemy/engine/base.py", line 1995, in _safe_close_cursor
#     cursor.close()
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/dbapi.py", line 618, in close
#     self.cancel()
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/dbapi.py", line 612, in cancel
#     raise trino.exceptions.OperationalError(
# trino.exceptions.OperationalError: Cancel query failed; no running query
# 2024-06-06 17:17:03,342 - ERROR - Attempt 2 failed with error: error 502: bad gateway
# 2024-06-06 17:17:08,905 - INFO - failed after 3 attempts
# 2024-06-06 17:17:08,906 - ERROR - Error closing cursor
# Traceback (most recent call last):
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/sqlalchemy/engine/base.py", line 1900, in _execute_context
#     self.dialect.do_execute(
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/sqlalchemy/dialect.py", line 365, in do_execute
#     cursor.execute(statement, parameters)
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/dbapi.py", line 482, in execute
#     self._prepare_statement(operation, statement_name)
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/dbapi.py", line 379, in _prepare_statement
#     query.execute()
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/client.py", line 807, in execute
#     status = self._request.process(response)
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/client.py", line 617, in process
#     self.raise_response_error(http_response)
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/client.py", line 600, in raise_response_error
#     raise exceptions.Http502Error("error 502: bad gateway")
# trino.exceptions.Http502Error: error 502: bad gateway
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/sqlalchemy/engine/base.py", line 1995, in _safe_close_cursor
#     cursor.close()
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/dbapi.py", line 618, in close
#     self.cancel()
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/dbapi.py", line 612, in cancel
#     raise trino.exceptions.OperationalError(
# trino.exceptions.OperationalError: Cancel query failed; no running query
# 2024-06-06 17:17:08,907 - ERROR - Attempt 3 failed with error: error 502: bad gateway
# 2024-06-06 17:17:08,907 - ERROR - Failed to insert data into table pd_co_20191017_agg5 after 3 attempts
# 2024-06-06 17:17:09,661 - INFO - failed after 3 attempts
# 2024-06-06 17:17:09,662 - ERROR - Error closing cursor
# Traceback (most recent call last):
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/sqlalchemy/engine/base.py", line 1900, in _execute_context
#     self.dialect.do_execute(
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/sqlalchemy/dialect.py", line 365, in do_execute
#     cursor.execute(statement, parameters)
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/dbapi.py", line 482, in execute
#     self._prepare_statement(operation, statement_name)
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/dbapi.py", line 379, in _prepare_statement
#     query.execute()
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/client.py", line 807, in execute
#     status = self._request.process(response)
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/client.py", line 617, in process
#     self.raise_response_error(http_response)
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/client.py", line 600, in raise_response_error
#     raise exceptions.Http502Error("error 502: bad gateway")
# trino.exceptions.Http502Error: error 502: bad gateway
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/sqlalchemy/engine/base.py", line 1995, in _safe_close_cursor
#     cursor.close()
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/dbapi.py", line 618, in close
#     self.cancel()
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/dbapi.py", line 612, in cancel
#     raise trino.exceptions.OperationalError(
# trino.exceptions.OperationalError: Cancel query failed; no running query
# 2024-06-06 17:17:09,663 - ERROR - Attempt 1 failed with error: error 502: bad gateway
# 2024-06-06 17:17:15,749 - INFO - failed after 3 attempts
# 2024-06-06 17:17:15,750 - ERROR - Error closing cursor
# Traceback (most recent call last):
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/sqlalchemy/engine/base.py", line 1900, in _execute_context
#     self.dialect.do_execute(
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/sqlalchemy/dialect.py", line 365, in do_execute
#     cursor.execute(statement, parameters)
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/dbapi.py", line 482, in execute
#     self._prepare_statement(operation, statement_name)
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/dbapi.py", line 379, in _prepare_statement
#     query.execute()
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/client.py", line 807, in execute
#     status = self._request.process(response)
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/client.py", line 617, in process
#     self.raise_response_error(http_response)
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/client.py", line 600, in raise_response_error
#     raise exceptions.Http502Error("error 502: bad gateway")
# trino.exceptions.Http502Error: error 502: bad gateway
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/sqlalchemy/engine/base.py", line 1995, in _safe_close_cursor
#     cursor.close()
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/dbapi.py", line 618, in close
#     self.cancel()
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/dbapi.py", line 612, in cancel
#     raise trino.exceptions.OperationalError(
# trino.exceptions.OperationalError: Cancel query failed; no running query
# 2024-06-06 17:17:15,752 - ERROR - Attempt 2 failed with error: error 502: bad gateway
# 2024-06-06 17:17:21,629 - INFO - failed after 3 attempts
# 2024-06-06 17:17:21,634 - ERROR - Error closing cursor
# Traceback (most recent call last):
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/sqlalchemy/engine/base.py", line 1900, in _execute_context
#     self.dialect.do_execute(
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/sqlalchemy/dialect.py", line 365, in do_execute
#     cursor.execute(statement, parameters)
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/dbapi.py", line 482, in execute
#     self._prepare_statement(operation, statement_name)
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/dbapi.py", line 379, in _prepare_statement
#     query.execute()
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/client.py", line 807, in execute
#     status = self._request.process(response)
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/client.py", line 617, in process
#     self.raise_response_error(http_response)
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/client.py", line 600, in raise_response_error
#     raise exceptions.Http502Error("error 502: bad gateway")
# trino.exceptions.Http502Error: error 502: bad gateway
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/sqlalchemy/engine/base.py", line 1995, in _safe_close_cursor
#     cursor.close()
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/dbapi.py", line 618, in close
#     self.cancel()
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/dbapi.py", line 612, in cancel
#     raise trino.exceptions.OperationalError(
# trino.exceptions.OperationalError: Cancel query failed; no running query
# 2024-06-06 17:17:21,637 - ERROR - Attempt 3 failed with error: error 502: bad gateway
# 2024-06-06 17:17:21,638 - ERROR - Failed to insert data into table pd_co_20191017_agg3 after 3 attempts

# %%
table_name_agg3 = f"pd_{country_code.lower()}_{formatted_current_date}_agg3"

filtered_data_3.to_sql(
    table_name_agg3, 
    con, 
    index=False, 
    if_exists="append", 
    method="multi"
)
# Out:
# 2024-06-06 18:33:43,066 - INFO - failed after 3 attempts
# 2024-06-06 18:33:43,067 - ERROR - Error closing cursor
# Traceback (most recent call last):
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/sqlalchemy/engine/base.py", line 1900, in _execute_context
#     self.dialect.do_execute(
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/sqlalchemy/dialect.py", line 365, in do_execute
#     cursor.execute(statement, parameters)
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/dbapi.py", line 482, in execute
#     self._prepare_statement(operation, statement_name)
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/dbapi.py", line 379, in _prepare_statement
#     query.execute()
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/client.py", line 807, in execute
#     status = self._request.process(response)
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/client.py", line 617, in process
#     self.raise_response_error(http_response)
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/client.py", line 600, in raise_response_error
#     raise exceptions.Http502Error("error 502: bad gateway")
# trino.exceptions.Http502Error: error 502: bad gateway
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/sqlalchemy/engine/base.py", line 1995, in _safe_close_cursor
#     cursor.close()
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/dbapi.py", line 618, in close
#     self.cancel()
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/dbapi.py", line 612, in cancel
#     raise trino.exceptions.OperationalError(
# trino.exceptions.OperationalError: Cancel query failed; no running query
# ---------------------------------------------------------------------------
# Http502Error                              Traceback (most recent call last)
# Cell In [21], line 3
#       1 table_name_agg3 = f"pd_{country_code.lower()}_{formatted_current_date}_agg3"
# ----> 3 filtered_data_3.to_sql(
#       4     table_name_agg3,
#       5     con,
#       6     index=False,
#       7     if_exists="append",
#       8     method="multi"
#       9 )
#
# File /srv/conda/envs/notebook/lib/python3.9/site-packages/pandas/core/generic.py:2987, in NDFrame.to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#    2830 """
#    2831 Write records stored in a DataFrame to a SQL database.
#    2832
#    (...)
#    2983 [(1,), (None,), (2,)]
#    2984 """  # noqa:E501
#    2985 from pandas.io import sql
# -> 2987 return sql.to_sql(
#    2988     self,
#    2989     name,
#    2990     con,
#    2991     schema=schema,
#    2992     if_exists=if_exists,
#    2993     index=index,
#    2994     index_label=index_label,
#    2995     chunksize=chunksize,
#    2996     dtype=dtype,
#    2997     method=method,
#    2998 )
#
# File /srv/conda/envs/notebook/lib/python3.9/site-packages/pandas/io/sql.py:695, in to_sql(frame, name, con, schema, if_exists, index, index_label, chunksize, dtype, method, engine, **engine_kwargs)
#     690 elif not isinstance(frame, DataFrame):
#     691     raise NotImplementedError(
#     692         "'frame' argument should be either a Series or a DataFrame"
#     693     )
# --> 695 return pandas_sql.to_sql(
#     696     frame,
#     697     name,
#     698     if_exists=if_exists,
#     699     index=index,
#     700     index_label=index_label,
#     701     schema=schema,
#     702     chunksize=chunksize,
#     703     dtype=dtype,
#     704     method=method,
#     705     engine=engine,
#     706     **engine_kwargs,
#     707 )
#
# File /srv/conda/envs/notebook/lib/python3.9/site-packages/pandas/io/sql.py:1728, in SQLDatabase.to_sql(self, frame, name, if_exists, index, index_label, schema, chunksize, dtype, method, engine, **engine_kwargs)
#    1678 """
#    1679 Write records stored in a DataFrame to a SQL database.
#    1680
#    (...)
#    1724     Any additional kwargs are passed to the engine.
#    1725 """
#    1726 sql_engine = get_engine(engine)
# -> 1728 table = self.prep_table(
#    1729     frame=frame,
#    1730     name=name,
#    1731     if_exists=if_exists,
#    1732     index=index,
#    1733     index_label=index_label,
#    1734     schema=schema,
#    1735     dtype=dtype,
#    1736 )
#    1738 total_inserted = sql_engine.insert_records(
#    1739     table=table,
#    1740     con=self.connectable,
#    (...)
#    1747     **engine_kwargs,
#    1748 )
#    1750 self.check_case_sensitive(name=name, schema=schema)
#
# File /srv/conda/envs/notebook/lib/python3.9/site-packages/pandas/io/sql.py:1631, in SQLDatabase.prep_table(self, frame, name, if_exists, index, index_label, schema, dtype)
#    1619             raise ValueError(f"The type of {col} is not a SQLAlchemy type")
#    1621 table = SQLTable(
#    1622     name,
#    1623     self,
#    (...)
#    1629     dtype=dtype,
#    1630 )
# -> 1631 table.create()
#    1632 return table
#
# File /srv/conda/envs/notebook/lib/python3.9/site-packages/pandas/io/sql.py:827, in SQLTable.create(self)
#     826 def create(self) -> None:
# --> 827     if self.exists():
#     828         if self.if_exists == "fail":
#     829             raise ValueError(f"Table '{self.name}' already exists.")
#
# File /srv/conda/envs/notebook/lib/python3.9/site-packages/pandas/io/sql.py:814, in SQLTable.exists(self)
#     813 def exists(self):
# --> 814     return self.pd_sql.has_table(self.name, self.schema)
#
# File /srv/conda/envs/notebook/lib/python3.9/site-packages/pandas/io/sql.py:1761, in SQLDatabase.has_table(self, name, schema)
#    1758 from sqlalchemy import inspect as sqlalchemy_inspect
#    1760 insp = sqlalchemy_inspect(self.connectable)
# -> 1761 return insp.has_table(name, schema or self.meta.schema)
#
# File /srv/conda/envs/notebook/lib/python3.9/site-packages/sqlalchemy/engine/reflection.py:283, in Inspector.has_table(self, table_name, schema)
#     281 # TODO: info_cache?
#     282 with self._operation_context() as conn:
# --> 283     return self.dialect.has_table(conn, table_name, schema)
#
# File /srv/conda/envs/notebook/lib/python3.9/site-packages/trino/sqlalchemy/dialect.py:332, in TrinoDialect.has_table(self, connection, table_name, schema, **kw)
#     323     return False
#     324 query = dedent(
#     325     """
#     326     SELECT "table_name"
#    (...)
#     330 """
#     331 ).strip()
# --> 332 res = connection.execute(sql.text(query), {"schema": schema, "table": table_name})
#     333 return res.first() is not None
#
# File /srv/conda/envs/notebook/lib/python3.9/site-packages/sqlalchemy/engine/base.py:1380, in Connection.execute(self, statement, *multiparams, **params)
#    1376     util.raise_(
#    1377         exc.ObjectNotExecutableError(statement), replace_context=err
#    1378     )
#    1379 else:
# -> 1380     return meth(self, multiparams, params, _EMPTY_EXECUTION_OPTS)
#
# File /srv/conda/envs/notebook/lib/python3.9/site-packages/sqlalchemy/sql/elements.py:334, in ClauseElement._execute_on_connection(self, connection, multiparams, params, execution_options, _force)
#     330 def _execute_on_connection(
#     331     self, connection, multiparams, params, execution_options, _force=False
#     332 ):
#     333     if _force or self.supports_execution:
# --> 334         return connection._execute_clauseelement(
#     335             self, multiparams, params, execution_options
#     336         )
#     337     else:
#     338         raise exc.ObjectNotExecutableError(self)
#
# File /srv/conda/envs/notebook/lib/python3.9/site-packages/sqlalchemy/engine/base.py:1572, in Connection._execute_clauseelement(self, elem, multiparams, params, execution_options)
#    1560 compiled_cache = execution_options.get(
#    1561     "compiled_cache", self.engine._compiled_cache
#    1562 )
#    1564 compiled_sql, extracted_params, cache_hit = elem._compile_w_cache(
#    1565     dialect=dialect,
#    1566     compiled_cache=compiled_cache,
#    (...)
#    1570     linting=self.dialect.compiler_linting | compiler.WARN_LINTING,
#    1571 )
# -> 1572 ret = self._execute_context(
#    1573     dialect,
#    1574     dialect.execution_ctx_cls._init_compiled,
#    1575     compiled_sql,
#    1576     distilled_params,
#    1577     execution_options,
#    1578     compiled_sql,
#    1579     distilled_params,
#    1580     elem,
#    1581     extracted_params,
#    1582     cache_hit=cache_hit,
#    1583 )
#    1584 if has_events:
#    1585     self.dispatch.after_execute(
#    1586         self,
#    1587         elem,
#    (...)
#    1591         ret,
#    1592     )
#
# File /srv/conda/envs/notebook/lib/python3.9/site-packages/sqlalchemy/engine/base.py:1943, in Connection._execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1940             branched.close()
#    1942 except BaseException as e:
# -> 1943     self._handle_dbapi_exception(
#    1944         e, statement, parameters, cursor, context
#    1945     )
#    1947 return result
#
# File /srv/conda/envs/notebook/lib/python3.9/site-packages/sqlalchemy/engine/base.py:2128, in Connection._handle_dbapi_exception(self, e, statement, parameters, cursor, context)
#    2124         util.raise_(
#    2125             sqlalchemy_exception, with_traceback=exc_info[2], from_=e
#    2126         )
#    2127     else:
# -> 2128         util.raise_(exc_info[1], with_traceback=exc_info[2])
#    2130 finally:
#    2131     del self._reentrant_error
#
# File /srv/conda/envs/notebook/lib/python3.9/site-packages/sqlalchemy/util/compat.py:211, in raise_(***failed resolving arguments***)
#     208     exception.__cause__ = replace_context
#     210 try:
# --> 211     raise exception
#     212 finally:
#     213     # credit to
#     214     # https://cosmicpercolator.com/2016/01/13/exception-leaks-in-python-2-and-3/
#     215     # as the __traceback__ object creates a cycle
#     216     del exception, replace_context, from_, with_traceback
#
# File /srv/conda/envs/notebook/lib/python3.9/site-packages/sqlalchemy/engine/base.py:1900, in Connection._execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1898                 break
#    1899     if not evt_handled:
# -> 1900         self.dialect.do_execute(
#    1901             cursor, statement, parameters, context
#    1902         )
#    1904 if self._has_events or self.engine._has_events:
#    1905     self.dispatch.after_cursor_execute(
#    1906         self,
#    1907         cursor,
#    (...)
#    1911         context.executemany,
#    1912     )
#
# File /srv/conda/envs/notebook/lib/python3.9/site-packages/trino/sqlalchemy/dialect.py:365, in TrinoDialect.do_execute(self, cursor, statement, parameters, context)
#     362 def do_execute(
#     363     self, cursor: Cursor, statement: str, parameters: Tuple[Any, ...], context: DefaultExecutionContext = None
#     364 ):
# --> 365     cursor.execute(statement, parameters)
#
# File /srv/conda/envs/notebook/lib/python3.9/site-packages/trino/dbapi.py:482, in Cursor.execute(self, operation, params)
#     476 assert isinstance(params, (list, tuple)), (
#     477     'params must be a list or tuple containing the query '
#     478     'parameter values'
#     479 )
#     481 statement_name = self._generate_unique_statement_name()
# --> 482 self._prepare_statement(operation, statement_name)
#     484 try:
#     485     # Send execute statement and assign the return value to `results`
#     486     # as it will be returned by the function
#     487     self._query = self._execute_prepared_statement(
#     488         statement_name, params
#     489     )
#
# File /srv/conda/envs/notebook/lib/python3.9/site-packages/trino/dbapi.py:379, in Cursor._prepare_statement(self, statement, name)
#     376 sql = f"PREPARE {name} FROM {statement}"
#     377 query = trino.client.TrinoQuery(self.connection._create_request(), query=sql,
#     378                                 legacy_primitive_types=self._legacy_primitive_types)
# --> 379 query.execute()
#
# File /srv/conda/envs/notebook/lib/python3.9/site-packages/trino/client.py:807, in TrinoQuery.execute(self, additional_http_headers)
#     804     raise exceptions.TrinoUserError("Query has been cancelled", self.query_id)
#     806 response = self._request.post(self._query, additional_http_headers)
# --> 807 status = self._request.process(response)
#     808 self._info_uri = status.info_uri
#     809 self._query_id = status.id
#
# File /srv/conda/envs/notebook/lib/python3.9/site-packages/trino/client.py:617, in TrinoRequest.process(self, http_response)
#     615 def process(self, http_response) -> TrinoStatus:
#     616     if not http_response.ok:
# --> 617         self.raise_response_error(http_response)
#     619     http_response.encoding = "utf-8"
#     620     response = http_response.json()
#
# File /srv/conda/envs/notebook/lib/python3.9/site-packages/trino/client.py:600, in TrinoRequest.raise_response_error(self, http_response)
#     598 def raise_response_error(self, http_response):
#     599     if http_response.status_code == 502:
# --> 600         raise exceptions.Http502Error("error 502: bad gateway")
#     602     if http_response.status_code == 503:
#     603         raise exceptions.Http503Error("error 503: service unavailable")
#
# Http502Error: error 502: bad gateway
