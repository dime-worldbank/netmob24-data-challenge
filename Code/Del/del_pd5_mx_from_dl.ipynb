# %%
# %reload_ext sql
# %config SqlMagic.autocommit=False
# %config SqlMagic.autolimit=0
# %config SqlMagic.autopandas=True
# %config SqlMagic.displaylimit=200

# %%
# %sql trino://localhost:9090/cuebiq/
# Out:
# 'Connected: @cuebiq/'

# %%
pip install geohash2
# Out:
# Collecting geohash2
#   Using cached geohash2-1.1-py3-none-any.whl
# Collecting docutils>=0.3
#   Using cached docutils-0.21.2-py3-none-any.whl (587 kB)
# Installing collected packages: docutils, geohash2
# Successfully installed docutils-0.21.2 geohash2-1.1
# Note: you may need to restart the kernel to use updated packages.

# %%
import gc
import os
import time
import logging
import geohash2
import pandas as pd
from sqlalchemy import create_engine
from datetime import datetime, timedelta
from trino.dbapi import connect

# %%
# SQL engine class
class TrinoEngine():
    def __init__(self):
        conn = connect(
            host="localhost",
            port=9090,
            catalog="cuebiq"
        )
        self.cur = conn.cursor()
        self.engine = create_engine("trino://localhost:9090/cuebiq/")
    
    def execute_statement(self, query:str) -> list:
        """
        Create and drop statements.
        """
        self.cur.execute(query)
        return self.cur.fetchall()
    
    def read_sql(self, query:str) -> pd.DataFrame: 
        """
        Select and insert into operations.
        """
        return pd.read_sql(query, self.engine)

    def read_sql_chunked(self, query: str, chunksize: int = 10000):
        return pd.read_sql(query, self.engine, chunksize=chunksize)

sql_engine = TrinoEngine()

# %%
# Set up logging
logging.basicConfig(level=logging.INFO, format='%(asctime)s - %(levelname)s - %(message)s')

# Database connection setup
output_schema_name = 'pop_density'
con = create_engine(f"trino://localhost:9090/dedicated/{output_schema_name}")

start_time = time.time()  # Start timing

# Define the input parameters
country_code = 'MX'
start_date = 20190101
end_date = 20190105

# Define the input schema and table name
schema_name = {'cda': 'cuebiq.paas_cda_pe_v3'}
pe_dl_table = f"{schema_name['cda']}.device_location_uplevelled"

# Convert integer dates to datetime objects
start_date_dt = datetime.strptime(str(start_date), '%Y%m%d')
end_date_dt = datetime.strptime(str(end_date), '%Y%m%d')

# Define the sorted longitude boundaries
sorted_lons = [-115.3125, -113.90625, -112.5, -111.09375, -109.6875, -108.28125, -106.875, -105.46875, -104.0625, -102.65625, -101.25, -99.84375, -98.4375, -97.03125, -95.625, -94.21875, -92.8125, -91.40625]
sorted_lats = [16.875, 18.28125, 19.6875]

# Initialize a list to store failed insertions
failed_inserts = []
# Define the buffer value
buffer_value = 20

# %%
# Function to insert data with retry mechanism
def insert_data_with_retry(df, table_name, con, retries=3, delay=5):
    for attempt in range(retries):
        try:
            df.to_sql(
                table_name, 
                con, 
                index=False, 
                if_exists="append", 
                method="multi"
            )
            logging.info(f"Inserted data into table {table_name}")
            return True
        except Exception as e:
            logging.error(f"Attempt {attempt+1} failed with error: {e}")
            if attempt < retries - 1:
                time.sleep(delay)
            else:
                logging.error(f"Failed to insert data into table {table_name} after {retries} attempts")
                return False

# %%
# Loop through each day from start_date to end_date
current_date = start_date_dt
while current_date <= end_date_dt:
    try:
        # Calculate the lookback and lookahead dates
        lookback_date = current_date - timedelta(days=1)
        lookahead_date = current_date + timedelta(days=35)
        
        # Format dates for the SQL query
        formatted_lookback_date = lookback_date.strftime('%Y%m%d')
        formatted_current_date = current_date.strftime('%Y%m%d')
        formatted_lookahead_date = lookahead_date.strftime('%Y%m%d')
        
        # Loop through each latitude range
        for j in range(len(sorted_lats) + 1):
            if j == 0:
                min_lat = 14
                max_lat = sorted_lats[j]
            elif j == len(sorted_lats):
                min_lat = sorted_lats[j - 1]
                max_lat = 32
            else:
                min_lat = sorted_lats[j - 1]
                max_lat = sorted_lats[j]
            
            # Loop through each longitude range
            for i in range(len(sorted_lons) + 1):
                if i == 0:
                    min_lon = sorted_lons[i] - buffer_value
                    max_lon = sorted_lons[i]
                elif i == len(sorted_lons):
                    min_lon = sorted_lons[i - 1]
                    max_lon = sorted_lons[i - 1] + buffer_value
                else:
                    min_lon = sorted_lons[i - 1]
                    max_lon = sorted_lons[i]
                
                # Construct the SQL query
                query = f"""
                SELECT 
                    cuebiq_id, 
                    event_zoned_datetime, 
                    processing_date,
                    lat,
                    lng
                FROM {pe_dl_table}
                WHERE 
                    processing_date BETWEEN {formatted_lookback_date} AND {formatted_lookahead_date}
                    AND country_code = '{country_code}' 
                    AND event_zoned_datetime IS NOT NULL
                    AND TRY(date_parse(substr(event_zoned_datetime, 1, 19), '%Y-%m-%dT%H:%i:%s')) IS NOT NULL
                    AND DATE(TRY(date_parse(substr(event_zoned_datetime, 1, 19), '%Y-%m-%dT%H:%i:%s'))) = date_parse('{formatted_current_date}', '%Y%m%d')
                    AND lat BETWEEN {min_lat} AND {max_lat}
                    AND lng BETWEEN {min_lon} AND {max_lon}
                """
                
                logging.info(f"Executing SQL query for date {formatted_current_date} and lat range {min_lat} to {max_lat} and lon range {min_lon} to {max_lon}")
                
                try:
                    pe_dl_table_gen = sql_engine.read_sql_chunked(query)
                    
                    # Convert the generator to a DataFrame
                    chunks = [chunk for chunk in pe_dl_table_gen]
                    if chunks:
                        pe_dl_table_df = pd.concat(chunks, ignore_index=True)
                        
                        # Calculate geohashes
                        pe_dl_table_df['geohash5'] = pe_dl_table_df.apply(lambda row: geohash2.encode(row['lat'], row['lng'], precision=5), axis=1)
                        
                        # Aggregate data for geohash5
                        aggregated_data_5 = pe_dl_table_df.groupby('geohash5').agg(
                            no_of_points=('geohash5', 'size'),
                            no_of_unique_users=('cuebiq_id', 'nunique')
                        ).reset_index()
                        
                        # Filter rows with no_of_unique_users > 10
                        filtered_data_5 = aggregated_data_5[aggregated_data_5['no_of_unique_users'] > 10].copy()
                        
                        # Add the local_date column
                        filtered_data_5.loc[:, 'local_date'] = formatted_current_date
                        
                        # Insert filtered aggregated data for geohash5 into SQL table
                        if not filtered_data_5.empty:
                            table_name_agg5 = f"pd_{country_code.lower()}_{formatted_current_date}_agg5"
                            if not insert_data_with_retry(filtered_data_5, table_name_agg5, con):
                                failed_inserts.append((formatted_current_date, min_lat, max_lat, min_lon, max_lon))
                    else:
                        logging.info(f"No data found for date {formatted_current_date}, lat range {min_lat} to {max_lat}, and lon range {min_lon} to {max_lon}")
                
                except Exception as e:
                    logging.error(f"Error while processing data for date {formatted_current_date}, lat range {min_lat} to {max_lat}, and longitude range {min_lon} to {max_lon}: {e}")
                    failed_inserts.append((formatted_current_date, min_lat, max_lat, min_lon, max_lon))
    
    except Exception as e:
        logging.error(f"Error while processing data for date {formatted_current_date}: {e}")
        failed_inserts.append((formatted_current_date, None, None, None, None))
    
    # Move to the next day
    current_date += timedelta(days=1)

# Print the failed inserts
if failed_inserts:
    print("Failed inserts:")
    for failed_insert in failed_inserts:
        print(failed_insert)

logging.info("Data extraction, aggregation, and saving completed.")
# Out:
# 2024-06-09 15:09:46,552 - INFO - Executing SQL query for date 20190101 and lat range 14 to 16.875 and lon range -135.3125 to -115.3125
# 2024-06-09 15:10:13,062 - ERROR - Error while processing data for date 20190101, lat range 14 to 16.875, and longitude range -135.3125 to -115.3125: cannot set a frame with no defined index and a scalar
# 2024-06-09 15:10:13,063 - INFO - Executing SQL query for date 20190101 and lat range 14 to 16.875 and lon range -115.3125 to -113.90625
# 2024-06-09 15:10:36,008 - ERROR - Error while processing data for date 20190101, lat range 14 to 16.875, and longitude range -115.3125 to -113.90625: cannot set a frame with no defined index and a scalar
# 2024-06-09 15:10:36,009 - INFO - Executing SQL query for date 20190101 and lat range 14 to 16.875 and lon range -113.90625 to -112.5
# 2024-06-09 15:10:59,127 - ERROR - Error while processing data for date 20190101, lat range 14 to 16.875, and longitude range -113.90625 to -112.5: cannot set a frame with no defined index and a scalar
# 2024-06-09 15:10:59,127 - INFO - Executing SQL query for date 20190101 and lat range 14 to 16.875 and lon range -112.5 to -111.09375
# 2024-06-09 15:11:21,152 - ERROR - Error while processing data for date 20190101, lat range 14 to 16.875, and longitude range -112.5 to -111.09375: cannot set a frame with no defined index and a scalar
# 2024-06-09 15:11:21,153 - INFO - Executing SQL query for date 20190101 and lat range 14 to 16.875 and lon range -111.09375 to -109.6875
# 2024-06-09 15:11:44,108 - ERROR - Error while processing data for date 20190101, lat range 14 to 16.875, and longitude range -111.09375 to -109.6875: cannot set a frame with no defined index and a scalar
# 2024-06-09 15:11:44,109 - INFO - Executing SQL query for date 20190101 and lat range 14 to 16.875 and lon range -109.6875 to -108.28125
# 2024-06-09 15:12:06,373 - ERROR - Error while processing data for date 20190101, lat range 14 to 16.875, and longitude range -109.6875 to -108.28125: cannot set a frame with no defined index and a scalar
# 2024-06-09 15:12:06,374 - INFO - Executing SQL query for date 20190101 and lat range 14 to 16.875 and lon range -108.28125 to -106.875
# 2024-06-09 15:12:28,279 - ERROR - Error while processing data for date 20190101, lat range 14 to 16.875, and longitude range -108.28125 to -106.875: cannot set a frame with no defined index and a scalar
# 2024-06-09 15:12:28,280 - INFO - Executing SQL query for date 20190101 and lat range 14 to 16.875 and lon range -106.875 to -105.46875
# 2024-06-09 15:12:49,953 - ERROR - Error while processing data for date 20190101, lat range 14 to 16.875, and longitude range -106.875 to -105.46875: cannot set a frame with no defined index and a scalar
# 2024-06-09 15:12:49,953 - INFO - Executing SQL query for date 20190101 and lat range 14 to 16.875 and lon range -105.46875 to -104.0625
# 2024-06-09 15:13:12,692 - ERROR - Error while processing data for date 20190101, lat range 14 to 16.875, and longitude range -105.46875 to -104.0625: cannot set a frame with no defined index and a scalar
# 2024-06-09 15:13:12,692 - INFO - Executing SQL query for date 20190101 and lat range 14 to 16.875 and lon range -104.0625 to -102.65625
# 2024-06-09 15:13:35,666 - ERROR - Error while processing data for date 20190101, lat range 14 to 16.875, and longitude range -104.0625 to -102.65625: cannot set a frame with no defined index and a scalar
# 2024-06-09 15:13:35,666 - INFO - Executing SQL query for date 20190101 and lat range 14 to 16.875 and lon range -102.65625 to -101.25
# 2024-06-09 15:13:59,694 - ERROR - Error while processing data for date 20190101, lat range 14 to 16.875, and longitude range -102.65625 to -101.25: cannot set a frame with no defined index and a scalar
# 2024-06-09 15:13:59,695 - INFO - Executing SQL query for date 20190101 and lat range 14 to 16.875 and lon range -101.25 to -99.84375
# 2024-06-09 15:14:33,805 - INFO - Inserted data into table pd_mx_20190101_agg5
# 2024-06-09 15:14:33,806 - INFO - Executing SQL query for date 20190101 and lat range 14 to 16.875 and lon range -99.84375 to -98.4375
# 2024-06-09 15:15:02,731 - INFO - Inserted data into table pd_mx_20190101_agg5
# 2024-06-09 15:15:02,731 - INFO - Executing SQL query for date 20190101 and lat range 14 to 16.875 and lon range -98.4375 to -97.03125
# 2024-06-09 15:15:33,158 - INFO - Inserted data into table pd_mx_20190101_agg5
# 2024-06-09 15:15:33,159 - INFO - Executing SQL query for date 20190101 and lat range 14 to 16.875 and lon range -97.03125 to -95.625
# 2024-06-09 15:15:57,895 - INFO - failed after 3 attempts
# 2024-06-09 15:15:58,351 - INFO - failed after 3 attempts
# 2024-06-09 15:15:58,352 - ERROR - Attempt 1 failed with error: error 502: bad gateway
# 2024-06-09 15:16:04,188 - INFO - failed after 3 attempts
# 2024-06-09 15:16:04,189 - ERROR - Error closing cursor
# Traceback (most recent call last):
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/sqlalchemy/engine/base.py", line 1900, in _execute_context
#     self.dialect.do_execute(
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/sqlalchemy/dialect.py", line 365, in do_execute
#     cursor.execute(statement, parameters)
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/dbapi.py", line 482, in execute
#     self._prepare_statement(operation, statement_name)
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/dbapi.py", line 379, in _prepare_statement
#     query.execute()
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/client.py", line 807, in execute
#     status = self._request.process(response)
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/client.py", line 617, in process
#     self.raise_response_error(http_response)
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/client.py", line 600, in raise_response_error
#     raise exceptions.Http502Error("error 502: bad gateway")
# trino.exceptions.Http502Error: error 502: bad gateway
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/sqlalchemy/engine/base.py", line 1995, in _safe_close_cursor
#     cursor.close()
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/dbapi.py", line 618, in close
#     self.cancel()
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/dbapi.py", line 612, in cancel
#     raise trino.exceptions.OperationalError(
# trino.exceptions.OperationalError: Cancel query failed; no running query
# 2024-06-09 15:16:04,191 - ERROR - Attempt 2 failed with error: error 502: bad gateway
# 2024-06-09 15:16:10,057 - INFO - failed after 3 attempts
# 2024-06-09 15:16:10,058 - ERROR - Error closing cursor
# Traceback (most recent call last):
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/sqlalchemy/engine/base.py", line 1900, in _execute_context
#     self.dialect.do_execute(
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/sqlalchemy/dialect.py", line 365, in do_execute
#     cursor.execute(statement, parameters)
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/dbapi.py", line 482, in execute
#     self._prepare_statement(operation, statement_name)
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/dbapi.py", line 379, in _prepare_statement
#     query.execute()
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/client.py", line 807, in execute
#     status = self._request.process(response)
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/client.py", line 617, in process
#     self.raise_response_error(http_response)
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/client.py", line 600, in raise_response_error
#     raise exceptions.Http502Error("error 502: bad gateway")
# trino.exceptions.Http502Error: error 502: bad gateway
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/sqlalchemy/engine/base.py", line 1995, in _safe_close_cursor
#     cursor.close()
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/dbapi.py", line 618, in close
#     self.cancel()
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/dbapi.py", line 612, in cancel
#     raise trino.exceptions.OperationalError(
# trino.exceptions.OperationalError: Cancel query failed; no running query
# 2024-06-09 15:16:10,058 - ERROR - Attempt 3 failed with error: error 502: bad gateway
# 2024-06-09 15:16:10,059 - ERROR - Failed to insert data into table pd_mx_20190101_agg5 after 3 attempts
# 2024-06-09 15:16:10,059 - INFO - Executing SQL query for date 20190101 and lat range 14 to 16.875 and lon range -95.625 to -94.21875
# 2024-06-09 15:16:36,774 - INFO - failed after 3 attempts
# 2024-06-09 15:16:36,774 - ERROR - Error closing cursor
# Traceback (most recent call last):
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/sqlalchemy/engine/base.py", line 1900, in _execute_context
#     self.dialect.do_execute(
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/sqlalchemy/dialect.py", line 365, in do_execute
#     cursor.execute(statement, parameters)
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/dbapi.py", line 482, in execute
#     self._prepare_statement(operation, statement_name)
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/dbapi.py", line 379, in _prepare_statement
#     query.execute()
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/client.py", line 807, in execute
#     status = self._request.process(response)
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/client.py", line 617, in process
#     self.raise_response_error(http_response)
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/client.py", line 600, in raise_response_error
#     raise exceptions.Http502Error("error 502: bad gateway")
# trino.exceptions.Http502Error: error 502: bad gateway
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/sqlalchemy/engine/base.py", line 1995, in _safe_close_cursor
#     cursor.close()
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/dbapi.py", line 618, in close
#     self.cancel()
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/dbapi.py", line 612, in cancel
#     raise trino.exceptions.OperationalError(
# trino.exceptions.OperationalError: Cancel query failed; no running query
# 2024-06-09 15:16:36,775 - ERROR - Attempt 1 failed with error: error 502: bad gateway
# 2024-06-09 15:16:42,935 - INFO - failed after 3 attempts
# 2024-06-09 15:16:42,935 - ERROR - Error closing cursor
# Traceback (most recent call last):
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/sqlalchemy/engine/base.py", line 1900, in _execute_context
#     self.dialect.do_execute(
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/sqlalchemy/dialect.py", line 365, in do_execute
#     cursor.execute(statement, parameters)
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/dbapi.py", line 482, in execute
#     self._prepare_statement(operation, statement_name)
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/dbapi.py", line 379, in _prepare_statement
#     query.execute()
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/client.py", line 807, in execute
#     status = self._request.process(response)
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/client.py", line 617, in process
#     self.raise_response_error(http_response)
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/client.py", line 600, in raise_response_error
#     raise exceptions.Http502Error("error 502: bad gateway")
# trino.exceptions.Http502Error: error 502: bad gateway
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/sqlalchemy/engine/base.py", line 1995, in _safe_close_cursor
#     cursor.close()
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/dbapi.py", line 618, in close
#     self.cancel()
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/dbapi.py", line 612, in cancel
#     raise trino.exceptions.OperationalError(
# trino.exceptions.OperationalError: Cancel query failed; no running query
# 2024-06-09 15:16:42,937 - ERROR - Attempt 2 failed with error: error 502: bad gateway
# 2024-06-09 15:16:48,568 - INFO - failed after 3 attempts
# 2024-06-09 15:16:48,569 - ERROR - Error closing cursor
# Traceback (most recent call last):
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/sqlalchemy/engine/base.py", line 1900, in _execute_context
#     self.dialect.do_execute(
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/sqlalchemy/dialect.py", line 365, in do_execute
#     cursor.execute(statement, parameters)
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/dbapi.py", line 482, in execute
#     self._prepare_statement(operation, statement_name)
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/dbapi.py", line 379, in _prepare_statement
#     query.execute()
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/client.py", line 807, in execute
#     status = self._request.process(response)
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/client.py", line 617, in process
#     self.raise_response_error(http_response)
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/client.py", line 600, in raise_response_error
#     raise exceptions.Http502Error("error 502: bad gateway")
# trino.exceptions.Http502Error: error 502: bad gateway
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/sqlalchemy/engine/base.py", line 1995, in _safe_close_cursor
#     cursor.close()
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/dbapi.py", line 618, in close
#     self.cancel()
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/dbapi.py", line 612, in cancel
#     raise trino.exceptions.OperationalError(
# trino.exceptions.OperationalError: Cancel query failed; no running query
# 2024-06-09 15:16:48,570 - ERROR - Attempt 3 failed with error: error 502: bad gateway
# 2024-06-09 15:16:48,570 - ERROR - Failed to insert data into table pd_mx_20190101_agg5 after 3 attempts
# 2024-06-09 15:16:48,571 - INFO - Executing SQL query for date 20190101 and lat range 14 to 16.875 and lon range -94.21875 to -92.8125
# 2024-06-09 15:17:15,975 - INFO - failed after 3 attempts
# 2024-06-09 15:17:15,976 - ERROR - Error closing cursor
# Traceback (most recent call last):
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/sqlalchemy/engine/base.py", line 1900, in _execute_context
#     self.dialect.do_execute(
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/sqlalchemy/dialect.py", line 365, in do_execute
#     cursor.execute(statement, parameters)
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/dbapi.py", line 482, in execute
#     self._prepare_statement(operation, statement_name)
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/dbapi.py", line 379, in _prepare_statement
#     query.execute()
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/client.py", line 807, in execute
#     status = self._request.process(response)
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/client.py", line 617, in process
#     self.raise_response_error(http_response)
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/client.py", line 600, in raise_response_error
#     raise exceptions.Http502Error("error 502: bad gateway")
# trino.exceptions.Http502Error: error 502: bad gateway
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/sqlalchemy/engine/base.py", line 1995, in _safe_close_cursor
#     cursor.close()
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/dbapi.py", line 618, in close
#     self.cancel()
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/dbapi.py", line 612, in cancel
#     raise trino.exceptions.OperationalError(
# trino.exceptions.OperationalError: Cancel query failed; no running query
# 2024-06-09 15:17:15,977 - ERROR - Attempt 1 failed with error: error 502: bad gateway
# 2024-06-09 15:17:21,592 - INFO - failed after 3 attempts
# 2024-06-09 15:17:21,592 - ERROR - Error closing cursor
# Traceback (most recent call last):
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/sqlalchemy/engine/base.py", line 1900, in _execute_context
#     self.dialect.do_execute(
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/sqlalchemy/dialect.py", line 365, in do_execute
#     cursor.execute(statement, parameters)
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/dbapi.py", line 482, in execute
#     self._prepare_statement(operation, statement_name)
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/dbapi.py", line 379, in _prepare_statement
#     query.execute()
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/client.py", line 807, in execute
#     status = self._request.process(response)
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/client.py", line 617, in process
#     self.raise_response_error(http_response)
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/client.py", line 600, in raise_response_error
#     raise exceptions.Http502Error("error 502: bad gateway")
# trino.exceptions.Http502Error: error 502: bad gateway
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/sqlalchemy/engine/base.py", line 1995, in _safe_close_cursor
#     cursor.close()
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/dbapi.py", line 618, in close
#     self.cancel()
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/dbapi.py", line 612, in cancel
#     raise trino.exceptions.OperationalError(
# trino.exceptions.OperationalError: Cancel query failed; no running query
# 2024-06-09 15:17:21,593 - ERROR - Attempt 2 failed with error: error 502: bad gateway
# 2024-06-09 15:17:27,465 - INFO - failed after 3 attempts
# 2024-06-09 15:17:27,465 - ERROR - Error closing cursor
# Traceback (most recent call last):
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/sqlalchemy/engine/base.py", line 1900, in _execute_context
#     self.dialect.do_execute(
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/sqlalchemy/dialect.py", line 365, in do_execute
#     cursor.execute(statement, parameters)
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/dbapi.py", line 482, in execute
#     self._prepare_statement(operation, statement_name)
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/dbapi.py", line 379, in _prepare_statement
#     query.execute()
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/client.py", line 807, in execute
#     status = self._request.process(response)
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/client.py", line 617, in process
#     self.raise_response_error(http_response)
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/client.py", line 600, in raise_response_error
#     raise exceptions.Http502Error("error 502: bad gateway")
# trino.exceptions.Http502Error: error 502: bad gateway
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/sqlalchemy/engine/base.py", line 1995, in _safe_close_cursor
#     cursor.close()
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/dbapi.py", line 618, in close
#     self.cancel()
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/dbapi.py", line 612, in cancel
#     raise trino.exceptions.OperationalError(
# trino.exceptions.OperationalError: Cancel query failed; no running query
# 2024-06-09 15:17:27,466 - ERROR - Attempt 3 failed with error: error 502: bad gateway
# 2024-06-09 15:17:27,467 - ERROR - Failed to insert data into table pd_mx_20190101_agg5 after 3 attempts
# 2024-06-09 15:17:27,468 - INFO - Executing SQL query for date 20190101 and lat range 14 to 16.875 and lon range -92.8125 to -91.40625
# 2024-06-09 15:17:55,153 - INFO - failed after 3 attempts
# 2024-06-09 15:17:55,154 - ERROR - Error closing cursor
# Traceback (most recent call last):
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/sqlalchemy/engine/base.py", line 1900, in _execute_context
#     self.dialect.do_execute(
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/sqlalchemy/dialect.py", line 365, in do_execute
#     cursor.execute(statement, parameters)
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/dbapi.py", line 482, in execute
#     self._prepare_statement(operation, statement_name)
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/dbapi.py", line 379, in _prepare_statement
#     query.execute()
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/client.py", line 807, in execute
#     status = self._request.process(response)
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/client.py", line 617, in process
#     self.raise_response_error(http_response)
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/client.py", line 600, in raise_response_error
#     raise exceptions.Http502Error("error 502: bad gateway")
# trino.exceptions.Http502Error: error 502: bad gateway
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/sqlalchemy/engine/base.py", line 1995, in _safe_close_cursor
#     cursor.close()
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/dbapi.py", line 618, in close
#     self.cancel()
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/dbapi.py", line 612, in cancel
#     raise trino.exceptions.OperationalError(
# trino.exceptions.OperationalError: Cancel query failed; no running query
# 2024-06-09 15:17:55,155 - ERROR - Attempt 1 failed with error: error 502: bad gateway
# 2024-06-09 15:18:01,047 - INFO - failed after 3 attempts
# 2024-06-09 15:18:01,048 - ERROR - Error closing cursor
# Traceback (most recent call last):
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/sqlalchemy/engine/base.py", line 1900, in _execute_context
#     self.dialect.do_execute(
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/sqlalchemy/dialect.py", line 365, in do_execute
#     cursor.execute(statement, parameters)
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/dbapi.py", line 482, in execute
#     self._prepare_statement(operation, statement_name)
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/dbapi.py", line 379, in _prepare_statement
#     query.execute()
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/client.py", line 807, in execute
#     status = self._request.process(response)
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/client.py", line 617, in process
#     self.raise_response_error(http_response)
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/client.py", line 600, in raise_response_error
#     raise exceptions.Http502Error("error 502: bad gateway")
# trino.exceptions.Http502Error: error 502: bad gateway
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/sqlalchemy/engine/base.py", line 1995, in _safe_close_cursor
#     cursor.close()
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/dbapi.py", line 618, in close
#     self.cancel()
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/dbapi.py", line 612, in cancel
#     raise trino.exceptions.OperationalError(
# trino.exceptions.OperationalError: Cancel query failed; no running query
# 2024-06-09 15:18:01,048 - ERROR - Attempt 2 failed with error: error 502: bad gateway
# 2024-06-09 15:18:07,005 - INFO - failed after 3 attempts
# 2024-06-09 15:18:07,006 - ERROR - Error closing cursor
# Traceback (most recent call last):
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/sqlalchemy/engine/base.py", line 1900, in _execute_context
#     self.dialect.do_execute(
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/sqlalchemy/dialect.py", line 365, in do_execute
#     cursor.execute(statement, parameters)
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/dbapi.py", line 482, in execute
#     self._prepare_statement(operation, statement_name)
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/dbapi.py", line 379, in _prepare_statement
#     query.execute()
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/client.py", line 807, in execute
#     status = self._request.process(response)
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/client.py", line 617, in process
#     self.raise_response_error(http_response)
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/client.py", line 600, in raise_response_error
#     raise exceptions.Http502Error("error 502: bad gateway")
# trino.exceptions.Http502Error: error 502: bad gateway
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/sqlalchemy/engine/base.py", line 1995, in _safe_close_cursor
#     cursor.close()
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/dbapi.py", line 618, in close
#     self.cancel()
#   File "/srv/conda/envs/notebook/lib/python3.9/site-packages/trino/dbapi.py", line 612, in cancel
#     raise trino.exceptions.OperationalError(
# trino.exceptions.OperationalError: Cancel query failed; no running query
# 2024-06-09 15:18:07,007 - ERROR - Attempt 3 failed with error: error 502: bad gateway
# 2024-06-09 15:18:07,007 - ERROR - Failed to insert data into table pd_mx_20190101_agg5 after 3 attempts
# 2024-06-09 15:18:07,007 - INFO - Executing SQL query for date 20190101 and lat range 14 to 16.875 and lon range -91.40625 to -71.40625
# 2024-06-09 15:18:29,547 - ERROR - Error while processing data for date 20190101, lat range 14 to 16.875, and longitude range -91.40625 to -71.40625: cannot set a frame with no defined index and a scalar
# 2024-06-09 15:18:29,548 - INFO - Executing SQL query for date 20190101 and lat range 16.875 to 18.28125 and lon range -135.3125 to -115.3125
# 2024-06-09 15:18:52,890 - ERROR - Error while processing data for date 20190101, lat range 16.875 to 18.28125, and longitude range -135.3125 to -115.3125: cannot set a frame with no defined index and a scalar
# 2024-06-09 15:18:52,890 - INFO - Executing SQL query for date 20190101 and lat range 16.875 to 18.28125 and lon range -115.3125 to -113.90625
# 2024-06-09 15:19:16,906 - ERROR - Error while processing data for date 20190101, lat range 16.875 to 18.28125, and longitude range -115.3125 to -113.90625: cannot set a frame with no defined index and a scalar
# 2024-06-09 15:19:16,907 - INFO - Executing SQL query for date 20190101 and lat range 16.875 to 18.28125 and lon range -113.90625 to -112.5
# 2024-06-09 15:19:39,249 - ERROR - Error while processing data for date 20190101, lat range 16.875 to 18.28125, and longitude range -113.90625 to -112.5: cannot set a frame with no defined index and a scalar
# 2024-06-09 15:19:39,249 - INFO - Executing SQL query for date 20190101 and lat range 16.875 to 18.28125 and lon range -112.5 to -111.09375
# 2024-06-09 15:20:02,086 - ERROR - Error while processing data for date 20190101, lat range 16.875 to 18.28125, and longitude range -112.5 to -111.09375: cannot set a frame with no defined index and a scalar
# 2024-06-09 15:20:02,087 - INFO - Executing SQL query for date 20190101 and lat range 16.875 to 18.28125 and lon range -111.09375 to -109.6875
# 2024-06-09 15:20:26,241 - ERROR - Error while processing data for date 20190101, lat range 16.875 to 18.28125, and longitude range -111.09375 to -109.6875: cannot set a frame with no defined index and a scalar
# 2024-06-09 15:20:26,242 - INFO - Executing SQL query for date 20190101 and lat range 16.875 to 18.28125 and lon range -109.6875 to -108.28125
# 2024-06-09 15:20:49,640 - ERROR - Error while processing data for date 20190101, lat range 16.875 to 18.28125, and longitude range -109.6875 to -108.28125: cannot set a frame with no defined index and a scalar
# 2024-06-09 15:20:49,640 - INFO - Executing SQL query for date 20190101 and lat range 16.875 to 18.28125 and lon range -108.28125 to -106.875
# 2024-06-09 15:21:11,941 - ERROR - Error while processing data for date 20190101, lat range 16.875 to 18.28125, and longitude range -108.28125 to -106.875: cannot set a frame with no defined index and a scalar
# 2024-06-09 15:21:11,942 - INFO - Executing SQL query for date 20190101 and lat range 16.875 to 18.28125 and lon range -106.875 to -105.46875
# 2024-06-09 15:21:33,805 - ERROR - Error while processing data for date 20190101, lat range 16.875 to 18.28125, and longitude range -106.875 to -105.46875: cannot set a frame with no defined index and a scalar
# 2024-06-09 15:21:33,806 - INFO - Executing SQL query for date 20190101 and lat range 16.875 to 18.28125 and lon range -105.46875 to -104.0625
# 2024-06-09 15:21:56,730 - ERROR - Error while processing data for date 20190101, lat range 16.875 to 18.28125, and longitude range -105.46875 to -104.0625: cannot set a frame with no defined index and a scalar
# 2024-06-09 15:21:56,731 - INFO - Executing SQL query for date 20190101 and lat range 16.875 to 18.28125 and lon range -104.0625 to -102.65625
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In [8], line 60
#      57 logging.info(f"Executing SQL query for date {formatted_current_date} and lat range {min_lat} to {max_lat} and lon range {min_lon} to {max_lon}")
#      59 try:
# ---> 60     pe_dl_table_gen = sql_engine.read_sql_chunked(query)
#      62     # Convert the generator to a DataFrame
#      63     chunks = [chunk for chunk in pe_dl_table_gen]
#
# Cell In [5], line 26, in TrinoEngine.read_sql_chunked(self, query, chunksize)
#      25 def read_sql_chunked(self, query: str, chunksize: int = 10000):
# ---> 26     return pd.read_sql(query, self.engine, chunksize=chunksize)
#
# File /srv/conda/envs/notebook/lib/python3.9/site-packages/pandas/io/sql.py:590, in read_sql(sql, con, index_col, coerce_float, params, parse_dates, columns, chunksize)
#     581     return pandas_sql.read_table(
#     582         sql,
#     583         index_col=index_col,
#    (...)
#     587         chunksize=chunksize,
#     588     )
#     589 else:
# --> 590     return pandas_sql.read_query(
#     591         sql,
#     592         index_col=index_col,
#     593         params=params,
#     594         coerce_float=coerce_float,
#     595         parse_dates=parse_dates,
#     596         chunksize=chunksize,
#     597     )
#
# File /srv/conda/envs/notebook/lib/python3.9/site-packages/pandas/io/sql.py:1560, in SQLDatabase.read_query(self, sql, index_col, coerce_float, parse_dates, params, chunksize, dtype)
#    1512 """
#    1513 Read SQL query into a DataFrame.
#    1514
#    (...)
#    1556
#    1557 """
#    1558 args = _convert_params(sql, params)
# -> 1560 result = self.execute(*args)
#    1561 columns = result.keys()
#    1563 if chunksize is not None:
#
# File /srv/conda/envs/notebook/lib/python3.9/site-packages/pandas/io/sql.py:1405, in SQLDatabase.execute(self, *args, **kwargs)
#    1403 def execute(self, *args, **kwargs):
#    1404     """Simple passthrough to SQLAlchemy connectable"""
# -> 1405     return self.connectable.execution_options().execute(*args, **kwargs)
#
# File <string>:2, in execute(self, statement, *multiparams, **params)
#
# File /srv/conda/envs/notebook/lib/python3.9/site-packages/sqlalchemy/util/deprecations.py:402, in _decorate_with_warning.<locals>.warned(fn, *args, **kwargs)
#     400 if not skip_warning:
#     401     _warn_with_version(message, version, wtype, stacklevel=3)
# --> 402 return fn(*args, **kwargs)
#
# File /srv/conda/envs/notebook/lib/python3.9/site-packages/sqlalchemy/engine/base.py:3257, in Engine.execute(self, statement, *multiparams, **params)
#    3239 """Executes the given construct and returns a
#    3240 :class:`_engine.CursorResult`.
#    3241
#    (...)
#    3254
#    3255 """
#    3256 connection = self.connect(close_with_result=True)
# -> 3257 return connection.execute(statement, *multiparams, **params)
#
# File /srv/conda/envs/notebook/lib/python3.9/site-packages/sqlalchemy/engine/base.py:1365, in Connection.execute(self, statement, *multiparams, **params)
#    1356 if isinstance(statement, util.string_types):
#    1357     util.warn_deprecated_20(
#    1358         "Passing a string to Connection.execute() is "
#    1359         "deprecated and will be removed in version 2.0.  Use the "
#    (...)
#    1362         "driver-level SQL string."
#    1363     )
# -> 1365     return self._exec_driver_sql(
#    1366         statement,
#    1367         multiparams,
#    1368         params,
#    1369         _EMPTY_EXECUTION_OPTS,
#    1370         future=False,
#    1371     )
#    1373 try:
#    1374     meth = statement._execute_on_connection
#
# File /srv/conda/envs/notebook/lib/python3.9/site-packages/sqlalchemy/engine/base.py:1669, in Connection._exec_driver_sql(self, statement, multiparams, params, execution_options, future)
#    1659         (
#    1660             statement,
#    1661             distilled_params,
#    (...)
#    1665             statement, distilled_parameters, execution_options
#    1666         )
#    1668 dialect = self.dialect
# -> 1669 ret = self._execute_context(
#    1670     dialect,
#    1671     dialect.execution_ctx_cls._init_statement,
#    1672     statement,
#    1673     distilled_parameters,
#    1674     execution_options,
#    1675     statement,
#    1676     distilled_parameters,
#    1677 )
#    1679 if not future:
#    1680     if self._has_events or self.engine._has_events:
#
# File /srv/conda/envs/notebook/lib/python3.9/site-packages/sqlalchemy/engine/base.py:1943, in Connection._execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1940             branched.close()
#    1942 except BaseException as e:
# -> 1943     self._handle_dbapi_exception(
#    1944         e, statement, parameters, cursor, context
#    1945     )
#    1947 return result
#
# File /srv/conda/envs/notebook/lib/python3.9/site-packages/sqlalchemy/engine/base.py:2128, in Connection._handle_dbapi_exception(self, e, statement, parameters, cursor, context)
#    2124         util.raise_(
#    2125             sqlalchemy_exception, with_traceback=exc_info[2], from_=e
#    2126         )
#    2127     else:
# -> 2128         util.raise_(exc_info[1], with_traceback=exc_info[2])
#    2130 finally:
#    2131     del self._reentrant_error
#
# File /srv/conda/envs/notebook/lib/python3.9/site-packages/sqlalchemy/util/compat.py:211, in raise_(***failed resolving arguments***)
#     208     exception.__cause__ = replace_context
#     210 try:
# --> 211     raise exception
#     212 finally:
#     213     # credit to
#     214     # https://cosmicpercolator.com/2016/01/13/exception-leaks-in-python-2-and-3/
#     215     # as the __traceback__ object creates a cycle
#     216     del exception, replace_context, from_, with_traceback
#
# File /srv/conda/envs/notebook/lib/python3.9/site-packages/sqlalchemy/engine/base.py:1900, in Connection._execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1898                 break
#    1899     if not evt_handled:
# -> 1900         self.dialect.do_execute(
#    1901             cursor, statement, parameters, context
#    1902         )
#    1904 if self._has_events or self.engine._has_events:
#    1905     self.dispatch.after_cursor_execute(
#    1906         self,
#    1907         cursor,
#    (...)
#    1911         context.executemany,
#    1912     )
#
# File /srv/conda/envs/notebook/lib/python3.9/site-packages/trino/sqlalchemy/dialect.py:365, in TrinoDialect.do_execute(self, cursor, statement, parameters, context)
#     362 def do_execute(
#     363     self, cursor: Cursor, statement: str, parameters: Tuple[Any, ...], context: DefaultExecutionContext = None
#     364 ):
# --> 365     cursor.execute(statement, parameters)
#
# File /srv/conda/envs/notebook/lib/python3.9/site-packages/trino/dbapi.py:501, in Cursor.execute(self, operation, params)
#     498 else:
#     499     self._query = trino.client.TrinoQuery(self._request, query=operation,
#     500                                           legacy_primitive_types=self._legacy_primitive_types)
# --> 501     self._iterator = iter(self._query.execute())
#     502 return self
#
# File /srv/conda/envs/notebook/lib/python3.9/site-packages/trino/client.py:821, in TrinoQuery.execute(self, additional_http_headers)
#     819 # Execute should block until at least one row is received or query is finished or cancelled
#     820 while not self.finished and not self.cancelled and len(self._result.rows) == 0:
# --> 821     self._result.rows += self.fetch()
#     822 return self._result
#
# File /srv/conda/envs/notebook/lib/python3.9/site-packages/trino/client.py:837, in TrinoQuery.fetch(self)
#     835 def fetch(self) -> List[List[Any]]:
#     836     """Continue fetching data for the current query_id"""
# --> 837     response = self._request.get(self._request.next_uri)
#     838     status = self._request.process(response)
#     839     self._update_state(status)
#
# File /srv/conda/envs/notebook/lib/python3.9/site-packages/trino/client.py:579, in TrinoRequest.get(self, url)
#     578 def get(self, url: str):
# --> 579     return self._get(
#     580         url,
#     581         headers=self.http_headers,
#     582         timeout=self._request_timeout,
#     583         proxies=PROXIES,
#     584     )
#
# File /srv/conda/envs/notebook/lib/python3.9/site-packages/trino/client.py:886, in _retry_with.<locals>.wrapper.<locals>.decorated(*args, **kwargs)
#     884 for attempt in range(1, max_attempts + 1):
#     885     try:
# --> 886         result = func(*args, **kwargs)
#     887         if any(guard(result) for guard in conditions):
#     888             handle_retry.retry(func, args, kwargs, None, attempt)
#
# File /srv/conda/envs/notebook/lib/python3.9/site-packages/requests/sessions.py:600, in Session.get(self, url, **kwargs)
#     592 r"""Sends a GET request. Returns :class:`Response` object.
#     593
#     594 :param url: URL for the new :class:`Request` object.
#     595 :param \*\*kwargs: Optional arguments that ``request`` takes.
#     596 :rtype: requests.Response
#     597 """
#     599 kwargs.setdefault("allow_redirects", True)
# --> 600 return self.request("GET", url, **kwargs)
#
# File /srv/conda/envs/notebook/lib/python3.9/site-packages/requests/sessions.py:587, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     582 send_kwargs = {
#     583     "timeout": timeout,
#     584     "allow_redirects": allow_redirects,
#     585 }
#     586 send_kwargs.update(settings)
# --> 587 resp = self.send(prep, **send_kwargs)
#     589 return resp
#
# File /srv/conda/envs/notebook/lib/python3.9/site-packages/requests/sessions.py:701, in Session.send(self, request, **kwargs)
#     698 start = preferred_clock()
#     700 # Send the request
# --> 701 r = adapter.send(request, **kwargs)
#     703 # Total elapsed time of the request (approximately)
#     704 elapsed = preferred_clock() - start
#
# File /srv/conda/envs/notebook/lib/python3.9/site-packages/requests/adapters.py:489, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     487 try:
#     488     if not chunked:
# --> 489         resp = conn.urlopen(
#     490             method=request.method,
#     491             url=url,
#     492             body=request.body,
#     493             headers=request.headers,
#     494             redirect=False,
#     495             assert_same_host=False,
#     496             preload_content=False,
#     497             decode_content=False,
#     498             retries=self.max_retries,
#     499             timeout=timeout,
#     500         )
#     502     # Send the request.
#     503     else:
#     504         if hasattr(conn, "proxy_pool"):
#
# File /srv/conda/envs/notebook/lib/python3.9/site-packages/urllib3/connectionpool.py:703, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     700     self._prepare_proxy(conn)
#     702 # Make the request on the httplib connection object.
# --> 703 httplib_response = self._make_request(
#     704     conn,
#     705     method,
#     706     url,
#     707     timeout=timeout_obj,
#     708     body=body,
#     709     headers=headers,
#     710     chunked=chunked,
#     711 )
#     713 # If we're going to release the connection in ``finally:``, then
#     714 # the response doesn't need to know about the connection. Otherwise
#     715 # it will also try to release it and we'll have a double-release
#     716 # mess.
#     717 response_conn = conn if not release_conn else None
#
# File /srv/conda/envs/notebook/lib/python3.9/site-packages/urllib3/connectionpool.py:449, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     444             httplib_response = conn.getresponse()
#     445         except BaseException as e:
#     446             # Remove the TypeError from the exception chain in
#     447             # Python 3 (including for exceptions like SystemExit).
#     448             # Otherwise it looks like a bug in the code.
# --> 449             six.raise_from(e, None)
#     450 except (SocketTimeout, BaseSSLError, SocketError) as e:
#     451     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File <string>:3, in raise_from(value, from_value)
#
# File /srv/conda/envs/notebook/lib/python3.9/site-packages/urllib3/connectionpool.py:444, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     441 except TypeError:
#     442     # Python 3
#     443     try:
# --> 444         httplib_response = conn.getresponse()
#     445     except BaseException as e:
#     446         # Remove the TypeError from the exception chain in
#     447         # Python 3 (including for exceptions like SystemExit).
#     448         # Otherwise it looks like a bug in the code.
#     449         six.raise_from(e, None)
#
# File /srv/conda/envs/notebook/lib/python3.9/http/client.py:1377, in HTTPConnection.getresponse(self)
#    1375 try:
#    1376     try:
# -> 1377         response.begin()
#    1378     except ConnectionError:
#    1379         self.close()
#
# File /srv/conda/envs/notebook/lib/python3.9/http/client.py:320, in HTTPResponse.begin(self)
#     318 # read until we get a non-100 response
#     319 while True:
# --> 320     version, status, reason = self._read_status()
#     321     if status != CONTINUE:
#     322         break
#
# File /srv/conda/envs/notebook/lib/python3.9/http/client.py:281, in HTTPResponse._read_status(self)
#     280 def _read_status(self):
# --> 281     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     282     if len(line) > _MAXLINE:
#     283         raise LineTooLong("status line")
#
# File /srv/conda/envs/notebook/lib/python3.9/socket.py:704, in SocketIO.readinto(self, b)
#     702 while True:
#     703     try:
# --> 704         return self._sock.recv_into(b)
#     705     except timeout:
#     706         self._timeout_occurred = True
#
# KeyboardInterrupt:

# %% [markdown]
# # BREAK DOWN FOR CHECKING

# %%
# # Process data for one day and one longitude range
# current_date = start_date_dt

# # Calculate the lookback and lookahead dates
# lookback_date = current_date - timedelta(days=1)
# lookahead_date = current_date + timedelta(days=35)

# # Format dates for the SQL query
# formatted_lookback_date = lookback_date.strftime('%Y%m%d')
# formatted_current_date = current_date.strftime('%Y%m%d')
# formatted_lookahead_date = lookahead_date.strftime('%Y%m%d')

# # Use the first longitude range for testing
# min_lon = sorted_lons[0]
# max_lon = sorted_lons[1]

# %%
# # Construct the SQL query
# query = f"""
# SELECT 
#     cuebiq_id, 
#     event_zoned_datetime, 
#     processing_date,
#     lat,
#     lng
# FROM {pe_dl_table}
# WHERE 
#     processing_date BETWEEN {formatted_lookback_date} AND {formatted_lookahead_date}
#     AND country_code = '{country_code}' 
#     AND event_zoned_datetime IS NOT NULL
#     AND TRY(date_parse(substr(event_zoned_datetime, 1, 19), '%Y-%m-%dT%H:%i:%s')) IS NOT NULL
#     AND DATE(TRY(date_parse(substr(event_zoned_datetime, 1, 19), '%Y-%m-%dT%H:%i:%s'))) = date_parse('{formatted_current_date}', '%Y%m%d')
#     AND lng BETWEEN {min_lon} AND {max_lon}
# """

# logging.info(f"Executing SQL query for date {formatted_current_date} and longitude range {min_lon} to {max_lon}")

# # Execute the query and fetch data in chunks
# pe_dl_table_gen = sql_engine.read_sql_chunked(query)

# # Convert the generator to a DataFrame
# chunks = [chunk for chunk in pe_dl_table_gen]
# if chunks:
#     pe_dl_table_df = pd.concat(chunks, ignore_index=True)
    
#     # Calculate geohashes
#     pe_dl_table_df['geohash3'] = pe_dl_table_df.apply(lambda row: geohash2.encode(row['lat'], row['lng'], precision=3), axis=1)
    
#     # Aggregate data for geohash3
#     aggregated_data_3 = pe_dl_table_df.groupby('geohash3').agg(
#         no_of_points=('geohash3', 'size'),
#         no_of_unique_users=('cuebiq_id', 'nunique')
#     ).reset_index()
    
#     # Filter rows with no_of_unique_users > 10
#     filtered_data_3 = aggregated_data_3[aggregated_data_3['no_of_unique_users'] > 10].copy()
    
#     # Add the local_date column
#     filtered_data_3.loc[:, 'local_date'] = formatted_current_date
    
#     # Insert filtered aggregated data for geohash3 into SQL table
#     if not filtered_data_3.empty:
#         table_name_agg3 = f"pd_{country_code.lower()}_{formatted_current_date}_agg3"
#         insert_data_with_retry(filtered_data_3, table_name_agg3, con)

# logging.info("Data processing for one day and one longitude range completed.")
# Out:
# 2024-06-08 19:40:27,978 - INFO - Executing SQL query for date 20190101 and longitude range -115.3125 to -113.90625
# 2024-06-08 19:41:10,228 - INFO - Inserted data into table pd_mx_20190101_agg3
# 2024-06-08 19:41:10,229 - INFO - Data processing for one day and one longitude range completed.

# %%
# pe_dl_table_df
# Out:
#          cuebiq_id       event_zoned_datetime  processing_date        lat  \
# 0       1343567179  2019-01-01T14:02:33-07:00         20190101  32.449442
# 1       1343567179  2019-01-01T05:06:31-07:00         20190101  32.459550
# 2       1343567179  2019-01-01T05:06:35-07:00         20190101  32.459550
# 3       1343567179  2019-01-01T12:46:02-07:00         20190101  32.459550
# 4       1343567179  2019-01-01T12:50:02-07:00         20190101  32.459550
# ...            ...                        ...              ...        ...
# 159406  1337007288  2019-01-01T18:05:30-08:00         20190116  32.403619
# 159407   888303874  2019-01-01T14:57:41-07:00         20190120  32.459543
# 159408  1350491159  2019-01-01T07:07:10-08:00         20190112  31.131851
# 159409   757754946  2019-01-01T10:26:13-07:00         20190112  32.441030
# 159410   757754946  2019-01-01T10:21:24-07:00         20190112  32.441666
#
#                lng geohash3
# 0      -114.787196      9my
# 1      -114.796062      9my
# 2      -114.796062      9my
# 3      -114.796062      9my
# 4      -114.796062      9my
# ...            ...      ...
# 159406 -115.188200      9my
# 159407 -114.723860      9my
# 159408 -114.889627      9mw
# 159409 -114.722863      9my
# 159410 -114.722319      9my
#
# [159411 rows x 6 columns]
