# %%
# %reload_ext sql
# %config SqlMagic.autocommit=False
# %config SqlMagic.autolimit=0
# %config SqlMagic.autopandas=True
# %config SqlMagic.displaylimit=200

# %%
# %sql trino://localhost:9090/cuebiq/
# Out:
# 'Connected: @cuebiq/'

# %%
pip install python-geohash
# Out:
# Collecting python-geohash
#   Using cached python_geohash-0.8.5-cp39-cp39-linux_x86_64.whl
# Installing collected packages: python-geohash
# Successfully installed python-geohash-0.8.5
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
import time
import geohash
import logging
import pandas as pd
from datetime import datetime, timedelta
from sqlalchemy import create_engine

# %%
# SQL engine
from trino.dbapi import connect 
from sqlalchemy import create_engine
import pandas as pd
import time

class TrinoEngine():
    def __init__(self):
        conn = connect(
            host="localhost",
            port=9090,
            catalog="cuebiq"
        )
        self.cur = conn.cursor()
        self.engine = create_engine("trino://localhost:9090/cuebiq/")
    
    def execute_statement(self, query:str) -> list:
        """
        Create and drop statements.
        """
        self.cur.execute(query)
        return self.cur.fetchall()
    
    def read_sql(self, query:str) -> pd.DataFrame: 
        """
        Select and insert into operations.
        """
        return pd.read_sql(query, self.engine)

sql_engine = TrinoEngine()

# %%
schema_name = {'cda': 'cuebiq.paas_cda_pe_v3'}
pe_tj_table = f"{schema_name['cda']}.trajectory_uplevelled"

# %% [markdown]
# # Export to local

# %%
# Set up logging
logging.basicConfig(level=logging.INFO, format='%(asctime)s - %(levelname)s - %(message)s')

# %%
# Function to process data for a specific date
def process_data_for_date(event_date, country_code, export_path):
    errors = []  # List to keep track of errors
    
    # Define the export file paths
    csv3_file = f"od_{country_code.lower()}6_agg3_3h.csv"
    csv5_file = f"od_{country_code.lower()}6_agg5_3h.csv"
    csv3_file_path = f"{export_path}{csv3_file}"
    csv5_file_path = f"{export_path}{csv5_file}"

    # Loop through 24 hours in increments of 3 hours
    for start_hour in range(0, 24, 3):
        end_hour = start_hour + 3  # end hour for the 3-hour interval
        logging.info(f"Querying data for date: {event_date}, hours: {start_hour}-{end_hour}")

        try:
            # Fetch the data for the specified event date and country code
            pe_tj_df3 = sql_engine.read_sql(
                f"""
                SELECT 
                    cuebiq_id,
                    duration_minutes,
                    length_meters,
                    number_of_points,
                    TRY(date_parse(substr(start_zoned_datetime, 1, 19), '%Y-%m-%dT%H:%i:%s')) AS event_datetime_local,
                    EXTRACT(HOUR FROM TRY(date_parse(substr(start_zoned_datetime, 1, 19), '%Y-%m-%dT%H:%i:%s'))) AS event_hour,
                    geohash_encode(start_lat, start_lng, 5) AS start_geohash5,
                    geohash_encode(start_lat, start_lng, 3) AS start_geohash3,
                    geohash_encode(end_lat, end_lng, 5) AS end_geohash5,
                    geohash_encode(end_lat, end_lng, 3) AS end_geohash3,
                    DATE_FORMAT(date_parse(substr(start_zoned_datetime, 1, 10), '%Y-%m-%d'), '%Y%m%d') AS local_date
                FROM cuebiq.paas_cda_pe_v3.trajectory_uplevelled
                WHERE 
                    event_date = {event_date}
                    AND end_country = '{country_code}' 
                    AND start_country = '{country_code}' 
                """
            )

            # Filter the DataFrame for the current 3-hour interval
            logging.info(f"Processing data for date: {event_date}, hours: {start_hour}-{end_hour}")
            filtered_df = pe_tj_df3[(pe_tj_df3['event_hour'] >= start_hour) & (pe_tj_df3['event_hour'] < end_hour)]

            # Add user numbers to the aggregated data for geohash3
            aggregated_df3 = filtered_df.groupby(['start_geohash3', 'end_geohash3', 'local_date']).agg({
                'cuebiq_id': 'count',
                'duration_minutes': ['mean', 'median', 'std'],
                'length_meters': ['mean', 'median', 'std'],
                'number_of_points': ['mean', 'median', 'std']
            }).reset_index()

            # Flatten the MultiIndex columns
            aggregated_df3.columns = ['start_geohash3', 'end_geohash3', 'local_date', 'trip_count', 
                                      'm_duration_min', 'mdn_duration_min', 'sd_duration_min', 
                                      'm_length_m', 'mdn_length_m', 'sd_length_m',
                                      'm_points_no', 'mdn_points_no', 'sd_points_no']

            # Add the local_time column
            aggregated_df3['local_time'] = aggregated_df3['local_date'].astype(str) + \
                                           f" {start_hour:02d}:00:00 - {end_hour:02d}:00:00"

            # Filter out rows where trip_count is less than or equal to 9
            aggregated_df3 = aggregated_df3[aggregated_df3['trip_count'] > 9]

            # Append the results to the CSV file for geohash3
            logging.info(f"Exporting aggregated data (geohash3) for date: {event_date}, hours: {start_hour}-{end_hour}")
            if not os.path.isfile(csv3_file_path):
                aggregated_df3.to_csv(csv3_file_path, index=False)
            else:
                aggregated_df3.to_csv(csv3_file_path, mode='a', header=False, index=False)

            # Add user numbers to the aggregated data for geohash5
            aggregated_df5 = filtered_df.groupby(['start_geohash5', 'end_geohash5', 'local_date']).agg({
                'cuebiq_id': 'count',
                'duration_minutes': ['mean', 'median', 'std'],
                'length_meters': ['mean', 'median', 'std'],
                'number_of_points': ['mean', 'median', 'std']
            }).reset_index()

            # Flatten the MultiIndex columns
            aggregated_df5.columns = ['start_geohash5', 'end_geohash5', 'local_date', 'trip_count', 
                                      'm_duration_min', 'mdn_duration_min', 'sd_duration_min', 
                                      'm_length_m', 'mdn_length_m', 'sd_length_m',
                                      'm_points_no', 'mdn_points_no', 'sd_points_no']

            # Add the local_time column
            aggregated_df5['local_time'] = aggregated_df5['local_date'].astype(str) + \
                                           f" {start_hour:02d}:00:00 - {end_hour:02d}:00:00"

            # Filter out rows where trip_count is less than or equal to 9
            aggregated_df5 = aggregated_df5[aggregated_df5['trip_count'] > 9]

            # Append the results to the CSV file for geohash5
            logging.info(f"Exporting aggregated data (geohash5) for date: {event_date}, hours: {start_hour}-{end_hour}")
            if not os.path.isfile(csv5_file_path):
                aggregated_df5.to_csv(csv5_file_path, index=False)
            else:
                aggregated_df5.to_csv(csv5_file_path, mode='a', header=False, index=False)
        
        except Exception as e:
            error_message = f"Error processing date: {event_date}, hours: {start_hour}-{end_hour} - {str(e)}"
            logging.error(error_message)
            errors.append(error_message)
    
    return errors

# Function to process data for a range of dates
def process_data_for_date_range(start_date, end_date, country_code, export_path):
    current_date = start_date
    all_errors = []
    while current_date <= end_date:
        event_date = current_date.strftime("%Y%m%d")
        logging.info(f"Processing data for date: {event_date}")
        errors = process_data_for_date(event_date, country_code, export_path)
        all_errors.extend(errors)
        current_date += timedelta(days=1)
    
    # Log any errors that occurred
    if all_errors:
        logging.info("Errors occurred during processing:")
        for error in all_errors:
            logging.info(error)

# %%
# Specify the date range
start_date = datetime.strptime("20191001", "%Y%m%d")
end_date = datetime.strptime("20191031", "%Y%m%d")
country_code = 'ID'
export_path = '/home/jovyan/Data/TJ/3h/'


# Process data for the specified date range
process_data_for_date_range(start_date, end_date, country_code, export_path)
# Out:
# 2024-07-03 06:14:19,858 - INFO - Processing data for date: 20191001
# 2024-07-03 06:14:19,859 - INFO - Querying data for date: 20191001, hours: 0-3
# 2024-07-03 06:14:41,274 - INFO - Processing data for date: 20191001, hours: 0-3
# 2024-07-03 06:14:41,288 - INFO - Exporting aggregated data (geohash3) for date: 20191001, hours: 0-3
# 2024-07-03 06:14:41,308 - INFO - Exporting aggregated data (geohash5) for date: 20191001, hours: 0-3
# 2024-07-03 06:14:41,319 - INFO - Querying data for date: 20191001, hours: 3-6
# 2024-07-03 06:14:56,005 - INFO - Processing data for date: 20191001, hours: 3-6
# 2024-07-03 06:14:56,026 - INFO - Exporting aggregated data (geohash3) for date: 20191001, hours: 3-6
# 2024-07-03 06:14:56,051 - INFO - Exporting aggregated data (geohash5) for date: 20191001, hours: 3-6
# 2024-07-03 06:14:56,061 - INFO - Querying data for date: 20191001, hours: 6-9
# 2024-07-03 06:15:10,436 - INFO - Processing data for date: 20191001, hours: 6-9
# 2024-07-03 06:15:10,475 - INFO - Exporting aggregated data (geohash3) for date: 20191001, hours: 6-9
# 2024-07-03 06:15:10,521 - INFO - Exporting aggregated data (geohash5) for date: 20191001, hours: 6-9
# 2024-07-03 06:15:10,552 - INFO - Querying data for date: 20191001, hours: 9-12
# 2024-07-03 06:15:25,957 - INFO - Processing data for date: 20191001, hours: 9-12
# 2024-07-03 06:15:26,016 - INFO - Exporting aggregated data (geohash3) for date: 20191001, hours: 9-12
# 2024-07-03 06:15:26,079 - INFO - Exporting aggregated data (geohash5) for date: 20191001, hours: 9-12
# 2024-07-03 06:15:26,109 - INFO - Querying data for date: 20191001, hours: 12-15
# 2024-07-03 06:15:39,574 - INFO - Processing data for date: 20191001, hours: 12-15
# 2024-07-03 06:15:39,636 - INFO - Exporting aggregated data (geohash3) for date: 20191001, hours: 12-15
# 2024-07-03 06:15:39,696 - INFO - Exporting aggregated data (geohash5) for date: 20191001, hours: 12-15
# 2024-07-03 06:15:39,723 - INFO - Querying data for date: 20191001, hours: 15-18
# 2024-07-03 06:15:54,385 - INFO - Processing data for date: 20191001, hours: 15-18
# 2024-07-03 06:15:54,448 - INFO - Exporting aggregated data (geohash3) for date: 20191001, hours: 15-18
# 2024-07-03 06:15:54,526 - INFO - Exporting aggregated data (geohash5) for date: 20191001, hours: 15-18
# 2024-07-03 06:15:54,558 - INFO - Querying data for date: 20191001, hours: 18-21
# 2024-07-03 06:16:08,426 - INFO - Processing data for date: 20191001, hours: 18-21
# 2024-07-03 06:16:08,478 - INFO - Exporting aggregated data (geohash3) for date: 20191001, hours: 18-21
# 2024-07-03 06:16:08,534 - INFO - Exporting aggregated data (geohash5) for date: 20191001, hours: 18-21
# 2024-07-03 06:16:08,555 - INFO - Querying data for date: 20191001, hours: 21-24
# 2024-07-03 06:16:22,987 - INFO - Processing data for date: 20191001, hours: 21-24
# 2024-07-03 06:16:23,020 - INFO - Exporting aggregated data (geohash3) for date: 20191001, hours: 21-24
# 2024-07-03 06:16:23,052 - INFO - Exporting aggregated data (geohash5) for date: 20191001, hours: 21-24
# 2024-07-03 06:16:23,126 - INFO - Processing data for date: 20191002
# 2024-07-03 06:16:23,126 - INFO - Querying data for date: 20191002, hours: 0-3
# 2024-07-03 06:16:47,648 - INFO - Processing data for date: 20191002, hours: 0-3
# 2024-07-03 06:16:47,661 - INFO - Exporting aggregated data (geohash3) for date: 20191002, hours: 0-3
# 2024-07-03 06:16:47,680 - INFO - Exporting aggregated data (geohash5) for date: 20191002, hours:
- INFO - Exporting aggregated data (geohash5) for date: 20191012, hours: 18-21
# 2024-07-03 06:57:19,692 - INFO - Querying data for date: 20191012, hours: 21-24
# 2024-07-03 06:57:57,661 - INFO - Processing data for date: 20191012, hours: 21-24
# 2024-07-03 06:57:57,700 - INFO - Exporting aggregated data (geohash3) for date: 20191012, hours: 21-24
# 2024-07-03 06:57:57,739 - INFO - Exporting aggregated data (geohash5) for date: 20191012, hours: 21-24
# 2024-07-03 06:57:57,821 - INFO - Processing data for date: 20191013
# 2024-07-03 06:57:57,822 - INFO - Querying data for date: 20191013, hours: 0-3
# 2024-07-03 06:58:21,692 - INFO - Processing data for date: 20191013, hours: 0-3
# 2024-07-03 06:58:21,704 - INFO - Exporting aggregated data (geohash3) for date: 20191013, hours: 0-3
# 2024-07-03 06:58:21,773 - INFO - Exporting aggregated data (geohash5) for date: 20191013, hours: 0-3
# 2024-07-03 06:58:21,784 - INFO - Querying data for date: 20191013, hours: 3-6
# 2024-07-03 06:58:47,715 - INFO - Processing data for date: 20191013, hours: 3-6
# 2024-07-03 06:58:47,770 - INFO - Exporting aggregated data (geohash3) for date: 20191013, hours: 3-6
# 2024-07-03 06:58:47,805 - INFO - Exporting aggregated data (geohash5) for date: 20191013, hours: 3-6
# 2024-07-03 06:58:47,819 - INFO - Querying data for date: 20191013, hours: 6-9
# 2024-07-03 06:59:22,601 - INFO - Processing data for date: 20191013, hours: 6-9
# 2024-07-03 06:59:22,772 - INFO - Exporting aggregated data (geohash3) for date: 20191013, hours: 6-9
# 2024-07-03 06:59:22,873 - INFO - Exporting aggregated data (geohash5) for date: 20191013, hours: 6-9
# 2024-07-03 06:59:22,898 - INFO - Querying data for date: 20191013, hours: 9-12
# 2024-07-03 06:59:39,025 - INFO - Processing data for date: 20191013, hours: 9-12
# 2024-07-03 06:59:39,121 - INFO - Exporting aggregated data (geohash3) for date: 20191013, hours: 9-12
# 2024-07-03 06:59:39,231 - INFO - Exporting aggregated data (geohash5) for date: 20191013, hours: 9-12
# 2024-07-03 06:59:39,261 - INFO - Querying data for date: 20191013, hours: 12-15
# 2024-07-03 07:00:12,742 - INFO - Processing data for date: 20191013, hours: 12-15
# 2024-07-03 07:00:12,795 - INFO - Exporting aggregated data (geohash3) for date: 20191013, hours: 12-15
# 2024-07-03 07:00:12,859 - INFO - Exporting aggregated data (geohash5) for date: 20191013, hours: 12-15
# 2024-07-03 07:00:12,884 - INFO - Querying data for date: 20191013, hours: 15-18
# 2024-07-03 07:00:50,330 - INFO - Processing data for date: 20191013, hours: 15-18
# 2024-07-03 07:00:50,384 - INFO - Exporting aggregated data (geohash3) for date: 20191013, hours: 15-18
# 2024-07-03 07:00:50,440 - INFO - Exporting aggregated data (geohash5) for date: 20191013, hours: 15-18
# 2024-07-03 07:00:50,465 - INFO - Querying data for date: 20191013, hours: 18-21
# 2024-07-03 07:01:38,017 - INFO - Processing data for date: 20191013, hours: 18-21
# 2024-07-03 07:01:38,066 - INFO - Exporting aggregated data (geohash3) for date: 20191013, hours: 18-21
# 2024-07-03 07:01:38,125 - INFO - Exporting aggregated data (geohash5) for date: 20191013, hours: 18-21
# 2024-07-03 07:01:38,149 - INFO - Querying data for date: 20191013, hours: 21-24
# 2024-07-03 07:02:12,909 - INFO - Processing data for date: 20191013, hours: 21-24
# 2024-07-03 07:02:12,956 - INFO - Exporting aggregated data (geohash3) for date: 20191013, hours: 21-24
# 2024-07-03 07:02:12,993 - INFO - Exporting aggregated data (geohash5) for date: 20191013, hours: 21-24
# 2024-07-03 07:02:13,061 - INFO - Processing data for date: 20191014
# 2024-07-03 07:02:13,062 - INFO - Querying data for date: 20191014, hours: 0-3
# 2024-07-03 07:03:31,527 - INFO - Processing data for date: 20191014, hours: 0-3
# 2024-07-03 07:03:31,538 - INFO - Exporting aggregated data (geohash3) for date: 20191014, hours: 0-3
# 2024-07-03 07:03:31,559 - INFO - Exporting aggregated data (geohash5) for date: 20191014, hours: 0-3
# 2024-07-03 07:03:31,570 - INFO - Querying data for date: 20191014, hours: 3-6
# 2024-07-03 07:04:17,336 - INFO - Processing data for date: 20191014, hours: 3-6
# 2024-07-03 07:04:17,357 - INFO - Exporting aggregated data (geohash3) for date: 20191014, hours: 3-6
# 2024-07-03 07:04:17,389 - INFO - Exporting aggregated data (geohash5) for date: 20191014, hours: 3-6
# 2024-07-03 07:04:17,405 - INFO - Querying data for date: 20191014, hours: 6-9
# 2024-07-03 07:04:36,983 - INFO - Processing data for date: 20191014, hours: 6-9
# 2024-07-03 07:04:37,034 - INFO - Exporting aggregated data (geohash3) for date: 20191014, hours: 6-9
# 2024-07-03 07:04:37,103 - INFO - Exporting aggregated data (geohash5) for date: 20191014, hours: 6-9
# 2024-07-03 07:04:37,124 - INFO - Querying data for date: 20191014, hours: 9-12
# 2024-07-03 07:04:59,974 - INFO - Processing data for date: 20191014, hours: 9-12
# 2024-07-03 07:05:00,111 - INFO - Exporting aggregated data (geohash3) for date: 20191014, hours: 9-12
# 2024-07-03 07:05:00,310 - INFO - Exporting aggregated data (geohash5) for date: 20191014, hours: 9-12
# 2024-07-03 07:05:00,398 - INFO - Querying data for date: 20191014, hours: 12-15
# 2024-07-03 07:05:19,831 - INFO - Processing data for date: 20191014, hours: 12-15
# 2024-07-03 07:05:19,942 - INFO - Exporting aggregated data (geohash3) for date: 20191014, hours: 12-15
# 2024-07-03 07:05:20,032 - INFO - Exporting aggregated data (geohash5) for date: 20191014, hours: 12-15
# 2024-07-03 07:05:20,080 - INFO - Querying data for date: 20191014, hours: 15-18
# 2024-07-03 07:05:41,804 - INFO - Processing data for date: 20191014, hours: 15-18
# 2024-07-03 07:05:41,976 - INFO - Exporting aggregated data (geohash3) for date: 20191014, hours: 15-18
# 2024-07-03 07:05:42,109 - INFO - Exporting aggregated data (geohash5) for date: 20191014, hours: 15-18
# 2024-07-03 07:05:42,146 - INFO - Querying data for date: 20191014, hours: 18-21
# 2024-07-03 07:06:22,688 - INFO - Processing data for date: 20191014, hours: 18-21
# 2024-07-03 07:06:22,788 - INFO - Exporting aggregated data (geohash3) for date: 20191014, hours: 18-21
# 2024-07-03 07:06:22,915 - INFO - Exporting aggregated data (geohash5) for date: 20191014, hours: 18-21
# 2024-07-03 07:06:22,982 - INFO - Querying data for date: 20191014, hours: 21-24
# 2024-07-03 07:06:40,824 - INFO - Processing data for date: 20191014, hours: 21-24
# 2024-07-03 07:06:40,860 - INFO - Exporting aggregated data (geohash3) for date: 20191014, hours: 21-24
# 2024-07-03 07:06:40,898 - INFO - Exporting aggregated data (geohash5) for date: 20191014, hours: 21-24
# 2024-07-03 07:06:40,980 - INFO - Processing data for date: 20191015
# 2024-07-03 07:06:40,981 - INFO - Querying data for date: 20191015, hours: 0-3
# 2024-07-03 07:07:55,338 - INFO - Processing data for date: 20191015, hours: 0-3
# 2024-07-03 07:07:55,350 - INFO - Exporting aggregated data (geohash3) for date: 20191015, hours: 0-3
# 2024-07-03 07:07:55,370 - INFO - Exporting aggregated data (geohash5) for date: 20191015, hours: 0-3
# 2024-07-03 07:07:55,382 - INFO - Querying data for date: 20191015, hours: 3-6
# 2024-07-03 07:09:04,423 - INFO - Processing data for date: 20191015, hours: 3-6
# 2024-07-03 07:09:04,445 - INFO - Exporting aggregated data (geohash3) for date: 20191015, hours: 3-6
# 2024-07-03 07:09:04,478 - INFO - Exporting aggregated data (geohash5) for date: 20191015, hours: 3-6
# 2024-07-03 07:09:04,492 - INFO - Querying data for date: 20191015, hours: 6-9
# 2024-07-03 07:10:02,321 - INFO - Processing data for date: 20191015, hours: 6-9
# 2024-07-03 07:10:02,409 - INFO - Exporting aggregated data (geohash3) for date: 20191015, hours: 6-9
# 2024-07-03 07:10:02,482 - INFO - Exporting aggregated data (geohash5) for date: 20191015, hours: 6-9
# 2024-07-03 07:10:02,507 - INFO - Querying data for date: 20191015, hours: 9-12
# 2024-07-03 07:11:03,381 - INFO - Processing data for date: 20191015, hours: 9-12
# 2024-07-03 07:11:03,683 - INFO - Exporting aggregated data (geohash3) for date: 20191015, hours: 9-12
# 2024-07-03 07:11:03,869 - INFO - Exporting aggregated data (geohash5) for date: 20191015, hours: 9-12
# 2024-07-03 07:11:03,906 - INFO - Querying data for date: 20191015, hours: 12-15
# 2024-07-03 07:11:21,704 - INFO - Processing data for date: 20191015, hours: 12-15
# 2024-07-03 07:11:21,802 - INFO - Exporting aggregated data (geohash3) for date: 20191015, hours: 12-15
# 2024-07-03 07:11:21,877 - INFO - Exporting aggregated data (geohash5) for date: 20191015, hours: 12-15
# 2024-07-03 07:11:21,905 - INFO - Querying data for date: 20191015, hours: 15-18
# 2024-07-03 07:12:03,496 - INFO - Processing data for date: 20191015, hours: 15-18
# 2024-07-03 07:12:03,696 - INFO - Exporting aggregated data (geohash3) for date: 20191015, hours: 15-18
# 2024-07-03 07:12:03,884 - INFO - Exporting aggregated data (geohash5) for date: 20191015, hours: 15-18
# 2024-07-03 07:12:03,978 - INFO - Querying data for date: 20191015, hours: 18-21
# 2024-07-03 07:12:22,598 - INFO - Processing data for date: 20191015, hours: 18-21
# 2024-07-03 07:12:22,685 - INFO - Exporting aggregated data (geohash3) for date: 20191015, hours: 18-21
# 2024-07-03 07:12:22,787 - INFO - Exporting aggregated data (geohash5) for date: 20191015, hours: 18-21
# 2024-07-03 07:12:22,820 - INFO - Querying data for date: 20191015, hours: 21-24
# 2024-07-03 07:13:03,615 - INFO - Processing data for date: 20191015, hours: 21-24
# 2024-07-03 07:13:03,650 - INFO - Exporting aggregated data (geohash3) for date: 20191015, hours: 21-24
# 2024-07-03 07:13:03,683 - INFO - Exporting aggregated data (geohash5) for date: 20191015, hours: 21-24
# 2024-07-03 07:13:03,769 - INFO - Processing data for date: 20191016
# 2024-07-03 07:13:03,770 - INFO - Querying data for date: 20191016, hours: 0-3
# 2024-07-03 07:14:03,760 - INFO - Processing data for date: 20191016, hours: 0-3
# 2024-07-03 07:14:03,772 - INFO - Exporting aggregated data (geohash3) for date: 20191016, hours: 0-3
# 2024-07-03 07:14:03,797 - INFO - Exporting aggregated data (geohash5) for date: 20191016, hours: 0-3
# 2024-07-03 07:14:03,808 - INFO - Querying data for date: 20191016, hours: 3-6
# 2024-07-03 07:15:10,697 - INFO - Processing data for date: 20191016, hours: 3-6
# 2024-07-03 07:15:10,719 - INFO - Exporting aggregated data (geohash3) for date: 20191016, hours: 3-6
# 2024-07-03 07:15:10,750 - INFO - Exporting aggregated data (geohash5) for date: 20191016, hours: 3-6
# 2024-07-03 07:15:10,765 - INFO - Querying data for date: 20191016, hours: 6-9
# 2024-07-03 07:16:15,387 - INFO - Processing data for date: 20191016, hours: 6-9
# 2024-07-03 07:16:15,493 - INFO - Exporting aggregated data (geohash3) for date: 20191016, hours: 6-9
# 2024-07-03 07:16:15,602 - INFO - Exporting aggregated data (geohash5) for date: 20191016, hours: 6-9
# 2024-07-03 07:16:15,663 - INFO - Querying data for date: 20191016, hours: 9-12
# 2024-07-03 07:16:54,147 - INFO - Processing data for date: 20191016, hours: 9-12
# 2024-07-03 07:16:54,224 - INFO - Exporting aggregated data (geohash3) for date: 20191016, hours: 9-12
# 2024-07-03 07:16:54,293 - INFO - Exporting aggregated data (geohash5) for date: 20191016, hours: 9-12
# 2024-07-03 07:16:54,321 - INFO - Querying data for date: 20191016, hours: 12-15
# 2024-07-03 07:17:30,016 - INFO - Processing data for date: 20191016, hours: 12-15
# 2024-07-03 07:17:30,126 - INFO - Exporting aggregated data (geohash3) for date: 20191016, hours: 12-15
# 2024-07-03 07:17:30,283 - INFO - Exporting aggregated data (geohash5) for date: 20191016, hours: 12-15
# 2024-07-03 07:17:30,320 - INFO - Querying data for date: 20191016, hours: 15-18
# 2024-07-03 07:17:50,203 - INFO - Processing data for date: 20191016, hours: 15-18
# 2024-07-03 07:17:50,381 - INFO - Exporting aggregated data (geohash3) for date: 20191016, hours: 15-18
# 2024-07-03 07:17:50,669 - INFO - Exporting aggregated data (geohash5) for date: 20191016, hours: 15-18
# 2024-07-03 07:17:50,709 - INFO - Querying data for date: 20191016, hours: 18-21
# 2024-07-03 07:18:09,767 - INFO - Processing data for date: 20191016, hours: 18-21
# 2024-07-03 07:18:09,868 - INFO - Exporting aggregated data (geohash3) for date: 20191016, hours: 18-21
# 2024-07-03 07:18:09,979 - INFO - Exporting aggregated data (geohash5) for date: 20191016, hours: 18-21
# 2024-07-03 07:18:10,001 - INFO - Querying data for date: 20191016, hours: 21-24
# 2024-07-03 07:18:29,367 - INFO - Processing data for date: 20191016, hours: 21-24
# 2024-07-03 07:18:29,405 - INFO - Exporting aggregated data (geohash3) for date: 20191016, hours: 21-24
# 2024-07-03 07:18:29,441 - INFO - Exporting aggregated data (geohash5) for date: 20191016, hours: 21-24
# 2024-07-03 07:18:29,526 - INFO - Processing data for date: 20191017
# 2024-07-03 07:18:29,527 - INFO - Querying data for date: 20191017, hours: 0-3
# 2024-07-03 07:19:37,591 - INFO - Processing data for date: 20191017, hours: 0-3
# ...
# 2024-07-03 07:50:25,240 - INFO - Exporting aggregated data (geohash5) for date: 20191026, hours: 15-18
# 2024-07-03 07:50:25,264 - INFO - Querying data for date: 20191026, hours: 18-21
# 2024-07-03 07:50:53,141 - INFO - Processing data for date: 20191026, hours: 18-21
# 2024-07-03 07:50:53,190 - INFO - Exporting aggregated data (geohash3) for date: 20191026, hours: 18-21
# 2024-07-03 07:50:53,238 - INFO - Exporting aggregated data (geohash5) for date: 20191026, hours: 18-21
# 2024-07-03 07:50:53,259 - INFO - Querying data for date: 20191026, hours: 21-24
# 2024-07-03 07:51:16,149 - INFO - Processing data for date: 20191026, hours: 21-24
# 2024-07-03 07:51:16,182 - INFO - Exporting aggregated data (geohash3) for date: 20191026, hours: 21-24
# 2024-07-03 07:51:16,218 - INFO - Exporting aggregated data (geohash5) for date: 20191026, hours: 21-24
# 2024-07-03 07:51:16,286 - INFO - Processing data for date: 20191027
# 2024-07-03 07:51:16,287 - INFO - Querying data for date: 20191027, hours: 0-3
# 2024-07-03 07:52:00,063 - INFO - Processing data for date: 20191027, hours: 0-3
# 2024-07-03 07:52:00,075 - INFO - Exporting aggregated data (geohash3) for date: 20191027, hours: 0-3
# 2024-07-03 07:52:00,096 - INFO - Exporting aggregated data (geohash5) for date: 20191027, hours: 0-3
# 2024-07-03 07:52:00,106 - INFO - Querying data for date: 20191027, hours: 3-6
# 2024-07-03 07:52:24,903 - INFO - Processing data for date: 20191027, hours: 3-6
# 2024-07-03 07:52:24,921 - INFO - Exporting aggregated data (geohash3) for date: 20191027, hours: 3-6
# 2024-07-03 07:52:24,979 - INFO - Exporting aggregated data (geohash5) for date: 20191027, hours: 3-6
# 2024-07-03 07:52:24,993 - INFO - Querying data for date: 20191027, hours: 6-9
# 2024-07-03 07:52:42,728 - INFO - Processing data for date: 20191027, hours: 6-9
# 2024-07-03 07:52:42,762 - INFO - Exporting aggregated data (geohash3) for date: 20191027, hours: 6-9
# 2024-07-03 07:52:42,808 - INFO - Exporting aggregated data (geohash5) for date: 20191027, hours: 6-9
# 2024-07-03 07:52:42,826 - INFO - Querying data for date: 20191027, hours: 9-12
# 2024-07-03 07:52:56,847 - INFO - Processing data for date: 20191027, hours: 9-12
# 2024-07-03 07:52:56,968 - INFO - Exporting aggregated data (geohash3) for date: 20191027, hours: 9-12
# 2024-07-03 07:52:57,080 - INFO - Exporting aggregated data (geohash5) for date: 20191027, hours: 9-12
# 2024-07-03 07:52:57,103 - INFO - Querying data for date: 20191027, hours: 12-15
# 2024-07-03 07:53:11,836 - INFO - Processing data for date: 20191027, hours: 12-15
# 2024-07-03 07:53:11,887 - INFO - Exporting aggregated data (geohash3) for date: 20191027, hours: 12-15
# 2024-07-03 07:53:11,948 - INFO - Exporting aggregated data (geohash5) for date: 20191027, hours: 12-15
# 2024-07-03 07:53:11,968 - INFO - Querying data for date: 20191027, hours: 15-18
# 2024-07-03 07:53:41,583 - INFO - Processing data for date: 20191027, hours: 15-18
# 2024-07-03 07:53:41,631 - INFO - Exporting aggregated data (geohash3) for date: 20191027, hours: 15-18
# 2024-07-03 07:53:41,696 - INFO - Exporting aggregated data (geohash5) for date: 20191027, hours: 15-18
# 2024-07-03 07:53:41,715 - INFO - Querying data for date: 20191027, hours: 18-21
# 2024-07-03 07:54:05,050 - INFO - Processing data for date: 20191027, hours: 18-21
# 2024-07-03 07:54:05,094 - INFO - Exporting aggregated data (geohash3) for date: 20191027, hours: 18-21
# 2024-07-03 07:54:05,143 - INFO - Exporting aggregated data (geohash5) for date: 20191027, hours: 18-21
# 2024-07-03 07:54:05,163 - INFO - Querying data for date: 20191027, hours: 21-24
# 2024-07-03 07:54:34,981 - INFO - Processing data for date: 20191027, hours: 21-24
# 2024-07-03 07:54:35,009 - INFO - Exporting aggregated data (geohash3) for date: 20191027, hours: 21-24
# 2024-07-03 07:54:35,039 - INFO - Exporting aggregated data (geohash5) for date: 20191027, hours: 21-24
# 2024-07-03 07:54:35,099 - INFO - Processing data for date: 20191028
# 2024-07-03 07:54:35,099 - INFO - Querying data for date: 20191028, hours: 0-3
# 2024-07-03 07:55:07,307 - INFO - Processing data for date: 20191028, hours: 0-3
# 2024-07-03 07:55:07,319 - INFO - Exporting aggregated data (geohash3) for date: 20191028, hours: 0-3
# 2024-07-03 07:55:07,347 - INFO - Exporting aggregated data (geohash5) for date: 20191028, hours: 0-3
# 2024-07-03 07:55:07,361 - INFO - Querying data for date: 20191028, hours: 3-6
# 2024-07-03 07:55:25,481 - INFO - Processing data for date: 20191028, hours: 3-6
# 2024-07-03 07:55:25,500 - INFO - Exporting aggregated data (geohash3) for date: 20191028, hours: 3-6
# 2024-07-03 07:55:25,529 - INFO - Exporting aggregated data (geohash5) for date: 20191028, hours: 3-6
# 2024-07-03 07:55:25,541 - INFO - Querying data for date: 20191028, hours: 6-9
# 2024-07-03 07:55:41,503 - INFO - Processing data for date: 20191028, hours: 6-9
# 2024-07-03 07:55:41,591 - INFO - Exporting aggregated data (geohash3) for date: 20191028, hours: 6-9
# 2024-07-03 07:55:41,640 - INFO - Exporting aggregated data (geohash5) for date: 20191028, hours: 6-9
# 2024-07-03 07:55:41,664 - INFO - Querying data for date: 20191028, hours: 9-12
# 2024-07-03 07:55:54,310 - INFO - Processing data for date: 20191028, hours: 9-12
# 2024-07-03 07:55:54,377 - INFO - Exporting aggregated data (geohash3) for date: 20191028, hours: 9-12
# 2024-07-03 07:55:54,438 - INFO - Exporting aggregated data (geohash5) for date: 20191028, hours: 9-12
# 2024-07-03 07:55:54,487 - INFO - Querying data for date: 20191028, hours: 12-15
# 2024-07-03 07:56:13,889 - INFO - Processing data for date: 20191028, hours: 12-15
# 2024-07-03 07:56:13,994 - INFO - Exporting aggregated data (geohash3) for date: 20191028, hours: 12-15
# 2024-07-03 07:56:14,110 - INFO - Exporting aggregated data (geohash5) for date: 20191028, hours: 12-15
# 2024-07-03 07:56:14,164 - INFO - Querying data for date: 20191028, hours: 15-18
# 2024-07-03 07:56:31,876 - INFO - Processing data for date: 20191028, hours: 15-18
# 2024-07-03 07:56:31,930 - INFO - Exporting aggregated data (geohash3) for date: 20191028, hours: 15-18
# 2024-07-03 07:56:32,004 - INFO - Exporting aggregated data (geohash5) for date: 20191028, hours: 15-18
# 2024-07-03 07:56:32,031 - INFO - Querying data for date: 20191028, hours: 18-21
# 2024-07-03 07:56:44,665 - INFO - Processing data for date: 20191028, hours: 18-21
# 2024-07-03 07:56:44,711 - INFO - Exporting aggregated data (geohash3) for date: 20191028, hours: 18-21
# 2024-07-03 07:56:44,754 - INFO - Exporting aggregated data (geohash5) for date: 20191028, hours: 18-21
# 2024-07-03 07:56:44,774 - INFO - Querying data for date: 20191028, hours: 21-24
# 2024-07-03 07:57:12,058 - INFO - Processing data for date: 20191028, hours: 21-24
# 2024-07-03 07:57:12,099 - INFO - Exporting aggregated data (geohash3) for date: 20191028, hours: 21-24
# 2024-07-03 07:57:12,138 - INFO - Exporting aggregated data (geohash5) for date: 20191028, hours: 21-24
# 2024-07-03 07:57:12,216 - INFO - Processing data for date: 20191029
# 2024-07-03 07:57:12,217 - INFO - Querying data for date: 20191029, hours: 0-3
# 2024-07-03 07:57:54,485 - INFO - Processing data for date: 20191029, hours: 0-3
# 2024-07-03 07:57:54,498 - INFO - Exporting aggregated data (geohash3) for date: 20191029, hours: 0-3
# 2024-07-03 07:57:54,519 - INFO - Exporting aggregated data (geohash5) for date: 20191029, hours: 0-3
# 2024-07-03 07:57:54,530 - INFO - Querying data for date: 20191029, hours: 3-6
# 2024-07-03 07:58:32,264 - INFO - Processing data for date: 20191029, hours: 3-6
# 2024-07-03 07:58:32,284 - INFO - Exporting aggregated data (geohash3) for date: 20191029, hours: 3-6
# 2024-07-03 07:58:32,326 - INFO - Exporting aggregated data (geohash5) for date: 20191029, hours: 3-6
# 2024-07-03 07:58:32,364 - INFO - Querying data for date: 20191029, hours: 6-9
# 2024-07-03 07:58:47,078 - INFO - Processing data for date: 20191029, hours: 6-9
# 2024-07-03 07:58:47,115 - INFO - Exporting aggregated data (geohash3) for date: 20191029, hours: 6-9
# 2024-07-03 07:58:47,175 - INFO - Exporting aggregated data (geohash5) for date: 20191029, hours: 6-9
# 2024-07-03 07:58:47,195 - INFO - Querying data for date: 20191029, hours: 9-12
# 2024-07-03 07:59:07,198 - INFO - Processing data for date: 20191029, hours: 9-12
# 2024-07-03 07:59:07,260 - INFO - Exporting aggregated data (geohash3) for date: 20191029, hours: 9-12
# 2024-07-03 07:59:07,344 - INFO - Exporting aggregated data (geohash5) for date: 20191029, hours: 9-12
# 2024-07-03 07:59:07,374 - INFO - Querying data for date: 20191029, hours: 12-15
# 2024-07-03 07:59:21,419 - INFO - Processing data for date: 20191029, hours: 12-15
# 2024-07-03 07:59:21,495 - INFO - Exporting aggregated data (geohash3) for date: 20191029, hours: 12-15
# 2024-07-03 07:59:21,580 - INFO - Exporting aggregated data (geohash5) for date: 20191029, hours: 12-15
# 2024-07-03 07:59:21,607 - INFO - Querying data for date: 20191029, hours: 15-18
# 2024-07-03 07:59:43,097 - INFO - Processing data for date: 20191029, hours: 15-18
# 2024-07-03 07:59:43,204 - INFO - Exporting aggregated data (geohash3) for date: 20191029, hours: 15-18
# 2024-07-03 07:59:43,309 - INFO - Exporting aggregated data (geohash5) for date: 20191029, hours: 15-18
# 2024-07-03 07:59:43,384 - INFO - Querying data for date: 20191029, hours: 18-21
# 2024-07-03 07:59:55,866 - INFO - Processing data for date: 20191029, hours: 18-21
# 2024-07-03 07:59:55,912 - INFO - Exporting aggregated data (geohash3) for date: 20191029, hours: 18-21
# 2024-07-03 07:59:55,959 - INFO - Exporting aggregated data (geohash5) for date: 20191029, hours: 18-21
# 2024-07-03 07:59:55,981 - INFO - Querying data for date: 20191029, hours: 21-24
# 2024-07-03 08:00:16,198 - INFO - Processing data for date: 20191029, hours: 21-24
# 2024-07-03 08:00:16,286 - INFO - Exporting aggregated data (geohash3) for date: 20191029, hours: 21-24
# 2024-07-03 08:00:16,381 - INFO - Exporting aggregated data (geohash5) for date: 20191029, hours: 21-24
# 2024-07-03 08:00:16,508 - INFO - Processing data for date: 20191030
# 2024-07-03 08:00:16,509 - INFO - Querying data for date: 20191030, hours: 0-3
# 2024-07-03 08:00:31,917 - INFO - Processing data for date: 20191030, hours: 0-3
# 2024-07-03 08:00:31,929 - INFO - Exporting aggregated data (geohash3) for date: 20191030, hours: 0-3
# 2024-07-03 08:00:31,963 - INFO - Exporting aggregated data (geohash5) for date: 20191030, hours: 0-3
# 2024-07-03 08:00:31,978 - INFO - Querying data for date: 20191030, hours: 3-6
# 2024-07-03 08:01:09,984 - INFO - Processing data for date: 20191030, hours: 3-6
# 2024-07-03 08:01:10,003 - INFO - Exporting aggregated data (geohash3) for date: 20191030, hours: 3-6
# 2024-07-03 08:01:10,036 - INFO - Exporting aggregated data (geohash5) for date: 20191030, hours: 3-6
# 2024-07-03 08:01:10,050 - INFO - Querying data for date: 20191030, hours: 6-9
# 2024-07-03 08:01:39,265 - INFO - Processing data for date: 20191030, hours: 6-9
# 2024-07-03 08:01:39,302 - INFO - Exporting aggregated data (geohash3) for date: 20191030, hours: 6-9
# 2024-07-03 08:01:39,352 - INFO - Exporting aggregated data (geohash5) for date: 20191030, hours: 6-9
# 2024-07-03 08:01:39,377 - INFO - Querying data for date: 20191030, hours: 9-12
# 2024-07-03 08:02:11,849 - INFO - Processing data for date: 20191030, hours: 9-12
# 2024-07-03 08:02:11,901 - INFO - Exporting aggregated data (geohash3) for date: 20191030, hours: 9-12
# 2024-07-03 08:02:11,983 - INFO - Exporting aggregated data (geohash5) for date: 20191030, hours: 9-12
# 2024-07-03 08:02:12,007 - INFO - Querying data for date: 20191030, hours: 12-15
# 2024-07-03 08:02:33,780 - INFO - Processing data for date: 20191030, hours: 12-15
# 2024-07-03 08:02:33,879 - INFO - Exporting aggregated data (geohash3) for date: 20191030, hours: 12-15
# 2024-07-03 08:02:34,005 - INFO - Exporting aggregated data (geohash5) for date: 20191030, hours: 12-15
# 2024-07-03 08:02:34,031 - INFO - Querying data for date: 20191030, hours: 15-18
# 2024-07-03 08:02:45,812 - INFO - Processing data for date: 20191030, hours: 15-18
# 2024-07-03 08:02:45,866 - INFO - Exporting aggregated data (geohash3) for date: 20191030, hours: 15-18
# 2024-07-03 08:02:45,929 - INFO - Exporting aggregated data (geohash5) for date: 20191030, hours: 15-18
# 2024-07-03 08:02:45,951 - INFO - Querying data for date: 20191030, hours: 18-21
# 2024-07-03 08:03:03,413 - INFO - Processing data for date: 20191030, hours: 18-21
# 2024-07-03 08:03:03,459 - INFO - Exporting aggregated data (geohash3) for date: 20191030, hours: 18-21
# 2024-07-03 08:03:03,510 - INFO - Exporting aggregated data (geohash5) for date: 20191030, hours: 18-21
# 2024-07-03 08:03:03,532 - INFO - Querying data for date: 20191030, hours: 21-24
# 2024-07-03 08:03:18,993 - INFO - Processing data for date: 20191030, hours: 21-24
# 2024-07-03 08:03:19,029 - INFO - Exporting aggregated data (geohash3) for date: 20191030, hours: 21-24
# 2024-07-03 08:03:19,095 - INFO - Exporting aggregated data (geohash5) for date: 20191030, hours: 21-24
# 2024-07-03 08:03:19,283 - INFO - Processing data for date: 20191031
# 2024-07-03 08:03:19,284 - INFO - Querying data for date: 20191031, hours: 0-3
# 2024-07-03 08:03:37,791 - INFO - Processing data for date: 20191031, hours: 0-3
# 2024-07-03 08:03:37,803 - INFO - Exporting aggregated data (geohash3) for date: 20191031, hours: 0-3
# 2024-07-03 08:03:37,825 - INFO - Exporting aggregated data (geohash5) for date: 20191031, hours: 0-3
# 2024-07-03 08:03:37,836 - INFO - Querying data for date: 20191031, hours: 3-6
# 2024-07-03 08:04:01,811 - INFO - Processing data for date: 20191031, hours: 3-6
# 2024-07-03 08:04:01,864 - INFO - Exporting aggregated data (geohash3) for date: 20191031, hours: 3-6
# 2024-07-03 08:04:01,896 - INFO - Exporting aggregated data (geohash5) for date: 20191031, hours: 3-6
# 2024-07-03 08:04:01,909 - INFO - Querying data for date: 20191031, hours: 6-9
# 2024-07-03 08:04:16,713 - INFO - Processing data for date: 20191031, hours: 6-9
# 2024-07-03 08:04:16,754 - INFO - Exporting aggregated data (geohash3) for date: 20191031, hours: 6-9
# 2024-07-03 08:04:16,810 - INFO - Exporting aggregated data (geohash5) for date: 20191031, hours: 6-9
# 2024-07-03 08:04:16,839 - INFO - Querying data for date: 20191031, hours: 9-12
# 2024-07-03 08:04:37,195 - INFO - Processing data for date: 20191031, hours: 9-12
# 2024-07-03 08:04:37,296 - INFO - Exporting aggregated data (geohash3) for date: 20191031, hours: 9-12
# 2024-07-03 08:04:37,382 - INFO - Exporting aggregated data (geohash5) for date: 20191031, hours: 9-12
# 2024-07-03 08:04:37,414 - INFO - Querying data for date: 20191031, hours: 12-15
# 2024-07-03 08:04:52,234 - INFO - Processing data for date: 20191031, hours: 12-15
# 2024-07-03 08:04:52,294 - INFO - Exporting aggregated data (geohash3) for date: 20191031, hours: 12-15
# 2024-07-03 08:04:52,364 - INFO - Exporting aggregated data (geohash5) for date: 20191031, hours: 12-15
# 2024-07-03 08:04:52,395 - INFO - Querying data for date: 20191031, hours: 15-18
# 2024-07-03 08:05:20,933 - INFO - Processing data for date: 20191031, hours: 15-18
# 2024-07-03 08:05:20,989 - INFO - Exporting aggregated data (geohash3) for date: 20191031, hours: 15-18
# 2024-07-03 08:05:21,050 - INFO - Exporting aggregated data (geohash5) for date: 20191031, hours: 15-18
# 2024-07-03 08:05:21,072 - INFO - Querying data for date: 20191031, hours: 18-21
# 2024-07-03 08:05:47,174 - INFO - Processing data for date: 20191031, hours: 18-21
# 2024-07-03 08:05:47,221 - INFO - Exporting aggregated data (geohash3) for date: 20191031, hours: 18-21
# 2024-07-03 08:05:47,271 - INFO - Exporting aggregated data (geohash5) for date: 20191031, hours: 18-21
# 2024-07-03 08:05:47,294 - INFO - Querying data for date: 20191031, hours: 21-24
# 2024-07-03 08:06:13,451 - INFO - Processing data for date: 20191031, hours: 21-24
# 2024-07-03 08:06:13,485 - INFO - Exporting aggregated data (geohash3) for date: 20191031, hours: 21-24
# 2024-07-03 08:06:13,515 - INFO - Exporting aggregated data (geohash5) for date: 20191031, hours: 21-24
# 2024-07-03 08:06:13,591 - INFO - Errors occurred during processing:
# 2024-07-03 08:06:13,592 - INFO - Error processing date: 20191017, hours: 3-6 - error 502: bad gateway

# %% [markdown]
# # Fillin Gaps

# %% [markdown]
# Missing info:
# Missing hours for each date:
#          Date        Missing Hours
# 0  2019-01-02              [0, 21]
# 1  2019-01-03                  [0]
# 2  2019-01-07                  [0]
# 3  2019-01-09                  [0]
# 4  2019-01-10                  [0]
# 5  2019-01-11                  [0]
# 6  2019-01-14                  [0]
# 7  2019-01-15                  [0]
# 8  2019-01-16                  [0]
# 9  2019-01-18                  [0]
# 10 2019-01-21                  [0]
# 11 2019-01-22                  [0]
# 12 2019-01-25                  [0]
# 13 2019-01-28                  [0]
# 14 2019-01-29                  [0]
# 15 2019-02-02                  [0]
# 16 2019-04-04                  [0]
# 17 2019-04-12                  [3]
# 18 2019-04-29                  [0]
# 19 2019-05-26                 [21]
# 20 2019-06-06                 [12]
# 21 2019-08-01             [18, 21]
# 22 2019-08-31                 [18]
# 23 2019-09-08                  [3]
# 24 2019-10-17                 [21]
# 25 2019-10-22  [9, 12, 15, 18, 21]
# 26 2019-10-28                  [6]
# 27 2019-11-26                  [0]
# 28 2019-11-27                  [0]
# 29 2019-11-28                  [0]
# 30 2019-12-02                  [0]
# 31 2019-12-03                  [0]
# 32 2019-12-05                  [0]
# 33 2019-12-06                  [0]
# 34 2019-12-07                  [0]
# 35 2019-12-08                  [0]
# 36 2019-12-09                  [0]
# 37 2019-12-10                  [0]
# 38 2019-12-11                  [0]
# 39 2019-12-12                  [0]
# 40 2019-12-13                  [0]
# 41 2019-12-17                  [0]
# 42 2019-12-18                  [0]
# 43 2019-12-19                  [0]
# 44 2019-12-20                  [0]
# 45 2019-12-21                  [0]
# 46 2019-12-23                  [0]
# 47 2019-12-24                  [0]
# 48 2019-12-25                  [0]
# 49 2019-12-26                  [0]
# 50 2019-12-27                  [0]
# 51 2019-12-28                  [0]
# 52 2019-12-29                  [0]
# 53 2019-12-30                  [0]

# %%
# Configure logging
logging.basicConfig(level=logging.INFO, format='%(asctime)s - %(levelname)s - %(message)s')

# Function to process data for a specific date and time intervals
def process_data_for_date(event_date, country_code, export_path, start_hour, end_hour):
    # Define the export file paths
    csv3_file = f"od3_id/od_{country_code.lower()}5_agg3_3h.csv"
    csv5_file = f"od5_id/od_{country_code.lower()}5_agg5_3h.csv"
    csv3_file_path = f"{export_path}{csv3_file}"
    csv5_file_path = f"{export_path}{csv5_file}"

    # Loop through the specified hours in increments of 3 hours
    for hour in range(start_hour, end_hour, 3):
        next_hour = hour + 3  # end hour for the 3-hour interval
        logging.info(f"Querying data for date: {event_date}, hours: {hour}-{next_hour}")

        # Fetch the data for the specified event date and country code
        pe_tj_df3 = sql_engine.read_sql(
            f"""
            SELECT 
                cuebiq_id,
                duration_minutes,
                length_meters,
                number_of_points,
                TRY(date_parse(substr(start_zoned_datetime, 1, 19), '%Y-%m-%dT%H:%i:%s')) AS event_datetime_local,
                EXTRACT(HOUR FROM TRY(date_parse(substr(start_zoned_datetime, 1, 19), '%Y-%m-%dT%H:%i:%s'))) AS event_hour,
                geohash_encode(start_lat, start_lng, 5) AS start_geohash5,
                geohash_encode(start_lat, start_lng, 3) AS start_geohash3,
                geohash_encode(end_lat, end_lng, 5) AS end_geohash5,
                geohash_encode(end_lat, end_lng, 3) AS end_geohash3,
                DATE_FORMAT(date_parse(substr(start_zoned_datetime, 1, 10), '%Y-%m-%d'), '%Y%m%d') AS local_date
            FROM cuebiq.paas_cda_pe_v3.trajectory_uplevelled
            WHERE 
                event_date = {event_date}
                AND end_country = '{country_code}' 
                AND start_country = '{country_code}' 
            """
        )

        # Filter the DataFrame for the current 3-hour interval
        logging.info(f"Processing data for date: {event_date}, hours: {hour}-{next_hour}")
        filtered_df = pe_tj_df3[(pe_tj_df3['event_hour'] >= hour) & (pe_tj_df3['event_hour'] < next_hour)]

        # Add user numbers to the aggregated data for geohash3
        aggregated_df3 = filtered_df.groupby(['start_geohash3', 'end_geohash3', 'local_date']).agg({
            'cuebiq_id': 'count',
            'duration_minutes': ['mean', 'median', 'std'],
            'length_meters': ['mean', 'median', 'std'],
            'number_of_points': ['mean', 'median', 'std']
        }).reset_index()

        # Flatten the MultiIndex columns
        aggregated_df3.columns = ['start_geohash3', 'end_geohash3', 'local_date', 'trip_count', 
                                  'm_duration_min', 'mdn_duration_min', 'sd_duration_min', 
                                  'm_length_m', 'mdn_length_m', 'sd_length_m',
                                  'm_points_no', 'mdn_points_no', 'sd_points_no']

        # Add the local_time column
        aggregated_df3['local_time'] = aggregated_df3['local_date'].astype(str) + \
                                       f" {hour:02d}:00:00 - {next_hour:02d}:00:00"

        # Filter out rows where trip_count is less than or equal to 9
        aggregated_df3 = aggregated_df3[aggregated_df3['trip_count'] > 9]

        # Append the results to the CSV file for geohash3
        logging.info(f"Exporting aggregated data (geohash3) for date: {event_date}, hours: {hour}-{next_hour}")
        if not os.path.isfile(csv3_file_path):
            aggregated_df3.to_csv(csv3_file_path, index=False)
        else:
            aggregated_df3.to_csv(csv3_file_path, mode='a', header=False, index=False)

        # Add user numbers to the aggregated data for geohash5
        aggregated_df5 = filtered_df.groupby(['start_geohash5', 'end_geohash5', 'local_date']).agg({
            'cuebiq_id': 'count',
            'duration_minutes': ['mean', 'median', 'std'],
            'length_meters': ['mean', 'median', 'std'],
            'number_of_points': ['mean', 'median', 'std']
        }).reset_index()

        # Flatten the MultiIndex columns
        aggregated_df5.columns = ['start_geohash5', 'end_geohash5', 'local_date', 'trip_count', 
                                  'm_duration_min', 'mdn_duration_min', 'sd_duration_min', 
                                  'm_length_m', 'mdn_length_m', 'sd_length_m',
                                  'm_points_no', 'mdn_points_no', 'sd_points_no']

        # Add the local_time column
        aggregated_df5['local_time'] = aggregated_df5['local_date'].astype(str) + \
                                       f" {hour:02d}:00:00 - {next_hour:02d}:00:00"

        # Filter out rows where trip_count is less than or equal to 9
        aggregated_df5 = aggregated_df5[aggregated_df5['trip_count'] > 9]

        # Append the results to the CSV file for geohash5
        logging.info(f"Exporting aggregated data (geohash5) for date: {event_date}, hours: {hour}-{next_hour}")
        if not os.path.isfile(csv5_file_path):
            aggregated_df5.to_csv(csv5_file_path, index=False)
        else:
            aggregated_df5.to_csv(csv5_file_path, mode='a', header=False, index=False)

# %%
# Specify the date and initial time interval
event_date = "20190606"
start_hour = 0
end_hour = 24
country_code = 'ID'
export_path = '/home/jovyan/Data/TJ/3h/'

# Process data for the specified date and time intervals
process_data_for_date(event_date, country_code, export_path, start_hour, end_hour)
# Out:
# 2024-07-03 05:51:34,723 - INFO - Querying data for date: 20190606, hours: 0-3
# 2024-07-03 05:51:56,832 - INFO - Processing data for date: 20190606, hours: 0-3
# 2024-07-03 05:51:56,845 - INFO - Exporting aggregated data (geohash3) for date: 20190606, hours: 0-3
# 2024-07-03 05:51:56,911 - INFO - Exporting aggregated data (geohash5) for date: 20190606, hours: 0-3
# 2024-07-03 05:51:56,923 - INFO - Querying data for date: 20190606, hours: 3-6
# 2024-07-03 05:52:07,508 - INFO - Processing data for date: 20190606, hours: 3-6
# 2024-07-03 05:52:07,526 - INFO - Exporting aggregated data (geohash3) for date: 20190606, hours: 3-6
# 2024-07-03 05:52:07,549 - INFO - Exporting aggregated data (geohash5) for date: 20190606, hours: 3-6
# 2024-07-03 05:52:07,559 - INFO - Querying data for date: 20190606, hours: 6-9
# 2024-07-03 05:52:22,204 - INFO - Processing data for date: 20190606, hours: 6-9
# 2024-07-03 05:52:22,230 - INFO - Exporting aggregated data (geohash3) for date: 20190606, hours: 6-9
# 2024-07-03 05:52:22,278 - INFO - Exporting aggregated data (geohash5) for date: 20190606, hours: 6-9
# 2024-07-03 05:52:22,306 - INFO - Querying data for date: 20190606, hours: 9-12
# 2024-07-03 05:52:36,930 - INFO - Processing data for date: 20190606, hours: 9-12
# 2024-07-03 05:52:36,964 - INFO - Exporting aggregated data (geohash3) for date: 20190606, hours: 9-12
# 2024-07-03 05:52:37,013 - INFO - Exporting aggregated data (geohash5) for date: 20190606, hours: 9-12
# 2024-07-03 05:52:37,042 - INFO - Querying data for date: 20190606, hours: 12-15
# 2024-07-03 05:52:57,422 - INFO - Processing data for date: 20190606, hours: 12-15
# 2024-07-03 05:52:57,464 - INFO - Exporting aggregated data (geohash3) for date: 20190606, hours: 12-15
# 2024-07-03 05:52:57,550 - INFO - Exporting aggregated data (geohash5) for date: 20190606, hours: 12-15
# 2024-07-03 05:52:57,628 - INFO - Querying data for date: 20190606, hours: 15-18
# 2024-07-03 05:53:07,522 - INFO - Processing data for date: 20190606, hours: 15-18
# 2024-07-03 05:53:07,602 - INFO - Exporting aggregated data (geohash3) for date: 20190606, hours: 15-18
# 2024-07-03 05:53:07,703 - INFO - Exporting aggregated data (geohash5) for date: 20190606, hours: 15-18
# 2024-07-03 05:53:07,731 - INFO - Querying data for date: 20190606, hours: 18-21
# 2024-07-03 05:53:19,535 - INFO - Processing data for date: 20190606, hours: 18-21
# 2024-07-03 05:53:19,577 - INFO - Exporting aggregated data (geohash3) for date: 20190606, hours: 18-21
# 2024-07-03 05:53:19,620 - INFO - Exporting aggregated data (geohash5) for date: 20190606, hours: 18-21
# 2024-07-03 05:53:19,647 - INFO - Querying data for date: 20190606, hours: 21-24
# 2024-07-03 05:53:37,695 - INFO - Processing data for date: 20190606, hours: 21-24
# 2024-07-03 05:53:37,718 - INFO - Exporting aggregated data (geohash3) for date: 20190606, hours: 21-24
# 2024-07-03 05:53:37,763 - INFO - Exporting aggregated data (geohash5) for date: 20190606, hours: 21-24

# %%
# Configure logging
logging.basicConfig(level=logging.INFO, format='%(asctime)s - %(levelname)s - %(message)s')

# Function to process data for a specific date and time intervals
def process_data_for_date(event_dates, country_code, export_path, start_hour, end_hour):
    # Define the export file paths
    csv3_file = f"od_{country_code.lower()}3_agg3_3h.csv"
    csv5_file = f"od_{country_code.lower()}3_agg5_3h.csv"
    csv3_file_path = f"{export_path}{csv3_file}"
    csv5_file_path = f"{export_path}{csv5_file}"

    # Loop through each date
    for event_date in event_dates:
        # Loop through the specified hours in increments of 3 hours
        for hour in range(start_hour, end_hour, 3):
            next_hour = hour + 3  # end hour for the 3-hour interval
            logging.info(f"Querying data for date: {event_date}, hours: {hour}-{next_hour}")

            # Fetch the data for the specified event date and country code
            pe_tj_df3 = sql_engine.read_sql(
                f"""
                SELECT 
                    cuebiq_id,
                    duration_minutes,
                    length_meters,
                    number_of_points,
                    TRY(date_parse(substr(start_zoned_datetime, 1, 19), '%Y-%m-%dT%H:%i:%s')) AS event_datetime_local,
                    EXTRACT(HOUR FROM TRY(date_parse(substr(start_zoned_datetime, 1, 19), '%Y-%m-%dT%H:%i:%s'))) AS event_hour,
                    geohash_encode(start_lat, start_lng, 5) AS start_geohash5,
                    geohash_encode(start_lat, start_lng, 3) AS start_geohash3,
                    geohash_encode(end_lat, end_lng, 5) AS end_geohash5,
                    geohash_encode(end_lat, end_lng, 3) AS end_geohash3,
                    DATE_FORMAT(date_parse(substr(start_zoned_datetime, 1, 10), '%Y-%m-%d'), '%Y%m%d') AS local_date
                FROM cuebiq.paas_cda_pe_v3.trajectory_uplevelled
                WHERE 
                    event_date = {event_date}
                    AND end_country = '{country_code}' 
                    AND start_country = '{country_code}' 
                """
            )

            # Filter the DataFrame for the current 3-hour interval
            logging.info(f"Processing data for date: {event_date}, hours: {hour}-{next_hour}")
            filtered_df = pe_tj_df3[(pe_tj_df3['event_hour'] >= hour) & (pe_tj_df3['event_hour'] < next_hour)]

            # Add user numbers to the aggregated data for geohash3
            aggregated_df3 = filtered_df.groupby(['start_geohash3', 'end_geohash3', 'local_date']).agg({
                'cuebiq_id': 'count',
                'duration_minutes': ['mean', 'median', 'std'],
                'length_meters': ['mean', 'median', 'std'],
                'number_of_points': ['mean', 'median', 'std']
            }).reset_index()

            # Flatten the MultiIndex columns
            aggregated_df3.columns = ['start_geohash3', 'end_geohash3', 'local_date', 'trip_count', 
                                      'm_duration_min', 'mdn_duration_min', 'sd_duration_min', 
                                      'm_length_m', 'mdn_length_m', 'sd_length_m',
                                      'm_points_no', 'mdn_points_no', 'sd_points_no']

            # Add the local_time column
            aggregated_df3['local_time'] = aggregated_df3['local_date'].astype(str) + \
                                           f" {hour:02d}:00:00 - {next_hour:02d}:00:00"

            # Filter out rows where trip_count is less than or equal to 9
            aggregated_df3 = aggregated_df3[aggregated_df3['trip_count'] > 9]

            # Append the results to the CSV file for geohash3
            logging.info(f"Exporting aggregated data (geohash3) for date: {event_date}, hours: {hour}-{next_hour}")
            if not os.path.isfile(csv3_file_path):
                aggregated_df3.to_csv(csv3_file_path, index=False)
            else:
                aggregated_df3.to_csv(csv3_file_path, mode='a', header=False, index=False)

            # Add user numbers to the aggregated data for geohash5
            aggregated_df5 = filtered_df.groupby(['start_geohash5', 'end_geohash5', 'local_date']).agg({
                'cuebiq_id': 'count',
                'duration_minutes': ['mean', 'median', 'std'],
                'length_meters': ['mean', 'median', 'std'],
                'number_of_points': ['mean', 'median', 'std']
            }).reset_index()

            # Flatten the MultiIndex columns
            aggregated_df5.columns = ['start_geohash5', 'end_geohash5', 'local_date', 'trip_count', 
                                      'm_duration_min', 'mdn_duration_min', 'sd_duration_min', 
                                      'm_length_m', 'mdn_length_m', 'sd_length_m',
                                      'm_points_no', 'mdn_points_no', 'sd_points_no']

            # Add the local_time column
            aggregated_df5['local_time'] = aggregated_df5['local_date'].astype(str) + \
                                           f" {hour:02d}:00:00 - {next_hour:02d}:00:00"

            # Filter out rows where trip_count is less than or equal to 9
            aggregated_df5 = aggregated_df5[aggregated_df5['trip_count'] > 9]

            # Append the results to the CSV file for geohash5
            logging.info(f"Exporting aggregated data (geohash5) for date: {event_date}, hours: {hour}-{next_hour}")
            if not os.path.isfile(csv5_file_path):
                aggregated_df5.to_csv(csv5_file_path, index=False)
            else:
                aggregated_df5.to_csv(csv5_file_path, mode='a', header=False, index=False)

# %%
# For all 0s:

# event_dates = ["20190103", "20190107", "20190109", "20190110", "20190111", "20190114"]
event_dates = [
     # "20190115", "20190116", "20190118", "20190121", 
    "20190122", 
     "20190125", "20190128", "20190129", "20190202", "20190404", 
     "20190429", "20191126", "20191127", "20191128", "20191202", 
     "20191203", "20191205", "20191206", "20191207", "20191208", 
     "20191209", "20191210", "20191211", "20191212", "20191213", 
     "20191217", "20191218", "20191219", "20191220", "20191221", 
     "20191223", "20191224", "20191225", "20191226", "20191227", 
     "20191228", "20191229", "20191230"]

start_hour = 0
end_hour = 3 
country_code = 'ID'
export_path = '/home/jovyan/Data/TJ/3h/'

# Process data for the specified dates and time intervals
process_data_for_date(event_dates, country_code, export_path, start_hour, end_hour)
# Out:
# 2024-07-02 21:59:54,830 - INFO - Querying data for date: 20190122, hours: 0-3
# 2024-07-02 22:00:09,080 - INFO - Processing data for date: 20190122, hours: 0-3
# 2024-07-02 22:00:09,092 - INFO - Exporting aggregated data (geohash3) for date: 20190122, hours: 0-3
# 2024-07-02 22:00:09,112 - INFO - Exporting aggregated data (geohash5) for date: 20190122, hours: 0-3
# 2024-07-02 22:00:09,114 - INFO - Querying data for date: 20190125, hours: 0-3
# 2024-07-02 22:00:34,751 - INFO - Processing data for date: 20190125, hours: 0-3
# 2024-07-02 22:00:34,763 - INFO - Exporting aggregated data (geohash3) for date: 20190125, hours: 0-3
# 2024-07-02 22:00:34,779 - INFO - Exporting aggregated data (geohash5) for date: 20190125, hours: 0-3
# 2024-07-02 22:00:34,782 - INFO - Querying data for date: 20190128, hours: 0-3
# 2024-07-02 22:01:15,562 - INFO - Processing data for date: 20190128, hours: 0-3
# 2024-07-02 22:01:15,574 - INFO - Exporting aggregated data (geohash3) for date: 20190128, hours: 0-3
# 2024-07-02 22:01:15,591 - INFO - Exporting aggregated data (geohash5) for date: 20190128, hours: 0-3
# 2024-07-02 22:01:15,592 - INFO - Querying data for date: 20190129, hours: 0-3
# 2024-07-02 22:01:38,593 - INFO - Processing data for date: 20190129, hours: 0-3
# 2024-07-02 22:01:38,605 - INFO - Exporting aggregated data (geohash3) for date: 20190129, hours: 0-3
# 2024-07-02 22:01:38,621 - INFO - Exporting aggregated data (geohash5) for date: 20190129, hours: 0-3
# 2024-07-02 22:01:38,623 - INFO - Querying data for date: 20190202, hours: 0-3
# 2024-07-02 22:01:50,426 - INFO - Processing data for date: 20190202, hours: 0-3
# 2024-07-02 22:01:50,438 - INFO - Exporting aggregated data (geohash3) for date: 20190202, hours: 0-3
# 2024-07-02 22:01:50,455 - INFO - Exporting aggregated data (geohash5) for date: 20190202, hours: 0-3
# 2024-07-02 22:01:50,457 - INFO - Querying data for date: 20190404, hours: 0-3
# 2024-07-02 22:02:03,003 - INFO - Processing data for date: 20190404, hours: 0-3
# 2024-07-02 22:02:03,016 - INFO - Exporting aggregated data (geohash3) for date: 20190404, hours: 0-3
# 2024-07-02 22:02:03,032 - INFO - Exporting aggregated data (geohash5) for date: 20190404, hours: 0-3
# 2024-07-02 22:02:03,034 - INFO - Querying data for date: 20190429, hours: 0-3
# 2024-07-02 22:02:16,016 - INFO - Processing data for date: 20190429, hours: 0-3
# 2024-07-02 22:02:16,029 - INFO - Exporting aggregated data (geohash3) for date: 20190429, hours: 0-3
# 2024-07-02 22:02:16,048 - INFO - Exporting aggregated data (geohash5) for date: 20190429, hours: 0-3
# 2024-07-02 22:02:16,050 - INFO - Querying data for date: 20191126, hours: 0-3
# 2024-07-02 22:02:26,120 - INFO - Processing data for date: 20191126, hours: 0-3
# 2024-07-02 22:02:26,132 - INFO - Exporting aggregated data (geohash3) for date: 20191126, hours: 0-3
# 2024-07-02 22:02:26,148 - INFO - Exporting aggregated data (geohash5) for date: 20191126, hours: 0-3
# 2024-07-02 22:02:26,150 - INFO - Querying data for date: 20191127, hours: 0-3
# 2024-07-02 22:02:36,339 - INFO - Processing data for date: 20191127, hours: 0-3
# 2024-07-02 22:02:36,350 - INFO - Exporting aggregated data (geohash3) for date: 20191127, hours: 0-3
# 2024-07-02 22:02:36,366 - INFO - Exporting aggregated data (geohash5) for date: 20191127, hours: 0-3
# 2024-07-02 22:02:36,368 - INFO - Querying data for date: 20191128, hours: 0-3
# 2024-07-02 22:03:09,792 - INFO - Processing data for date: 20191128, hours: 0-3
# 2024-07-02 22:03:09,803 - INFO - Exporting aggregated data (geohash3) for date: 20191128, hours: 0-3
# 2024-07-02 22:03:09,819 - INFO - Exporting aggregated data (geohash5) for date: 20191128, hours: 0-3
# 2024-07-02 22:03:09,821 - INFO - Querying data for date: 20191202, hours: 0-3
# 2024-07-02 22:03:50,511 - INFO - Processing data for date: 20191202, hours: 0-3
# 2024-07-02 22:03:50,523 - INFO - Exporting aggregated data (geohash3) for date: 20191202, hours: 0-3
# 2024-07-02 22:03:50,540 - INFO - Exporting aggregated data (geohash5) for date: 20191202, hours: 0-3
# 2024-07-02 22:03:50,542 - INFO - Querying data for date: 20191203, hours: 0-3
# 2024-07-02 22:04:23,685 - INFO - Processing data for date: 20191203, hours: 0-3
# 2024-07-02 22:04:23,696 - INFO - Exporting aggregated data (geohash3) for date: 20191203, hours: 0-3
# 2024-07-02 22:04:23,712 - INFO - Exporting aggregated data (geohash5) for date: 20191203, hours: 0-3
# 2024-07-02 22:04:23,714 - INFO - Querying data for date: 20191205, hours: 0-3
# 2024-07-02 22:04:52,945 - INFO - Processing data for date: 20191205, hours: 0-3
# 2024-07-02 22:04:52,956 - INFO - Exporting aggregated data (geohash3) for date: 20191205, hours: 0-3
# 2024-07-02 22:04:52,972 - INFO - Exporting aggregated data (geohash5) for date: 20191205, hours: 0-3
# 2024-07-02 22:04:52,974 - INFO - Querying data for date: 20191206, hours: 0-3
# 2024-07-02 22:05:26,785 - INFO - Processing data for date: 20191206, hours: 0-3
# 2024-07-02 22:05:26,797 - INFO - Exporting aggregated data (geohash3) for date: 20191206, hours: 0-3
# 2024-07-02 22:05:26,816 - INFO - Exporting aggregated data (geohash5) for date: 20191206, hours: 0-3
# 2024-07-02 22:05:26,818 - INFO - Querying data for date: 20191207, hours: 0-3
# 2024-07-02 22:06:08,510 - INFO - Processing data for date: 20191207, hours: 0-3
# 2024-07-02 22:06:08,522 - INFO - Exporting aggregated data (geohash3) for date: 20191207, hours: 0-3
# 2024-07-02 22:06:08,539 - INFO - Exporting aggregated data (geohash5) for date: 20191207, hours: 0-3
# 2024-07-02 22:06:08,541 - INFO - Querying data for date: 20191208, hours: 0-3
# 2024-07-02 22:06:39,461 - INFO - Processing data for date: 20191208, hours: 0-3
# 2024-07-02 22:06:39,472 - INFO - Exporting aggregated data (geohash3) for date: 20191208, hours: 0-3
# 2024-07-02 22:06:39,488 - INFO - Exporting aggregated data (geohash5) for date: 20191208, hours: 0-3
# 2024-07-02 22:06:39,490 - INFO - Querying data for date: 20191209, hours: 0-3
# 2024-07-02 22:07:09,266 - INFO - Processing data for date: 20191209, hours: 0-3
# 2024-07-02 22:07:09,278 - INFO - Exporting aggregated data (geohash3) for date: 20191209, hours: 0-3
# 2024-07-02 22:07:09,294 - INFO - Exporting aggregated data (geohash5) for date: 20191209, hours: 0-3
# 2024-07-02 22:07:09,296 - INFO - Querying data for date: 20191210, hours: 0-3
# 2024-07-02 22:07:40,251 - INFO - Processing data for date: 20191210, hours: 0-3
# 2024-07-02 22:07:40,262 - INFO - Exporting aggregated data (geohash3) for date: 20191210, hours: 0-3
# 2024-07-02 22:07:40,278 - INFO - Exporting aggregated data (geohash5) for date: 20191210, hours: 0-3
# 2024-07-02 22:07:40,280 - INFO - Querying data for date: 20191211, hours: 0-3
# 2024-07-02 22:08:12,549 - INFO - Processing data for date: 20191211, hours: 0-3
# 2024-07-02 22:08:12,560 - INFO - Exporting aggregated data (geohash3) for date: 20191211, hours: 0-3
# 2024-07-02 22:08:12,576 - INFO - Exporting aggregated data (geohash5) for date: 20191211, hours: 0-3
# 2024-07-02 22:08:12,578 - INFO - Querying data for date: 20191212, hours: 0-3
# 2024-07-02 22:08:54,522 - INFO - Processing data for date: 20191212, hours: 0-3
# 2024-07-02 22:08:54,533 - INFO - Exporting aggregated data (geohash3) for date: 20191212, hours: 0-3
# 2024-07-02 22:08:54,549 - INFO - Exporting aggregated data (geohash5) for date: 20191212, hours: 0-3
# 2024-07-02 22:08:54,552 - INFO - Querying data for date: 20191213, hours: 0-3
# 2024-07-02 22:09:26,025 - INFO - Processing data for date: 20191213, hours: 0-3
# 2024-07-02 22:09:26,038 - INFO - Exporting aggregated data (geohash3) for date: 20191213, hours: 0-3
# 2024-07-02 22:09:26,054 - INFO - Exporting aggregated data (geohash5) for date: 20191213, hours: 0-3
# 2024-07-02 22:09:26,056 - INFO - Querying data for date: 20191217, hours: 0-3
# 2024-07-02 22:09:54,051 - INFO - Processing data for date: 20191217, hours: 0-3
# 2024-07-02 22:09:54,062 - INFO - Exporting aggregated data (geohash3) for date: 20191217, hours: 0-3
# 2024-07-02 22:09:54,082 - INFO - Exporting aggregated data (geohash5) for date: 20191217, hours: 0-3
# 2024-07-02 22:09:54,084 - INFO - Querying data for date: 20191218, hours: 0-3
# 2024-07-02 22:10:22,712 - INFO - Processing data for date: 20191218, hours: 0-3
# 2024-07-02 22:10:22,724 - INFO - Exporting aggregated data (geohash3) for date: 20191218, hours: 0-3
# 2024-07-02 22:10:22,740 - INFO - Exporting aggregated data (geohash5) for date: 20191218, hours: 0-3
# 2024-07-02 22:10:22,742 - INFO - Querying data for date: 20191219, hours: 0-3
# 2024-07-02 22:10:58,356 - INFO - Processing data for date: 20191219, hours: 0-3
# 2024-07-02 22:10:58,368 - INFO - Exporting aggregated data (geohash3) for date: 20191219, hours: 0-3
# 2024-07-02 22:10:58,425 - INFO - Exporting aggregated data (geohash5) for date: 20191219, hours: 0-3
# 2024-07-02 22:10:58,427 - INFO - Querying data for date: 20191220, hours: 0-3
# 2024-07-02 22:11:32,660 - INFO - Processing data for date: 20191220, hours: 0-3
# 2024-07-02 22:11:32,675 - INFO - Exporting aggregated data (geohash3) for date: 20191220, hours: 0-3
# 2024-07-02 22:11:32,695 - INFO - Exporting aggregated data (geohash5) for date: 20191220, hours: 0-3
# 2024-07-02 22:11:32,698 - INFO - Querying data for date: 20191221, hours: 0-3
# 2024-07-02 22:12:08,295 - INFO - Processing data for date: 20191221, hours: 0-3
# 2024-07-02 22:12:08,307 - INFO - Exporting aggregated data (geohash3) for date: 20191221, hours: 0-3
# 2024-07-02 22:12:08,323 - INFO - Exporting aggregated data (geohash5) for date: 20191221, hours: 0-3
# 2024-07-02 22:12:08,325 - INFO - Querying data for date: 20191223, hours: 0-3
# 2024-07-02 22:12:40,484 - INFO - Processing data for date: 20191223, hours: 0-3
# 2024-07-02 22:12:40,495 - INFO - Exporting aggregated data (geohash3) for date: 20191223, hours: 0-3
# 2024-07-02 22:12:40,511 - INFO - Exporting aggregated data (geohash5) for date: 20191223, hours: 0-3
# 2024-07-02 22:12:40,513 - INFO - Querying data for date: 20191224, hours: 0-3
# 2024-07-02 22:13:18,280 - INFO - Processing data for date: 20191224, hours: 0-3
# 2024-07-02 22:13:18,292 - INFO - Exporting aggregated data (geohash3) for date: 20191224, hours: 0-3
# 2024-07-02 22:13:18,322 - INFO - Exporting aggregated data (geohash5) for date: 20191224, hours: 0-3
# 2024-07-02 22:13:18,324 - INFO - Querying data for date: 20191225, hours: 0-3
# 2024-07-02 22:13:44,806 - INFO - Processing data for date: 20191225, hours: 0-3
# 2024-07-02 22:13:44,817 - INFO - Exporting aggregated data (geohash3) for date: 20191225, hours: 0-3
# 2024-07-02 22:13:44,839 - INFO - Exporting aggregated data (geohash5) for date: 20191225, hours: 0-3
# 2024-07-02 22:13:44,841 - INFO - Querying data for date: 20191226, hours: 0-3
# 2024-07-02 22:14:25,757 - INFO - Processing data for date: 20191226, hours: 0-3
# 2024-07-02 22:14:25,768 - INFO - Exporting aggregated data (geohash3) for date: 20191226, hours: 0-3
# 2024-07-02 22:14:25,788 - INFO - Exporting aggregated data (geohash5) for date: 20191226, hours: 0-3
# 2024-07-02 22:14:25,790 - INFO - Querying data for date: 20191227, hours: 0-3
# 2024-07-02 22:14:58,989 - INFO - Processing data for date: 20191227, hours: 0-3
# 2024-07-02 22:14:59,001 - INFO - Exporting aggregated data (geohash3) for date: 20191227, hours: 0-3
# 2024-07-02 22:14:59,025 - INFO - Exporting aggregated data (geohash5) for date: 20191227, hours: 0-3
# 2024-07-02 22:14:59,027 - INFO - Querying data for date: 20191228, hours: 0-3
# 2024-07-02 22:15:32,923 - INFO - Processing data for date: 20191228, hours: 0-3
# 2024-07-02 22:15:32,935 - INFO - Exporting aggregated data (geohash3) for date: 20191228, hours: 0-3
# 2024-07-02 22:15:32,954 - INFO - Exporting aggregated data (geohash5) for date: 20191228, hours: 0-3
# 2024-07-02 22:15:32,956 - INFO - Querying data for date: 20191229, hours: 0-3
# 2024-07-02 22:15:57,552 - INFO - Processing data for date: 20191229, hours: 0-3
# 2024-07-02 22:15:57,564 - INFO - Exporting aggregated data (geohash3) for date: 20191229, hours: 0-3
# 2024-07-02 22:15:57,585 - INFO - Exporting aggregated data (geohash5) for date: 20191229, hours: 0-3
# 2024-07-02 22:15:57,587 - INFO - Querying data for date: 20191230, hours: 0-3
# 2024-07-02 22:16:36,674 - INFO - Processing data for date: 20191230, hours: 0-3
# 2024-07-02 22:16:36,686 - INFO - Exporting aggregated data (geohash3) for date: 20191230, hours: 0-3
# 2024-07-02 22:16:36,706 - INFO - Exporting aggregated data (geohash5) for date: 20191230, hours: 0-3
